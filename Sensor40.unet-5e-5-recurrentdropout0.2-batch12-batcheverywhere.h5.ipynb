# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor40.unet-5e-5-recurrentdropout0.2-batch12-batcheverywhere.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),


            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=8,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
train_loader, val_loader = DataLoader("/gdrive/MyDrive/adjustedROI/final_output", squeeze=False).get_loaders()

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
x.shape
# Out:
# TensorShape([8, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
print(num_val_images)
# Out:
# 477

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv2)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv5)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv9])
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_61 (TimeDistr  (None, 3, 256, 256,  160        ['input_2[0][0]']
#  ibuted)                         16)
#
#  time_distributed_62 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_61[0][0]']
#  ibuted)                         16)
#
#  time_distributed_63 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_62[0][0]']
#  ibuted)                         16)
#
#  time_distributed_64 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_63[0][0]']
#  ibuted)                         16)
#
#  time_distributed_65 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_64[0][0]']
#  ibuted)                         16)
#
#  time_distributed_66 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_65[0][0]']
#  ibuted)                         16)
#
#  time_distributed_67 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_66[0][0]']
#  ibuted)                         16)
#
#  time_distributed_68 (TimeDistr  (None, 3, 128, 128,  4640       ['time_distributed_67[0][0]']
#  ibuted)                         32)
#
#  time_distributed_69 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_68[0][0]']
#  ibuted)                         32)
#
#  time_distributed_70 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_69[0][0]']
#  ibuted)                         32)
#
#  time_distributed_71 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_70[0][0]']
#  ibuted)                         32)
#
#  time_distributed_72 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_71[0][0]']
#  ibuted)                         32)
#
#  time_distributed_73 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_72[0][0]']
#  ibuted)                         32)
#
#  time_distributed_74 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_73[0][0]']
#  ibuted)                        2)
#
#  time_distributed_75 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_74[0][0]']
#  ibuted)                        4)
#
#  time_distributed_76 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_75[0][0]']
#  ibuted)                        4)
#
#  time_distributed_77 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_76[0][0]']
#  ibuted)                        4)
#
#  time_distributed_78 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_77[0][0]']
#  ibuted)                        4)
#
#  time_distributed_79 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_78[0][0]']
#  ibuted)                        4)
#
#  time_distributed_80 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_79[0][0]']
#  ibuted)                        4)
#
#  time_distributed_81 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_80[0][0]']
#  ibuted)                        4)
#
#  time_distributed_82 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_81[0][0]']
#  ibuted)                        28)
#
#  time_distributed_83 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_82[0][0]']
#  ibuted)                        28)
#
#  time_distributed_84 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_83[0][0]']
#  ibuted)                        28)
#
#  time_distributed_85 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_84[0][0]']
#  ibuted)                        28)
#
#  time_distributed_86 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_85[0][0]']
#  ibuted)                        28)
#
#  time_distributed_87 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_86[0][0]']
#  ibuted)                        28)
#
#  time_distributed_88 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_87[0][0]']
#  ibuted)                        28)
#
#  time_distributed_89 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_88[0][0]']
#  ibuted)                        56)
#
#  time_distributed_90 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_89[0][0]']
#  ibuted)                        56)
#
#  time_distributed_91 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_90[0][0]']
#  ibuted)                        56)
#
#  time_distributed_92 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_91[0][0]']
#  ibuted)                        56)
#
#  time_distributed_93 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_92[0][0]']
#  ibuted)                        56)
#
#  time_distributed_94 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_93[0][0]']
#  ibuted)                        56)
#
#  bidirectional_2 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_94[0][0]']
#  )                              12)
#
#  time_distributed_95 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional_2[0][0]']
#  ibuted)                        28)
#
#  concatenate_4 (Concatenate)    (None, 3, 32, 32, 2  0           ['time_distributed_95[0][0]',
#                                 56)                               'time_distributed_87[0][0]']
#
#  time_distributed_96 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate_4[0][0]']
#  ibuted)                        28)
#
#  time_distributed_97 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_96[0][0]']
#  ibuted)                        28)
#
#  time_distributed_98 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_97[0][0]']
#  ibuted)                        28)
#
#  time_distributed_99 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_98[0][0]']
#  ibuted)                        28)
#
#  time_distributed_100 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_99[0][0]']
#  ributed)                       28)
#
#  time_distributed_101 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_100[0][0]']
#  ributed)                       28)
#
#  time_distributed_102 (TimeDist  (None, 3, 64, 64, 6  73792      ['time_distributed_101[0][0]']
#  ributed)                       4)
#
#  concatenate_5 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_102[0][0]',
#                                 28)                               'time_distributed_80[0][0]']
#
#  time_distributed_105 (TimeDist  (None, 3, 64, 64, 6  73792      ['concatenate_5[0][0]']
#  ributed)                       4)
#
#  time_distributed_106 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_105[0][0]']
#  ributed)                       4)
#
#  time_distributed_107 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_106[0][0]']
#  ributed)                       4)
#
#  time_distributed_108 (TimeDist  (None, 3, 128, 128,  18464      ['time_distributed_107[0][0]']
#  ributed)                        32)
#
#  concatenate_6 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_108[0][0]',
#                                  64)                              'time_distributed_73[0][0]']
#
#  time_distributed_109 (TimeDist  (None, 3, 128, 128,  18464      ['concatenate_6[0][0]']
#  ributed)                        32)
#
#  time_distributed_110 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_109[0][0]']
#  ributed)                        32)
#
#  time_distributed_111 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_110[0][0]']
#  ributed)                        32)
#
#  time_distributed_112 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_111[0][0]']
#  ributed)                        32)
#
#  time_distributed_113 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_112[0][0]']
#  ributed)                        32)
#
#  time_distributed_114 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_113[0][0]']
#  ributed)                        32)
#
#  time_distributed_115 (TimeDist  (None, 3, 256, 256,  4624       ['time_distributed_114[0][0]']
#  ributed)                        16)
#
#  concatenate_7 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_115[0][0]',
#                                  32)                              'time_distributed_66[0][0]']
#
#  time_distributed_116 (TimeDist  (None, 3, 256, 256,  4624       ['concatenate_7[0][0]']
#  ributed)                        16)
#
#  time_distributed_117 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_116[0][0]']
#  ributed)                        16)
#
#  time_distributed_118 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_117[0][0]']
#  ributed)                        16)
#
#  time_distributed_119 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_118[0][0]']
#  ributed)                        16)
#
#  time_distributed_120 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_119[0][0]']
#  ributed)                        16)
#
#  time_distributed_121 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_120[0][0]']
#  ributed)                        16)
#
#  bidirectional_3 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_121[0][0]']
#  )                              )
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_3[0][0]']
#                                  32)
#
#  conv2d_55 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims_1[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 12,883,201
# Trainable params: 12,879,041
# Non-trainable params: 4,160
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/40
# 248/248 [==============================] - 322s 1s/step - loss: 0.8904 - dice_coefficient: 0.1096 - binary_accuracy: 0.7218 - val_loss: 0.8174 - val_dice_coefficient: 0.1826 - val_binary_accuracy: 0.8181
# Epoch 2/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.5274 - dice_coefficient: 0.4726 - binary_accuracy: 0.9738 - val_loss: 0.4628 - val_dice_coefficient: 0.5372 - val_binary_accuracy: 0.9755
# Epoch 3/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.4270 - dice_coefficient: 0.5730 - binary_accuracy: 0.9808 - val_loss: 0.3532 - val_dice_coefficient: 0.6468 - val_binary_accuracy: 0.9765
# Epoch 4/40
# 248/248 [==============================] - 300s 1s/step - loss: 0.3788 - dice_coefficient: 0.6212 - binary_accuracy: 0.9827 - val_loss: 0.4701 - val_dice_coefficient: 0.5299 - val_binary_accuracy: 0.9800
# Epoch 5/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.3597 - dice_coefficient: 0.6403 - binary_accuracy: 0.9829 - val_loss: 0.4054 - val_dice_coefficient: 0.5946 - val_binary_accuracy: 0.9697
# Epoch 6/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.3330 - dice_coefficient: 0.6670 - binary_accuracy: 0.9836 - val_loss: 0.3159 - val_dice_coefficient: 0.6841 - val_binary_accuracy: 0.9832
# Epoch 7/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.3129 - dice_coefficient: 0.6871 - binary_accuracy: 0.9840 - val_loss: 0.3457 - val_dice_coefficient: 0.6543 - val_binary_accuracy: 0.9816
# Epoch 8/40
# 248/248 [==============================] - 300s 1s/step - loss: 0.3007 - dice_coefficient: 0.6993 - binary_accuracy: 0.9848 - val_loss: 0.3259 - val_dice_coefficient: 0.6741 - val_binary_accuracy: 0.9786
# Epoch 9/40
# 248/248 [==============================] - 300s 1s/step - loss: 0.2785 - dice_coefficient: 0.7215 - binary_accuracy: 0.9856 - val_loss: 0.3855 - val_dice_coefficient: 0.6145 - val_binary_accuracy: 0.9822
# Epoch 10/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2946 - dice_coefficient: 0.7054 - binary_accuracy: 0.9864 - val_loss: 0.4254 - val_dice_coefficient: 0.5746 - val_binary_accuracy: 0.9802
# Epoch 11/40
# 248/248 [==============================] - 300s 1s/step - loss: 0.2638 - dice_coefficient: 0.7362 - binary_accuracy: 0.9865 - val_loss: 0.3893 - val_dice_coefficient: 0.6107 - val_binary_accuracy: 0.9821
# Epoch 12/40
# 248/248 [==============================] - 300s 1s/step - loss: 0.2616 - dice_coefficient: 0.7384 - binary_accuracy: 0.9871 - val_loss: 0.3258 - val_dice_coefficient: 0.6742 - val_binary_accuracy: 0.9813
# Epoch 13/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2443 - dice_coefficient: 0.7557 - binary_accuracy: 0.9873 - val_loss: 0.3472 - val_dice_coefficient: 0.6528 - val_binary_accuracy: 0.9822
# Epoch 14/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2518 - dice_coefficient: 0.7482 - binary_accuracy: 0.9874 - val_loss: 0.3351 - val_dice_coefficient: 0.6649 - val_binary_accuracy: 0.9821
# Epoch 15/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2511 - dice_coefficient: 0.7489 - binary_accuracy: 0.9872 - val_loss: 0.3039 - val_dice_coefficient: 0.6961 - val_binary_accuracy: 0.9827
# Epoch 16/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2629 - dice_coefficient: 0.7371 - binary_accuracy: 0.9866 - val_loss: 0.2966 - val_dice_coefficient: 0.7034 - val_binary_accuracy: 0.9807
# Epoch 17/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2419 - dice_coefficient: 0.7581 - binary_accuracy: 0.9876 - val_loss: 0.3070 - val_dice_coefficient: 0.6930 - val_binary_accuracy: 0.9837
# Epoch 18/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2504 - dice_coefficient: 0.7496 - binary_accuracy: 0.9874 - val_loss: 0.4299 - val_dice_coefficient: 0.5701 - val_binary_accuracy: 0.9807
# Epoch 19/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2385 - dice_coefficient: 0.7615 - binary_accuracy: 0.9879 - val_loss: 0.3162 - val_dice_coefficient: 0.6838 - val_binary_accuracy: 0.9815
# Epoch 20/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2117 - dice_coefficient: 0.7883 - binary_accuracy: 0.9888 - val_loss: 0.3031 - val_dice_coefficient: 0.6969 - val_binary_accuracy: 0.9819
# Epoch 21/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2161 - dice_coefficient: 0.7839 - binary_accuracy: 0.9882 - val_loss: 0.3348 - val_dice_coefficient: 0.6652 - val_binary_accuracy: 0.9809
# Epoch 22/40
# 248/248 [==============================] - 303s 1s/step - loss: 0.2147 - dice_coefficient: 0.7853 - binary_accuracy: 0.9888 - val_loss: 0.2698 - val_dice_coefficient: 0.7302 - val_binary_accuracy: 0.9825
# Epoch 23/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2413 - dice_coefficient: 0.7587 - binary_accuracy: 0.9872 - val_loss: 0.3253 - val_dice_coefficient: 0.6747 - val_binary_accuracy: 0.9794
# Epoch 24/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2355 - dice_coefficient: 0.7645 - binary_accuracy: 0.9888 - val_loss: 0.3257 - val_dice_coefficient: 0.6743 - val_binary_accuracy: 0.9804
# Epoch 25/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2244 - dice_coefficient: 0.7756 - binary_accuracy: 0.9884 - val_loss: 0.3466 - val_dice_coefficient: 0.6534 - val_binary_accuracy: 0.9817
# Epoch 26/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2232 - dice_coefficient: 0.7768 - binary_accuracy: 0.9890 - val_loss: 0.3085 - val_dice_coefficient: 0.6915 - val_binary_accuracy: 0.9831
# Epoch 27/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2202 - dice_coefficient: 0.7798 - binary_accuracy: 0.9888 - val_loss: 0.2600 - val_dice_coefficient: 0.7400 - val_binary_accuracy: 0.9834
# Epoch 28/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2205 - dice_coefficient: 0.7795 - binary_accuracy: 0.9887 - val_loss: 0.3402 - val_dice_coefficient: 0.6598 - val_binary_accuracy: 0.9812
# Epoch 29/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2157 - dice_coefficient: 0.7843 - binary_accuracy: 0.9889 - val_loss: 0.3348 - val_dice_coefficient: 0.6652 - val_binary_accuracy: 0.9830
# Epoch 30/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2155 - dice_coefficient: 0.7845 - binary_accuracy: 0.9887 - val_loss: 0.3257 - val_dice_coefficient: 0.6743 - val_binary_accuracy: 0.9806
# Epoch 31/40
# 248/248 [==============================] - 307s 1s/step - loss: 0.1958 - dice_coefficient: 0.8042 - binary_accuracy: 0.9891 - val_loss: 0.2886 - val_dice_coefficient: 0.7114 - val_binary_accuracy: 0.9829
# Epoch 32/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2069 - dice_coefficient: 0.7931 - binary_accuracy: 0.9894 - val_loss: 0.2806 - val_dice_coefficient: 0.7194 - val_binary_accuracy: 0.9832
# Epoch 33/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2011 - dice_coefficient: 0.7989 - binary_accuracy: 0.9890 - val_loss: 0.3462 - val_dice_coefficient: 0.6538 - val_binary_accuracy: 0.9833
# Epoch 34/40
# 248/248 [==============================] - 302s 1s/step - loss: 0.2100 - dice_coefficient: 0.7900 - binary_accuracy: 0.9888 - val_loss: 0.2471 - val_dice_coefficient: 0.7529 - val_binary_accuracy: 0.9841
# Epoch 35/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.1814 - dice_coefficient: 0.8186 - binary_accuracy: 0.9899 - val_loss: 0.3203 - val_dice_coefficient: 0.6797 - val_binary_accuracy: 0.9807
# Epoch 36/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.1981 - dice_coefficient: 0.8019 - binary_accuracy: 0.9897 - val_loss: 0.2801 - val_dice_coefficient: 0.7199 - val_binary_accuracy: 0.9818
# Epoch 37/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.1996 - dice_coefficient: 0.8004 - binary_accuracy: 0.9895 - val_loss: 0.2808 - val_dice_coefficient: 0.7192 - val_binary_accuracy: 0.9827
# Epoch 38/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.1992 - dice_coefficient: 0.8008 - binary_accuracy: 0.9896 - val_loss: 0.3493 - val_dice_coefficient: 0.6507 - val_binary_accuracy: 0.9826
# Epoch 39/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.1856 - dice_coefficient: 0.8144 - binary_accuracy: 0.9894 - val_loss: 0.3464 - val_dice_coefficient: 0.6536 - val_binary_accuracy: 0.9813
# Epoch 40/40
# 248/248 [==============================] - 301s 1s/step - loss: 0.2073 - dice_coefficient: 0.7927 - binary_accuracy: 0.9893 - val_loss: 0.3586 - val_dice_coefficient: 0.6414 - val_binary_accuracy: 0.9810

# %%
model.save('/gdrive/MyDrive/Sensor40.unet-5e-5-roiadjusted-relu-recurrentdropout-dropout01-batch12-filters8-savethebest.h5')

# %%
model.save('/gdrive/MyDrive/Sensor40.unet-5e-5-recurrentdropout0.2-batch12-batcheverywhere.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor40.unet-5e-5-recurrentdropout0.2-batch12-batcheverywhere.h5", compile=False)

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=400,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
data_folder = "/gdrive/MyDrive/adjustedROI/final_output"
train,val_loader = DataLoader(data_folder, batch_size=477).get_loaders()

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.8359647

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 0.8381742
# 1/1 [==============================] - 0s 29ms/step
# 0.7483213
# 1/1 [==============================] - 0s 30ms/step
# 0.5999571
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.83236444
# 1/1 [==============================] - 0s 33ms/step
# 0.6403344
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 0.7678099
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.81996286
# 1/1 [==============================] - 0s 31ms/step
# 0.48145294
# 1/1 [==============================] - 0s 28ms/step
# 0.868165
# 1/1 [==============================] - 0s 33ms/step
# 0.8214585
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.81650937
# 1/1 [==============================] - 0s 28ms/step
# 0.8459779
# 1/1 [==============================] - 0s 34ms/step
# 0.88311553
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.755368
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.65905607
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 39ms/step
# 0.66504645
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.8082739
# 1/1 [==============================] - 0s 31ms/step
# 0.7525064
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 40ms/step
# 0.49411774
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8783488
# 1/1 [==============================] - 0s 30ms/step
# 0.7192611
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.85322416
# 1/1 [==============================] - 0s 32ms/step
# 0.83236444
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.75049037
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 44ms/step
# 0.8663326
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.7513094
# 1/1 [==============================] - 0s 36ms/step
# 0.70475173
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49253082
# 1/1 [==============================] - 0s 35ms/step
# 0.82937306
# 1/1 [==============================] - 0s 31ms/step
# 0.7791039
# 1/1 [==============================] - 0s 28ms/step
# 0.78777313
# 1/1 [==============================] - 0s 29ms/step
# 0.49897766
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.71361786
# 1/1 [==============================] - 0s 29ms/step
# 0.49970245
# 1/1 [==============================] - 0s 32ms/step
# 0.8359647
# 1/1 [==============================] - 0s 28ms/step
# 0.7854878
# 1/1 [==============================] - 0s 32ms/step
# 0.49388885
# 1/1 [==============================] - 0s 31ms/step
# 0.7747149
# 1/1 [==============================] - 0s 29ms/step
# 0.7775874
# 1/1 [==============================] - 0s 31ms/step
# 0.857183
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.65905607
# 1/1 [==============================] - 0s 32ms/step
# 0.71080923
# 1/1 [==============================] - 0s 31ms/step
# 0.8332628
# 1/1 [==============================] - 0s 32ms/step
# 0.85131574
# 1/1 [==============================] - 0s 31ms/step
# 0.649817
# 1/1 [==============================] - 0s 27ms/step
# 0.85374606
# 1/1 [==============================] - 0s 28ms/step
# 0.85131574
# 1/1 [==============================] - 0s 32ms/step
# 0.85322416
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.8548981
# 1/1 [==============================] - 0s 34ms/step
# 0.86103517
# 1/1 [==============================] - 0s 29ms/step
# 0.7513094
# 1/1 [==============================] - 0s 28ms/step
# 0.8180052
# 1/1 [==============================] - 0s 34ms/step
# 0.8110839
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 0.8548981
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.86842656
# 1/1 [==============================] - 0s 36ms/step
# 0.7664924
# 1/1 [==============================] - 0s 34ms/step
# 0.4982376
# 1/1 [==============================] - 0s 35ms/step
# 0.8409855
# 1/1 [==============================] - 0s 31ms/step
# 0.8509098
# 1/1 [==============================] - 0s 36ms/step
# 0.78522855
# 1/1 [==============================] - 0s 34ms/step
# 0.50195473
# 1/1 [==============================] - 0s 34ms/step
# 0.82889163
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.5999571
# 1/1 [==============================] - 0s 31ms/step
# 0.83181095
# 1/1 [==============================] - 0s 32ms/step
# 0.81549317
# 1/1 [==============================] - 0s 29ms/step
# 0.65905607
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.857183
# 1/1 [==============================] - 0s 32ms/step
# 0.50839037
# 1/1 [==============================] - 0s 32ms/step
# 0.8074713
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.66504645
# 1/1 [==============================] - 0s 35ms/step
# 0.4886856
# 1/1 [==============================] - 0s 30ms/step
# 0.7854878
# 1/1 [==============================] - 0s 32ms/step
# 0.860685
# 1/1 [==============================] - 0s 28ms/step
# 0.7707281
# 1/1 [==============================] - 0s 34ms/step
# 0.7707281
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.87460446
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.7747149
# 1/1 [==============================] - 0s 33ms/step
# 0.49253082
# 1/1 [==============================] - 0s 32ms/step
# 0.4974146
# 1/1 [==============================] - 0s 31ms/step
# 0.7868171
# 1/1 [==============================] - 0s 29ms/step
# 0.82198286
# 1/1 [==============================] - 0s 28ms/step
# 0.8085371
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.6844093
# 1/1 [==============================] - 0s 32ms/step
# 0.8332628
# 1/1 [==============================] - 0s 43ms/step
# 0.49253082
# 1/1 [==============================] - 0s 30ms/step
# 0.49388885
# 1/1 [==============================] - 0s 31ms/step
# 0.6813228
# 1/1 [==============================] - 0s 32ms/step
# 0.68643993
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.4992432
# 1/1 [==============================] - 0s 32ms/step
# 0.62739
# 1/1 [==============================] - 0s 38ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.8684062
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0