# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30-unet-noaugonvalidation-5e-5-recurrentdropout02-batch8-dropoout0.1-2blocks-relu-layers.Activation-batcheverywhere-savethebest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 8,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 8
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=8,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=8,
    squeeze=False,
    augmentation=True,

)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([8, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
batch_size=8

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
num_val_images
# Out:
# 477

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))

x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
conv2=layers.TimeDistributed(layers.Activation('relu'))(conv2)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)

x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
conv5=layers.TimeDistributed(layers.Activation('relu'))(conv5)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)


x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)
conv8=layers.TimeDistributed(layers.Activation('relu'))(conv8)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)
conv9=layers.TimeDistributed(layers.Activation('relu'))(conv9)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(x)

up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

#expanding path
concat1 = layers.concatenate([up1, conv9])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat2 = layers.concatenate([up2, conv8])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat3 = layers.concatenate([up3, conv5])

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat4 = layers.concatenate([up4, conv2])

x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)

x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Activation('relu'))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_409 (TimeDist  (None, 3, 256, 256,  160        ['input_7[0][0]']
#  ributed)                        16)
#
#  time_distributed_410 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_409[0][0]']
#  ributed)                        16)
#
#  time_distributed_411 (TimeDist  (None, 3, 256, 256,  0          ['time_distributed_410[0][0]']
#  ributed)                        16)
#
#  time_distributed_412 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_411[0][0]']
#  ributed)                        16)
#
#  time_distributed_413 (TimeDist  (None, 3, 256, 256,  0          ['time_distributed_412[0][0]']
#  ributed)                        16)
#
#  time_distributed_414 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_413[0][0]']
#  ributed)                        16)
#
#  time_distributed_415 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_414[0][0]']
#  ributed)                        16)
#
#  time_distributed_416 (TimeDist  (None, 3, 256, 256,  0          ['time_distributed_415[0][0]']
#  ributed)                        16)
#
#  time_distributed_417 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_416[0][0]']
#  ributed)                        16)
#
#  time_distributed_418 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_417[0][0]']
#  ributed)                        16)
#
#  time_distributed_419 (TimeDist  (None, 3, 128, 128,  4640       ['time_distributed_418[0][0]']
#  ributed)                        32)
#
#  time_distributed_420 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_419[0][0]']
#  ributed)                        32)
#
#  time_distributed_421 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_420[0][0]']
#  ributed)                        32)
#
#  time_distributed_422 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_421[0][0]']
#  ributed)                        32)
#
#  time_distributed_423 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_422[0][0]']
#  ributed)                        32)
#
#  time_distributed_424 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_423[0][0]']
#  ributed)                        32)
#
#  time_distributed_425 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_424[0][0]']
#  ributed)                        32)
#
#  time_distributed_426 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_425[0][0]']
#  ributed)                        32)
#
#  time_distributed_427 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_426[0][0]']
#  ributed)                        32)
#
#  time_distributed_428 (TimeDist  (None, 3, 64, 64, 3  0          ['time_distributed_427[0][0]']
#  ributed)                       2)
#
#  time_distributed_429 (TimeDist  (None, 3, 64, 64, 6  18496      ['time_distributed_428[0][0]']
#  ributed)                       4)
#
#  time_distributed_430 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_429[0][0]']
#  ributed)                       4)
#
#  time_distributed_431 (TimeDist  (None, 3, 64, 64, 6  0          ['time_distributed_430[0][0]']
#  ributed)                       4)
#
#  time_distributed_432 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_431[0][0]']
#  ributed)                       4)
#
#  time_distributed_433 (TimeDist  (None, 3, 64, 64, 6  0          ['time_distributed_432[0][0]']
#  ributed)                       4)
#
#  time_distributed_434 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_433[0][0]']
#  ributed)                       4)
#
#  time_distributed_435 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_434[0][0]']
#  ributed)                       4)
#
#  time_distributed_436 (TimeDist  (None, 3, 64, 64, 6  0          ['time_distributed_435[0][0]']
#  ributed)                       4)
#
#  time_distributed_437 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_436[0][0]']
#  ributed)                       4)
#
#  time_distributed_438 (TimeDist  (None, 3, 32, 32, 6  0          ['time_distributed_437[0][0]']
#  ributed)                       4)
#
#  time_distributed_439 (TimeDist  (None, 3, 32, 32, 1  73856      ['time_distributed_438[0][0]']
#  ributed)                       28)
#
#  time_distributed_440 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_439[0][0]']
#  ributed)                       28)
#
#  time_distributed_441 (TimeDist  (None, 3, 32, 32, 1  0          ['time_distributed_440[0][0]']
#  ributed)                       28)
#
#  time_distributed_442 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_441[0][0]']
#  ributed)                       28)
#
#  time_distributed_443 (TimeDist  (None, 3, 32, 32, 1  0          ['time_distributed_442[0][0]']
#  ributed)                       28)
#
#  time_distributed_444 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_443[0][0]']
#  ributed)                       28)
#
#  time_distributed_445 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_444[0][0]']
#  ributed)                       28)
#
#  time_distributed_446 (TimeDist  (None, 3, 32, 32, 1  0          ['time_distributed_445[0][0]']
#  ributed)                       28)
#
#  time_distributed_447 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_446[0][0]']
#  ributed)                       28)
#
#  time_distributed_448 (TimeDist  (None, 3, 16, 16, 1  0          ['time_distributed_447[0][0]']
#  ributed)                       28)
#
#  time_distributed_449 (TimeDist  (None, 3, 16, 16, 2  295168     ['time_distributed_448[0][0]']
#  ributed)                       56)
#
#  time_distributed_450 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_449[0][0]']
#  ributed)                       56)
#
#  time_distributed_451 (TimeDist  (None, 3, 16, 16, 2  0          ['time_distributed_450[0][0]']
#  ributed)                       56)
#
#  time_distributed_452 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_451[0][0]']
#  ributed)                       56)
#
#  time_distributed_453 (TimeDist  (None, 3, 16, 16, 2  0          ['time_distributed_452[0][0]']
#  ributed)                       56)
#
#  time_distributed_454 (TimeDist  (None, 3, 16, 16, 2  590080     ['time_distributed_453[0][0]']
#  ributed)                       56)
#
#  time_distributed_455 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_454[0][0]']
#  ributed)                       56)
#
#  time_distributed_456 (TimeDist  (None, 3, 16, 16, 2  0          ['time_distributed_455[0][0]']
#  ributed)                       56)
#
#  time_distributed_457 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_456[0][0]']
#  ributed)                       56)
#
#  bidirectional_7 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_457[0][0]']
#  )                              12)
#
#  time_distributed_458 (TimeDist  (None, 3, 32, 32, 1  589952     ['bidirectional_7[0][0]']
#  ributed)                       28)
#
#  concatenate_16 (Concatenate)   (None, 3, 32, 32, 2  0           ['time_distributed_458[0][0]',
#                                 56)                               'time_distributed_447[0][0]']
#
#  time_distributed_459 (TimeDist  (None, 3, 32, 32, 1  295040     ['concatenate_16[0][0]']
#  ributed)                       28)
#
#  time_distributed_460 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_459[0][0]']
#  ributed)                       28)
#
#  time_distributed_461 (TimeDist  (None, 3, 32, 32, 1  0          ['time_distributed_460[0][0]']
#  ributed)                       28)
#
#  time_distributed_462 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_461[0][0]']
#  ributed)                       28)
#
#  time_distributed_463 (TimeDist  (None, 3, 32, 32, 1  0          ['time_distributed_462[0][0]']
#  ributed)                       28)
#
#  time_distributed_464 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_463[0][0]']
#  ributed)                       28)
#
#  time_distributed_465 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_464[0][0]']
#  ributed)                       28)
#
#  time_distributed_466 (TimeDist  (None, 3, 32, 32, 1  0          ['time_distributed_465[0][0]']
#  ributed)                       28)
#
#  time_distributed_467 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_466[0][0]']
#  ributed)                       28)
#
#  time_distributed_468 (TimeDist  (None, 3, 64, 64, 6  73792      ['time_distributed_467[0][0]']
#  ributed)                       4)
#
#  concatenate_17 (Concatenate)   (None, 3, 64, 64, 1  0           ['time_distributed_468[0][0]',
#                                 28)                               'time_distributed_437[0][0]']
#
#  time_distributed_469 (TimeDist  (None, 3, 64, 64, 6  73792      ['concatenate_17[0][0]']
#  ributed)                       4)
#
#  time_distributed_470 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_469[0][0]']
#  ributed)                       4)
#
#  time_distributed_471 (TimeDist  (None, 3, 64, 64, 6  0          ['time_distributed_470[0][0]']
#  ributed)                       4)
#
#  time_distributed_472 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_471[0][0]']
#  ributed)                       4)
#
#  time_distributed_473 (TimeDist  (None, 3, 64, 64, 6  0          ['time_distributed_472[0][0]']
#  ributed)                       4)
#
#  time_distributed_474 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_473[0][0]']
#  ributed)                       4)
#
#  time_distributed_475 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_474[0][0]']
#  ributed)                       4)
#
#  time_distributed_476 (TimeDist  (None, 3, 64, 64, 6  0          ['time_distributed_475[0][0]']
#  ributed)                       4)
#
#  time_distributed_477 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_476[0][0]']
#  ributed)                       4)
#
#  time_distributed_478 (TimeDist  (None, 3, 128, 128,  18464      ['time_distributed_477[0][0]']
#  ributed)                        32)
#
#  concatenate_18 (Concatenate)   (None, 3, 128, 128,  0           ['time_distributed_478[0][0]',
#                                  64)                              'time_distributed_427[0][0]']
#
#  time_distributed_479 (TimeDist  (None, 3, 128, 128,  18464      ['concatenate_18[0][0]']
#  ributed)                        32)
#
#  time_distributed_480 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_479[0][0]']
#  ributed)                        32)
#
#  time_distributed_481 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_480[0][0]']
#  ributed)                        32)
#
#  time_distributed_482 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_481[0][0]']
#  ributed)                        32)
#
#  time_distributed_483 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_482[0][0]']
#  ributed)                        32)
#
#  time_distributed_484 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_483[0][0]']
#  ributed)                        32)
#
#  time_distributed_485 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_484[0][0]']
#  ributed)                        32)
#
#  time_distributed_486 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_485[0][0]']
#  ributed)                        32)
#
#  time_distributed_487 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_486[0][0]']
#  ributed)                        32)
#
#  time_distributed_488 (TimeDist  (None, 3, 256, 256,  4624       ['time_distributed_487[0][0]']
#  ributed)                        16)
#
#  concatenate_19 (Concatenate)   (None, 3, 256, 256,  0           ['time_distributed_488[0][0]',
#                                  32)                              'time_distributed_417[0][0]']
#
#  time_distributed_489 (TimeDist  (None, 3, 256, 256,  4624       ['concatenate_19[0][0]']
#  ributed)                        16)
#
#  time_distributed_490 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_489[0][0]']
#  ributed)                        16)
#
#  time_distributed_491 (TimeDist  (None, 3, 256, 256,  0          ['time_distributed_490[0][0]']
#  ributed)                        16)
#
#  time_distributed_492 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_491[0][0]']
#  ributed)                        16)
#
#  time_distributed_493 (TimeDist  (None, 3, 256, 256,  0          ['time_distributed_492[0][0]']
#  ributed)                        16)
#
#  time_distributed_494 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_493[0][0]']
#  ributed)                        16)
#
#  time_distributed_495 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_494[0][0]']
#  ributed)                        16)
#
#  time_distributed_496 (TimeDist  (None, 3, 256, 256,  0          ['time_distributed_495[0][0]']
#  ributed)                        16)
#
#  time_distributed_497 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_496[0][0]']
#  ributed)                        16)
#
#  bidirectional_8 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_497[0][0]']
#  )                              )
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_8[0][0]']
#                                  32)
#
#  conv2d_101 (Conv2D)            (None, 1, 256, 256,  33          ['tf.expand_dims_1[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,941,345
# Trainable params: 11,935,457
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 372/372 [==============================] - 458s 1s/step - loss: 0.7875 - dice_coefficient: 0.2125 - binary_accuracy: 0.8481 - val_loss: 0.6943 - val_dice_coefficient: 0.3057 - val_binary_accuracy: 0.9515
# Epoch 2/30
# 372/372 [==============================] - 435s 1s/step - loss: 0.4573 - dice_coefficient: 0.5427 - binary_accuracy: 0.9746 - val_loss: 0.6686 - val_dice_coefficient: 0.3314 - val_binary_accuracy: 0.9725
# Epoch 3/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.3772 - dice_coefficient: 0.6228 - binary_accuracy: 0.9790 - val_loss: 0.7734 - val_dice_coefficient: 0.2266 - val_binary_accuracy: 0.9779
# Epoch 4/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.3277 - dice_coefficient: 0.6723 - binary_accuracy: 0.9815 - val_loss: 0.7255 - val_dice_coefficient: 0.2745 - val_binary_accuracy: 0.9764
# Epoch 5/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.3218 - dice_coefficient: 0.6782 - binary_accuracy: 0.9816 - val_loss: 0.6738 - val_dice_coefficient: 0.3262 - val_binary_accuracy: 0.9817
# Epoch 6/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.3052 - dice_coefficient: 0.6948 - binary_accuracy: 0.9826 - val_loss: 0.8058 - val_dice_coefficient: 0.1942 - val_binary_accuracy: 0.9812
# Epoch 7/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2933 - dice_coefficient: 0.7067 - binary_accuracy: 0.9837 - val_loss: 0.8426 - val_dice_coefficient: 0.1574 - val_binary_accuracy: 0.9819
# Epoch 8/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2894 - dice_coefficient: 0.7106 - binary_accuracy: 0.9837 - val_loss: 0.9042 - val_dice_coefficient: 0.0958 - val_binary_accuracy: 0.9781
# Epoch 9/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2713 - dice_coefficient: 0.7287 - binary_accuracy: 0.9847 - val_loss: 0.8324 - val_dice_coefficient: 0.1676 - val_binary_accuracy: 0.9843
# Epoch 10/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.2720 - dice_coefficient: 0.7280 - binary_accuracy: 0.9848 - val_loss: 0.6427 - val_dice_coefficient: 0.3573 - val_binary_accuracy: 0.9848
# Epoch 11/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2541 - dice_coefficient: 0.7459 - binary_accuracy: 0.9856 - val_loss: 0.9294 - val_dice_coefficient: 0.0706 - val_binary_accuracy: 0.9850
# Epoch 12/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2556 - dice_coefficient: 0.7444 - binary_accuracy: 0.9852 - val_loss: 0.7204 - val_dice_coefficient: 0.2796 - val_binary_accuracy: 0.9854
# Epoch 13/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2394 - dice_coefficient: 0.7606 - binary_accuracy: 0.9862 - val_loss: 0.6529 - val_dice_coefficient: 0.3471 - val_binary_accuracy: 0.9884
# Epoch 14/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2272 - dice_coefficient: 0.7728 - binary_accuracy: 0.9867 - val_loss: 0.7531 - val_dice_coefficient: 0.2469 - val_binary_accuracy: 0.9858
# Epoch 15/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2190 - dice_coefficient: 0.7810 - binary_accuracy: 0.9872 - val_loss: 0.8368 - val_dice_coefficient: 0.1632 - val_binary_accuracy: 0.9866
# Epoch 16/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.2353 - dice_coefficient: 0.7647 - binary_accuracy: 0.9871 - val_loss: 0.6146 - val_dice_coefficient: 0.3854 - val_binary_accuracy: 0.9822
# Epoch 17/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.2258 - dice_coefficient: 0.7742 - binary_accuracy: 0.9871 - val_loss: 0.7799 - val_dice_coefficient: 0.2201 - val_binary_accuracy: 0.9848
# Epoch 18/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.2331 - dice_coefficient: 0.7669 - binary_accuracy: 0.9873 - val_loss: 0.7264 - val_dice_coefficient: 0.2736 - val_binary_accuracy: 0.9859
# Epoch 19/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.2215 - dice_coefficient: 0.7785 - binary_accuracy: 0.9877 - val_loss: 0.7268 - val_dice_coefficient: 0.2732 - val_binary_accuracy: 0.9869
# Epoch 20/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.2203 - dice_coefficient: 0.7797 - binary_accuracy: 0.9876 - val_loss: 0.6404 - val_dice_coefficient: 0.3596 - val_binary_accuracy: 0.9875
# Epoch 21/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2109 - dice_coefficient: 0.7891 - binary_accuracy: 0.9876 - val_loss: 0.6274 - val_dice_coefficient: 0.3726 - val_binary_accuracy: 0.9873
# Epoch 22/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2056 - dice_coefficient: 0.7944 - binary_accuracy: 0.9876 - val_loss: 0.6375 - val_dice_coefficient: 0.3625 - val_binary_accuracy: 0.9882
# Epoch 23/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.1956 - dice_coefficient: 0.8044 - binary_accuracy: 0.9881 - val_loss: 0.8902 - val_dice_coefficient: 0.1098 - val_binary_accuracy: 0.9853
# Epoch 24/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.1938 - dice_coefficient: 0.8062 - binary_accuracy: 0.9880 - val_loss: 0.5749 - val_dice_coefficient: 0.4251 - val_binary_accuracy: 0.9878
# Epoch 25/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.1975 - dice_coefficient: 0.8025 - binary_accuracy: 0.9885 - val_loss: 0.5986 - val_dice_coefficient: 0.4014 - val_binary_accuracy: 0.9844
# Epoch 26/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.2065 - dice_coefficient: 0.7935 - binary_accuracy: 0.9883 - val_loss: 0.7173 - val_dice_coefficient: 0.2827 - val_binary_accuracy: 0.9863
# Epoch 27/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.1962 - dice_coefficient: 0.8038 - binary_accuracy: 0.9883 - val_loss: 0.6300 - val_dice_coefficient: 0.3700 - val_binary_accuracy: 0.9865
# Epoch 28/30
# 372/372 [==============================] - 436s 1s/step - loss: 0.1839 - dice_coefficient: 0.8161 - binary_accuracy: 0.9889 - val_loss: 0.6178 - val_dice_coefficient: 0.3822 - val_binary_accuracy: 0.9849
# Epoch 29/30
# 372/372 [==============================] - 434s 1s/step - loss: 0.1826 - dice_coefficient: 0.8174 - binary_accuracy: 0.9887 - val_loss: 0.6733 - val_dice_coefficient: 0.3267 - val_binary_accuracy: 0.9860
# Epoch 30/30
# 372/372 [==============================] - 433s 1s/step - loss: 0.1746 - dice_coefficient: 0.8254 - binary_accuracy: 0.9889 - val_loss: 0.6352 - val_dice_coefficient: 0.3648 - val_binary_accuracy: 0.9844

# %%
model.save('/gdrive/MyDrive/Sensor30-unet-noaugonvalidation-5e-5-recurrentdropout02-batch8-dropoout0.1-2blocks-relu-layers.Activation-batcheverywhere-savethebest.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30-unet-noaugonvalidation-5e-5-recurrentdropout02-batch8-dropoout0.1-2blocks-relu-layers.Activation-batcheverywhere-savethebest.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 1.0

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.4895935
# 1/1 [==============================] - 0s 29ms/step
# 0.48737335
# 1/1 [==============================] - 0s 52ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.47922516
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.7775356
# 1/1 [==============================] - 0s 57ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.46548462
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.77669764
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49990082
# 1/1 [==============================] - 0s 27ms/step
# 0.48854828
# 1/1 [==============================] - 0s 27ms/step
# 0.49983215
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49996948
# 1/1 [==============================] - 0s 25ms/step
# 0.7706903
# 1/1 [==============================] - 0s 28ms/step
# 0.6008939
# 1/1 [==============================] - 0s 30ms/step
# 0.66597795
# 1/1 [==============================] - 0s 27ms/step
# 0.7877532
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48880768
# 1/1 [==============================] - 0s 31ms/step
# 0.48750305
# 1/1 [==============================] - 0s 29ms/step
# 0.49938965
# 1/1 [==============================] - 0s 28ms/step
# 0.67270565
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.65146077
# 1/1 [==============================] - 0s 28ms/step
# 0.49363708
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.49938965
# 1/1 [==============================] - 0s 29ms/step
# 0.78758335
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.47998047
# 1/1 [==============================] - 0s 31ms/step
# 0.47408295
# 1/1 [==============================] - 0s 26ms/step
# 0.48856354
# 1/1 [==============================] - 0s 27ms/step
# 0.7877532
# 1/1 [==============================] - 0s 29ms/step
# 0.47766113
# 1/1 [==============================] - 0s 39ms/step
# 0.48825836
# 1/1 [==============================] - 0s 28ms/step
# 0.49451447
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.5165531
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4634018
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.6910551
# 1/1 [==============================] - 0s 27ms/step
# 0.8201202
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.64023775
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.69460416
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48737335
# 1/1 [==============================] - 0s 30ms/step
# 0.75702417
# 1/1 [==============================] - 0s 30ms/step
# 0.48737335
# 1/1 [==============================] - 0s 25ms/step
# 0.48861694
# 1/1 [==============================] - 0s 28ms/step
# 0.49614716
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0