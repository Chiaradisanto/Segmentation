# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30.unet-noaugonvalidation-5e-5-roiadjusted-recurrentdropout-Leackyrelu-batch8-3blocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 8,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 8
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/final_output",
        "val_images", "images"
    ),
    batch_size=8,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/final_output", "train_images", "images"
    ),
    batch_size=8,
    squeeze=False,
        augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-26-3731a7aa9310> in <module>
#       2
#       3 for i in range(0,12):
# ----> 4     image = x[i,0,:,:,0]
#       5     #mask = np.argmax(y[i], axis=2)
#       6     mask= y[i,0,:,:,0]
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    7162 def raise_from_not_ok_status(e, name):
#    7163   e.message += (" name: " + name if name is not None else "")
# -> 7164   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7165
#    7166
#
# InvalidArgumentError: slice index 8 of dimension 0 out of bounds. [Op:StridedSlice] name: strided_slice/

# %%
x.shape
# Out:
# TensorShape([8, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=8

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))


x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()))) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv5)

up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv4])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)

up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv3])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv2])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv1])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)

x=tf.expand_dims(x,axis=1)
out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_58 (TimeDistr  (None, 3, 256, 256,  160        ['input_2[0][0]']
#  ibuted)                         16)
#
#  time_distributed_59 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_58[0][0]']
#  ibuted)                         16)
#
#  time_distributed_60 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_59[0][0]']
#  ibuted)                         16)
#
#  time_distributed_61 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_60[0][0]']
#  ibuted)                         16)
#
#  time_distributed_62 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_61[0][0]']
#  ibuted)                         16)
#
#  time_distributed_63 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_62[0][0]']
#  ibuted)                         16)
#
#  time_distributed_64 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_63[0][0]']
#  ibuted)                         16)
#
#  time_distributed_65 (TimeDistr  (None, 3, 128, 128,  4640       ['time_distributed_64[0][0]']
#  ibuted)                         32)
#
#  time_distributed_66 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_65[0][0]']
#  ibuted)                         32)
#
#  time_distributed_67 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_66[0][0]']
#  ibuted)                         32)
#
#  time_distributed_68 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_67[0][0]']
#  ibuted)                         32)
#
#  time_distributed_69 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_68[0][0]']
#  ibuted)                         32)
#
#  time_distributed_70 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_69[0][0]']
#  ibuted)                         32)
#
#  time_distributed_71 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_70[0][0]']
#  ibuted)                        2)
#
#  time_distributed_72 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_71[0][0]']
#  ibuted)                        4)
#
#  time_distributed_73 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_72[0][0]']
#  ibuted)                        4)
#
#  time_distributed_74 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_73[0][0]']
#  ibuted)                        4)
#
#  time_distributed_75 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_74[0][0]']
#  ibuted)                        4)
#
#  time_distributed_76 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_75[0][0]']
#  ibuted)                        4)
#
#  time_distributed_77 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_76[0][0]']
#  ibuted)                        4)
#
#  time_distributed_78 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_77[0][0]']
#  ibuted)                        4)
#
#  time_distributed_79 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_78[0][0]']
#  ibuted)                        28)
#
#  time_distributed_80 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_79[0][0]']
#  ibuted)                        28)
#
#  time_distributed_81 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_80[0][0]']
#  ibuted)                        28)
#
#  time_distributed_82 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_81[0][0]']
#  ibuted)                        28)
#
#  time_distributed_83 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_82[0][0]']
#  ibuted)                        28)
#
#  time_distributed_84 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_83[0][0]']
#  ibuted)                        28)
#
#  time_distributed_85 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_84[0][0]']
#  ibuted)                        28)
#
#  time_distributed_86 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_85[0][0]']
#  ibuted)                        56)
#
#  time_distributed_87 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_86[0][0]']
#  ibuted)                        56)
#
#  time_distributed_88 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_87[0][0]']
#  ibuted)                        56)
#
#  time_distributed_89 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_88[0][0]']
#  ibuted)                        56)
#
#  time_distributed_90 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_89[0][0]']
#  ibuted)                        56)
#
#  time_distributed_91 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_90[0][0]']
#  ibuted)                        56)
#
#  bidirectional_2 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_91[0][0]']
#  )                              12)
#
#  time_distributed_92 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional_2[0][0]']
#  ibuted)                        28)
#
#  concatenate_4 (Concatenate)    (None, 3, 32, 32, 2  0           ['time_distributed_92[0][0]',
#                                 56)                               'time_distributed_84[0][0]']
#
#  time_distributed_93 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate_4[0][0]']
#  ibuted)                        28)
#
#  time_distributed_94 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_93[0][0]']
#  ibuted)                        28)
#
#  time_distributed_95 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_94[0][0]']
#  ibuted)                        28)
#
#  time_distributed_96 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_95[0][0]']
#  ibuted)                        28)
#
#  time_distributed_97 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_96[0][0]']
#  ibuted)                        28)
#
#  time_distributed_98 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_97[0][0]']
#  ibuted)                        4)
#
#  concatenate_5 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_98[0][0]',
#                                 28)                               'time_distributed_77[0][0]']
#
#  time_distributed_99 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_5[0][0]']
#  ibuted)                        4)
#
#  time_distributed_100 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_99[0][0]']
#  ributed)                       4)
#
#  time_distributed_101 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_100[0][0]']
#  ributed)                       4)
#
#  time_distributed_102 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_101[0][0]']
#  ributed)                       4)
#
#  time_distributed_103 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_102[0][0]']
#  ributed)                       4)
#
#  time_distributed_104 (TimeDist  (None, 3, 128, 128,  18464      ['time_distributed_103[0][0]']
#  ributed)                        32)
#
#  concatenate_6 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_104[0][0]',
#                                  64)                              'time_distributed_70[0][0]']
#
#  time_distributed_105 (TimeDist  (None, 3, 128, 128,  18464      ['concatenate_6[0][0]']
#  ributed)                        32)
#
#  time_distributed_106 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_105[0][0]']
#  ributed)                        32)
#
#  time_distributed_107 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_106[0][0]']
#  ributed)                        32)
#
#  time_distributed_108 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_107[0][0]']
#  ributed)                        32)
#
#  time_distributed_109 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_108[0][0]']
#  ributed)                        32)
#
#  time_distributed_110 (TimeDist  (None, 3, 256, 256,  4624       ['time_distributed_109[0][0]']
#  ributed)                        16)
#
#  concatenate_7 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_110[0][0]',
#                                  32)                              'time_distributed_63[0][0]']
#
#  time_distributed_111 (TimeDist  (None, 3, 256, 256,  4624       ['concatenate_7[0][0]']
#  ributed)                        16)
#
#  time_distributed_112 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_111[0][0]']
#  ributed)                        16)
#
#  time_distributed_113 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_112[0][0]']
#  ributed)                        16)
#
#  time_distributed_114 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_113[0][0]']
#  ributed)                        16)
#
#  time_distributed_115 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_114[0][0]']
#  ributed)                        16)
#
#  bidirectional_3 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_115[0][0]']
#  )                              )
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_3[0][0]']
#                                  32)
#
#  conv2d_55 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims_1[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 12,919,681
# Trainable params: 12,915,745
# Non-trainable params: 3,936
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 372/372 [==============================] - 488s 1s/step - loss: 0.6523 - dice_coefficient: 0.3477 - binary_accuracy: 0.9014 - val_loss: 0.6527 - val_dice_coefficient: 0.3473 - val_binary_accuracy: 0.9504
# Epoch 2/30
# 372/372 [==============================] - 463s 1s/step - loss: 0.3804 - dice_coefficient: 0.6196 - binary_accuracy: 0.9793 - val_loss: 0.6581 - val_dice_coefficient: 0.3419 - val_binary_accuracy: 0.9858
# Epoch 3/30
# 372/372 [==============================] - 462s 1s/step - loss: 0.3407 - dice_coefficient: 0.6593 - binary_accuracy: 0.9811 - val_loss: 0.7486 - val_dice_coefficient: 0.2514 - val_binary_accuracy: 0.9772
# Epoch 4/30
# 372/372 [==============================] - 463s 1s/step - loss: 0.3166 - dice_coefficient: 0.6834 - binary_accuracy: 0.9822 - val_loss: 0.8506 - val_dice_coefficient: 0.1494 - val_binary_accuracy: 0.9856
# Epoch 5/30
# 372/372 [==============================] - 463s 1s/step - loss: 0.3162 - dice_coefficient: 0.6838 - binary_accuracy: 0.9834 - val_loss: 0.9484 - val_dice_coefficient: 0.0516 - val_binary_accuracy: 0.9859
# Epoch 6/30
# 372/372 [==============================] - 463s 1s/step - loss: 0.2857 - dice_coefficient: 0.7143 - binary_accuracy: 0.9839 - val_loss: 0.6666 - val_dice_coefficient: 0.3334 - val_binary_accuracy: 0.9871
# Epoch 7/30
# 372/372 [==============================] - 463s 1s/step - loss: 0.2795 - dice_coefficient: 0.7205 - binary_accuracy: 0.9851 - val_loss: 0.6354 - val_dice_coefficient: 0.3646 - val_binary_accuracy: 0.9852
# Epoch 8/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2578 - dice_coefficient: 0.7422 - binary_accuracy: 0.9853 - val_loss: 0.7417 - val_dice_coefficient: 0.2583 - val_binary_accuracy: 0.9878
# Epoch 9/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2422 - dice_coefficient: 0.7578 - binary_accuracy: 0.9857 - val_loss: 0.7452 - val_dice_coefficient: 0.2548 - val_binary_accuracy: 0.9876
# Epoch 10/30
# 372/372 [==============================] - 463s 1s/step - loss: 0.2448 - dice_coefficient: 0.7552 - binary_accuracy: 0.9861 - val_loss: 0.4829 - val_dice_coefficient: 0.5171 - val_binary_accuracy: 0.9886
# Epoch 11/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2453 - dice_coefficient: 0.7547 - binary_accuracy: 0.9864 - val_loss: 0.5209 - val_dice_coefficient: 0.4791 - val_binary_accuracy: 0.9785
# Epoch 12/30
# 372/372 [==============================] - 464s 1s/step - loss: 0.2325 - dice_coefficient: 0.7675 - binary_accuracy: 0.9866 - val_loss: 0.5219 - val_dice_coefficient: 0.4781 - val_binary_accuracy: 0.9868
# Epoch 13/30
# 372/372 [==============================] - 466s 1s/step - loss: 0.2522 - dice_coefficient: 0.7478 - binary_accuracy: 0.9864 - val_loss: 0.4357 - val_dice_coefficient: 0.5643 - val_binary_accuracy: 0.9899
# Epoch 14/30
# 372/372 [==============================] - 465s 1s/step - loss: 0.2333 - dice_coefficient: 0.7667 - binary_accuracy: 0.9866 - val_loss: 0.5826 - val_dice_coefficient: 0.4174 - val_binary_accuracy: 0.9816
# Epoch 15/30
# 372/372 [==============================] - 464s 1s/step - loss: 0.2367 - dice_coefficient: 0.7633 - binary_accuracy: 0.9866 - val_loss: 0.3788 - val_dice_coefficient: 0.6212 - val_binary_accuracy: 0.9902
# Epoch 16/30
# 372/372 [==============================] - 462s 1s/step - loss: 0.2206 - dice_coefficient: 0.7794 - binary_accuracy: 0.9874 - val_loss: 0.4747 - val_dice_coefficient: 0.5253 - val_binary_accuracy: 0.9894
# Epoch 17/30
# 372/372 [==============================] - 462s 1s/step - loss: 0.2437 - dice_coefficient: 0.7563 - binary_accuracy: 0.9868 - val_loss: 0.6933 - val_dice_coefficient: 0.3067 - val_binary_accuracy: 0.9865
# Epoch 18/30
# 372/372 [==============================] - 462s 1s/step - loss: 0.2183 - dice_coefficient: 0.7817 - binary_accuracy: 0.9874 - val_loss: 0.5962 - val_dice_coefficient: 0.4038 - val_binary_accuracy: 0.9852
# Epoch 19/30
# 372/372 [==============================] - 462s 1s/step - loss: 0.2172 - dice_coefficient: 0.7828 - binary_accuracy: 0.9874 - val_loss: 0.9299 - val_dice_coefficient: 0.0701 - val_binary_accuracy: 0.9850
# Epoch 20/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2218 - dice_coefficient: 0.7782 - binary_accuracy: 0.9872 - val_loss: 0.5158 - val_dice_coefficient: 0.4842 - val_binary_accuracy: 0.9892
# Epoch 21/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2111 - dice_coefficient: 0.7889 - binary_accuracy: 0.9881 - val_loss: 0.5388 - val_dice_coefficient: 0.4612 - val_binary_accuracy: 0.9903
# Epoch 22/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2039 - dice_coefficient: 0.7961 - binary_accuracy: 0.9880 - val_loss: 0.4136 - val_dice_coefficient: 0.5864 - val_binary_accuracy: 0.9908
# Epoch 23/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2187 - dice_coefficient: 0.7813 - binary_accuracy: 0.9874 - val_loss: 0.6363 - val_dice_coefficient: 0.3637 - val_binary_accuracy: 0.9875
# Epoch 24/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2130 - dice_coefficient: 0.7870 - binary_accuracy: 0.9874 - val_loss: 0.5105 - val_dice_coefficient: 0.4895 - val_binary_accuracy: 0.9896
# Epoch 25/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.1900 - dice_coefficient: 0.8100 - binary_accuracy: 0.9882 - val_loss: 0.5095 - val_dice_coefficient: 0.4905 - val_binary_accuracy: 0.9884
# Epoch 26/30
# 372/372 [==============================] - 464s 1s/step - loss: 0.2028 - dice_coefficient: 0.7972 - binary_accuracy: 0.9883 - val_loss: 0.5208 - val_dice_coefficient: 0.4792 - val_binary_accuracy: 0.9911
# Epoch 27/30
# 372/372 [==============================] - 462s 1s/step - loss: 0.1976 - dice_coefficient: 0.8024 - binary_accuracy: 0.9883 - val_loss: 0.4988 - val_dice_coefficient: 0.5012 - val_binary_accuracy: 0.9894
# Epoch 28/30
# 372/372 [==============================] - 462s 1s/step - loss: 0.2013 - dice_coefficient: 0.7987 - binary_accuracy: 0.9879 - val_loss: 0.5895 - val_dice_coefficient: 0.4105 - val_binary_accuracy: 0.9885
# Epoch 29/30
# 372/372 [==============================] - 461s 1s/step - loss: 0.2073 - dice_coefficient: 0.7927 - binary_accuracy: 0.9878 - val_loss: 0.5550 - val_dice_coefficient: 0.4450 - val_binary_accuracy: 0.9899
# Epoch 30/30
# 372/372 [==============================] - 464s 1s/step - loss: 0.1891 - dice_coefficient: 0.8109 - binary_accuracy: 0.9887 - val_loss: 0.6997 - val_dice_coefficient: 0.3003 - val_binary_accuracy: 0.9873

# %%
model.save('/gdrive/MyDrive/Sensor30.unet-noaugonvalidation-5e-5-roiadjusted-recurrentdropout-Leackyrelu-batch8-3blocks.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30.unet-noaugonvalidation-5e-5-roiadjusted-recurrentdropout-Leackyrelu-batch8-3blocks.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.6021136

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 0.49962616
# 1/1 [==============================] - 0s 26ms/step
# 0.49583435
# 1/1 [==============================] - 0s 27ms/step
# 0.6021136
# 1/1 [==============================] - 0s 28ms/step
# 0.49583435
# 1/1 [==============================] - 0s 33ms/step
# 0.49510956
# 1/1 [==============================] - 0s 30ms/step
# 0.49676514
# 1/1 [==============================] - 0s 28ms/step
# 0.63825977
# 1/1 [==============================] - 0s 29ms/step
# 0.49700165
# 1/1 [==============================] - 0s 28ms/step
# 0.6094886
# 1/1 [==============================] - 0s 29ms/step
# 0.49388885
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.5710223
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.61632687
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.5260738
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.6207324
# 1/1 [==============================] - 0s 29ms/step
# 0.5816038
# 1/1 [==============================] - 0s 27ms/step
# 0.49663544
# 1/1 [==============================] - 0s 30ms/step
# 0.49453735
# 1/1 [==============================] - 0s 29ms/step
# 0.5928378
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.49104205
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.4977646
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.5162325
# 1/1 [==============================] - 0s 27ms/step
# 0.5940568
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.54346806
# 1/1 [==============================] - 0s 26ms/step
# 0.4983139
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.59150344
# 1/1 [==============================] - 0s 27ms/step
# 0.49838257
# 1/1 [==============================] - 0s 26ms/step
# 0.490448
# 1/1 [==============================] - 0s 28ms/step
# 0.4883499
# 1/1 [==============================] - 0s 28ms/step
# 0.49638134
# 1/1 [==============================] - 0s 28ms/step
# 0.59296995
# 1/1 [==============================] - 0s 28ms/step
# 0.6094886
# 1/1 [==============================] - 0s 26ms/step
# 0.48737335
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49962616
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.55678964
# 1/1 [==============================] - 0s 26ms/step
# 0.5259774
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.49746704
# 1/1 [==============================] - 0s 28ms/step
# 0.49700165
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.5943022
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49964905
# 1/1 [==============================] - 0s 28ms/step
# 0.4911499
# 1/1 [==============================] - 0s 28ms/step
# 0.51034987
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.5905475
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.54346806
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.49676514
# 1/1 [==============================] - 0s 37ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.7006502
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.6278425
# 1/1 [==============================] - 0s 44ms/step
# 0.49319458
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49460602
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.5707166
# 1/1 [==============================] - 0s 29ms/step
# 0.52663904
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.