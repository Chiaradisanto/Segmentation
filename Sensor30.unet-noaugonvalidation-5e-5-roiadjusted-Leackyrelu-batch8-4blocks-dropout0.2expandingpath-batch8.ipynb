# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30.unet-noaugonvalidation-5e-5-roiadjusted-Leackyrelu-batch8-4blocks-dropout0.2expandingpath-batch8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 8,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 8
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=8,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=8,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([8, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=8

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))

x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()))) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()))) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv5)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

#expanding path

concat1 = layers.concatenate([up1, conv4])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (concat1)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)

up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv3])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (concat2)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)

up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv2])

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (concat3)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv1])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (concat4)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)

x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)
out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_122 (TimeDist  (None, 3, 256, 256,  160        ['input_3[0][0]']
#  ributed)                        16)
#
#  time_distributed_123 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_122[0][0]']
#  ributed)                        16)
#
#  time_distributed_124 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_123[0][0]']
#  ributed)                        16)
#
#  time_distributed_125 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_124[0][0]']
#  ributed)                        16)
#
#  time_distributed_126 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_125[0][0]']
#  ributed)                        16)
#
#  time_distributed_127 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_126[0][0]']
#  ributed)                        16)
#
#  time_distributed_128 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_127[0][0]']
#  ributed)                        16)
#
#  time_distributed_129 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_128[0][0]']
#  ributed)                        16)
#
#  time_distributed_130 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_129[0][0]']
#  ributed)                        16)
#
#  time_distributed_131 (TimeDist  (None, 3, 128, 128,  4640       ['time_distributed_130[0][0]']
#  ributed)                        32)
#
#  time_distributed_132 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_131[0][0]']
#  ributed)                        32)
#
#  time_distributed_133 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_132[0][0]']
#  ributed)                        32)
#
#  time_distributed_134 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_133[0][0]']
#  ributed)                        32)
#
#  time_distributed_135 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_134[0][0]']
#  ributed)                        32)
#
#  time_distributed_136 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_135[0][0]']
#  ributed)                        32)
#
#  time_distributed_137 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_136[0][0]']
#  ributed)                        32)
#
#  time_distributed_138 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_137[0][0]']
#  ributed)                        32)
#
#  time_distributed_139 (TimeDist  (None, 3, 64, 64, 3  0          ['time_distributed_138[0][0]']
#  ributed)                       2)
#
#  time_distributed_140 (TimeDist  (None, 3, 64, 64, 6  18496      ['time_distributed_139[0][0]']
#  ributed)                       4)
#
#  time_distributed_141 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_140[0][0]']
#  ributed)                       4)
#
#  time_distributed_142 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_141[0][0]']
#  ributed)                       4)
#
#  time_distributed_143 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_142[0][0]']
#  ributed)                       4)
#
#  time_distributed_144 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_143[0][0]']
#  ributed)                       4)
#
#  time_distributed_145 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_144[0][0]']
#  ributed)                       4)
#
#  time_distributed_146 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_145[0][0]']
#  ributed)                       4)
#
#  time_distributed_147 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_146[0][0]']
#  ributed)                       4)
#
#  time_distributed_148 (TimeDist  (None, 3, 32, 32, 6  0          ['time_distributed_147[0][0]']
#  ributed)                       4)
#
#  time_distributed_149 (TimeDist  (None, 3, 32, 32, 1  73856      ['time_distributed_148[0][0]']
#  ributed)                       28)
#
#  time_distributed_150 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_149[0][0]']
#  ributed)                       28)
#
#  time_distributed_151 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_150[0][0]']
#  ributed)                       28)
#
#  time_distributed_152 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_151[0][0]']
#  ributed)                       28)
#
#  time_distributed_153 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_152[0][0]']
#  ributed)                       28)
#
#  time_distributed_154 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_153[0][0]']
#  ributed)                       28)
#
#  time_distributed_155 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_154[0][0]']
#  ributed)                       28)
#
#  time_distributed_156 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_155[0][0]']
#  ributed)                       28)
#
#  time_distributed_157 (TimeDist  (None, 3, 16, 16, 1  0          ['time_distributed_156[0][0]']
#  ributed)                       28)
#
#  time_distributed_158 (TimeDist  (None, 3, 16, 16, 2  295168     ['time_distributed_157[0][0]']
#  ributed)                       56)
#
#  time_distributed_159 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_158[0][0]']
#  ributed)                       56)
#
#  time_distributed_160 (TimeDist  (None, 3, 16, 16, 2  590080     ['time_distributed_159[0][0]']
#  ributed)                       56)
#
#  time_distributed_161 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_160[0][0]']
#  ributed)                       56)
#
#  time_distributed_162 (TimeDist  (None, 3, 16, 16, 2  590080     ['time_distributed_161[0][0]']
#  ributed)                       56)
#
#  time_distributed_163 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_162[0][0]']
#  ributed)                       56)
#
#  time_distributed_164 (TimeDist  (None, 3, 16, 16, 2  590080     ['time_distributed_163[0][0]']
#  ributed)                       56)
#
#  time_distributed_165 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_164[0][0]']
#  ributed)                       56)
#
#  bidirectional_4 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_165[0][0]']
#  )                              12)
#
#  time_distributed_166 (TimeDist  (None, 3, 32, 32, 1  589952     ['bidirectional_4[0][0]']
#  ributed)                       28)
#
#  concatenate_8 (Concatenate)    (None, 3, 32, 32, 2  0           ['time_distributed_166[0][0]',
#                                 56)                               'time_distributed_156[0][0]']
#
#  time_distributed_167 (TimeDist  (None, 3, 32, 32, 1  295040     ['concatenate_8[0][0]']
#  ributed)                       28)
#
#  time_distributed_168 (TimeDist  (None, 3, 32, 32, 1  0          ['time_distributed_167[0][0]']
#  ributed)                       28)
#
#  time_distributed_169 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_168[0][0]']
#  ributed)                       28)
#
#  time_distributed_170 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_169[0][0]']
#  ributed)                       28)
#
#  time_distributed_171 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_170[0][0]']
#  ributed)                       28)
#
#  time_distributed_172 (TimeDist  (None, 3, 64, 64, 6  73792      ['time_distributed_171[0][0]']
#  ributed)                       4)
#
#  concatenate_9 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_172[0][0]',
#                                 28)                               'time_distributed_147[0][0]']
#
#  time_distributed_173 (TimeDist  (None, 3, 64, 64, 6  73792      ['concatenate_9[0][0]']
#  ributed)                       4)
#
#  time_distributed_174 (TimeDist  (None, 3, 64, 64, 6  0          ['time_distributed_173[0][0]']
#  ributed)                       4)
#
#  time_distributed_175 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_174[0][0]']
#  ributed)                       4)
#
#  time_distributed_176 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_175[0][0]']
#  ributed)                       4)
#
#  time_distributed_177 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_176[0][0]']
#  ributed)                       4)
#
#  time_distributed_178 (TimeDist  (None, 3, 128, 128,  18464      ['time_distributed_177[0][0]']
#  ributed)                        32)
#
#  concatenate_10 (Concatenate)   (None, 3, 128, 128,  0           ['time_distributed_178[0][0]',
#                                  64)                              'time_distributed_138[0][0]']
#
#  time_distributed_179 (TimeDist  (None, 3, 128, 128,  18464      ['concatenate_10[0][0]']
#  ributed)                        32)
#
#  time_distributed_180 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_179[0][0]']
#  ributed)                        32)
#
#  time_distributed_181 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_180[0][0]']
#  ributed)                        32)
#
#  time_distributed_182 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_181[0][0]']
#  ributed)                        32)
#
#  time_distributed_183 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_182[0][0]']
#  ributed)                        32)
#
#  time_distributed_184 (TimeDist  (None, 3, 256, 256,  4624       ['time_distributed_183[0][0]']
#  ributed)                        16)
#
#  concatenate_11 (Concatenate)   (None, 3, 256, 256,  0           ['time_distributed_184[0][0]',
#                                  32)                              'time_distributed_129[0][0]']
#
#  time_distributed_185 (TimeDist  (None, 3, 256, 256,  4624       ['concatenate_11[0][0]']
#  ributed)                        16)
#
#  time_distributed_186 (TimeDist  (None, 3, 256, 256,  0          ['time_distributed_185[0][0]']
#  ributed)                        16)
#
#  time_distributed_187 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_186[0][0]']
#  ributed)                        16)
#
#  time_distributed_188 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_187[0][0]']
#  ributed)                        16)
#
#  time_distributed_189 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_188[0][0]']
#  ributed)                        16)
#
#  bidirectional_5 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_189[0][0]']
#  )                              )
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_5[0][0]']
#                                  32)
#
#  conv2d_101 (Conv2D)            (None, 1, 256, 256,  33          ['tf.expand_dims_2[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 13,901,985
# Trainable params: 13,898,017
# Non-trainable params: 3,968
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 372/372 [==============================] - 494s 1s/step - loss: 0.6157 - dice_coefficient: 0.3843 - binary_accuracy: 0.9529 - val_loss: 0.6027 - val_dice_coefficient: 0.3973 - val_binary_accuracy: 0.9748
# Epoch 2/30
# 372/372 [==============================] - 477s 1s/step - loss: 0.4226 - dice_coefficient: 0.5774 - binary_accuracy: 0.9780 - val_loss: 0.6760 - val_dice_coefficient: 0.3240 - val_binary_accuracy: 0.9817
# Epoch 3/30
# 372/372 [==============================] - 476s 1s/step - loss: 0.3790 - dice_coefficient: 0.6210 - binary_accuracy: 0.9806 - val_loss: 0.8088 - val_dice_coefficient: 0.1912 - val_binary_accuracy: 0.9804
# Epoch 4/30
# 372/372 [==============================] - 475s 1s/step - loss: 0.3288 - dice_coefficient: 0.6712 - binary_accuracy: 0.9824 - val_loss: 0.6516 - val_dice_coefficient: 0.3484 - val_binary_accuracy: 0.9854
# Epoch 5/30
# 372/372 [==============================] - 476s 1s/step - loss: 0.3072 - dice_coefficient: 0.6928 - binary_accuracy: 0.9836 - val_loss: 0.6793 - val_dice_coefficient: 0.3207 - val_binary_accuracy: 0.9796
# Epoch 6/30
# 372/372 [==============================] - 476s 1s/step - loss: 0.2923 - dice_coefficient: 0.7077 - binary_accuracy: 0.9837 - val_loss: 0.5842 - val_dice_coefficient: 0.4158 - val_binary_accuracy: 0.9791
# Epoch 7/30
# 372/372 [==============================] - 477s 1s/step - loss: 0.2897 - dice_coefficient: 0.7103 - binary_accuracy: 0.9845 - val_loss: 0.4609 - val_dice_coefficient: 0.5391 - val_binary_accuracy: 0.9906
# Epoch 8/30
# 372/372 [==============================] - 476s 1s/step - loss: 0.2695 - dice_coefficient: 0.7305 - binary_accuracy: 0.9849 - val_loss: 0.4920 - val_dice_coefficient: 0.5080 - val_binary_accuracy: 0.9877
# Epoch 9/30
# 372/372 [==============================] - 476s 1s/step - loss: 0.2854 - dice_coefficient: 0.7146 - binary_accuracy: 0.9850 - val_loss: 0.6365 - val_dice_coefficient: 0.3635 - val_binary_accuracy: 0.9846
# Epoch 10/30
# 372/372 [==============================] - 477s 1s/step - loss: 0.2651 - dice_coefficient: 0.7349 - binary_accuracy: 0.9850 - val_loss: 0.4882 - val_dice_coefficient: 0.5118 - val_binary_accuracy: 0.9889
# Epoch 11/30
# 372/372 [==============================] - 477s 1s/step - loss: 0.2523 - dice_coefficient: 0.7477 - binary_accuracy: 0.9857 - val_loss: 0.6529 - val_dice_coefficient: 0.3471 - val_binary_accuracy: 0.9876
# Epoch 12/30
# 372/372 [==============================] - 481s 1s/step - loss: 0.2554 - dice_coefficient: 0.7446 - binary_accuracy: 0.9857 - val_loss: 0.4947 - val_dice_coefficient: 0.5053 - val_binary_accuracy: 0.9905
# Epoch 13/30
# 372/372 [==============================] - 477s 1s/step - loss: 0.2479 - dice_coefficient: 0.7521 - binary_accuracy: 0.9860 - val_loss: 0.5923 - val_dice_coefficient: 0.4077 - val_binary_accuracy: 0.9851
# Epoch 14/30
# 372/372 [==============================] - 478s 1s/step - loss: 0.2507 - dice_coefficient: 0.7493 - binary_accuracy: 0.9865 - val_loss: 0.4794 - val_dice_coefficient: 0.5206 - val_binary_accuracy: 0.9843
# Epoch 15/30
# 372/372 [==============================] - 479s 1s/step - loss: 0.2577 - dice_coefficient: 0.7423 - binary_accuracy: 0.9854 - val_loss: 0.5474 - val_dice_coefficient: 0.4526 - val_binary_accuracy: 0.9877
# Epoch 16/30
# 372/372 [==============================] - 482s 1s/step - loss: 0.2330 - dice_coefficient: 0.7670 - binary_accuracy: 0.9868 - val_loss: 0.5482 - val_dice_coefficient: 0.4518 - val_binary_accuracy: 0.9890
# Epoch 17/30
# 372/372 [==============================] - 483s 1s/step - loss: 0.2253 - dice_coefficient: 0.7747 - binary_accuracy: 0.9868 - val_loss: 0.6292 - val_dice_coefficient: 0.3708 - val_binary_accuracy: 0.9884
# Epoch 18/30
# 372/372 [==============================] - 483s 1s/step - loss: 0.2298 - dice_coefficient: 0.7702 - binary_accuracy: 0.9868 - val_loss: 0.5088 - val_dice_coefficient: 0.4912 - val_binary_accuracy: 0.9801
# Epoch 19/30
# 372/372 [==============================] - 482s 1s/step - loss: 0.2408 - dice_coefficient: 0.7592 - binary_accuracy: 0.9874 - val_loss: 0.5255 - val_dice_coefficient: 0.4745 - val_binary_accuracy: 0.9844
# Epoch 20/30
# 372/372 [==============================] - 482s 1s/step - loss: 0.2163 - dice_coefficient: 0.7837 - binary_accuracy: 0.9876 - val_loss: 0.4930 - val_dice_coefficient: 0.5070 - val_binary_accuracy: 0.9884
# Epoch 21/30
# 372/372 [==============================] - 483s 1s/step - loss: 0.2280 - dice_coefficient: 0.7720 - binary_accuracy: 0.9869 - val_loss: 0.4863 - val_dice_coefficient: 0.5137 - val_binary_accuracy: 0.9882
# Epoch 22/30
# 372/372 [==============================] - 483s 1s/step - loss: 0.2223 - dice_coefficient: 0.7777 - binary_accuracy: 0.9873 - val_loss: 0.8721 - val_dice_coefficient: 0.1279 - val_binary_accuracy: 0.9854
# Epoch 23/30
# 372/372 [==============================] - 483s 1s/step - loss: 0.2290 - dice_coefficient: 0.7710 - binary_accuracy: 0.9872 - val_loss: 0.5981 - val_dice_coefficient: 0.4019 - val_binary_accuracy: 0.9900
# Epoch 24/30
# 372/372 [==============================] - 483s 1s/step - loss: 0.2147 - dice_coefficient: 0.7853 - binary_accuracy: 0.9877 - val_loss: 0.9811 - val_dice_coefficient: 0.0189 - val_binary_accuracy: 0.9854
# Epoch 25/30
# 372/372 [==============================] - 483s 1s/step - loss: 0.2071 - dice_coefficient: 0.7929 - binary_accuracy: 0.9880 - val_loss: 0.4610 - val_dice_coefficient: 0.5390 - val_binary_accuracy: 0.9888
# Epoch 26/30
# 372/372 [==============================] - 487s 1s/step - loss: 0.2298 - dice_coefficient: 0.7702 - binary_accuracy: 0.9875 - val_loss: 0.4212 - val_dice_coefficient: 0.5788 - val_binary_accuracy: 0.9903
# Epoch 27/30
# 372/372 [==============================] - 485s 1s/step - loss: 0.2330 - dice_coefficient: 0.7670 - binary_accuracy: 0.9872 - val_loss: 0.5065 - val_dice_coefficient: 0.4935 - val_binary_accuracy: 0.9907
# Epoch 28/30
# 372/372 [==============================] - 485s 1s/step - loss: 0.2185 - dice_coefficient: 0.7815 - binary_accuracy: 0.9879 - val_loss: 0.3861 - val_dice_coefficient: 0.6139 - val_binary_accuracy: 0.9918
# Epoch 29/30
# 372/372 [==============================] - 485s 1s/step - loss: 0.2128 - dice_coefficient: 0.7872 - binary_accuracy: 0.9877 - val_loss: 0.3347 - val_dice_coefficient: 0.6653 - val_binary_accuracy: 0.9925
# Epoch 30/30
# 372/372 [==============================] - 484s 1s/step - loss: 0.2111 - dice_coefficient: 0.7889 - binary_accuracy: 0.9882 - val_loss: 0.3661 - val_dice_coefficient: 0.6339 - val_binary_accuracy: 0.9915

# %%
model.save('/gdrive/MyDrive/Sensor30.unet-noaugonvalidation-5e-5-roiadjusted-Leackyrelu-batch8-4blocks-dropout0.2expandingpath-batch8.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30.unet-noaugonvalidation-5e-5-roiadjusted-Leackyrelu-batch8-4blocks-dropout0.2expandingpath-batch8.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
# Out:
# 476

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')

  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.86006796

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 0.84993625
# 1/1 [==============================] - 0s 30ms/step
# 0.49942017
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.82824886
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.8213937
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4853058
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.81417537
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49113837
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.4903525
# 1/1 [==============================] - 0s 28ms/step
# 0.8635632
# 1/1 [==============================] - 0s 36ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.49113837
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.48870087
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.49712372
# 1/1 [==============================] - 0s 34ms/step
# 0.8604083
# 1/1 [==============================] - 0s 29ms/step
# 0.8524778
# 1/1 [==============================] - 0s 32ms/step
# 0.8223814
# 1/1 [==============================] - 0s 37ms/step
# 0.48421478
# 1/1 [==============================] - 0s 43ms/step
# 0.48877716
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.84892684
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.8132391
# 1/1 [==============================] - 0s 31ms/step
# 0.8460641
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48836517
# 1/1 [==============================] - 0s 30ms/step
# 0.84552187
# 1/1 [==============================] - 0s 32ms/step
# 0.4833145
# 1/1 [==============================] - 0s 34ms/step
# 0.4885025
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.48854828
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.4853058
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.83893704
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8515568
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.499588
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 0.82824886
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.82133126
# 1/1 [==============================] - 0s 35ms/step
# 0.48863983
# 1/1 [==============================] - 0s 29ms/step
# 0.4877243
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 39ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.8217422
# 1/1 [==============================] - 0s 31ms/step
# 0.48737335
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.8132391
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.8318427
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.82913136
# 1/1 [==============================] - 0s 33ms/step
# 0.49995422
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48789978
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.49790955
# 1/1 [==============================] - 0s 28ms/step
# 0.5864632
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49933624
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.48789978
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49995422
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.8213937
# 1/1 [==============================] - 0s 30ms/step
# 0.4992218
# 1/1 [==============================] - 0s 30ms/step
# 0.8107466
# 1/1 [==============================] - 0s 35ms/step
# 0.5864632
# 1/1 [==============================] - 0s 31ms/step
# 0.8261117
# 1/1 [==============================] - 0s 31ms/step
# 0.48801422
# 1/1 [==============================] - 0s 35ms/step
# 0.48789978
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.49993896
# 1/1 [==============================] - 0s 28ms/step
# 0.5358758
# 1/1 [==============================] - 0s 33ms/step
# 0.48773956
# 1/1 [==============================] - 0s 32ms/step
# 0.81746984
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48825836
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.49173737
# 1/1 [==============================] - 0s 31ms/step
# 0.48870087
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 41ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.48856354
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.82913136
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 40ms/step
# 0.8165424
# 1/1 [==============================] - 0s 33ms/step
# 0.8141723
# 1/1 [==============================] - 0s 33ms/step
# 0.82259
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.48840332
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48773956
# 1/1 [==============================] - 0s 40ms/step
# 0.49965063
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.8524783
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.80910194
# 1/1 [==============================] - 0s 32ms/step
# 0.79042304
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 0