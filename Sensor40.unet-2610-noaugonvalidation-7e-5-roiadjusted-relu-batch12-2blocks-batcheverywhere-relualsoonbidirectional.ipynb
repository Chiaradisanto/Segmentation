# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor40.unet-2610-noaugonvalidation-7e-5-roiadjusted-relu-batch12-2blocks-batcheverywhere-relualsoonbidirectional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)


x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2,activation='relu'))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv9])
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2,activation='relu'))(x)
x=tf.expand_dims(x,axis=1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_4[0][0]']
#  buted)                          32)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_5[0][0]']
#  buted)                          32)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 64, 64, 3  0          ['time_distributed_8[0][0]']
#  buted)                         2)
#
#  time_distributed_10 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_9[0][0]']
#  ibuted)                        4)
#
#  time_distributed_11 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_10[0][0]']
#  ibuted)                        4)
#
#  time_distributed_12 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_11[0][0]']
#  ibuted)                        4)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_12[0][0]']
#  ibuted)                        4)
#
#  time_distributed_14 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_14[0][0]']
#  ibuted)                        28)
#
#  time_distributed_16 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_15[0][0]']
#  ibuted)                        28)
#
#  time_distributed_17 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_16[0][0]']
#  ibuted)                        28)
#
#  time_distributed_18 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_17[0][0]']
#  ibuted)                        28)
#
#  time_distributed_19 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_18[0][0]']
#  ibuted)                        28)
#
#  time_distributed_20 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_19[0][0]']
#  ibuted)                        56)
#
#  time_distributed_21 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_20[0][0]']
#  ibuted)                        56)
#
#  time_distributed_22 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_21[0][0]']
#  ibuted)                        56)
#
#  time_distributed_23 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_22[0][0]']
#  ibuted)                        56)
#
#  bidirectional (Bidirectional)  (None, 3, 16, 16, 5  9439232     ['time_distributed_23[0][0]']
#                                 12)
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_24[0][0]',
#                                 56)                               'time_distributed_18[0][0]']
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  0          ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_26[0][0]']
#  ibuted)                        28)
#
#  time_distributed_28 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_27[0][0]']
#  ibuted)                        28)
#
#  time_distributed_29 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_28[0][0]']
#  ibuted)                        28)
#
#  time_distributed_30 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_29[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_30[0][0]',
#                                 28)                               'time_distributed_13[0][0]']
#
#  time_distributed_31 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_32 (TimeDistr  (None, 3, 64, 64, 6  0          ['time_distributed_31[0][0]']
#  ibuted)                        4)
#
#  time_distributed_33 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_32[0][0]']
#  ibuted)                        4)
#
#  time_distributed_34 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_33[0][0]']
#  ibuted)                        4)
#
#  time_distributed_35 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_34[0][0]']
#  ibuted)                        4)
#
#  time_distributed_36 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_35[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_36[0][0]',
#                                  64)                              'time_distributed_8[0][0]']
#
#  time_distributed_37 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_38 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_37[0][0]']
#  ibuted)                         32)
#
#  time_distributed_39 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_38[0][0]']
#  ibuted)                         32)
#
#  time_distributed_40 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_39[0][0]']
#  ibuted)                         32)
#
#  time_distributed_41 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_40[0][0]']
#  ibuted)                         32)
#
#  time_distributed_42 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_41[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_42[0][0]',
#                                  32)                              'time_distributed_3[0][0]']
#
#  time_distributed_43 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_44 (TimeDistr  (None, 3, 256, 256,  0          ['time_distributed_43[0][0]']
#  ibuted)                         16)
#
#  time_distributed_45 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_44[0][0]']
#  ibuted)                         16)
#
#  time_distributed_46 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_45[0][0]']
#  ibuted)                         16)
#
#  time_distributed_47 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_46[0][0]']
#  ibuted)                         16)
#
#  bidirectional_1 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_47[0][0]']
#  )                              )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['bidirectional_1[0][0]']
#                                  32)
#
#  time_distributed_48 (TimeDistr  (None, 1, 256, 256,  128        ['tf.expand_dims[0][0]']
#  ibuted)                         32)
#
#  conv2d_18 (Conv2D)             (None, 1, 256, 256,  33          ['time_distributed_48[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,935,585
# Trainable params: 11,932,577
# Non-trainable params: 3,008
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 7e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/40
# 248/248 [==============================] - 424s 2s/step - loss: 0.8729 - dice_coefficient: 0.1271 - binary_accuracy: 0.7097 - val_loss: 0.9584 - val_dice_coefficient: 0.0416 - val_binary_accuracy: 0.3970
# Epoch 2/40
# 248/248 [==============================] - 391s 2s/step - loss: 0.7874 - dice_coefficient: 0.2126 - binary_accuracy: 0.8783 - val_loss: 0.8802 - val_dice_coefficient: 0.1198 - val_binary_accuracy: 0.8465
# Epoch 3/40
# 248/248 [==============================] - 391s 2s/step - loss: 0.7218 - dice_coefficient: 0.2782 - binary_accuracy: 0.9253 - val_loss: 0.7429 - val_dice_coefficient: 0.2571 - val_binary_accuracy: 0.9453
# Epoch 4/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.6489 - dice_coefficient: 0.3511 - binary_accuracy: 0.9479 - val_loss: 0.8222 - val_dice_coefficient: 0.1778 - val_binary_accuracy: 0.9512
# Epoch 5/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.5791 - dice_coefficient: 0.4209 - binary_accuracy: 0.9609 - val_loss: 0.7594 - val_dice_coefficient: 0.2406 - val_binary_accuracy: 0.9346
# Epoch 6/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.5274 - dice_coefficient: 0.4726 - binary_accuracy: 0.9678 - val_loss: 0.7190 - val_dice_coefficient: 0.2810 - val_binary_accuracy: 0.9737
# Epoch 7/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.4606 - dice_coefficient: 0.5394 - binary_accuracy: 0.9740 - val_loss: 0.7517 - val_dice_coefficient: 0.2483 - val_binary_accuracy: 0.9786
# Epoch 8/40
# 248/248 [==============================] - 391s 2s/step - loss: 0.4206 - dice_coefficient: 0.5794 - binary_accuracy: 0.9776 - val_loss: 0.5620 - val_dice_coefficient: 0.4380 - val_binary_accuracy: 0.9795
# Epoch 9/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.3744 - dice_coefficient: 0.6256 - binary_accuracy: 0.9800 - val_loss: 0.9775 - val_dice_coefficient: 0.0225 - val_binary_accuracy: 0.9871
# Epoch 10/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.3402 - dice_coefficient: 0.6598 - binary_accuracy: 0.9826 - val_loss: 0.4809 - val_dice_coefficient: 0.5191 - val_binary_accuracy: 0.9880
# Epoch 11/40
# 248/248 [==============================] - 391s 2s/step - loss: 0.3262 - dice_coefficient: 0.6738 - binary_accuracy: 0.9837 - val_loss: 0.4604 - val_dice_coefficient: 0.5396 - val_binary_accuracy: 0.9892
# Epoch 12/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.2808 - dice_coefficient: 0.7192 - binary_accuracy: 0.9846 - val_loss: 0.4508 - val_dice_coefficient: 0.5492 - val_binary_accuracy: 0.9895
# Epoch 13/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2478 - dice_coefficient: 0.7522 - binary_accuracy: 0.9860 - val_loss: 0.4665 - val_dice_coefficient: 0.5335 - val_binary_accuracy: 0.9900
# Epoch 14/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2487 - dice_coefficient: 0.7513 - binary_accuracy: 0.9863 - val_loss: 0.5298 - val_dice_coefficient: 0.4702 - val_binary_accuracy: 0.9885
# Epoch 15/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2483 - dice_coefficient: 0.7517 - binary_accuracy: 0.9865 - val_loss: 0.7764 - val_dice_coefficient: 0.2236 - val_binary_accuracy: 0.9883
# Epoch 16/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2356 - dice_coefficient: 0.7644 - binary_accuracy: 0.9870 - val_loss: 0.5411 - val_dice_coefficient: 0.4589 - val_binary_accuracy: 0.9897
# Epoch 17/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2282 - dice_coefficient: 0.7718 - binary_accuracy: 0.9872 - val_loss: 0.6417 - val_dice_coefficient: 0.3583 - val_binary_accuracy: 0.9880
# Epoch 18/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2091 - dice_coefficient: 0.7909 - binary_accuracy: 0.9875 - val_loss: 0.4695 - val_dice_coefficient: 0.5305 - val_binary_accuracy: 0.9897
# Epoch 19/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.2187 - dice_coefficient: 0.7813 - binary_accuracy: 0.9871 - val_loss: 0.4102 - val_dice_coefficient: 0.5898 - val_binary_accuracy: 0.9912
# Epoch 20/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2061 - dice_coefficient: 0.7939 - binary_accuracy: 0.9875 - val_loss: 0.8361 - val_dice_coefficient: 0.1639 - val_binary_accuracy: 0.9855
# Epoch 21/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1995 - dice_coefficient: 0.8005 - binary_accuracy: 0.9879 - val_loss: 0.8491 - val_dice_coefficient: 0.1509 - val_binary_accuracy: 0.9870
# Epoch 22/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1951 - dice_coefficient: 0.8049 - binary_accuracy: 0.9880 - val_loss: 0.5826 - val_dice_coefficient: 0.4174 - val_binary_accuracy: 0.9891
# Epoch 23/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1879 - dice_coefficient: 0.8121 - binary_accuracy: 0.9890 - val_loss: 0.6071 - val_dice_coefficient: 0.3929 - val_binary_accuracy: 0.9883
# Epoch 24/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1870 - dice_coefficient: 0.8130 - binary_accuracy: 0.9885 - val_loss: 0.7024 - val_dice_coefficient: 0.2976 - val_binary_accuracy: 0.9876
# Epoch 25/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1828 - dice_coefficient: 0.8172 - binary_accuracy: 0.9888 - val_loss: 0.6428 - val_dice_coefficient: 0.3572 - val_binary_accuracy: 0.9871
# Epoch 26/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1695 - dice_coefficient: 0.8305 - binary_accuracy: 0.9895 - val_loss: 0.5043 - val_dice_coefficient: 0.4957 - val_binary_accuracy: 0.9884
# Epoch 27/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1847 - dice_coefficient: 0.8153 - binary_accuracy: 0.9884 - val_loss: 0.4541 - val_dice_coefficient: 0.5459 - val_binary_accuracy: 0.9893
# Epoch 28/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1804 - dice_coefficient: 0.8196 - binary_accuracy: 0.9892 - val_loss: 0.8666 - val_dice_coefficient: 0.1334 - val_binary_accuracy: 0.9855
# Epoch 29/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1655 - dice_coefficient: 0.8345 - binary_accuracy: 0.9892 - val_loss: 0.6242 - val_dice_coefficient: 0.3758 - val_binary_accuracy: 0.9870
# Epoch 30/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1631 - dice_coefficient: 0.8369 - binary_accuracy: 0.9899 - val_loss: 0.6494 - val_dice_coefficient: 0.3506 - val_binary_accuracy: 0.9876
# Epoch 31/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1674 - dice_coefficient: 0.8326 - binary_accuracy: 0.9895 - val_loss: 0.7817 - val_dice_coefficient: 0.2183 - val_binary_accuracy: 0.9873
# Epoch 32/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1538 - dice_coefficient: 0.8462 - binary_accuracy: 0.9897 - val_loss: 0.5609 - val_dice_coefficient: 0.4391 - val_binary_accuracy: 0.9887
# Epoch 33/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1709 - dice_coefficient: 0.8291 - binary_accuracy: 0.9892 - val_loss: 0.7026 - val_dice_coefficient: 0.2974 - val_binary_accuracy: 0.9868
# Epoch 34/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1611 - dice_coefficient: 0.8389 - binary_accuracy: 0.9896 - val_loss: 0.8402 - val_dice_coefficient: 0.1598 - val_binary_accuracy: 0.9856
# Epoch 35/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1654 - dice_coefficient: 0.8346 - binary_accuracy: 0.9894 - val_loss: 0.8248 - val_dice_coefficient: 0.1752 - val_binary_accuracy: 0.9842
# Epoch 36/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1596 - dice_coefficient: 0.8404 - binary_accuracy: 0.9896 - val_loss: 0.6356 - val_dice_coefficient: 0.3644 - val_binary_accuracy: 0.9882
# Epoch 37/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1587 - dice_coefficient: 0.8413 - binary_accuracy: 0.9901 - val_loss: 0.8586 - val_dice_coefficient: 0.1414 - val_binary_accuracy: 0.9867
# Epoch 38/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1583 - dice_coefficient: 0.8417 - binary_accuracy: 0.9900 - val_loss: 0.5547 - val_dice_coefficient: 0.4453 - val_binary_accuracy: 0.9907
# Epoch 39/40
# 248/248 [==============================] - 391s 2s/step - loss: 0.1548 - dice_coefficient: 0.8452 - binary_accuracy: 0.9899 - val_loss: 0.7742 - val_dice_coefficient: 0.2258 - val_binary_accuracy: 0.9864
# Epoch 40/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1514 - dice_coefficient: 0.8486 - binary_accuracy: 0.9902 - val_loss: 0.4358 - val_dice_coefficient: 0.5642 - val_binary_accuracy: 0.9906

# %%
model.save('/gdrive/MyDrive/Sensor40.unet-2610-noaugonvalidation-7e-5-roiadjusted-relu-batch12-2blocks-batcheverywhere-relualsoonbidirectional.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor40.unet-2610-noaugonvalidation-7e-5-roiadjusted-relu-batch12-2blocks-batcheverywhere-relualsoonbidirectional.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')

  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.8353697

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 0.47436523
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.487175
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8778941
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8186313
# 1/1 [==============================] - 0s 24ms/step
# 0.8353697
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.80114937
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.88605607
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.5155837
# 1/1 [==============================] - 0s 28ms/step
# 0.6913403
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.85921735
# 1/1 [==============================] - 0s 28ms/step
# 0.48638153
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.51551074
# 1/1 [==============================] - 0s 24ms/step
# 0.47416687
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.7217387
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.7700963
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.52824765
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.6103354
# 1/1 [==============================] - 0s 25ms/step
# 0.4869461
# 1/1 [==============================] - 0s 28ms/step
# 0.8778941
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4872818
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.841496
# 1/1 [==============================] - 0s 29ms/step
# 0.8716912
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.4743271
# 1/1 [==============================] - 0s 27ms/step
# 0.59422493
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.55248636
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48638153
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8353697
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48724365
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48609468
# 1/1 [==============================] - 0s 30ms/step
# 0.4760437
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.6051387
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.5226909
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.48847297
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.8052404
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.80114937
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48588562
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 39ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4760437
# 1/1 [==============================] - 0s 26ms/step
# 0.59422493
# 1/1 [==============================] - 0s 27ms/step
# 0.8585678
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8691391
# 1/1 [==============================] - 0s 26ms/step
# 0.79614794
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.8353697
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.8767259
# 1/1 [==============================] - 0s 26ms/step
# 0.5119791
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.49535865
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8656429
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.64464027
# 1/1 [==============================] - 0s 25ms/step
# 0.85921735
# 1/1 [==============================] - 0s 29ms/step
# 0.79614794
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.5088455
# 1/1 [==============================] - 0s 31ms/step
# 0.8716912
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.8739879
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49309313
# 1/1 [==============================] - 0s 28ms/step
# 0.8190203
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.86435497
# 1/1 [==============================] - 0s 25ms/step
# 0.5226909
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.5339841
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.82776237
# 1/1 [==============================] - 0s 27ms/step
# 0.49849376
# 1/1 [==============================] - 0s 28ms/step
# 0.49634907
# 1/1 [==============================] - 0s 33ms/step
# 0.8687841
# 1/1 [==============================] - 0s 28ms/step
# 0.5273311
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.86550874
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.49897766
# 1/1 [==============================] - 0s 26ms/step
# 0.82386565
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8052404
# 1/1 [==============================] - 0s 28ms/step
# 0.8353697
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.8691391
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8353697
# 1/1 [==============================] - 0s 27ms/step
# 0.5412128
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.5255088
# 1/1 [==============================] - 0s 29ms/step
# 0.8186313
# 1/1 [==============================] - 0s 29ms/step
# 0.48057854
# 1/1 [==============================] - 0s 27ms/step
# 0.8096504
# 1/1 [==============================] - 0s 26ms/step
# 0.6917833
# 1/1 [==============================] - 0s 26ms/step
# 0.48773956
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8052404
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.5339841
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47408295
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.47416687
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.48885128
# 1/1 [==============================] - 0s 24ms/step
# 0.49897766
# 1/1 [==============================] - 0s 28ms/step
# 0.823701
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.6913403
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49684143
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.50286394
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4858322
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.4743271
# 1/1 [==============================] - 0s 28ms/step
# 0.7297379
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.55248636
# 1/1 [==============================] - 0s 24ms/step
# 0.6401357
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.7765554
# 1/1 [==============================] - 0s 26ms/step
# 0.82441294
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.47436523
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8412229
# 1/1 [==============================] - 0s 24ms/step
# 0.535706
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.8780445
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47427368
# 1/1 [==============================] - 0s 25ms/step
# 0.48451996
# 1/1 [==============================] - 0s 27ms/step
# 0.8767259
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.7677616
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8826857
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8407275
# 1/1 [==============================] - 0s 24ms/step
# 0.8407275
# 1/1 [==============================] - 0s 29ms/step
# 0.85921735
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.72745764
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.86550874
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48885128
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48847297
# 1/1 [==============================] - 0s 28ms/step
# 0.8716912
# 1/1 [==============================] - 0s 24ms/step
# 0.8412229
# 1/1 [==============================] - 0s 26ms/step
# 0.48975372
# 1/1 [==============================] - 0s 24ms/step
# 0.47427368
# 1/1 [==============================] - 0s 28ms/step
# 0.59422493
# 1/1 [==============================] - 0s 25ms/step
# 0.53712976
# 1/1 [==============================] - 0s 24ms/step
# 0.86550874
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48773956
# 1/1 [==============================] - 0s 29ms/step
# 0.5226909
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48771667
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8519194
# 1/1 [==============================] - 0s 25ms/step
# 0.88484466
# 1/1 [==============================] - 0s 26ms/step
# 0.5155837
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.7693014
# 1/1 [==============================] - 0s 31ms/step
# 0.47789
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48771667
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.64464027
# 1/1 [==============================] - 0s 28ms/step
# 0.72745764
# 1/1 [==============================] - 0s 30ms/step
# 0.47571564
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.49638134
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.48700714
# 1/1 [==============================] - 0s 25ms/step
# 0.4743271
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.6917029
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8068764
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.5492262
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.49638134
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48696136
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.47408295
# 1/1 [==============================] - 0s 28ms/step
# 0.49535865
# 1/1 [==============================] - 0s 26ms/step
# 0.5116355
# 1/1 [==============================] - 0s 26ms/step
# 0.49821472
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.82441294
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.87167126
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47699738
# 1/1 [==============================] - 0s 27ms/step
# 0.48885128
# 1/1 [==============================] - 0s 24ms/step
# 0.48771667
# 1/1 [==============================] - 0s 31ms/step
# 0.8778941
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49821472
# 1/1 [==============================] - 0s 27ms/step
# 0.82441294
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.6051387
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.47699738
# 1/1 [==============================] - 0s 26ms/step
# 0.8353697
# 1/1 [==============================] - 0s 27ms/step
# 0.5155837
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.49638134
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47441864
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.5226909
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.6913403
# 1/1 [==============================] - 0s 38ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8508302
# 1/1 [==============================] - 0s 24ms/step
# 0.5255088
# 1/1 [==============================] - 0s 28ms/step
# 0.8703424
# 1/1 [==============================] - 0s 24ms/step
# 0.7251271
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8546111
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8186313
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7251271
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.8780445
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.7693014
# 1/1 [==============================] - 0s 27ms/step
# 0.86550874
# 1/1 [==============================] - 0s 28ms/step
# 0.48771667
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8703424
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.50794077
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.51235133
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4872818
# 1/1 [==============================] - 0s 27ms/step
# 0.78702796
# 1/1 [==============================] - 0s 24ms/step
# 0.8096504
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.51317286
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48975372
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.48723602
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.53687406
# 1/1 [==============================] - 0s 25ms/step
# 0.5528162
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.85921735
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.87787104
# 1/1 [==============================] - 0s 27ms/step
# 0.7700963
# 1/1 [==============================] - 0s 25ms/step
# 0.4858322
# 1/1 [==============================] - 0s 24ms/step
# 0.4909835
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48495483
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.82386565
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.49634907
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.48365784
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.7765554
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.5985664
# 1/1 [==============================] - 0s 28ms/step
# 0.5528162
# 1/1 [==============================] - 0s 27ms/step
# 0.8780445
# 1/1 [==============================] - 0s 28ms/step
# 0.487175
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48365784
# 1/1 [==============================] - 0s 29ms/step
# 0.48451996
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.48847297
# 1/1 [==============================] - 0s 31ms/step
# 0.55248636
# 1/1 [==============================] - 0s 29ms/step
# 0.4879303
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.7765554
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48638153
# 1/1 [==============================] - 0s 25ms/step
# 0.87787104
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7605972
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 40ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.6401357
# 1/1 [==============================] - 0s 25ms/step
# 0.48544312
# 1/1 [==============================] - 0s 27ms/step
# 0.8716912
# 1/1 [==============================] - 0s 23ms/step
# 0.48975372
# 1/1 [==============================] - 0s 27ms/step
# 0.4903561
# 1/1 [==============================] - 0s 24ms/step
# 0.4877243
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.64464027
# 1/1 [==============================] - 0s 26ms/step
# 0.48771667
# 1/1 [==============================] - 0s 28ms/step
# 0.474411
# 1/1 [==============================] - 0s 25ms/step
# 0.87787104
# 1/1 [==============================] - 0s 27ms/step
# 0.4877243
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.6051387
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# Mean IoU is:  [0.645863]
