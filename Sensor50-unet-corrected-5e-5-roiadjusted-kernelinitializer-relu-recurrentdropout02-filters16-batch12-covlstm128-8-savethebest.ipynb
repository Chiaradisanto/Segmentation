# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor50-unet-corrected-5e-5-roiadjusted-kernelinitializer-relu-recurrentdropout02-filters16-batch12-covlstm128-8-savethebest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=4,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
train_loader, val_loader = DataLoader("/gdrive/MyDrive/adjustedROI/final_output", squeeze=False).get_loaders()

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
num_val_images
# Out:
# 477

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.Bidirectional(layers.ConvLSTM2D(128,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True))(conv5)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv4])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat1)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv3])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat2)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)

up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv2])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat3)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv1])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat4)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

x=layers.Bidirectional(layers.ConvLSTM2D(8,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_4[0][0]']
#  buted)                          32)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_5[0][0]']
#  buted)                          32)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 64, 64, 3  0          ['time_distributed_8[0][0]']
#  buted)                         2)
#
#  time_distributed_10 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_9[0][0]']
#  ibuted)                        4)
#
#  time_distributed_11 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_10[0][0]']
#  ibuted)                        4)
#
#  time_distributed_12 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_11[0][0]']
#  ibuted)                        4)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_12[0][0]']
#  ibuted)                        4)
#
#  time_distributed_14 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_14[0][0]']
#  ibuted)                        28)
#
#  time_distributed_16 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_15[0][0]']
#  ibuted)                        28)
#
#  time_distributed_17 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_16[0][0]']
#  ibuted)                        28)
#
#  time_distributed_18 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_17[0][0]']
#  ibuted)                        28)
#
#  time_distributed_19 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_18[0][0]']
#  ibuted)                        28)
#
#  time_distributed_20 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_19[0][0]']
#  ibuted)                        56)
#
#  time_distributed_21 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_20[0][0]']
#  ibuted)                        56)
#
#  time_distributed_22 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_21[0][0]']
#  ibuted)                        56)
#
#  time_distributed_23 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_22[0][0]']
#  ibuted)                        56)
#
#  bidirectional (Bidirectional)  (None, 3, 16, 16, 2  3539968     ['time_distributed_23[0][0]']
#                                 56)
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  295040     ['bidirectional[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_24[0][0]',
#                                 56)                               'time_distributed_18[0][0]']
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_26[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_27[0][0]',
#                                 28)                               'time_distributed_13[0][0]']
#
#  time_distributed_28 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_29 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_28[0][0]']
#  ibuted)                        4)
#
#  time_distributed_30 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_29[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_30[0][0]',
#                                  64)                              'time_distributed_8[0][0]']
#
#  time_distributed_31 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_32 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_31[0][0]']
#  ibuted)                         32)
#
#  time_distributed_33 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_32[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_33[0][0]',
#                                  32)                              'time_distributed_3[0][0]']
#
#  time_distributed_34 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_35 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_34[0][0]']
#  ibuted)                         16)
#
#  bidirectional_1 (Bidirectional  (None, 256, 256, 16  13888      ['time_distributed_35[0][0]']
#  )                              )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['bidirectional_1[0][0]']
#                                  16)
#
#  conv2d_18 (Conv2D)             (None, 1, 256, 256,  17          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 5,716,241
# Trainable params: 5,714,257
# Non-trainable params: 1,984
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=50,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/50
# 248/248 [==============================] - 299s 1s/step - loss: 0.8565 - dice_coefficient: 0.1435 - binary_accuracy: 0.8095 - val_loss: 0.9156 - val_dice_coefficient: 0.0844 - val_binary_accuracy: 0.9760
# Epoch 2/50
# 248/248 [==============================] - 271s 1s/step - loss: 0.6940 - dice_coefficient: 0.3060 - binary_accuracy: 0.9684 - val_loss: 0.7805 - val_dice_coefficient: 0.2195 - val_binary_accuracy: 0.9737
# Epoch 3/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.6409 - dice_coefficient: 0.3591 - binary_accuracy: 0.9736 - val_loss: 0.7705 - val_dice_coefficient: 0.2295 - val_binary_accuracy: 0.9604
# Epoch 4/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.5975 - dice_coefficient: 0.4025 - binary_accuracy: 0.9766 - val_loss: 0.7888 - val_dice_coefficient: 0.2112 - val_binary_accuracy: 0.9705
# Epoch 5/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.5393 - dice_coefficient: 0.4607 - binary_accuracy: 0.9792 - val_loss: 0.6789 - val_dice_coefficient: 0.3211 - val_binary_accuracy: 0.9774
# Epoch 6/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.5105 - dice_coefficient: 0.4895 - binary_accuracy: 0.9814 - val_loss: 0.6610 - val_dice_coefficient: 0.3390 - val_binary_accuracy: 0.9789
# Epoch 7/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.4484 - dice_coefficient: 0.5516 - binary_accuracy: 0.9823 - val_loss: 0.7179 - val_dice_coefficient: 0.2821 - val_binary_accuracy: 0.9745
# Epoch 8/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.4239 - dice_coefficient: 0.5761 - binary_accuracy: 0.9828 - val_loss: 0.6255 - val_dice_coefficient: 0.3745 - val_binary_accuracy: 0.9806
# Epoch 9/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.4150 - dice_coefficient: 0.5850 - binary_accuracy: 0.9834 - val_loss: 0.5924 - val_dice_coefficient: 0.4076 - val_binary_accuracy: 0.9768
# Epoch 10/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.3651 - dice_coefficient: 0.6349 - binary_accuracy: 0.9849 - val_loss: 0.5275 - val_dice_coefficient: 0.4725 - val_binary_accuracy: 0.9845
# Epoch 11/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.3590 - dice_coefficient: 0.6410 - binary_accuracy: 0.9852 - val_loss: 0.5568 - val_dice_coefficient: 0.4432 - val_binary_accuracy: 0.9875
# Epoch 12/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.3400 - dice_coefficient: 0.6600 - binary_accuracy: 0.9855 - val_loss: 0.6165 - val_dice_coefficient: 0.3835 - val_binary_accuracy: 0.9837
# Epoch 13/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.3358 - dice_coefficient: 0.6642 - binary_accuracy: 0.9860 - val_loss: 0.5486 - val_dice_coefficient: 0.4514 - val_binary_accuracy: 0.9859
# Epoch 14/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.3150 - dice_coefficient: 0.6850 - binary_accuracy: 0.9863 - val_loss: 0.5887 - val_dice_coefficient: 0.4113 - val_binary_accuracy: 0.9885
# Epoch 15/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.3004 - dice_coefficient: 0.6996 - binary_accuracy: 0.9867 - val_loss: 0.5255 - val_dice_coefficient: 0.4745 - val_binary_accuracy: 0.9836
# Epoch 16/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.2913 - dice_coefficient: 0.7087 - binary_accuracy: 0.9867 - val_loss: 0.5283 - val_dice_coefficient: 0.4717 - val_binary_accuracy: 0.9864
# Epoch 17/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.2694 - dice_coefficient: 0.7306 - binary_accuracy: 0.9877 - val_loss: 0.4826 - val_dice_coefficient: 0.5174 - val_binary_accuracy: 0.9861
# Epoch 18/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.2744 - dice_coefficient: 0.7256 - binary_accuracy: 0.9875 - val_loss: 0.4643 - val_dice_coefficient: 0.5357 - val_binary_accuracy: 0.9848
# Epoch 19/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.2596 - dice_coefficient: 0.7404 - binary_accuracy: 0.9877 - val_loss: 0.4911 - val_dice_coefficient: 0.5089 - val_binary_accuracy: 0.9874
# Epoch 20/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.2522 - dice_coefficient: 0.7478 - binary_accuracy: 0.9878 - val_loss: 0.4816 - val_dice_coefficient: 0.5184 - val_binary_accuracy: 0.9886
# Epoch 21/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.2509 - dice_coefficient: 0.7491 - binary_accuracy: 0.9873 - val_loss: 0.4865 - val_dice_coefficient: 0.5135 - val_binary_accuracy: 0.9859
# Epoch 22/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.2278 - dice_coefficient: 0.7722 - binary_accuracy: 0.9882 - val_loss: 0.4157 - val_dice_coefficient: 0.5843 - val_binary_accuracy: 0.9877
# Epoch 23/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.2260 - dice_coefficient: 0.7740 - binary_accuracy: 0.9884 - val_loss: 0.4434 - val_dice_coefficient: 0.5566 - val_binary_accuracy: 0.9882
# Epoch 24/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.2244 - dice_coefficient: 0.7756 - binary_accuracy: 0.9886 - val_loss: 0.4824 - val_dice_coefficient: 0.5176 - val_binary_accuracy: 0.9889
# Epoch 25/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.2234 - dice_coefficient: 0.7766 - binary_accuracy: 0.9883 - val_loss: 0.4556 - val_dice_coefficient: 0.5444 - val_binary_accuracy: 0.9883
# Epoch 26/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.2167 - dice_coefficient: 0.7833 - binary_accuracy: 0.9886 - val_loss: 0.4570 - val_dice_coefficient: 0.5430 - val_binary_accuracy: 0.9880
# Epoch 27/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.2014 - dice_coefficient: 0.7986 - binary_accuracy: 0.9887 - val_loss: 0.4171 - val_dice_coefficient: 0.5829 - val_binary_accuracy: 0.9875
# Epoch 28/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.2010 - dice_coefficient: 0.7990 - binary_accuracy: 0.9888 - val_loss: 0.4521 - val_dice_coefficient: 0.5479 - val_binary_accuracy: 0.9874
# Epoch 29/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.1889 - dice_coefficient: 0.8111 - binary_accuracy: 0.9892 - val_loss: 0.4275 - val_dice_coefficient: 0.5725 - val_binary_accuracy: 0.9866
# Epoch 30/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1903 - dice_coefficient: 0.8097 - binary_accuracy: 0.9891 - val_loss: 0.3965 - val_dice_coefficient: 0.6035 - val_binary_accuracy: 0.9881
# Epoch 31/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1999 - dice_coefficient: 0.8001 - binary_accuracy: 0.9892 - val_loss: 0.4537 - val_dice_coefficient: 0.5463 - val_binary_accuracy: 0.9877
# Epoch 32/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1957 - dice_coefficient: 0.8043 - binary_accuracy: 0.9896 - val_loss: 0.4893 - val_dice_coefficient: 0.5107 - val_binary_accuracy: 0.9875
# Epoch 33/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1821 - dice_coefficient: 0.8179 - binary_accuracy: 0.9893 - val_loss: 0.4234 - val_dice_coefficient: 0.5766 - val_binary_accuracy: 0.9888
# Epoch 34/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.1813 - dice_coefficient: 0.8187 - binary_accuracy: 0.9893 - val_loss: 0.4267 - val_dice_coefficient: 0.5733 - val_binary_accuracy: 0.9877
# Epoch 35/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1714 - dice_coefficient: 0.8286 - binary_accuracy: 0.9894 - val_loss: 0.4482 - val_dice_coefficient: 0.5518 - val_binary_accuracy: 0.9873
# Epoch 36/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1696 - dice_coefficient: 0.8304 - binary_accuracy: 0.9899 - val_loss: 0.4786 - val_dice_coefficient: 0.5214 - val_binary_accuracy: 0.9883
# Epoch 37/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1736 - dice_coefficient: 0.8264 - binary_accuracy: 0.9897 - val_loss: 0.4614 - val_dice_coefficient: 0.5386 - val_binary_accuracy: 0.9860
# Epoch 38/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1664 - dice_coefficient: 0.8336 - binary_accuracy: 0.9899 - val_loss: 0.3678 - val_dice_coefficient: 0.6322 - val_binary_accuracy: 0.9884
# Epoch 39/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1720 - dice_coefficient: 0.8280 - binary_accuracy: 0.9900 - val_loss: 0.3951 - val_dice_coefficient: 0.6049 - val_binary_accuracy: 0.9872
# Epoch 40/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1624 - dice_coefficient: 0.8376 - binary_accuracy: 0.9900 - val_loss: 0.4428 - val_dice_coefficient: 0.5572 - val_binary_accuracy: 0.9893
# Epoch 41/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1638 - dice_coefficient: 0.8362 - binary_accuracy: 0.9900 - val_loss: 0.4367 - val_dice_coefficient: 0.5633 - val_binary_accuracy: 0.9877
# Epoch 42/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.1557 - dice_coefficient: 0.8443 - binary_accuracy: 0.9900 - val_loss: 0.3817 - val_dice_coefficient: 0.6183 - val_binary_accuracy: 0.9886
# Epoch 43/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1636 - dice_coefficient: 0.8364 - binary_accuracy: 0.9897 - val_loss: 0.3671 - val_dice_coefficient: 0.6329 - val_binary_accuracy: 0.9872
# Epoch 44/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1549 - dice_coefficient: 0.8451 - binary_accuracy: 0.9901 - val_loss: 0.3607 - val_dice_coefficient: 0.6393 - val_binary_accuracy: 0.9882
# Epoch 45/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1650 - dice_coefficient: 0.8350 - binary_accuracy: 0.9902 - val_loss: 0.3742 - val_dice_coefficient: 0.6258 - val_binary_accuracy: 0.9888
# Epoch 46/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1627 - dice_coefficient: 0.8373 - binary_accuracy: 0.9902 - val_loss: 0.4641 - val_dice_coefficient: 0.5359 - val_binary_accuracy: 0.9875
# Epoch 47/50
# 248/248 [==============================] - 268s 1s/step - loss: 0.1555 - dice_coefficient: 0.8445 - binary_accuracy: 0.9900 - val_loss: 0.4408 - val_dice_coefficient: 0.5592 - val_binary_accuracy: 0.9874
# Epoch 48/50
# 248/248 [==============================] - 269s 1s/step - loss: 0.1498 - dice_coefficient: 0.8502 - binary_accuracy: 0.9900 - val_loss: 0.3669 - val_dice_coefficient: 0.6331 - val_binary_accuracy: 0.9887
# Epoch 49/50
# 248/248 [==============================] - 270s 1s/step - loss: 0.1522 - dice_coefficient: 0.8478 - binary_accuracy: 0.9901 - val_loss: 0.3981 - val_dice_coefficient: 0.6019 - val_binary_accuracy: 0.9890
# Epoch 50/50
# 248/248 [==============================] - 271s 1s/step - loss: 0.1507 - dice_coefficient: 0.8493 - binary_accuracy: 0.9902 - val_loss: 0.4280 - val_dice_coefficient: 0.5720 - val_binary_accuracy: 0.9881

# %%
model.save('/gdrive/MyDrive/Sensor50-unet-corrected-5e-5-roiadjusted-kernelinitializer-relu-recurrentdropout02-filters16-batch12-covlstm128-8-savethebest.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor50-unet-corrected-5e-5-roiadjusted-kernelinitializer-relu-recurrentdropout02-filters16-batch12-covlstm128-8-savethebest.h5", compile=False)

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=400,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
data_folder = "/gdrive/MyDrive/adjustedROI/final_output"
train,val_loader = DataLoader(data_folder, batch_size=477).get_loaders()

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')

plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')


plt.show()
# Out:
# 1/1 [==============================] - 0s 58ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 1.0

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48750305
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4984665
# 1/1 [==============================] - 0s 28ms/step
# 0.4883499
# 1/1 [==============================] - 0s 25ms/step
# 0.6866398
# 1/1 [==============================] - 0s 28ms/step
# 0.49816895
# 1/1 [==============================] - 0s 24ms/step
# 0.4862213
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.48847198
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48836517
# 1/1 [==============================] - 0s 28ms/step
# 0.48825836
# 1/1 [==============================] - 0s 27ms/step
# 0.48783112
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.6608824
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4803604
# 1/1 [==============================] - 0s 23ms/step
# 0.4780655
# 1/1 [==============================] - 0s 26ms/step
# 0.5767989
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.48773956
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48856354
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7283769
# 1/1 [==============================] - 0s 29ms/step
# 0.49861145
# 1/1 [==============================] - 0s 27ms/step
# 0.49689484
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.47838593
# 1/1 [==============================] - 0s 26ms/step
# 0.49926758
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.70934606
# 1/1 [==============================] - 0s 28ms/step
# 0.5724641
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4992752
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48847198
# 1/1 [==============================] - 0s 26ms/step
# 0.70136404
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.5642675
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 38ms/step
# 0.47968292
# 1/1 [==============================] - 0s 25ms/step
# 0.4879303
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.4884796
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48877716
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48789978
# 1/1 [==============================] - 0s 32ms/step
# 0.79112107
# 1/1 [==============================] - 0s 25ms/step
# 0.49916077
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.76024556
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.6651031
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.70782655
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.47408295
# 1/1 [==============================] - 0s 24ms/step
# 0.47968292
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48723602
# 1/1 [==============================] - 0s 30ms/step
# 0.48679352
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.49991608
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.49944305
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.6342444
# 1/1 [==============================] - 0s 25ms/step
# 0.68295944
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0