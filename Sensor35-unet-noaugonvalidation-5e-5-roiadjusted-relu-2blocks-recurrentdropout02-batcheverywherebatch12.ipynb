# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor35-unet-noaugonvalidation-5e-5-roiadjusted-relu-2blocks-recurrentdropout02-batcheverywherebatch12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
batch_size=12

# %%
x, y = val_loader.__next__()
for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3,3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose( 128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path

concat1 = layers.concatenate([up1, conv9])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])

x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_4[0][0]']
#  buted)                          32)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_5[0][0]']
#  buted)                          32)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 64, 64, 3  0          ['time_distributed_8[0][0]']
#  buted)                         2)
#
#  time_distributed_10 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_9[0][0]']
#  ibuted)                        4)
#
#  time_distributed_11 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_10[0][0]']
#  ibuted)                        4)
#
#  time_distributed_12 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_11[0][0]']
#  ibuted)                        4)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_12[0][0]']
#  ibuted)                        4)
#
#  time_distributed_14 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_14[0][0]']
#  ibuted)                        28)
#
#  time_distributed_16 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_15[0][0]']
#  ibuted)                        28)
#
#  time_distributed_17 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_16[0][0]']
#  ibuted)                        28)
#
#  time_distributed_18 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_17[0][0]']
#  ibuted)                        28)
#
#  time_distributed_19 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_18[0][0]']
#  ibuted)                        56)
#
#  time_distributed_20 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_19[0][0]']
#  ibuted)                        56)
#
#  time_distributed_21 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_20[0][0]']
#  ibuted)                        56)
#
#  time_distributed_22 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_21[0][0]']
#  ibuted)                        56)
#
#  bidirectional (Bidirectional)  (None, 3, 16, 16, 5  9439232     ['time_distributed_22[0][0]']
#                                 12)
#
#  time_distributed_23 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_23[0][0]',
#                                 56)                               'time_distributed_17[0][0]']
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_24[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_26[0][0]']
#  ibuted)                        28)
#
#  time_distributed_28 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_27[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_28[0][0]',
#                                 28)                               'time_distributed_13[0][0]']
#
#  time_distributed_29 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_30 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_29[0][0]']
#  ibuted)                        4)
#
#  time_distributed_31 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_30[0][0]']
#  ibuted)                        4)
#
#  time_distributed_32 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_31[0][0]']
#  ibuted)                        4)
#
#  time_distributed_33 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_32[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_33[0][0]',
#                                  64)                              'time_distributed_8[0][0]']
#
#  time_distributed_34 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_35 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_34[0][0]']
#  ibuted)                         32)
#
#  time_distributed_36 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_35[0][0]']
#  ibuted)                         32)
#
#  time_distributed_37 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_36[0][0]']
#  ibuted)                         32)
#
#  time_distributed_38 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_37[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_38[0][0]',
#                                  32)                              'time_distributed_3[0][0]']
#
#  time_distributed_39 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_40 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_39[0][0]']
#  ibuted)                         16)
#
#  time_distributed_41 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_40[0][0]']
#  ibuted)                         16)
#
#  time_distributed_42 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_41[0][0]']
#  ibuted)                         16)
#
#  bidirectional_1 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_42[0][0]']
#  )                              )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['bidirectional_1[0][0]']
#                                  32)
#
#  conv2d_18 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,934,945
# Trainable params: 11,932,257
# Non-trainable params: 2,688
# __________________________________________________________________________________________________

# %%
 from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[ dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=35,
          verbose=1,
          validation_data=val_loader,
          callbacks=[model_checkpoint_callback],
    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/35
# 248/248 [==============================] - 417s 2s/step - loss: 0.8514 - dice_coefficient: 0.1486 - binary_accuracy: 0.8126 - val_loss: 0.6983 - val_dice_coefficient: 0.3017 - val_binary_accuracy: 0.9177
# Epoch 2/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.5238 - dice_coefficient: 0.4762 - binary_accuracy: 0.9770 - val_loss: 0.4497 - val_dice_coefficient: 0.5503 - val_binary_accuracy: 0.9735
# Epoch 3/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.4042 - dice_coefficient: 0.5958 - binary_accuracy: 0.9818 - val_loss: 0.3554 - val_dice_coefficient: 0.6446 - val_binary_accuracy: 0.9839
# Epoch 4/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.3549 - dice_coefficient: 0.6451 - binary_accuracy: 0.9828 - val_loss: 0.3441 - val_dice_coefficient: 0.6559 - val_binary_accuracy: 0.9847
# Epoch 5/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.3138 - dice_coefficient: 0.6862 - binary_accuracy: 0.9839 - val_loss: 0.4251 - val_dice_coefficient: 0.5749 - val_binary_accuracy: 0.9827
# Epoch 6/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.2980 - dice_coefficient: 0.7020 - binary_accuracy: 0.9857 - val_loss: 0.3397 - val_dice_coefficient: 0.6603 - val_binary_accuracy: 0.9833
# Epoch 7/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2785 - dice_coefficient: 0.7215 - binary_accuracy: 0.9861 - val_loss: 0.3677 - val_dice_coefficient: 0.6323 - val_binary_accuracy: 0.9834
# Epoch 8/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2694 - dice_coefficient: 0.7306 - binary_accuracy: 0.9868 - val_loss: 0.3439 - val_dice_coefficient: 0.6561 - val_binary_accuracy: 0.9843
# Epoch 9/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.2685 - dice_coefficient: 0.7315 - binary_accuracy: 0.9869 - val_loss: 0.3212 - val_dice_coefficient: 0.6788 - val_binary_accuracy: 0.9837
# Epoch 10/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2375 - dice_coefficient: 0.7625 - binary_accuracy: 0.9879 - val_loss: 0.3427 - val_dice_coefficient: 0.6573 - val_binary_accuracy: 0.9822
# Epoch 11/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2309 - dice_coefficient: 0.7691 - binary_accuracy: 0.9880 - val_loss: 0.3593 - val_dice_coefficient: 0.6407 - val_binary_accuracy: 0.9841
# Epoch 12/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2151 - dice_coefficient: 0.7849 - binary_accuracy: 0.9883 - val_loss: 0.3880 - val_dice_coefficient: 0.6120 - val_binary_accuracy: 0.9829
# Epoch 13/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2142 - dice_coefficient: 0.7858 - binary_accuracy: 0.9885 - val_loss: 0.4351 - val_dice_coefficient: 0.5649 - val_binary_accuracy: 0.9812
# Epoch 14/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2142 - dice_coefficient: 0.7858 - binary_accuracy: 0.9882 - val_loss: 0.3856 - val_dice_coefficient: 0.6144 - val_binary_accuracy: 0.9805
# Epoch 15/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2090 - dice_coefficient: 0.7910 - binary_accuracy: 0.9886 - val_loss: 0.3692 - val_dice_coefficient: 0.6308 - val_binary_accuracy: 0.9818
# Epoch 16/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2067 - dice_coefficient: 0.7933 - binary_accuracy: 0.9888 - val_loss: 0.3750 - val_dice_coefficient: 0.6250 - val_binary_accuracy: 0.9777
# Epoch 17/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2093 - dice_coefficient: 0.7907 - binary_accuracy: 0.9891 - val_loss: 0.3833 - val_dice_coefficient: 0.6167 - val_binary_accuracy: 0.9846
# Epoch 18/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.2124 - dice_coefficient: 0.7876 - binary_accuracy: 0.9890 - val_loss: 0.3752 - val_dice_coefficient: 0.6248 - val_binary_accuracy: 0.9783
# Epoch 19/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.1985 - dice_coefficient: 0.8015 - binary_accuracy: 0.9892 - val_loss: 0.4186 - val_dice_coefficient: 0.5814 - val_binary_accuracy: 0.9832
# Epoch 20/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1896 - dice_coefficient: 0.8104 - binary_accuracy: 0.9895 - val_loss: 0.3855 - val_dice_coefficient: 0.6145 - val_binary_accuracy: 0.9802
# Epoch 21/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1886 - dice_coefficient: 0.8114 - binary_accuracy: 0.9893 - val_loss: 0.3911 - val_dice_coefficient: 0.6089 - val_binary_accuracy: 0.9836
# Epoch 22/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1902 - dice_coefficient: 0.8098 - binary_accuracy: 0.9894 - val_loss: 0.4250 - val_dice_coefficient: 0.5750 - val_binary_accuracy: 0.9829
# Epoch 23/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.1838 - dice_coefficient: 0.8162 - binary_accuracy: 0.9895 - val_loss: 0.3258 - val_dice_coefficient: 0.6742 - val_binary_accuracy: 0.9839
# Epoch 24/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.1790 - dice_coefficient: 0.8210 - binary_accuracy: 0.9901 - val_loss: 0.3367 - val_dice_coefficient: 0.6633 - val_binary_accuracy: 0.9817
# Epoch 25/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1877 - dice_coefficient: 0.8123 - binary_accuracy: 0.9898 - val_loss: 0.3711 - val_dice_coefficient: 0.6289 - val_binary_accuracy: 0.9813
# Epoch 26/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.1760 - dice_coefficient: 0.8240 - binary_accuracy: 0.9901 - val_loss: 0.3413 - val_dice_coefficient: 0.6587 - val_binary_accuracy: 0.9834
# Epoch 27/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.1681 - dice_coefficient: 0.8319 - binary_accuracy: 0.9900 - val_loss: 0.4225 - val_dice_coefficient: 0.5775 - val_binary_accuracy: 0.9778
# Epoch 28/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.1722 - dice_coefficient: 0.8278 - binary_accuracy: 0.9900 - val_loss: 0.3290 - val_dice_coefficient: 0.6710 - val_binary_accuracy: 0.9824
# Epoch 29/35
# 248/248 [==============================] - 394s 2s/step - loss: 0.1627 - dice_coefficient: 0.8373 - binary_accuracy: 0.9903 - val_loss: 0.3507 - val_dice_coefficient: 0.6493 - val_binary_accuracy: 0.9828
# Epoch 30/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1735 - dice_coefficient: 0.8265 - binary_accuracy: 0.9900 - val_loss: 0.3529 - val_dice_coefficient: 0.6471 - val_binary_accuracy: 0.9820
# Epoch 31/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1721 - dice_coefficient: 0.8279 - binary_accuracy: 0.9904 - val_loss: 0.3560 - val_dice_coefficient: 0.6440 - val_binary_accuracy: 0.9805
# Epoch 32/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1640 - dice_coefficient: 0.8360 - binary_accuracy: 0.9905 - val_loss: 0.3554 - val_dice_coefficient: 0.6446 - val_binary_accuracy: 0.9816
# Epoch 33/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1686 - dice_coefficient: 0.8314 - binary_accuracy: 0.9904 - val_loss: 0.4165 - val_dice_coefficient: 0.5835 - val_binary_accuracy: 0.9828
# Epoch 34/35
# 248/248 [==============================] - 395s 2s/step - loss: 0.1686 - dice_coefficient: 0.8314 - binary_accuracy: 0.9902 - val_loss: 0.3695 - val_dice_coefficient: 0.6305 - val_binary_accuracy: 0.9829
# Epoch 35/35
# 248/248 [==============================] - ETA: 0s - loss: 0.1701 - dice_coefficient: 0.8299 - binary_accuracy: 0.9908

# %%
model.save('/gdrive/MyDrive/Sensor35-unet-noaugonvalidation-5e-5-roiadjusted-relu-2blocks-recurrentdropout02-batcheverywherebatch12.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor35-unet-noaugonvalidation-5e-5-roiadjusted-relu-2blocks-recurrentdropout02-batcheverywherebatch12.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.8564563

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 0.4977417
# 1/1 [==============================] - 2s 2s/step
# 0.88820827
# 1/1 [==============================] - 1s 1s/step
# 0.48931122
# 1/1 [==============================] - 2s 2s/step
# 0.7652918
# 1/1 [==============================] - 1s 1s/step
# 0.49978638
# 1/1 [==============================] - 1s 1s/step
# 0.48672485
# 1/1 [==============================] - 1s 1s/step
# 0.7772137
# 1/1 [==============================] - 2s 2s/step
# 0.50244236
# 1/1 [==============================] - 2s 2s/step
# 0.48883057
# 1/1 [==============================] - 1s 1s/step
# 0.81969494
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.4875183
# 1/1 [==============================] - 2s 2s/step
# 0.76605487
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.8499899
# 1/1 [==============================] - 1s 1s/step
# 0.88791883
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.4928589
# 1/1 [==============================] - 1s 1s/step
# 0.48083496
# 1/1 [==============================] - 1s 1s/step
# 0.49079132
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.8564563
# 1/1 [==============================] - 1s 1s/step
# 0.8883023
# 1/1 [==============================] - 2s 2s/step
# 0.8715693
# 1/1 [==============================] - 1s 1s/step
# 0.4917221
# 1/1 [==============================] - 2s 2s/step
# 0.48083496
# 1/1 [==============================] - 1s 1s/step
# 0.48215485
# 1/1 [==============================] - 2s 2s/step
# 0.49951172
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.48155975
# 1/1 [==============================] - 1s 1s/step
# 0.8260864
# 1/1 [==============================] - 1s 1s/step
# 0.7652918
# 1/1 [==============================] - 1s 1s/step
# 0.8099823
# 1/1 [==============================] - 1s 1s/step
# 0.8714517
# 1/1 [==============================] - 1s 1s/step
# 0.81545866
# 1/1 [==============================] - 2s 2s/step
# 0.49996948
# 1/1 [==============================] - 1s 1s/step
# 0.88820827
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.44916534
# 1/1 [==============================] - 2s 2s/step
# 0.7455225
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.49079132
# 1/1 [==============================] - 1s 1s/step
# 0.48410797
# 1/1 [==============================] - 2s 2s/step
# 0.49951172
# 1/1 [==============================] - 1s 1s/step
# 0.7772137
# 1/1 [==============================] - 2s 2s/step
# 0.45225525
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.49996185
# 1/1 [==============================] - 1s 1s/step
# 0.49882507
# 1/1 [==============================] - 1s 1s/step
# 0.48511505
# 1/1 [==============================] - 1s 1s/step
# 0.5068221
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.86690515
# 1/1 [==============================] - 2s 2s/step
# 0.48900604
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49967957
# 1/1 [==============================] - 3s 3s/step
# 0.5101546
# 1/1 [==============================] - 3s 3s/step
# 0.8527915
# 1/1 [==============================] - 1s 1s/step
# 0.8383574
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.7652918
# 1/1 [==============================] - 1s 1s/step
# 0.8299079
# 1/1 [==============================] - 1s 1s/step
# 0.48202515
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.7455225
# 1/1 [==============================] - 1s 1s/step
# 0.88876283
# 1/1 [==============================] - 2s 2s/step
# 0.8266572
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.89157426
# 1/1 [==============================] - 1s 1s/step
# 0.49599457
# 1/1 [==============================] - 2s 2s/step
# 0.8733691
# 1/1 [==============================] - 1s 1s/step
# 0.5265172
# 1/1 [==============================] - 2s 2s/step
# 0.49995422
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.7834246
# 1/1 [==============================] - 1s 1s/step
# 0.48215485
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.80742884
# 1/1 [==============================] - 3s 3s/step
# 0.4852829
# 1/1 [==============================] - 1s 1s/step
# 0.7834246
# 1/1 [==============================] - 1s 1s/step
# 0.49932098
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.48875427
# 1/1 [==============================] - 1s 1s/step
# 0.48631287
# 1/1 [==============================] - 1s 1s/step
# 0.84803605
# 1/1 [==============================] - 1s 1s/step
# 0.8260864
# 1/1 [==============================] - 2s 2s/step
# 0.49588776
# 1/1 [==============================] - 1s 1s/step
# 0.49988556
# 1/1 [==============================] - 1s 1s/step
# 0.7158069
# 1/1 [==============================] - 1s 1s/step
# 0.7430295
# 1/1 [==============================] - 2s 2s/step
# 0.8847068
# 1/1 [==============================] - 1s 1s/step
# 0.4573822
# 1/1 [==============================] - 2s 2s/step
# 0.8300736
# 1/1 [==============================] - 1s 1s/step
# 0.4928589
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49843597
# 1/1 [==============================] - 1s 1s/step
# 0.8260864
# 1/1 [==============================] - 2s 2s/step
# 0.44916534
# 1/1 [==============================] - 1s 1s/step
# 0.5265172
# 1/1 [==============================] - 2s 2s/step
# 0.81214833
# 1/1 [==============================] - 1s 1s/step
# 0.49891663
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.8599709
# 1/1 [==============================] - 1s 1s/step
# 0.8383508
# 1/1 [==============================] - 1s 1s/step
# 0.83658516
# 1/1 [==============================] - 1s 1s/step
# 0.50289404
# 1/1 [==============================] - 1s 1s/step
# 0.45333862
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49995422
# 1/1 [==============================] - 3s 3s/step
# 0.4998932
# 1/1 [==============================] - 2s 2s/step
# 0.4962387
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.8849783
# 1/1 [==============================] - 2s 2s/step
# 0.48505402
# 1/1 [==============================] - 2s 2s/step
# 0.80828464
# 1/1 [==============================] - 1s 1s/step
# 0.8383574
# 1/1 [==============================] - 2s 2s/step
# 0.46312714
# 1/1 [==============================] - 1s 1s/step
# 0.48386383
# 1/1 [==============================] - 2s 2s/step
# 0.89037275
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.81293094
# 1/1 [==============================] - 1s 1s/step
# 0.91019493
# 1/1 [==============================] - 1s 1s/step
# 0.7220008
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.47113037
# 1/1 [==============================] - 1s 1s/step
# 0.68880516
# 1/1 [==============================] - 2s 2s/step
# 0.49289703
# 1/1 [==============================] - 2s 2s/step
# 0.49757385
# 1/1 [==============================] - 1s 1s/step
# 0.8266572
# 1/1 [==============================] - 1s 1s/step
# 0.8599709
# 1/1 [==============================] - 1s 1s/step
# 0.4962387
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.8300736
# 1/1 [==============================] - 2s 2s/step
# 0.86747855
# 1/1 [==============================] - 1s 1s/step
# 0.8328531
# 1/1 [==============================] - 2s 2s/step
# 0.8814123
# 1/1 [==============================] - 1s 1s/step
# 0.87490976
# 1/1 [==============================] - 2s 2s/step
# 0.8260864
# 1/1 [==============================] - 1s 1s/step
# 0.4996338
# 1/1 [==============================] - 2s 2s/step
# 0.48348236
# 1/1 [==============================] - 1s 1s/step
# 0.49077606
# 1/1 [==============================] - 2s 2s/step
# 0.49933624
# 1/1 [==============================] - 1s 1s/step
# 0.49119568
# 1/1 [==============================] - 2s 2s/step
# 0.49588776
# 1/1 [==============================] - 1s 1s/step
# 0.49967957
# 1/1 [==============================] - 2s 2s/step
# 0.83710515
# 1/1 [==============================] - 1s 1s/step
# 0.80742884
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.74471474
# 1/1 [==============================] - 2s 2s/step
# 0.4996872
# 1/1 [==============================] - 1s 1s/step
# 0.48680878
# 1/1 [==============================] - 2s 2s/step
# 0.48554993
# 1/1 [==============================] - 2s 2s/step
# 0.48607635
# 1/1 [==============================] - 2s 2s/step
# 0.7382536
# 1/1 [==============================] - 2s 2s/step
# 0.847167
# 1/1 [==============================] - 2s 2s/step
# 0.79453945
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.81413054
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.8883023
# 1/1 [==============================] - 2s 2s/step
# 0.49996948
# 1/1 [==============================] - 2s 2s/step
# 0.87725556
# 1/1 [==============================] - 2s 2s/step
# 0.8257476
# 1/1 [==============================] - 1s 1s/step
# 0.8653404
# 1/1 [==============================] - 2s 2s/step
# 0.48123932
# 1/1 [==============================] - 2s 2s/step
# 0.49944305
# 1/1 [==============================] - 2s 2s/step
# 0.48671722
# 1/1 [==============================] - 1s 1s/step
# 0.49991608
# 1/1 [==============================] - 2s 2s/step
# 0.863137
# 1/1 [==============================] - 2s 2s/step
# 0.8440361
# 1/1 [==============================] - 2s 2s/step
# 0.7430295
# 1/1 [==============================] - 2s 2s/step
# 0.4884262
# 1/1 [==============================] - 2s 2s/step
# 0.48505402
# 1/1 [==============================] - 2s 2s/step
# 0.4971466
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.48317719
# 1/1 [==============================] - 2s 2s/step
# 0.8440361
# 1/1 [==============================] - 3s 3s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.45244598
# 1/1 [==============================] - 1s 1s/step
# 0.84243536
# 1/1 [==============================] - 1s 1s/step
# 0.54718584
# 1/1 [==============================] - 1s 1s/step
# 0.50561893
# 1/1 [==============================] - 1s 1s/step
# 0.4968872
# 1/1 [==============================] - 1s 1s/step
# 0.8452976
# 1/1 [==============================] - 1s 1s/step
# 0.49951172
# 1/1 [==============================] - 1s 1s/step
# 0.86965746
# 1/1 [==============================] - 1s 1s/step
# 0.68880516
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49998474
# 1/1 [==============================] - 2s 2s/step
# 0.48215485
# 1/1 [==============================] - 2s 2s/step
# 0.4913559
# 1/1 [==============================] - 2s 2s/step
# 0.49049377
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.63539726
# 1/1 [==============================] - 2s 2s/step
# 0.49993896
# 1/1 [==============================] - 2s 2s/step
# 0.557922
# 1/1 [==============================] - 2s 2s/step
# 0.68880516
# 1/1 [==============================] - 2s 2s/step
# 0.45225525
# 1/1 [==============================] - 1s 1s/step
# 0.8788139
# 1/1 [==============================] - 2s 2s/step
# 0.7725898
# 1/1 [==============================] - 2s 2s/step
# 0.63539726
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 3s 3s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.8789762
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.4884796
# 1/1 [==============================] - 2s 2s/step
# 0.7652918
# 1/1 [==============================] - 2s 2s/step
# 0.86690515
# 1/1 [==============================] - 2s 2s/step
# 0.49015808
# 1/1 [==============================] - 2s 2s/step
# 0.64280933
# 1/1 [==============================] - 1s 1s/step
# 0.45589447
# 1/1 [==============================] - 2s 2s/step
# 0.45654297
# 1/1 [==============================] - 2s 2s/step
# 0.8299079
# 1/1 [==============================] - 2s 2s/step
# 0.8714517
# 1/1 [==============================] - 2s 2s/step
# 0.48386383
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.45145416
# 1/1 [==============================] - 2s 2s/step
# 0.5265172
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.4918213
# 1/1 [==============================] - 2s 2s/step
# 0.48875427
# 1/1 [==============================] - 2s 2s/step
# 0.49082184
# 1/1 [==============================] - 1s 1s/step
# 0.49969482
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.8087648
# 1/1 [==============================] - 2s 2s/step
# 0.4842987
# 1/1 [==============================] - 2s 2s/step
# 0.4573822
# 1/1 [==============================] - 2s 2s/step
# 0.8299079
# 1/1 [==============================] - 1s 1s/step
# 0.80293477
# 1/1 [==============================] - 2s 2s/step
# 0.49942017
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.48554993
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.4884796
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.86747855
# 1/1 [==============================] - 2s 2s/step
# 0.8824872
# 1/1 [==============================] - 2s 2s/step
# 0.44916534
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.8738191
# 1/1 [==============================] - 1s 1s/step
# 0.8847068
# 1/1 [==============================] - 2s 2s/step
# 0.45128632
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.9176613
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49990845
# 1/1 [==============================] - 1s 1s/step
# 0.45372772
# 1/1 [==============================] - 2s 2s/step
# 0.49809265
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.5389915
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.8814123
# 1/1 [==============================] - 2s 2s/step
# 0.48931122
# 1/1 [==============================] - 2s 2s/step
# 0.4917221
# 1/1 [==============================] - 2s 2s/step
# 0.6867072
# 1/1 [==============================] - 1s 1s/step
# 0.7772137
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.45244598
# 1/1 [==============================] - 1s 1s/step
# 0.7778436
# 1/1 [==============================] - 2s 2s/step
# 0.4996872
# 1/1 [==============================] - 1s 1s/step
# 0.68880516
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49933624
# 1/1 [==============================] - 1s 1s/step
# 0.8799788
# 1/1 [==============================] - 2s 2s/step
# 0.81630397
# 1/1 [==============================] - 1s 1s/step
# 0.8508041
# 1/1 [==============================] - 1s 1s/step
# 0.49547577
# 1/1 [==============================] - 1s 1s/step
# 0.48631287
# 1/1 [==============================] - 1s 1s/step
# 0.557922
# 1/1 [==============================] - 2s 2s/step
# 0.48725128
# 1/1 [==============================] - 2s 2s/step
# 0.81542146
# 1/1 [==============================] - 1s 1s/step
# 0.48138428
# 1/1 [==============================] - 2s 2s/step
# 0.49998474
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.80828464
# 1/1 [==============================] - 1s 1s/step
# 0.79695976
# 1/1 [==============================] - 2s 2s/step
# 0.8564563
# 1/1 [==============================] - 1s 1s/step
# 0.49998474
# 1/1 [==============================] - 2s 2s/step
# 0.46312714
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.4493103
# 1/1 [==============================] - 3s 3s/step
# 0.48155975
# 1/1 [==============================] - 3s 3s/step
# 0.64280933
# 1/1 [==============================] - 1s 1s/step
# 0.5769037
# 1/1 [==============================] - 2s 2s/step
# 0.8564563
# 1/1 [==============================] - 1s 1s/step
# 0.45411682
# 1/1 [==============================] - 2s 2s/step
# 0.7220008
# 1/1 [==============================] - 1s 1s/step
# 0.8362863
# 1/1 [==============================] - 1s 1s/step
# 0.4902954
# 1/1 [==============================] - 1s 1s/step
# 0.8653404
# 1/1 [==============================] - 1s 1s/step
# 0.82417977
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.48554993
# 1/1 [==============================] - 1s 1s/step
# 0.7891748
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.63539726
# 1/1 [==============================] - 1s 1s/step
# 0.49154663
# 1/1 [==============================] - 2s 2s/step
# 0.5596588
# 1/1 [==============================] - 1s 1s/step
# 0.791857
# 1/1 [==============================] - 1s 1s/step
# 0.8705884
# 1/1 [==============================] - 1s 1s/step
# 0.4996872
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.8789762
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.8868301
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.4879837
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49988556
# 1/1 [==============================] - 2s 2s/step
# 0.4999771
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.45145416
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.45092773
# 1/1 [==============================] - 2s 2s/step
# 0.9171155
# 1/1 [==============================] - 1s 1s/step
# 0.49932098
# 1/1 [==============================] - 2s 2s/step
# 0.49843597
# 1/1 [==============================] - 1s 1s/step
# 0.48410797
# 1/1 [==============================] - 1s 1s/step
# 0.7772137
# 1/1 [==============================] - 1s 1s/step
# 0.85988146
# 1/1 [==============================] - 1s 1s/step
# 0.816144
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.51482433
# 1/1 [==============================] - 1s 1s/step
# 0.49964905
# 1/1 [==============================] - 2s 2s/step
# 0.8004508
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.83658516
# 1/1 [==============================] - 1s 1s/step
# 0.8222208
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.6353397
# 1/1 [==============================] - 2s 2s/step
# 0.54708886
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.4994049
# 1/1 [==============================] - 2s 2s/step
# 0.49289703
# 1/1 [==============================] - 1s 1s/step
# 0.79695976
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.48083496
# 1/1 [==============================] - 2s 2s/step
# 0.5101546
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.4875183
# 1/1 [==============================] - 2s 2s/step
# 0.4886322
# 1/1 [==============================] - 2s 2s/step
# 0.8340429
# 1/1 [==============================] - 2s 2s/step
# 0.4977417
# 1/1 [==============================] - 2s 2s/step
# 0.5425911
# 1/1 [==============================] - 2s 2s/step
# 0.7891748
# 1/1 [==============================] - 2s 2s/step
# 0.847167
# 1/1 [==============================] - 2s 2s/step
# 0.8222208
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49851227
# 1/1 [==============================] - 2s 2s/step
# 0.84637666
# 1/1 [==============================] - 1s 1s/step
# 0.5812832
# 1/1 [==============================] - 2s 2s/step
# 0.4994812
# 1/1 [==============================] - 2s 2s/step
# 0.49038696
# 1/1 [==============================] - 2s 2s/step
# 0.45411682
# 1/1 [==============================] - 2s 2s/step
# 0.840862
# 1/1 [==============================] - 1s 1s/step
# 0.48680878
# 1/1 [==============================] - 2s 2s/step
# 0.8963796
# 1/1 [==============================] - 2s 2s/step
# 0.54383624
# 1/1 [==============================] - 2s 2s/step
# 0.49015808
# 1/1 [==============================] - 2s 2s/step
# 0.8087648
# 1/1 [==============================] - 2s 2s/step
# 0.48680878
# 1/1 [==============================] - 1s 1s/step
# 0.88791883
# 1/1 [==============================] - 2s 2s/step
# 0.49713898
# 1/1 [==============================] - 2s 2s/step
# 0.49951172
# 1/1 [==============================] - 2s 2s/step
# 0.4530716
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.49978638
# 1/1 [==============================] - 2s 2s/step
# 0.4994812
# 1/1 [==============================] - 1s 1s/step
# 0.49040985
# 1/1 [==============================] - 2s 2s/step
# 0.86690515
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.86125714
# 1/1 [==============================] - 1s 1s/step
# 0.49969482
# 1/1 [==============================] - 1s 1s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.68880516
# 1/1 [==============================] - 2s 2s/step
# 0.8248383
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.48875427
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.45787048
# 1/1 [==============================] - 2s 2s/step
# 0.48377228
# 1/1 [==============================] - 2s 2s/step
# 0.87490976
# 1/1 [==============================] - 1s 1s/step
# 0.8715693
# 1/1 [==============================] - 2s 2s/step
# 0.71617347
# 1/1 [==============================] - 2s 2s/step
# 0.4998932
# 1/1 [==============================] - 2s 2s/step
# 0.49990845
# 1/1 [==============================] - 2s 2s/step
# 0.8849543
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.48725128
# 1/1 [==============================] - 2s 2s/step
# 0.49904633
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.87706494
# 1/1 [==============================] - 2s 2s/step
# 0.48239136
# 1/1 [==============================] - 2s 2s/step
# 0.45333862
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 3s 3s/step
# 0.4885025
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.8383574
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.816144
# 1/1 [==============================] - 2s 2s/step
# 0.45589447
# 1/1 [==============================] - 2s 2s/step
# 0.49988556
# 1/1 [==============================] - 2s 2s/step
# 0.48883057
# 1/1 [==============================] - 2s 2s/step
# 0.7891748
# 1/1 [==============================] - 2s 2s/step
# 0.83190095
# 1/1 [==============================] - 2s 2s/step
# 0.48680878
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.63539726
# 1/1 [==============================] - 2s 2s/step
# 0.49149323
# 1/1 [==============================] - 2s 2s/step
# 0.45411682
# 1/1 [==============================] - 2s 2s/step
# 0.50865525
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.4873886
# 1/1 [==============================] - 2s 2s/step
# 0.840862
# 1/1 [==============================] - 2s 2s/step
# 0.8260864
# 1/1 [==============================] - 2s 2s/step
# 0.7890912
# 1/1 [==============================] - 2s 2s/step
# 0.8257476
# 1/1 [==============================] - 2s 2s/step
# 0.48884583
# 1/1 [==============================] - 2s 2s/step
# 0.50498396
# 1/1 [==============================] - 2s 2s/step
# 0.91019493
# 1/1 [==============================] - 2s 2s/step
# 0.54708886
# 1/1 [==============================] - 2s 2s/step
# 0.8319551
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.86747855
# 1/1 [==============================] - 2s 2s/step
# 0.7158069
# 1/1 [==============================] - 2s 2s/step
# 0.48680878
# 1/1 [==============================] - 2s 2s/step
# 0.8296066
# 1/1 [==============================] - 2s 2s/step
# 0.816144
# 1/1 [==============================] - 2s 2s/step
# 0.4852829
# 1/1 [==============================] - 1s 1s/step
# 0.75066006
# 1/1 [==============================] - 2s 2s/step
# 0.4879837
# 1/1 [==============================] - 1s 1s/step
# 0.88339883
# 1/1 [==============================] - 2s 2s/step
# 0.4573822
# 1/1 [==============================] - 2s 2s/step
# 0.6353397
# 1/1 [==============================] - 2s 2s/step
# 0.7455225
# 1/1 [==============================] - 1s 1s/step
# 0.74471474
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 2s 2s/step
# 0.8537477
# 1/1 [==============================] - 2s 2s/step
# 0.4977417
# 1/1 [==============================] - 2s 2s/step
# 0.70119464
# 1/1 [==============================] - 2s 2s/step
# 0.7778436
# 1/1 [==============================] - 2s 2s/step
# 0.49957275
# 1/1 [==============================] - 2s 2s/step
# 0.83978975
# 1/1 [==============================] - 2s 2s/step
# 0.54718584
# 1/1 [==============================] - 2s 2s/step
# 0.8268995
# 1/1 [==============================] - 2s 2s/step
# 1.0
# 1/1 [==============================] - 1s 1s/step
# 0.828696
# 1/1 [==============================] - 2s 2s/step
# 0.49149323
# 1/1 [==============================] - 2s 2s/step
# 0.7772137
# 1/1 [==============================] - 2s 2s/step
# 0.49038696
# 1/1 [==============================] - 2s 2s/step
# 0.48386383
# 1/1 [==============================] - 2s 2s/step
# 1.0
# Mean IoU is:  [0.64297634]
