# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30-1111-.unet-no.augonvalidation-5e-5-diceloss-recurrentdropout0.2-CONVLSTM-3blocks-relu.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
                np.array(
                    [
                        img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_img_file_names
                    ]
                )
                / 255
            )
        self.masks = (
                np.array(
                    [
                      img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_mask_file_names
                    ]
                )
                / 255
                > 0.5
            ).astype(float)

        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2,interpolation='bilinear',fill_mode='reflect'),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
            if self.index >= len(self.imgs) - self.timesteps - self.batch_size:
                self.index = 0
                raise StopIteration
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    shuffle=True,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    shuffle=True,

    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()
for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)
conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2)(conv5)

up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv4])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)


up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv3])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)

up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv2])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv1])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

x=layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2)(x)
x=tf.expand_dims(x,axis=1)
out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_4[0][0]']
#  buted)                          16)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_5[0][0]']
#  buted)                          16)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_11 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_8[0][0]']
#  ibuted)                         32)
#
#  time_distributed_12 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_11[0][0]']
#  ibuted)                         32)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_12[0][0]']
#  ibuted)                        2)
#
#  time_distributed_14 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_14[0][0]']
#  ibuted)                        4)
#
#  time_distributed_18 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_15[0][0]']
#  ibuted)                        4)
#
#  time_distributed_19 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_18[0][0]']
#  ibuted)                        4)
#
#  time_distributed_20 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_19[0][0]']
#  ibuted)                        4)
#
#  time_distributed_21 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_20[0][0]']
#  ibuted)                        28)
#
#  time_distributed_22 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_21[0][0]']
#  ibuted)                        28)
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_22[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_26[0][0]']
#  ibuted)                        28)
#
#  time_distributed_28 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_27[0][0]']
#  ibuted)                        56)
#
#  time_distributed_29 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_28[0][0]']
#  ibuted)                        56)
#
#  time_distributed_32 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_29[0][0]']
#  ibuted)                        56)
#
#  time_distributed_33 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_32[0][0]']
#  ibuted)                        56)
#
#  conv_lstm2d (ConvLSTM2D)       (None, 3, 16, 16, 2  4719616     ['time_distributed_33[0][0]']
#                                 56)
#
#  time_distributed_34 (TimeDistr  (None, 3, 32, 32, 1  295040     ['conv_lstm2d[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_34[0][0]',
#                                 56)                               'time_distributed_26[0][0]']
#
#  time_distributed_35 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_36 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_35[0][0]']
#  ibuted)                        28)
#
#  time_distributed_37 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_36[0][0]']
#  ibuted)                        28)
#
#  time_distributed_38 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_37[0][0]']
#  ibuted)                        28)
#
#  time_distributed_39 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_38[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_39[0][0]',
#                                 28)                               'time_distributed_19[0][0]']
#
#  time_distributed_40 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_41 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_40[0][0]']
#  ibuted)                        4)
#
#  time_distributed_42 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_41[0][0]']
#  ibuted)                        4)
#
#  time_distributed_43 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_42[0][0]']
#  ibuted)                        4)
#
#  time_distributed_44 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_43[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_44[0][0]',
#                                  64)                              'time_distributed_12[0][0]']
#
#  time_distributed_45 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_46 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_45[0][0]']
#  ibuted)                         32)
#
#  time_distributed_47 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_46[0][0]']
#  ibuted)                         32)
#
#  time_distributed_48 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_47[0][0]']
#  ibuted)                         32)
#
#  time_distributed_49 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_48[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_49[0][0]',
#                                  32)                              'time_distributed_5[0][0]']
#
#  time_distributed_50 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_51 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_50[0][0]']
#  ibuted)                         16)
#
#  time_distributed_52 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_51[0][0]']
#  ibuted)                         16)
#
#  time_distributed_53 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_52[0][0]']
#  ibuted)                         16)
#
#  conv_lstm2d_1 (ConvLSTM2D)     (None, 256, 256, 16  18496       ['time_distributed_53[0][0]']
#                                 )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['conv_lstm2d_1[0][0]']
#                                  16)
#
#  conv2d_27 (Conv2D)             (None, 1, 256, 256,  17          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 7,097,537
# Trainable params: 7,095,073
# Non-trainable params: 2,464
# __________________________________________________________________________________________________

# %%
from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.75
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.60
    return K.pow((1-pt_1), gamma)

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 248/248 [==============================] - 298s 1s/step - loss: 0.7872 - dice_coefficient: 0.2128 - binary_accuracy: 0.7364 - val_loss: 0.6876 - val_dice_coefficient: 0.3124 - val_binary_accuracy: 0.9453
# Epoch 2/30
# 248/248 [==============================] - 276s 1s/step - loss: 0.4799 - dice_coefficient: 0.5201 - binary_accuracy: 0.9790 - val_loss: 0.6611 - val_dice_coefficient: 0.3389 - val_binary_accuracy: 0.9152
# Epoch 3/30
# 248/248 [==============================] - 275s 1s/step - loss: 0.4219 - dice_coefficient: 0.5781 - binary_accuracy: 0.9814 - val_loss: 0.4058 - val_dice_coefficient: 0.5942 - val_binary_accuracy: 0.9764
# Epoch 4/30
# 248/248 [==============================] - 275s 1s/step - loss: 0.3845 - dice_coefficient: 0.6155 - binary_accuracy: 0.9827 - val_loss: 0.4188 - val_dice_coefficient: 0.5812 - val_binary_accuracy: 0.9808
# Epoch 5/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.3655 - dice_coefficient: 0.6345 - binary_accuracy: 0.9835 - val_loss: 0.5050 - val_dice_coefficient: 0.4950 - val_binary_accuracy: 0.9814
# Epoch 6/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.3588 - dice_coefficient: 0.6412 - binary_accuracy: 0.9850 - val_loss: 0.4373 - val_dice_coefficient: 0.5627 - val_binary_accuracy: 0.9749
# Epoch 7/30
# 248/248 [==============================] - 275s 1s/step - loss: 0.3200 - dice_coefficient: 0.6800 - binary_accuracy: 0.9859 - val_loss: 0.3668 - val_dice_coefficient: 0.6332 - val_binary_accuracy: 0.9847
# Epoch 8/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2997 - dice_coefficient: 0.7003 - binary_accuracy: 0.9867 - val_loss: 0.4819 - val_dice_coefficient: 0.5181 - val_binary_accuracy: 0.9801
# Epoch 9/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2899 - dice_coefficient: 0.7101 - binary_accuracy: 0.9862 - val_loss: 0.4809 - val_dice_coefficient: 0.5191 - val_binary_accuracy: 0.9809
# Epoch 10/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2689 - dice_coefficient: 0.7311 - binary_accuracy: 0.9873 - val_loss: 0.4385 - val_dice_coefficient: 0.5615 - val_binary_accuracy: 0.9792
# Epoch 11/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2667 - dice_coefficient: 0.7333 - binary_accuracy: 0.9873 - val_loss: 0.4290 - val_dice_coefficient: 0.5710 - val_binary_accuracy: 0.9808
# Epoch 12/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2477 - dice_coefficient: 0.7523 - binary_accuracy: 0.9880 - val_loss: 0.4502 - val_dice_coefficient: 0.5498 - val_binary_accuracy: 0.9746
# Epoch 13/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2475 - dice_coefficient: 0.7525 - binary_accuracy: 0.9886 - val_loss: 0.4731 - val_dice_coefficient: 0.5269 - val_binary_accuracy: 0.9723
# Epoch 14/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2420 - dice_coefficient: 0.7580 - binary_accuracy: 0.9882 - val_loss: 0.4236 - val_dice_coefficient: 0.5764 - val_binary_accuracy: 0.9748
# Epoch 15/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2335 - dice_coefficient: 0.7665 - binary_accuracy: 0.9885 - val_loss: 0.4084 - val_dice_coefficient: 0.5916 - val_binary_accuracy: 0.9782
# Epoch 16/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2179 - dice_coefficient: 0.7821 - binary_accuracy: 0.9886 - val_loss: 0.3973 - val_dice_coefficient: 0.6027 - val_binary_accuracy: 0.9830
# Epoch 17/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2154 - dice_coefficient: 0.7846 - binary_accuracy: 0.9888 - val_loss: 0.4936 - val_dice_coefficient: 0.5064 - val_binary_accuracy: 0.9711
# Epoch 18/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2135 - dice_coefficient: 0.7865 - binary_accuracy: 0.9887 - val_loss: 0.3257 - val_dice_coefficient: 0.6743 - val_binary_accuracy: 0.9847
# Epoch 19/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2233 - dice_coefficient: 0.7767 - binary_accuracy: 0.9888 - val_loss: 0.3676 - val_dice_coefficient: 0.6324 - val_binary_accuracy: 0.9787
# Epoch 20/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2022 - dice_coefficient: 0.7978 - binary_accuracy: 0.9893 - val_loss: 0.3701 - val_dice_coefficient: 0.6299 - val_binary_accuracy: 0.9803
# Epoch 21/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.2074 - dice_coefficient: 0.7926 - binary_accuracy: 0.9895 - val_loss: 0.3739 - val_dice_coefficient: 0.6261 - val_binary_accuracy: 0.9838
# Epoch 22/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.1961 - dice_coefficient: 0.8039 - binary_accuracy: 0.9896 - val_loss: 0.3490 - val_dice_coefficient: 0.6510 - val_binary_accuracy: 0.9834
# Epoch 23/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.1914 - dice_coefficient: 0.8086 - binary_accuracy: 0.9896 - val_loss: 0.3857 - val_dice_coefficient: 0.6143 - val_binary_accuracy: 0.9836
# Epoch 24/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.1959 - dice_coefficient: 0.8041 - binary_accuracy: 0.9893 - val_loss: 0.3866 - val_dice_coefficient: 0.6134 - val_binary_accuracy: 0.9797
# Epoch 25/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.1886 - dice_coefficient: 0.8114 - binary_accuracy: 0.9901 - val_loss: 0.3666 - val_dice_coefficient: 0.6334 - val_binary_accuracy: 0.9824
# Epoch 26/30
# 248/248 [==============================] - 273s 1s/step - loss: 0.1929 - dice_coefficient: 0.8071 - binary_accuracy: 0.9897 - val_loss: 0.4297 - val_dice_coefficient: 0.5703 - val_binary_accuracy: 0.9708
# Epoch 27/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.1909 - dice_coefficient: 0.8091 - binary_accuracy: 0.9898 - val_loss: 0.3972 - val_dice_coefficient: 0.6028 - val_binary_accuracy: 0.9784
# Epoch 28/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.1783 - dice_coefficient: 0.8217 - binary_accuracy: 0.9899 - val_loss: 0.4220 - val_dice_coefficient: 0.5780 - val_binary_accuracy: 0.9782
# Epoch 29/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.1879 - dice_coefficient: 0.8121 - binary_accuracy: 0.9899 - val_loss: 0.3731 - val_dice_coefficient: 0.6269 - val_binary_accuracy: 0.9824
# Epoch 30/30
# 248/248 [==============================] - 274s 1s/step - loss: 0.1853 - dice_coefficient: 0.8147 - binary_accuracy: 0.9900 - val_loss: 0.3521 - val_dice_coefficient: 0.6479 - val_binary_accuracy: 0.9816

# %%
model.save('/gdrive/MyDrive/Sensor30-1111-.unet-no.augonvalidation-5e-5-diceloss-recurrentdropout0.2-CONVLSTM-3blocks-relu.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30-1111-.unet-no.augonvalidation-5e-5-diceloss-recurrentdropout0.2-CONVLSTM-3blocks-relu.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
                np.array(
                    [
                        img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_img_file_names
                    ]
                )
                / 255
            )
        self.masks = (
                np.array(
                    [
                      img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_mask_file_names
                    ]
                )
                / 255
                > 0.5
            ).astype(float)

        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3,interpolation='bilinear',fill_mode='nearest'),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
            if self.index >= len(self.imgs) - self.timesteps - self.batch_size:
                self.index = 0
                raise StopIteration
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,

)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.85862076

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)

    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    

mean_IoU = df.mean().values
boxplot = df.boxplot(grid=False, vert=True,  # vertical box alignment
                     patch_artist=False)  # fill with color)
std=df.std()
print('number of total masks is: ', len(IoU_values))

print("Mean IoU is: ", mean_IoU)
print("standard deviation is ",std)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 0.63190067
# 1/1 [==============================] - 0s 20ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.63901097
# 1/1 [==============================] - 0s 23ms/step
# 0.78423166
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.83941555
# 1/1 [==============================] - 0s 34ms/step
# 0.48576355
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.7027122
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.73123455
# 1/1 [==============================] - 0s 21ms/step
# 0.8188259
# 1/1 [==============================] - 0s 22ms/step
# 0.6393694
# 1/1 [==============================] - 0s 21ms/step
# 0.73123455
# 1/1 [==============================] - 0s 21ms/step
# 0.80028033
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 37ms/step
# 0.56753606
# 1/1 [==============================] - 0s 21ms/step
# 0.49427795
# 1/1 [==============================] - 0s 21ms/step
# 0.46623993
# 1/1 [==============================] - 0s 27ms/step
# 0.48603058
# 1/1 [==============================] - 0s 21ms/step
# 0.4969101
# 1/1 [==============================] - 0s 24ms/step
# 0.80723494
# 1/1 [==============================] - 0s 36ms/step
# 0.76178014
# 1/1 [==============================] - 0s 29ms/step
# 0.48727417
# 1/1 [==============================] - 0s 20ms/step
# 0.46285248
# 1/1 [==============================] - 0s 39ms/step
# 0.49772644
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.48449707
# 1/1 [==============================] - 0s 23ms/step
# 0.48213196
# 1/1 [==============================] - 0s 24ms/step
# 0.8131791
# 1/1 [==============================] - 0s 28ms/step
# 0.7590735
# 1/1 [==============================] - 0s 24ms/step
# 0.7992481
# 1/1 [==============================] - 0s 26ms/step
# 0.5074417
# 1/1 [==============================] - 0s 21ms/step
# 0.8582076
# 1/1 [==============================] - 0s 22ms/step
# 0.49993134
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.87428176
# 1/1 [==============================] - 0s 21ms/step
# 0.63190067
# 1/1 [==============================] - 0s 24ms/step
# 0.4958954
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7992481
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48220062
# 1/1 [==============================] - 0s 22ms/step
# 0.66044575
# 1/1 [==============================] - 0s 23ms/step
# 0.8113526
# 1/1 [==============================] - 0s 31ms/step
# 0.49785614
# 1/1 [==============================] - 0s 26ms/step
# 0.67355114
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.49620056
# 1/1 [==============================] - 0s 26ms/step
# 0.4937744
# 1/1 [==============================] - 0s 25ms/step
# 0.8618153
# 1/1 [==============================] - 0s 25ms/step
# 0.4958954
# 1/1 [==============================] - 0s 22ms/step
# 0.4916153
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.46285248
# 1/1 [==============================] - 0s 22ms/step
# 0.49032593
# 1/1 [==============================] - 0s 24ms/step
# 0.86484444
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.8188259
# 1/1 [==============================] - 0s 27ms/step
# 0.48215485
# 1/1 [==============================] - 0s 24ms/step
# 0.49892426
# 1/1 [==============================] - 0s 21ms/step
# 0.49025726
# 1/1 [==============================] - 0s 23ms/step
# 0.65602416
# 1/1 [==============================] - 0s 24ms/step
# 0.6815935
# 1/1 [==============================] - 0s 22ms/step
# 0.6489607
# 1/1 [==============================] - 0s 22ms/step
# 0.66387004
# 1/1 [==============================] - 0s 23ms/step
# 0.48329926
# 1/1 [==============================] - 0s 25ms/step
# 0.48242188
# 1/1 [==============================] - 0s 24ms/step
# 0.69959944
# 1/1 [==============================] - 0s 21ms/step
# 0.75640047
# 1/1 [==============================] - 0s 23ms/step
# 0.48317719
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.83941555
# 1/1 [==============================] - 0s 21ms/step
# 0.7628052
# 1/1 [==============================] - 0s 23ms/step
# 0.50726336
# 1/1 [==============================] - 0s 22ms/step
# 0.48220825
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.48329926
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.84513754
# 1/1 [==============================] - 0s 23ms/step
# 0.68894446
# 1/1 [==============================] - 0s 22ms/step
# 0.49032593
# 1/1 [==============================] - 0s 21ms/step
# 0.49983978
# 1/1 [==============================] - 0s 23ms/step
# 0.86012566
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.8398129
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.8438353
# 1/1 [==============================] - 0s 30ms/step
# 0.49785614
# 1/1 [==============================] - 0s 25ms/step
# 0.8716719
# 1/1 [==============================] - 0s 23ms/step
# 0.8563093
# 1/1 [==============================] - 0s 25ms/step
# 0.85548633
# 1/1 [==============================] - 0s 23ms/step
# 0.74889374
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.8577455
# 1/1 [==============================] - 0s 31ms/step
# 0.8599546
# 1/1 [==============================] - 0s 25ms/step
# 0.48207855
# 1/1 [==============================] - 0s 26ms/step
# 0.80723494
# 1/1 [==============================] - 0s 27ms/step
# 0.87625134
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8594351
# 1/1 [==============================] - 0s 22ms/step
# 0.81895113
# 1/1 [==============================] - 0s 24ms/step
# 0.741705
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.49629974
# number of total masks is:  477
# Mean IoU is:  [0.6531243]
# standard deviation is  IoU    0.15315
# dtype: float32
