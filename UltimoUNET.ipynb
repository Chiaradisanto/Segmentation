# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/UltimoUNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
batch_size=16

# %%
from matplotlib import pyplot as plt
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline
import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
#from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, add, concatenate,UpSampling2D,ZeroPadding2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_img_path = "/gdrive/MyDrive/TESI/outputHU/train/train_images"
train_mask_path = "/gdrive/MyDrive/TESI/outputHU/train/train_masks"

val_img_path = "/gdrive/MyDrive/TESI/outputHU/train/val_images"
val_mask_path = "/gdrive/MyDrive/TESI/outputHU/train/val_masks"

# %%
seed=24
from keras.preprocessing.image import ImageDataGenerator

img_data_gen_args = dict(rescale=1/255.,
                     
                     width_shift_range=0.3,
                     height_shift_range=0.3,
                     shear_range=0.5,
                     
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect')

mask_data_gen_args = dict( rescale=1/255.,
                     
                     width_shift_range=0.3,
                     height_shift_range=0.3,
                     shear_range=0.5,
                     
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect'
                     
                     ) #Binarize the output again. 

image_data_generator = ImageDataGenerator(**img_data_gen_args)
#image_data_generator.fit(X_train, augment=True, seed=seed)

# %%
image_data_generator = ImageDataGenerator(**img_data_gen_args)
image_generator = image_data_generator.flow_from_directory(train_img_path, 
                                                           seed=seed, 
                                                           batch_size=batch_size,
                                                           color_mode = 'grayscale',
                                                           
                                                           target_size=(512,512),
                                                       
                                                           class_mode=None)  #Very important to set this otherwise it returns multiple numpy arrays 
                                                                            #thinking class mode is binary.

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
mask_generator = mask_data_generator.flow_from_directory(train_mask_path, 
                                                         seed=seed, 
                                                         batch_size=batch_size,
                                                         color_mode = 'grayscale',
                                                       
                                                         target_size=(512,512)  , #Read masks in grayscale
                                                         class_mode=None)


valid_img_generator = image_data_generator.flow_from_directory(val_img_path, 
                                                               seed=seed, 
                                                               batch_size=batch_size, 
                                                               color_mode = 'grayscale', 
                                                               
                                                               target_size=(512,512),
                                                               class_mode=None) #Default batch size 32, if not specified here
valid_mask_generator = mask_data_generator.flow_from_directory(val_mask_path, 
                                                               seed=seed, 
                                                               batch_size=batch_size, 
                                                               target_size=(512,512),
                                                               
                                                               color_mode = 'grayscale',   #Read masks in grayscale
                                                               class_mode=None)  #Default batch size 32, if not specified here


train_generator = zip(image_generator, mask_generator)
val_generator = zip(valid_img_generator, valid_mask_generator)
# Out:
# Found 2942 images belonging to 1 classes.
# Found 2942 images belonging to 1 classes.
# Found 318 images belonging to 1 classes.
# Found 318 images belonging to 1 classes.

# %%
x, y = train_generator.__next__()

for i in range(0,16):
    image = x[i,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x, y = val_generator.__next__()

for i in range(0,16):
    image = x[i,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.max()
# Out:
# 1.0

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/TESI/outputHU/train/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/TESI/outputHU/train/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

IMG_HEIGHT = x.shape[1]
IMG_WIDTH  = x.shape[2]
IMG_CHANNELS = x.shape[3]
input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
print(input_shape)
# Out:
# (512, 512, 1)

# %%
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1= tf.keras.layers.BatchNormalization()(c1)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
c1= tf.keras.layers.BatchNormalization()(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2= tf.keras.layers.BatchNormalization()(c2)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
c2= tf.keras.layers.BatchNormalization()(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3= tf.keras.layers.BatchNormalization()(c3)

c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
c3= tf.keras.layers.BatchNormalization()(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4= tf.keras.layers.BatchNormalization()(c4)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
c4= tf.keras.layers.BatchNormalization()(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5= tf.keras.layers.BatchNormalization()(c5)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
c5= tf.keras.layers.BatchNormalization()(c5)
#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

# %%
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 512, 512, 16  160         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 512, 512, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  dropout_9 (Dropout)            (None, 512, 512, 16  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 512, 512, 16  2320        ['dropout_9[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 512, 512, 16  64         ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 16  0          ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  dropout_10 (Dropout)           (None, 256, 256, 32  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 32  9248        ['dropout_10[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 32  128        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 32  0          ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d_5[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 64  256        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  dropout_11 (Dropout)           (None, 128, 128, 64  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 64  36928       ['dropout_11[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 64  256        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  dropout_12 (Dropout)           (None, 64, 64, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 128)  147584      ['dropout_12[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_17[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  dropout_13 (Dropout)           (None, 32, 32, 256)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 256)  590080      ['dropout_13[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 128)  131200     ['batch_normalization_19[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_4[0][0]']
#
#  dropout_14 (Dropout)           (None, 64, 64, 128)  0           ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 128)  147584      ['dropout_14[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 64  32832      ['conv2d_30[0][0]']
#  spose)                         )
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_5[0][0]',
#                                 8)                                'batch_normalization_15[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_5[0][0]']
#                                 )
#
#  dropout_15 (Dropout)           (None, 128, 128, 64  0           ['conv2d_31[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 64  36928       ['dropout_15[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 32  8224       ['conv2d_32[0][0]']
#  spose)                         )
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_6[0][0]',
#                                 )                                 'batch_normalization_13[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_6[0][0]']
#                                 )
#
#  dropout_16 (Dropout)           (None, 256, 256, 32  0           ['conv2d_33[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 32  9248        ['dropout_16[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 16  2064       ['conv2d_34[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 512, 512, 32  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'batch_normalization_11[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 512, 512, 16  4624        ['concatenate_7[0][0]']
#                                 )
#
#  dropout_17 (Dropout)           (None, 512, 512, 16  0           ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 512, 512, 16  2320        ['dropout_17[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 512, 512, 1)  17          ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 1,944,785
# Trainable params: 1,942,801
# Non-trainable params: 1,984
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)

# %%
LR = 0.00001
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics = ['Accuracy', 'Precision', 'Recall',  dice_coefficient ]

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
history=model.fit(train_generator,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_generator,
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 183/183 [==============================] - 164s 884ms/step - loss: 0.9479 - Accuracy: 0.7464 - precision: 0.0538 - recall: 0.4355 - dice_coefficient: 0.0522 - val_loss: 0.9721 - val_Accuracy: 0.2769 - val_precision: 0.0214 - val_recall: 0.7312 - val_dice_coefficient: 0.0279
# Epoch 2/30
# 183/183 [==============================] - 160s 874ms/step - loss: 0.8163 - Accuracy: 0.8327 - precision: 0.1135 - recall: 0.6303 - dice_coefficient: 0.1837 - val_loss: 0.9438 - val_Accuracy: 0.6086 - val_precision: 0.0504 - val_recall: 0.9251 - val_dice_coefficient: 0.0562
# 183/183 [==============================] - 158s 862ms/step - loss: 0.3664 - Accuracy: 0.9735 - precision: 0.6747 - recall: 0.5787 - dice_coefficient: 0.6336 - val_loss: 0.4720 - val_Accuracy: 0.9786 - val_precision: 0.7105 - val_recall: 0.4537 - val_dice_coefficient: 0.5276
# Epoch 24/30
# 183/183 [==============================] - 157s 862ms/step - loss: 0.3695 - Accuracy: 0.9736 - precision: 0.6729 - recall: 0.5776 - dice_coefficient: 0.6304 - val_loss: 0.4622 - val_Accuracy: 0.9782 - val_precision: 0.7023 - val_recall: 0.4697 - val_dice_coefficient: 0.5375
# Epoch 25/30
# 183/183 [==============================] - 157s 861ms/step - loss: 0.3604 - Accuracy: 0.9736 - precision: 0.6918 - recall: 0.5762 - dice_coefficient: 0.6397 - val_loss: 0.4744 - val_Accuracy: 0.9772 - val_precision: 0.6715 - val_recall: 0.5105 - val_dice_coefficient: 0.5247
# Epoch 26/30
# 183/183 [==============================] - 157s 862ms/step - loss: 0.3675 - Accuracy: 0.9731 - precision: 0.6754 - recall: 0.5795 - dice_coefficient: 0.6324 - val_loss: 0.5007 - val_Accuracy: 0.9781 - val_precision: 0.7001 - val_recall: 0.4174 - val_dice_coefficient: 0.4992
# Epoch 27/30
# 183/183 [==============================] - 158s 862ms/step - loss: 0.3547 - Accuracy: 0.9738 - precision: 0.6895 - recall: 0.5790 - dice_coefficient: 0.6452 - val_loss: 0.4663 - val_Accuracy: 0.9775 - val_precision: 0.6825 - val_recall: 0.4831 - val_dice_coefficient: 0.5342
# Epoch 28/30
# 183/183 [==============================] - 158s 865ms/step - loss: 0.3491 - Accuracy: 0.9744 - precision: 0.6932 - recall: 0.5856 - dice_coefficient: 0.6509 - val_loss: 0.4899 - val_Accuracy: 0.9778 - val_precision: 0.6926 - val_recall: 0.4396 - val_dice_coefficient: 0.5101
# Epoch 29/30
# 183/183 [==============================] - 158s 862ms/step - loss: 0.3491 - Accuracy: 0.9735 - precision: 0.6917 - recall: 0.5855 - dice_coefficient: 0.6510 - val_loss: 0.4882 - val_Accuracy: 0.9780 - val_precision: 0.6799 - val_recall: 0.4365 - val_dice_coefficient: 0.5122
# Epoch 30/30
# 183/183 [==============================] - 159s 868ms/step - loss: 0.3491 - Accuracy: 0.9736 - precision: 0.6913 - recall: 0.5851 - dice_coefficient: 0.6509 - val_loss: 0.4929 - val_Accuracy: 0.9772 - val_precision: 0.6914 - val_recall: 0.4205 - val_dice_coefficient: 0.5066

# %%
model.save('/gdrive/MyDrive/unetHU.h5')

# %%
###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['Accuracy']
val_acc = history.history['val_Accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/unetHU.h5", compile=False)

# %%
test_image_batch, test_mask_batch = val_generator.__next__()

# %%
a = valid_img_generator.next()
b = valid_mask_generator.next()

# %%
for i in range(0,5):
    image = a[i]
    mask = b[i]
    plt.subplot(1,2,1)
    plt.axis('off')
    plt.imshow(image[:,:,0], cmap='gray')
    plt.subplot(1,2,2)
    plt.axis('off')
    plt.imshow(mask[:,:,0],cmap='gray')
    plt.show()

# %%
# Out:
# 512

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.56930953

# %%
 
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 0.49895096
# 0.6907151
# 0.6546918
# 1.0
# 0.56930953
# 0.49865532
# 0.5019022
# 1.0
# 1.0
# 0.5534443
# 0.5686083
# 0.5498243
# 0.49996758
# 0.75426257
# 1.0
# 0.68346566
# Mean IoU is:  [0.5853165]
