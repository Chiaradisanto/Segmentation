# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor40.unet-2610-noaugonvalidation-5e-5-roiadjusted-Randomrotation0.3-recurrentdropout0.2-batch12-2blocks-basso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3,interpolation="bilinear",fill_mode="reflect"),


            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))

x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu')) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv5)

up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv4])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)


up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv3])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv2])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv1])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)
out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_44 (TimeDistr  (None, 3, 256, 256,  160        ['input_2[0][0]']
#  ibuted)                         16)
#
#  time_distributed_45 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_44[0][0]']
#  ibuted)                         16)
#
#  time_distributed_46 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_45[0][0]']
#  ibuted)                         16)
#
#  time_distributed_47 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_46[0][0]']
#  ibuted)                         16)
#
#  time_distributed_48 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_47[0][0]']
#  ibuted)                         16)
#
#  time_distributed_49 (TimeDistr  (None, 3, 128, 128,  4640       ['time_distributed_48[0][0]']
#  ibuted)                         32)
#
#  time_distributed_50 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_49[0][0]']
#  ibuted)                         32)
#
#  time_distributed_51 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_50[0][0]']
#  ibuted)                         32)
#
#  time_distributed_52 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_51[0][0]']
#  ibuted)                         32)
#
#  time_distributed_53 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_52[0][0]']
#  ibuted)                        2)
#
#  time_distributed_54 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_53[0][0]']
#  ibuted)                        4)
#
#  time_distributed_55 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_54[0][0]']
#  ibuted)                        4)
#
#  time_distributed_56 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_55[0][0]']
#  ibuted)                        4)
#
#  time_distributed_57 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_56[0][0]']
#  ibuted)                        4)
#
#  time_distributed_58 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_57[0][0]']
#  ibuted)                        4)
#
#  time_distributed_59 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_58[0][0]']
#  ibuted)                        28)
#
#  time_distributed_60 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_59[0][0]']
#  ibuted)                        28)
#
#  time_distributed_61 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_60[0][0]']
#  ibuted)                        28)
#
#  time_distributed_62 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_61[0][0]']
#  ibuted)                        28)
#
#  time_distributed_63 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_62[0][0]']
#  ibuted)                        28)
#
#  time_distributed_64 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_63[0][0]']
#  ibuted)                        56)
#
#  time_distributed_65 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_64[0][0]']
#  ibuted)                        56)
#
#  time_distributed_66 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_65[0][0]']
#  ibuted)                        56)
#
#  time_distributed_67 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_66[0][0]']
#  ibuted)                        56)
#
#  bidirectional_2 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_67[0][0]']
#  )                              12)
#
#  time_distributed_68 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional_2[0][0]']
#  ibuted)                        28)
#
#  concatenate_4 (Concatenate)    (None, 3, 32, 32, 2  0           ['time_distributed_68[0][0]',
#                                 56)                               'time_distributed_62[0][0]']
#
#  time_distributed_69 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate_4[0][0]']
#  ibuted)                        28)
#
#  time_distributed_70 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_69[0][0]']
#  ibuted)                        28)
#
#  time_distributed_71 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_70[0][0]']
#  ibuted)                        28)
#
#  time_distributed_72 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_71[0][0]']
#  ibuted)                        28)
#
#  time_distributed_73 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_72[0][0]']
#  ibuted)                        4)
#
#  concatenate_5 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_73[0][0]',
#                                 28)                               'time_distributed_57[0][0]']
#
#  time_distributed_74 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_5[0][0]']
#  ibuted)                        4)
#
#  time_distributed_75 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_74[0][0]']
#  ibuted)                        4)
#
#  time_distributed_76 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_75[0][0]']
#  ibuted)                        4)
#
#  time_distributed_77 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_76[0][0]']
#  ibuted)                        4)
#
#  time_distributed_78 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_77[0][0]']
#  ibuted)                         32)
#
#  concatenate_6 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_78[0][0]',
#                                  64)                              'time_distributed_52[0][0]']
#
#  time_distributed_79 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_6[0][0]']
#  ibuted)                         32)
#
#  time_distributed_80 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_79[0][0]']
#  ibuted)                         32)
#
#  time_distributed_81 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_80[0][0]']
#  ibuted)                         32)
#
#  time_distributed_82 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_81[0][0]']
#  ibuted)                         32)
#
#  time_distributed_83 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_82[0][0]']
#  ibuted)                         16)
#
#  concatenate_7 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_83[0][0]',
#                                  32)                              'time_distributed_47[0][0]']
#
#  time_distributed_84 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_7[0][0]']
#  ibuted)                         16)
#
#  time_distributed_85 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_84[0][0]']
#  ibuted)                         16)
#
#  time_distributed_86 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_85[0][0]']
#  ibuted)                         16)
#
#  time_distributed_87 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_86[0][0]']
#  ibuted)                         16)
#
#  bidirectional_3 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_87[0][0]']
#  )                              )
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_3[0][0]']
#                                  32)
#
#  conv2d_37 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims_1[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,935,457
# Trainable params: 11,932,513
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/40
# 248/248 [==============================] - 423s 2s/step - loss: 0.8497 - dice_coefficient: 0.1503 - binary_accuracy: 0.8190 - val_loss: 0.8345 - val_dice_coefficient: 0.1655 - val_binary_accuracy: 0.9480
# Epoch 2/40
# 248/248 [==============================] - 391s 2s/step - loss: 0.5666 - dice_coefficient: 0.4334 - binary_accuracy: 0.9732 - val_loss: 0.6616 - val_dice_coefficient: 0.3384 - val_binary_accuracy: 0.9681
# Epoch 3/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.4207 - dice_coefficient: 0.5793 - binary_accuracy: 0.9797 - val_loss: 0.7099 - val_dice_coefficient: 0.2901 - val_binary_accuracy: 0.9804
# Epoch 4/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.3481 - dice_coefficient: 0.6519 - binary_accuracy: 0.9816 - val_loss: 0.6104 - val_dice_coefficient: 0.3896 - val_binary_accuracy: 0.9860
# Epoch 5/40
# 248/248 [==============================] - 390s 2s/step - loss: 0.3133 - dice_coefficient: 0.6867 - binary_accuracy: 0.9832 - val_loss: 0.7029 - val_dice_coefficient: 0.2971 - val_binary_accuracy: 0.9868
# Epoch 6/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.3050 - dice_coefficient: 0.6950 - binary_accuracy: 0.9840 - val_loss: 0.7363 - val_dice_coefficient: 0.2637 - val_binary_accuracy: 0.9816
# Epoch 7/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2676 - dice_coefficient: 0.7324 - binary_accuracy: 0.9851 - val_loss: 0.7398 - val_dice_coefficient: 0.2602 - val_binary_accuracy: 0.9817
# Epoch 8/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2605 - dice_coefficient: 0.7395 - binary_accuracy: 0.9856 - val_loss: 0.8441 - val_dice_coefficient: 0.1559 - val_binary_accuracy: 0.9801
# Epoch 9/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2573 - dice_coefficient: 0.7427 - binary_accuracy: 0.9860 - val_loss: 0.6277 - val_dice_coefficient: 0.3723 - val_binary_accuracy: 0.9857
# Epoch 10/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2398 - dice_coefficient: 0.7602 - binary_accuracy: 0.9863 - val_loss: 0.7651 - val_dice_coefficient: 0.2349 - val_binary_accuracy: 0.9851
# Epoch 11/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2299 - dice_coefficient: 0.7701 - binary_accuracy: 0.9868 - val_loss: 0.7187 - val_dice_coefficient: 0.2813 - val_binary_accuracy: 0.9601
# Epoch 12/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2227 - dice_coefficient: 0.7773 - binary_accuracy: 0.9869 - val_loss: 0.6939 - val_dice_coefficient: 0.3061 - val_binary_accuracy: 0.9825
# Epoch 13/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2165 - dice_coefficient: 0.7835 - binary_accuracy: 0.9872 - val_loss: 0.8374 - val_dice_coefficient: 0.1626 - val_binary_accuracy: 0.9861
# Epoch 14/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2158 - dice_coefficient: 0.7842 - binary_accuracy: 0.9874 - val_loss: 0.5160 - val_dice_coefficient: 0.4840 - val_binary_accuracy: 0.9874
# Epoch 15/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.2096 - dice_coefficient: 0.7904 - binary_accuracy: 0.9873 - val_loss: 0.8165 - val_dice_coefficient: 0.1835 - val_binary_accuracy: 0.9838
# Epoch 16/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.2227 - dice_coefficient: 0.7773 - binary_accuracy: 0.9879 - val_loss: 0.5441 - val_dice_coefficient: 0.4559 - val_binary_accuracy: 0.9869
# Epoch 17/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.2023 - dice_coefficient: 0.7977 - binary_accuracy: 0.9881 - val_loss: 0.6288 - val_dice_coefficient: 0.3712 - val_binary_accuracy: 0.9856
# Epoch 18/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.2088 - dice_coefficient: 0.7912 - binary_accuracy: 0.9881 - val_loss: 0.6046 - val_dice_coefficient: 0.3954 - val_binary_accuracy: 0.9847
# Epoch 19/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1896 - dice_coefficient: 0.8104 - binary_accuracy: 0.9886 - val_loss: 0.5466 - val_dice_coefficient: 0.4534 - val_binary_accuracy: 0.9849
# Epoch 20/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1964 - dice_coefficient: 0.8036 - binary_accuracy: 0.9882 - val_loss: 0.7408 - val_dice_coefficient: 0.2592 - val_binary_accuracy: 0.9856
# Epoch 21/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1928 - dice_coefficient: 0.8072 - binary_accuracy: 0.9883 - val_loss: 0.7365 - val_dice_coefficient: 0.2635 - val_binary_accuracy: 0.9853
# Epoch 22/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1854 - dice_coefficient: 0.8146 - binary_accuracy: 0.9886 - val_loss: 0.7186 - val_dice_coefficient: 0.2814 - val_binary_accuracy: 0.9832
# Epoch 23/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1837 - dice_coefficient: 0.8163 - binary_accuracy: 0.9889 - val_loss: 0.6123 - val_dice_coefficient: 0.3877 - val_binary_accuracy: 0.9866
# Epoch 24/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1809 - dice_coefficient: 0.8191 - binary_accuracy: 0.9891 - val_loss: 0.7018 - val_dice_coefficient: 0.2982 - val_binary_accuracy: 0.9892
# Epoch 25/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1783 - dice_coefficient: 0.8217 - binary_accuracy: 0.9891 - val_loss: 0.6461 - val_dice_coefficient: 0.3539 - val_binary_accuracy: 0.9873
# Epoch 26/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1669 - dice_coefficient: 0.8331 - binary_accuracy: 0.9892 - val_loss: 0.8103 - val_dice_coefficient: 0.1897 - val_binary_accuracy: 0.9855
# Epoch 27/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1824 - dice_coefficient: 0.8176 - binary_accuracy: 0.9889 - val_loss: 0.6589 - val_dice_coefficient: 0.3411 - val_binary_accuracy: 0.9871
# Epoch 28/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1702 - dice_coefficient: 0.8298 - binary_accuracy: 0.9891 - val_loss: 0.7971 - val_dice_coefficient: 0.2029 - val_binary_accuracy: 0.9850
# Epoch 29/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1729 - dice_coefficient: 0.8271 - binary_accuracy: 0.9894 - val_loss: 0.6954 - val_dice_coefficient: 0.3046 - val_binary_accuracy: 0.9861
# Epoch 30/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1673 - dice_coefficient: 0.8327 - binary_accuracy: 0.9895 - val_loss: 0.6474 - val_dice_coefficient: 0.3526 - val_binary_accuracy: 0.9877
# Epoch 31/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1682 - dice_coefficient: 0.8318 - binary_accuracy: 0.9892 - val_loss: 0.9811 - val_dice_coefficient: 0.0189 - val_binary_accuracy: 0.9859
# Epoch 32/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1754 - dice_coefficient: 0.8246 - binary_accuracy: 0.9891 - val_loss: 0.5189 - val_dice_coefficient: 0.4811 - val_binary_accuracy: 0.9878
# Epoch 33/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1636 - dice_coefficient: 0.8364 - binary_accuracy: 0.9900 - val_loss: 0.5837 - val_dice_coefficient: 0.4163 - val_binary_accuracy: 0.9874
# Epoch 34/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1584 - dice_coefficient: 0.8416 - binary_accuracy: 0.9900 - val_loss: 0.8409 - val_dice_coefficient: 0.1591 - val_binary_accuracy: 0.9855
# Epoch 35/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1597 - dice_coefficient: 0.8403 - binary_accuracy: 0.9897 - val_loss: 0.5452 - val_dice_coefficient: 0.4548 - val_binary_accuracy: 0.9854
# Epoch 36/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1556 - dice_coefficient: 0.8444 - binary_accuracy: 0.9900 - val_loss: 0.7894 - val_dice_coefficient: 0.2106 - val_binary_accuracy: 0.9870
# Epoch 37/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1563 - dice_coefficient: 0.8437 - binary_accuracy: 0.9903 - val_loss: 0.7629 - val_dice_coefficient: 0.2371 - val_binary_accuracy: 0.9865
# Epoch 38/40
# 248/248 [==============================] - 388s 2s/step - loss: 0.1666 - dice_coefficient: 0.8334 - binary_accuracy: 0.9898 - val_loss: 0.6243 - val_dice_coefficient: 0.3757 - val_binary_accuracy: 0.9870
# Epoch 39/40
# 248/248 [==============================] - 389s 2s/step - loss: 0.1581 - dice_coefficient: 0.8419 - binary_accuracy: 0.9897 - val_loss: 0.6626 - val_dice_coefficient: 0.3374 - val_binary_accuracy: 0.9836
# Epoch 40/40
# 248/248 [==============================] - 392s 2s/step - loss: 0.1493 - dice_coefficient: 0.8507 - binary_accuracy: 0.9902 - val_loss: 0.8397 - val_dice_coefficient: 0.1603 - val_binary_accuracy: 0.9870

# %%
model.save('/gdrive/MyDrive/Sensor40.unet-2610-noaugonvalidation-5e-5-roiadjusted-Randomrotation0.3-recurrentdropout0.2-batch12-2blocks-basso.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor40.unet-2610-noaugonvalidation-5e-5-roiadjusted-Randomrotation0.3-recurrentdropout0.2-batch12-2blocks-basso.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.47989655

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 0.48750305
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4789505
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.48854828
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4884796
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.47353363
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.6800978
# 1/1 [==============================] - 0s 28ms/step
# 0.8443153
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0