# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30-unet-2610-noaugonvalidation-5e-5-roiadjusted-relu-2blocks-8filters-recurrentdropout02-batcheverywhere-2dropout0.1inexpanding-batch12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
batch_size=12

# %%
x, y = val_loader.__next__()
for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)


x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation= 'relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)

up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

#expanding path

concat1 = layers.concatenate([up1, conv9])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal', activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu') ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)

x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up5= layers.TimeDistributed( layers.Conv2DTranspose( 8,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up5, conv1])

x = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

x=layers.Bidirectional(layers.ConvLSTM2D(8,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)

model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  80         ['input_1[0][0]']
#  ted)                            8)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  32         ['time_distributed[0][0]']
#  buted)                          8)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  584        ['time_distributed_1[0][0]']
#  buted)                          8)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  32         ['time_distributed_2[0][0]']
#  buted)                          8)
#
#  time_distributed_4 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_3[0][0]']
#  buted)                          8)
#
#  time_distributed_5 (TimeDistri  (None, 3, 128, 128,  1168       ['time_distributed_4[0][0]']
#  buted)                          16)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  64         ['time_distributed_5[0][0]']
#  buted)                          16)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  2320       ['time_distributed_6[0][0]']
#  buted)                          16)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  64         ['time_distributed_7[0][0]']
#  buted)                          16)
#
#  time_distributed_9 (TimeDistri  (None, 3, 64, 64, 1  0          ['time_distributed_8[0][0]']
#  buted)                         6)
#
#  time_distributed_10 (TimeDistr  (None, 3, 64, 64, 3  4640       ['time_distributed_9[0][0]']
#  ibuted)                        2)
#
#  time_distributed_11 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_10[0][0]']
#  ibuted)                        2)
#
#  time_distributed_12 (TimeDistr  (None, 3, 64, 64, 3  9248       ['time_distributed_11[0][0]']
#  ibuted)                        2)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_12[0][0]']
#  ibuted)                        2)
#
#  time_distributed_14 (TimeDistr  (None, 3, 32, 32, 3  0          ['time_distributed_13[0][0]']
#  ibuted)                        2)
#
#  time_distributed_15 (TimeDistr  (None, 3, 32, 32, 6  18496      ['time_distributed_14[0][0]']
#  ibuted)                        4)
#
#  time_distributed_16 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_15[0][0]']
#  ibuted)                        4)
#
#  time_distributed_17 (TimeDistr  (None, 3, 32, 32, 6  36928      ['time_distributed_16[0][0]']
#  ibuted)                        4)
#
#  time_distributed_18 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_17[0][0]']
#  ibuted)                        4)
#
#  time_distributed_19 (TimeDistr  (None, 3, 16, 16, 6  0          ['time_distributed_18[0][0]']
#  ibuted)                        4)
#
#  time_distributed_20 (TimeDistr  (None, 3, 16, 16, 1  73856      ['time_distributed_19[0][0]']
#  ibuted)                        28)
#
#  time_distributed_21 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_20[0][0]']
#  ibuted)                        28)
#
#  time_distributed_22 (TimeDistr  (None, 3, 16, 16, 1  147584     ['time_distributed_21[0][0]']
#  ibuted)                        28)
#
#  time_distributed_23 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_22[0][0]']
#  ibuted)                        28)
#
#  time_distributed_24 (TimeDistr  (None, 3, 8, 8, 128  0          ['time_distributed_23[0][0]']
#  ibuted)                        )
#
#  time_distributed_25 (TimeDistr  (None, 3, 8, 8, 256  295168     ['time_distributed_24[0][0]']
#  ibuted)                        )
#
#  time_distributed_26 (TimeDistr  (None, 3, 8, 8, 256  1024       ['time_distributed_25[0][0]']
#  ibuted)                        )
#
#  time_distributed_27 (TimeDistr  (None, 3, 8, 8, 256  590080     ['time_distributed_26[0][0]']
#  ibuted)                        )
#
#  time_distributed_28 (TimeDistr  (None, 3, 8, 8, 256  1024       ['time_distributed_27[0][0]']
#  ibuted)                        )
#
#  bidirectional (Bidirectional)  (None, 3, 8, 8, 512  9439232     ['time_distributed_28[0][0]']
#                                 )
#
#  time_distributed_29 (TimeDistr  (None, 3, 16, 16, 1  589952     ['bidirectional[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 16, 16, 2  0           ['time_distributed_29[0][0]',
#                                 56)                               'time_distributed_23[0][0]']
#
#  time_distributed_30 (TimeDistr  (None, 3, 16, 16, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_31 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_30[0][0]']
#  ibuted)                        28)
#
#  time_distributed_32 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_31[0][0]']
#  ibuted)                        28)
#
#  time_distributed_33 (TimeDistr  (None, 3, 16, 16, 1  147584     ['time_distributed_32[0][0]']
#  ibuted)                        28)
#
#  time_distributed_34 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_33[0][0]']
#  ibuted)                        28)
#
#  time_distributed_35 (TimeDistr  (None, 3, 32, 32, 6  73792      ['time_distributed_34[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 32, 32, 1  0           ['time_distributed_35[0][0]',
#                                 28)                               'time_distributed_18[0][0]']
#
#  time_distributed_36 (TimeDistr  (None, 3, 32, 32, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_37 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_36[0][0]']
#  ibuted)                        4)
#
#  time_distributed_38 (TimeDistr  (None, 3, 32, 32, 6  36928      ['time_distributed_37[0][0]']
#  ibuted)                        4)
#
#  time_distributed_39 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_38[0][0]']
#  ibuted)                        4)
#
#  time_distributed_40 (TimeDistr  (None, 3, 64, 64, 3  18464      ['time_distributed_39[0][0]']
#  ibuted)                        2)
#
#  concatenate_2 (Concatenate)    (None, 3, 64, 64, 6  0           ['time_distributed_40[0][0]',
#                                 4)                                'time_distributed_13[0][0]']
#
#  time_distributed_41 (TimeDistr  (None, 3, 64, 64, 3  18464      ['concatenate_2[0][0]']
#  ibuted)                        2)
#
#  time_distributed_42 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_41[0][0]']
#  ibuted)                        2)
#
#  time_distributed_43 (TimeDistr  (None, 3, 64, 64, 3  9248       ['time_distributed_42[0][0]']
#  ibuted)                        2)
#
#  time_distributed_44 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_43[0][0]']
#  ibuted)                        2)
#
#  time_distributed_45 (TimeDistr  (None, 3, 128, 128,  4624       ['time_distributed_44[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_45[0][0]',
#                                  32)                              'time_distributed_8[0][0]']
#
#  time_distributed_46 (TimeDistr  (None, 3, 128, 128,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_47 (TimeDistr  (None, 3, 128, 128,  64         ['time_distributed_46[0][0]']
#  ibuted)                         16)
#
#  time_distributed_48 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_47[0][0]']
#  ibuted)                         16)
#
#  time_distributed_49 (TimeDistr  (None, 3, 128, 128,  2320       ['time_distributed_48[0][0]']
#  ibuted)                         16)
#
#  time_distributed_50 (TimeDistr  (None, 3, 128, 128,  64         ['time_distributed_49[0][0]']
#  ibuted)                         16)
#
#  time_distributed_51 (TimeDistr  (None, 3, 256, 256,  1160       ['time_distributed_50[0][0]']
#  ibuted)                         8)
#
#  concatenate_4 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_51[0][0]',
#                                  16)                              'time_distributed_3[0][0]']
#
#  time_distributed_52 (TimeDistr  (None, 3, 256, 256,  1160       ['concatenate_4[0][0]']
#  ibuted)                         8)
#
#  time_distributed_53 (TimeDistr  (None, 3, 256, 256,  32         ['time_distributed_52[0][0]']
#  ibuted)                         8)
#
#  time_distributed_54 (TimeDistr  (None, 3, 256, 256,  584        ['time_distributed_53[0][0]']
#  ibuted)                         8)
#
#  time_distributed_55 (TimeDistr  (None, 3, 256, 256,  32         ['time_distributed_54[0][0]']
#  ibuted)                         8)
#
#  bidirectional_1 (Bidirectional  (None, 256, 256, 16  9280       ['time_distributed_55[0][0]']
#  )                              )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['bidirectional_1[0][0]']
#                                  16)
#
#  conv2d_22 (Conv2D)             (None, 1, 256, 256,  17          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,912,433
# Trainable params: 11,909,425
# Non-trainable params: 3,008
# __________________________________________________________________________________________________

# %%
from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[ dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=[model_checkpoint_callback],
    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 248/248 [==============================] - 257s 930ms/step - loss: 0.9245 - dice_coefficient: 0.0755 - binary_accuracy: 0.7586 - val_loss: 0.8648 - val_dice_coefficient: 0.1352 - val_binary_accuracy: 0.8867
# Epoch 2/30
# 248/248 [==============================] - 230s 929ms/step - loss: 0.7942 - dice_coefficient: 0.2058 - binary_accuracy: 0.9444 - val_loss: 0.6793 - val_dice_coefficient: 0.3207 - val_binary_accuracy: 0.9667
# Epoch 3/30
# 248/248 [==============================] - 232s 936ms/step - loss: 0.6464 - dice_coefficient: 0.3536 - binary_accuracy: 0.9724 - val_loss: 0.5818 - val_dice_coefficient: 0.4182 - val_binary_accuracy: 0.9808
# Epoch 4/30
# 248/248 [==============================] - 232s 936ms/step - loss: 0.5263 - dice_coefficient: 0.4737 - binary_accuracy: 0.9792 - val_loss: 0.5178 - val_dice_coefficient: 0.4822 - val_binary_accuracy: 0.9808
# Epoch 5/30
# 248/248 [==============================] - 232s 935ms/step - loss: 0.4359 - dice_coefficient: 0.5641 - binary_accuracy: 0.9819 - val_loss: 0.4740 - val_dice_coefficient: 0.5260 - val_binary_accuracy: 0.9821
# Epoch 6/30
# 248/248 [==============================] - 232s 935ms/step - loss: 0.3865 - dice_coefficient: 0.6135 - binary_accuracy: 0.9833 - val_loss: 0.4053 - val_dice_coefficient: 0.5947 - val_binary_accuracy: 0.9834
# Epoch 7/30
# 248/248 [==============================] - 231s 933ms/step - loss: 0.3433 - dice_coefficient: 0.6567 - binary_accuracy: 0.9844 - val_loss: 0.4047 - val_dice_coefficient: 0.5953 - val_binary_accuracy: 0.9835
# Epoch 8/30
# 248/248 [==============================] - 231s 931ms/step - loss: 0.3161 - dice_coefficient: 0.6839 - binary_accuracy: 0.9859 - val_loss: 0.4068 - val_dice_coefficient: 0.5932 - val_binary_accuracy: 0.9833
# Epoch 9/30
# 248/248 [==============================] - 231s 930ms/step - loss: 0.3084 - dice_coefficient: 0.6916 - binary_accuracy: 0.9862 - val_loss: 0.5266 - val_dice_coefficient: 0.4734 - val_binary_accuracy: 0.9803
# Epoch 10/30
# 248/248 [==============================] - 231s 932ms/step - loss: 0.3002 - dice_coefficient: 0.6998 - binary_accuracy: 0.9865 - val_loss: 0.3948 - val_dice_coefficient: 0.6052 - val_binary_accuracy: 0.9830
# Epoch 11/30
# 248/248 [==============================] - 230s 929ms/step - loss: 0.2827 - dice_coefficient: 0.7173 - binary_accuracy: 0.9870 - val_loss: 0.4053 - val_dice_coefficient: 0.5947 - val_binary_accuracy: 0.9816
# Epoch 12/30
# 248/248 [==============================] - 231s 931ms/step - loss: 0.2586 - dice_coefficient: 0.7414 - binary_accuracy: 0.9873 - val_loss: 0.3856 - val_dice_coefficient: 0.6144 - val_binary_accuracy: 0.9821
# Epoch 13/30
# 248/248 [==============================] - 230s 928ms/step - loss: 0.2574 - dice_coefficient: 0.7426 - binary_accuracy: 0.9876 - val_loss: 0.4198 - val_dice_coefficient: 0.5802 - val_binary_accuracy: 0.9853
# Epoch 14/30
# 248/248 [==============================] - 230s 928ms/step - loss: 0.2396 - dice_coefficient: 0.7604 - binary_accuracy: 0.9878 - val_loss: 0.4070 - val_dice_coefficient: 0.5930 - val_binary_accuracy: 0.9847
# Epoch 15/30
# 248/248 [==============================] - 230s 928ms/step - loss: 0.2336 - dice_coefficient: 0.7664 - binary_accuracy: 0.9884 - val_loss: 0.4369 - val_dice_coefficient: 0.5631 - val_binary_accuracy: 0.9807
# Epoch 16/30
# 248/248 [==============================] - 230s 928ms/step - loss: 0.2337 - dice_coefficient: 0.7663 - binary_accuracy: 0.9883 - val_loss: 0.6432 - val_dice_coefficient: 0.3568 - val_binary_accuracy: 0.9788
# Epoch 17/30
# 248/248 [==============================] - 230s 927ms/step - loss: 0.2301 - dice_coefficient: 0.7699 - binary_accuracy: 0.9885 - val_loss: 0.3736 - val_dice_coefficient: 0.6264 - val_binary_accuracy: 0.9844
# Epoch 18/30
# 248/248 [==============================] - 231s 930ms/step - loss: 0.2248 - dice_coefficient: 0.7752 - binary_accuracy: 0.9885 - val_loss: 0.3664 - val_dice_coefficient: 0.6336 - val_binary_accuracy: 0.9840
# Epoch 19/30
# 248/248 [==============================] - 230s 927ms/step - loss: 0.2093 - dice_coefficient: 0.7907 - binary_accuracy: 0.9889 - val_loss: 0.4071 - val_dice_coefficient: 0.5929 - val_binary_accuracy: 0.9823
# Epoch 20/30
# 248/248 [==============================] - 231s 930ms/step - loss: 0.2139 - dice_coefficient: 0.7861 - binary_accuracy: 0.9890 - val_loss: 0.5491 - val_dice_coefficient: 0.4509 - val_binary_accuracy: 0.9794
# Epoch 21/30
# 248/248 [==============================] - 231s 931ms/step - loss: 0.2151 - dice_coefficient: 0.7849 - binary_accuracy: 0.9887 - val_loss: 0.4610 - val_dice_coefficient: 0.5390 - val_binary_accuracy: 0.9819
# Epoch 22/30
# 248/248 [==============================] - 230s 930ms/step - loss: 0.2059 - dice_coefficient: 0.7941 - binary_accuracy: 0.9892 - val_loss: 0.3666 - val_dice_coefficient: 0.6334 - val_binary_accuracy: 0.9851
# Epoch 23/30
# 248/248 [==============================] - 230s 928ms/step - loss: 0.2132 - dice_coefficient: 0.7868 - binary_accuracy: 0.9886 - val_loss: 0.4255 - val_dice_coefficient: 0.5745 - val_binary_accuracy: 0.9816
# Epoch 24/30
# 248/248 [==============================] - 231s 931ms/step - loss: 0.1999 - dice_coefficient: 0.8001 - binary_accuracy: 0.9891 - val_loss: 0.4692 - val_dice_coefficient: 0.5308 - val_binary_accuracy: 0.9814
# Epoch 25/30
# 248/248 [==============================] - 231s 930ms/step - loss: 0.1920 - dice_coefficient: 0.8080 - binary_accuracy: 0.9897 - val_loss: 0.4440 - val_dice_coefficient: 0.5560 - val_binary_accuracy: 0.9819
# Epoch 26/30
# 248/248 [==============================] - 231s 930ms/step - loss: 0.1974 - dice_coefficient: 0.8026 - binary_accuracy: 0.9895 - val_loss: 0.5612 - val_dice_coefficient: 0.4388 - val_binary_accuracy: 0.9805
# Epoch 27/30
# 248/248 [==============================] - 230s 929ms/step - loss: 0.1823 - dice_coefficient: 0.8177 - binary_accuracy: 0.9893 - val_loss: 0.5447 - val_dice_coefficient: 0.4553 - val_binary_accuracy: 0.9802
# Epoch 28/30
# 248/248 [==============================] - 235s 946ms/step - loss: 0.1869 - dice_coefficient: 0.8131 - binary_accuracy: 0.9896 - val_loss: 0.5323 - val_dice_coefficient: 0.4677 - val_binary_accuracy: 0.9800
# Epoch 29/30
# 248/248 [==============================] - 231s 930ms/step - loss: 0.1888 - dice_coefficient: 0.8112 - binary_accuracy: 0.9900 - val_loss: 0.4197 - val_dice_coefficient: 0.5803 - val_binary_accuracy: 0.9806
# Epoch 30/30
# 248/248 [==============================] - 230s 929ms/step - loss: 0.1974 - dice_coefficient: 0.8026 - binary_accuracy: 0.9895 - val_loss: 0.4952 - val_dice_coefficient: 0.5048 - val_binary_accuracy: 0.9824

# %%
model.save('/gdrive/MyDrive/Sensor30-unet-2610-noaugonvalidation-5e-5-roiadjusted-relu-2blocks-8filters-recurrentdropout02-batcheverywhere-2dropout0.1inexpanding-batch12.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30-unet-2610-noaugonvalidation-5e-5-roiadjusted-relu-2blocks-8filters-recurrentdropout02-batcheverywhere-2dropout0.1inexpanding-batch12.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 1.0

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 0.49999237
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.6457073
# 1/1 [==============================] - 0s 33ms/step
# 0.6477448
# 1/1 [==============================] - 0s 33ms/step
# 0.49207306
# 1/1 [==============================] - 0s 32ms/step
# 0.4884796
# 1/1 [==============================] - 0s 33ms/step
# 0.48542786
# 1/1 [==============================] - 0s 29ms/step
# 0.64116836
# 1/1 [==============================] - 0s 30ms/step
# 0.49419403
# 1/1 [==============================] - 0s 32ms/step
# 0.49149323
# 1/1 [==============================] - 0s 34ms/step
# 0.49559784
# 1/1 [==============================] - 0s 31ms/step
# 0.84309244
# 1/1 [==============================] - 0s 30ms/step
# 0.64116836
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.7949277
# 1/1 [==============================] - 0s 31ms/step
# 0.5971792
# 1/1 [==============================] - 0s 36ms/step
# 0.7198021
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.4944229
# 1/1 [==============================] - 0s 35ms/step
# 0.48392487
# 1/1 [==============================] - 0s 30ms/step
# 0.49559784
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.499794
# 1/1 [==============================] - 0s 32ms/step
# 0.6658576
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48931885
# 1/1 [==============================] - 0s 32ms/step
# 0.5690352
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.6713095
# 1/1 [==============================] - 0s 32ms/step
# 0.48929596
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.75737906
# 1/1 [==============================] - 0s 39ms/step
# 0.82884175
# 1/1 [==============================] - 0s 30ms/step
# 0.49193573
# 1/1 [==============================] - 0s 33ms/step
# 0.6550054
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 37ms/step
# 0.49922943
# 1/1 [==============================] - 0s 37ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.6857108
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 1.0
# 1/1 [==============================] - 0s 38ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.760576
# 1/1 [==============================] - 0s 33ms/step
# 0.49079132
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0