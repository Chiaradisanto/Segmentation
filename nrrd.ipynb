# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/nrrd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install dicom
# Out:
# ...
#      |████████████████████████████████| 766 kB 7.1 MB/s
# ...

# %%
# !pip install pynrrd

# %%
import glob

# %%
mask_path= glob.glob('/gdrive/MyDrive/TESI/prova/ROI_out_HCM34.nrrd')

# %%
# !pip install SimpleITK
# Out:
# ...
#      |████████████████████████████████| 48.4 MB 1.8 MB/s
# ...

# %%
import os

import SimpleITK as sitk
import six
import nibabel as nib
# Out:
# /usr/local/lib/python3.7/dist-packages/dicom/__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %%
mask_sitk  = sitk.ReadImage(mask_path[0])
sitk_shape=mask_sitk.GetSize()
sitk_shape
# Out:
# (512, 512, 224)

# %%
images_path='/gdrive/MyDrive/TESI/output/train/034/masks/'

# %%
from matplotlib import pyplot as plt
import numpy as np
from os import path


num_slices=224
for i in range(num_slices):
    img=plt.imshow(sitk.GetArrayViewFromImage(mask_sitk)[i], cmap='gray')
    plt.axis('off')
    plt.savefig(f"{images_path}"+str(i)+".png")
    plt.show()


    #image = img.figure.savefig(f"{images_path}"+ i + '/ .png')
