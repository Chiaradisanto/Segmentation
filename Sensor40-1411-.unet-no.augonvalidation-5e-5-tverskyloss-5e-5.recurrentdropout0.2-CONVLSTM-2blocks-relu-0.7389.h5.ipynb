# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor40-1411-.unet-no.augonvalidation-5e-5-tverskyloss-5e-5.recurrentdropout0.2-CONVLSTM-2blocks-relu-0.7389.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
                np.array(
                    [
                        img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_img_file_names
                    ]
                )
                / 255
            )
        self.masks = (
                np.array(
                    [
                      img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_mask_file_names
                    ]
                )
                / 255
                > 0.5
            ).astype(float)

        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3,interpolation='bilinear',fill_mode='nearest'),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
            if self.index >= len(self.imgs) - self.timesteps - self.batch_size:
                self.index = 0
                raise StopIteration
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    shuffle=True,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    shuffle=True,

    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()
for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))

x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu')) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv5)

up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv4])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)


up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv3])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU() ) ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv2])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv1])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation=layers.LeakyReLU()) ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU()) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)
out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_4[0][0]']
#  buted)                          32)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_5[0][0]']
#  buted)                          32)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 64, 64, 3  0          ['time_distributed_8[0][0]']
#  buted)                         2)
#
#  time_distributed_10 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_9[0][0]']
#  ibuted)                        4)
#
#  time_distributed_11 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_10[0][0]']
#  ibuted)                        4)
#
#  time_distributed_12 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_11[0][0]']
#  ibuted)                        4)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_12[0][0]']
#  ibuted)                        4)
#
#  time_distributed_14 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_14[0][0]']
#  ibuted)                        28)
#
#  time_distributed_16 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_15[0][0]']
#  ibuted)                        28)
#
#  time_distributed_17 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_16[0][0]']
#  ibuted)                        28)
#
#  time_distributed_18 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_17[0][0]']
#  ibuted)                        28)
#
#  time_distributed_19 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_18[0][0]']
#  ibuted)                        28)
#
#  time_distributed_20 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_19[0][0]']
#  ibuted)                        56)
#
#  time_distributed_21 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_20[0][0]']
#  ibuted)                        56)
#
#  time_distributed_22 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_21[0][0]']
#  ibuted)                        56)
#
#  time_distributed_23 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_22[0][0]']
#  ibuted)                        56)
#
#  conv_lstm2d (ConvLSTM2D)       (None, 3, 16, 16, 2  4719616     ['time_distributed_23[0][0]']
#                                 56)
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  295040     ['conv_lstm2d[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_24[0][0]',
#                                 56)                               'time_distributed_18[0][0]']
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_26[0][0]']
#  ibuted)                        28)
#
#  time_distributed_28 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_27[0][0]']
#  ibuted)                        28)
#
#  time_distributed_29 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_28[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_29[0][0]',
#                                 28)                               'time_distributed_13[0][0]']
#
#  time_distributed_30 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_31 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_30[0][0]']
#  ibuted)                        4)
#
#  time_distributed_32 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_31[0][0]']
#  ibuted)                        4)
#
#  time_distributed_33 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_32[0][0]']
#  ibuted)                        4)
#
#  time_distributed_34 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_33[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_34[0][0]',
#                                  64)                              'time_distributed_8[0][0]']
#
#  time_distributed_35 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_36 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_35[0][0]']
#  ibuted)                         32)
#
#  time_distributed_37 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_36[0][0]']
#  ibuted)                         32)
#
#  time_distributed_38 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_37[0][0]']
#  ibuted)                         32)
#
#  time_distributed_39 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_38[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_39[0][0]',
#                                  32)                              'time_distributed_3[0][0]']
#
#  time_distributed_40 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_41 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_40[0][0]']
#  ibuted)                         16)
#
#  time_distributed_42 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_41[0][0]']
#  ibuted)                         16)
#
#  time_distributed_43 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_42[0][0]']
#  ibuted)                         16)
#
#  conv_lstm2d_1 (ConvLSTM2D)     (None, 256, 256, 16  18496       ['time_distributed_43[0][0]']
#                                 )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['conv_lstm2d_1[0][0]']
#                                  16)
#
#  conv2d_18 (Conv2D)             (None, 1, 256, 256,  17          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 6,902,417
# Trainable params: 6,899,473
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.75
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.60
    return K.pow((1-pt_1), gamma)

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=tversky_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/40
# 248/248 [==============================] - 294s 1s/step - loss: 0.8022 - dice_coefficient: 0.1161 - binary_accuracy: 0.7601 - val_loss: 0.8542 - val_dice_coefficient: 0.0808 - val_binary_accuracy: 0.4017
# Epoch 2/40
# 248/248 [==============================] - 270s 1s/step - loss: 0.4870 - dice_coefficient: 0.3800 - binary_accuracy: 0.9657 - val_loss: 0.5179 - val_dice_coefficient: 0.3522 - val_binary_accuracy: 0.9670
# Epoch 3/40
# 248/248 [==============================] - 270s 1s/step - loss: 0.3663 - dice_coefficient: 0.5156 - binary_accuracy: 0.9731 - val_loss: 0.4861 - val_dice_coefficient: 0.5279 - val_binary_accuracy: 0.9819
# Epoch 4/40
# 248/248 [==============================] - 270s 1s/step - loss: 0.3044 - dice_coefficient: 0.5963 - binary_accuracy: 0.9782 - val_loss: 0.3592 - val_dice_coefficient: 0.6108 - val_binary_accuracy: 0.9792
# Epoch 5/40
# 248/248 [==============================] - 269s 1s/step - loss: 0.2799 - dice_coefficient: 0.6269 - binary_accuracy: 0.9796 - val_loss: 0.4220 - val_dice_coefficient: 0.6094 - val_binary_accuracy: 0.9831
# Epoch 6/40
# 248/248 [==============================] - 269s 1s/step - loss: 0.2623 - dice_coefficient: 0.6512 - binary_accuracy: 0.9803 - val_loss: 0.3346 - val_dice_coefficient: 0.6660 - val_binary_accuracy: 0.9855
# Epoch 7/40
# 248/248 [==============================] - 269s 1s/step - loss: 0.2489 - dice_coefficient: 0.6652 - binary_accuracy: 0.9826 - val_loss: 0.2996 - val_dice_coefficient: 0.6938 - val_binary_accuracy: 0.9857
# Epoch 8/40
# 248/248 [==============================] - 269s 1s/step - loss: 0.2397 - dice_coefficient: 0.6778 - binary_accuracy: 0.9833 - val_loss: 0.2814 - val_dice_coefficient: 0.7116 - val_binary_accuracy: 0.9862
# Epoch 9/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.2171 - dice_coefficient: 0.7067 - binary_accuracy: 0.9840 - val_loss: 0.3035 - val_dice_coefficient: 0.6637 - val_binary_accuracy: 0.9831
# Epoch 10/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.2264 - dice_coefficient: 0.6945 - binary_accuracy: 0.9834 - val_loss: 0.3213 - val_dice_coefficient: 0.5553 - val_binary_accuracy: 0.9616
# Epoch 11/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.2098 - dice_coefficient: 0.7144 - binary_accuracy: 0.9842 - val_loss: 0.2588 - val_dice_coefficient: 0.7160 - val_binary_accuracy: 0.9851
# Epoch 12/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.2095 - dice_coefficient: 0.7164 - binary_accuracy: 0.9851 - val_loss: 0.2932 - val_dice_coefficient: 0.6908 - val_binary_accuracy: 0.9828
# Epoch 13/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1903 - dice_coefficient: 0.7396 - binary_accuracy: 0.9859 - val_loss: 0.3283 - val_dice_coefficient: 0.6250 - val_binary_accuracy: 0.9794
# Epoch 14/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1778 - dice_coefficient: 0.7553 - binary_accuracy: 0.9859 - val_loss: 0.2559 - val_dice_coefficient: 0.7075 - val_binary_accuracy: 0.9835
# Epoch 15/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1871 - dice_coefficient: 0.7415 - binary_accuracy: 0.9856 - val_loss: 0.2988 - val_dice_coefficient: 0.7028 - val_binary_accuracy: 0.9857
# Epoch 16/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1779 - dice_coefficient: 0.7537 - binary_accuracy: 0.9860 - val_loss: 0.3295 - val_dice_coefficient: 0.6675 - val_binary_accuracy: 0.9830
# Epoch 17/40
# 248/248 [==============================] - 269s 1s/step - loss: 0.1758 - dice_coefficient: 0.7594 - binary_accuracy: 0.9870 - val_loss: 0.2939 - val_dice_coefficient: 0.6791 - val_binary_accuracy: 0.9842
# Epoch 18/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1704 - dice_coefficient: 0.7647 - binary_accuracy: 0.9867 - val_loss: 0.3291 - val_dice_coefficient: 0.6533 - val_binary_accuracy: 0.9819
# Epoch 19/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1684 - dice_coefficient: 0.7637 - binary_accuracy: 0.9865 - val_loss: 0.2804 - val_dice_coefficient: 0.7120 - val_binary_accuracy: 0.9852
# Epoch 20/40
# 248/248 [==============================] - 269s 1s/step - loss: 0.1577 - dice_coefficient: 0.7791 - binary_accuracy: 0.9874 - val_loss: 0.2864 - val_dice_coefficient: 0.7175 - val_binary_accuracy: 0.9844
# Epoch 21/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1738 - dice_coefficient: 0.7609 - binary_accuracy: 0.9868 - val_loss: 0.3509 - val_dice_coefficient: 0.6334 - val_binary_accuracy: 0.9817
# Epoch 22/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1588 - dice_coefficient: 0.7763 - binary_accuracy: 0.9877 - val_loss: 0.2493 - val_dice_coefficient: 0.6781 - val_binary_accuracy: 0.9800
# Epoch 23/40
# 248/248 [==============================] - 269s 1s/step - loss: 0.1559 - dice_coefficient: 0.7807 - binary_accuracy: 0.9872 - val_loss: 0.2706 - val_dice_coefficient: 0.6685 - val_binary_accuracy: 0.9768
# Epoch 24/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1532 - dice_coefficient: 0.7865 - binary_accuracy: 0.9887 - val_loss: 0.3083 - val_dice_coefficient: 0.6534 - val_binary_accuracy: 0.9830
# Epoch 25/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1564 - dice_coefficient: 0.7841 - binary_accuracy: 0.9878 - val_loss: 0.4119 - val_dice_coefficient: 0.5592 - val_binary_accuracy: 0.9775
# Epoch 26/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1498 - dice_coefficient: 0.7913 - binary_accuracy: 0.9880 - val_loss: 0.3190 - val_dice_coefficient: 0.6790 - val_binary_accuracy: 0.9845
# Epoch 27/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1485 - dice_coefficient: 0.7891 - binary_accuracy: 0.9876 - val_loss: 0.3024 - val_dice_coefficient: 0.7152 - val_binary_accuracy: 0.9863
# Epoch 28/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1448 - dice_coefficient: 0.7945 - binary_accuracy: 0.9880 - val_loss: 0.3567 - val_dice_coefficient: 0.6786 - val_binary_accuracy: 0.9852
# Epoch 29/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1425 - dice_coefficient: 0.8002 - binary_accuracy: 0.9884 - val_loss: 0.3077 - val_dice_coefficient: 0.6946 - val_binary_accuracy: 0.9849
# Epoch 30/40
# 248/248 [==============================] - 269s 1s/step - loss: 0.1496 - dice_coefficient: 0.7918 - binary_accuracy: 0.9887 - val_loss: 0.3029 - val_dice_coefficient: 0.7223 - val_binary_accuracy: 0.9852
# Epoch 31/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1366 - dice_coefficient: 0.8050 - binary_accuracy: 0.9884 - val_loss: 0.2644 - val_dice_coefficient: 0.7100 - val_binary_accuracy: 0.9848
# Epoch 32/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1257 - dice_coefficient: 0.8216 - binary_accuracy: 0.9891 - val_loss: 0.3210 - val_dice_coefficient: 0.6776 - val_binary_accuracy: 0.9838
# Epoch 33/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1420 - dice_coefficient: 0.8004 - binary_accuracy: 0.9885 - val_loss: 0.2903 - val_dice_coefficient: 0.7036 - val_binary_accuracy: 0.9839
# Epoch 34/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1252 - dice_coefficient: 0.8209 - binary_accuracy: 0.9891 - val_loss: 0.2417 - val_dice_coefficient: 0.7389 - val_binary_accuracy: 0.9846
# Epoch 35/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1308 - dice_coefficient: 0.8149 - binary_accuracy: 0.9888 - val_loss: 0.3052 - val_dice_coefficient: 0.6782 - val_binary_accuracy: 0.9827
# Epoch 36/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1419 - dice_coefficient: 0.8034 - binary_accuracy: 0.9888 - val_loss: 0.3014 - val_dice_coefficient: 0.7223 - val_binary_accuracy: 0.9853
# Epoch 37/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1313 - dice_coefficient: 0.8162 - binary_accuracy: 0.9892 - val_loss: 0.3308 - val_dice_coefficient: 0.5977 - val_binary_accuracy: 0.9748
# Epoch 38/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1316 - dice_coefficient: 0.8127 - binary_accuracy: 0.9886 - val_loss: 0.3609 - val_dice_coefficient: 0.6330 - val_binary_accuracy: 0.9794
# Epoch 39/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1259 - dice_coefficient: 0.8213 - binary_accuracy: 0.9891 - val_loss: 0.3257 - val_dice_coefficient: 0.6992 - val_binary_accuracy: 0.9856
# Epoch 40/40
# 248/248 [==============================] - 268s 1s/step - loss: 0.1365 - dice_coefficient: 0.8081 - binary_accuracy: 0.9893 - val_loss: 0.3305 - val_dice_coefficient: 0.6279 - val_binary_accuracy: 0.9771

# %%
model.save('/gdrive/MyDrive/Sensor40-1411-.unet-no.augonvalidation-5e-5-tverskyloss-5e-5.recurrentdropout0.2-CONVLSTM-2blocks-relu-0.7389.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor40-1411-.unet-no.augonvalidation-5e-5-tverskyloss-5e-5.recurrentdropout0.2-CONVLSTM-2blocks-relu-0.7389.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
                np.array(
                    [
                        img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_img_file_names
                    ]
                )
                / 255
            )
        self.masks = (
                np.array(
                    [
                      img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_mask_file_names
                    ]
                )
                / 255
                > 0.5
            ).astype(float)

        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3,interpolation='bilinear',fill_mode='nearest'),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
            if self.index >= len(self.imgs) - self.timesteps - self.batch_size:
                self.index = 0
                raise StopIteration
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,

)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.49800873

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)

    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    

mean_IoU = df.mean().values
boxplot = df.boxplot(grid=False, vert=True,  # vertical box alignment
                     patch_artist=False)  # fill with color)
std=df.std()
print('number of total masks is: ', len(IoU_values))

print("Mean IoU is: ", mean_IoU)
print("standard deviation is ",std)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.49798584
# 1/1 [==============================] - 0s 21ms/step
# 0.8947656
# 1/1 [==============================] - 0s 22ms/step
# 0.48823547
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.7486187
# 1/1 [==============================] - 0s 20ms/step
# 0.8922724
# 1/1 [==============================] - 0s 21ms/step
# 0.88304627
# 1/1 [==============================] - 0s 20ms/step
# 0.43497467
# 1/1 [==============================] - 0s 23ms/step
# 0.53690106
# 1/1 [==============================] - 0s 20ms/step
# 0.8708222
# 1/1 [==============================] - 0s 22ms/step
# 0.6684171
# 1/1 [==============================] - 0s 23ms/step
# 0.91702235
# 1/1 [==============================] - 0s 22ms/step
# 0.8952939
# 1/1 [==============================] - 0s 23ms/step
# 0.47982025
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 20ms/step
# 0.9195103
# 1/1 [==============================] - 0s 20ms/step
# 0.4190216
# 1/1 [==============================] - 0s 21ms/step
# 0.898817
# 1/1 [==============================] - 0s 23ms/step
# 0.8304178
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.7461507
# 1/1 [==============================] - 0s 23ms/step
# 0.90054363
# 1/1 [==============================] - 0s 23ms/step
# 0.6904042
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48207855
# 1/1 [==============================] - 0s 20ms/step
# 0.9017309
# 1/1 [==============================] - 0s 22ms/step
# 0.4814148
# 1/1 [==============================] - 0s 21ms/step
# 0.8655008
# 1/1 [==============================] - 0s 23ms/step
# 0.9017309
# 1/1 [==============================] - 0s 23ms/step
# 0.49694824
# 1/1 [==============================] - 0s 23ms/step
# 0.597934
# 1/1 [==============================] - 0s 22ms/step
# 0.6198851
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.88654923
# 1/1 [==============================] - 0s 20ms/step
# 0.49798584
# 1/1 [==============================] - 0s 23ms/step
# 0.8883154
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.49840546
# 1/1 [==============================] - 0s 20ms/step
# 0.4798813
# 1/1 [==============================] - 0s 23ms/step
# 0.44795227
# 1/1 [==============================] - 0s 23ms/step
# 0.7026733
# 1/1 [==============================] - 0s 23ms/step
# 0.8901869
# 1/1 [==============================] - 0s 20ms/step
# 0.88644314
# 1/1 [==============================] - 0s 20ms/step
# 0.4850006
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 20ms/step
# 0.74685925
# 1/1 [==============================] - 0s 22ms/step
# 0.45918274
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.597934
# 1/1 [==============================] - 0s 25ms/step
# 0.9141687
# 1/1 [==============================] - 0s 20ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8668884
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.88469553
# 1/1 [==============================] - 0s 31ms/step
# 0.8668884
# 1/1 [==============================] - 0s 22ms/step
# 0.8807584
# 1/1 [==============================] - 0s 20ms/step
# 0.8345121
# 1/1 [==============================] - 0s 20ms/step
# 0.67690927
# 1/1 [==============================] - 0s 20ms/step
# 0.7376292
# 1/1 [==============================] - 0s 24ms/step
# 0.49108887
# 1/1 [==============================] - 0s 20ms/step
# 0.90773666
# 1/1 [==============================] - 0s 20ms/step
# 0.48535156
# number of total masks is:  477
# Mean IoU is:  [0.6710992]
# standard deviation is  IoU    0.180036
# dtype: float32
