# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor40.unet-noaugonvalidation-2510-5e-5-roiadjusted-relu-batch12-2blocks-batcheverywhere-relualsoonbidirectional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)


x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2,activation='relu'))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv9])
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2,activation='relu'))(x)
x=tf.expand_dims(x,axis=1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_55 (TimeDistr  (None, 3, 256, 256,  160        ['input_2[0][0]']
#  ibuted)                         16)
#
#  time_distributed_56 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_55[0][0]']
#  ibuted)                         16)
#
#  time_distributed_57 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_56[0][0]']
#  ibuted)                         16)
#
#  time_distributed_58 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_57[0][0]']
#  ibuted)                         16)
#
#  time_distributed_59 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_58[0][0]']
#  ibuted)                         16)
#
#  time_distributed_60 (TimeDistr  (None, 3, 128, 128,  4640       ['time_distributed_59[0][0]']
#  ibuted)                         32)
#
#  time_distributed_61 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_60[0][0]']
#  ibuted)                         32)
#
#  time_distributed_62 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_61[0][0]']
#  ibuted)                         32)
#
#  time_distributed_63 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_62[0][0]']
#  ibuted)                         32)
#
#  time_distributed_64 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_63[0][0]']
#  ibuted)                        2)
#
#  time_distributed_65 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_64[0][0]']
#  ibuted)                        4)
#
#  time_distributed_66 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_65[0][0]']
#  ibuted)                        4)
#
#  time_distributed_67 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_66[0][0]']
#  ibuted)                        4)
#
#  time_distributed_68 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_67[0][0]']
#  ibuted)                        4)
#
#  time_distributed_69 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_68[0][0]']
#  ibuted)                        4)
#
#  time_distributed_70 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_69[0][0]']
#  ibuted)                        28)
#
#  time_distributed_71 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_70[0][0]']
#  ibuted)                        28)
#
#  time_distributed_72 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_71[0][0]']
#  ibuted)                        28)
#
#  time_distributed_73 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_72[0][0]']
#  ibuted)                        28)
#
#  time_distributed_74 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_73[0][0]']
#  ibuted)                        28)
#
#  time_distributed_75 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_74[0][0]']
#  ibuted)                        56)
#
#  time_distributed_76 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_75[0][0]']
#  ibuted)                        56)
#
#  time_distributed_77 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_76[0][0]']
#  ibuted)                        56)
#
#  time_distributed_78 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_77[0][0]']
#  ibuted)                        56)
#
#  bidirectional_2 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_78[0][0]']
#  )                              12)
#
#  time_distributed_79 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional_2[0][0]']
#  ibuted)                        28)
#
#  concatenate_4 (Concatenate)    (None, 3, 32, 32, 2  0           ['time_distributed_79[0][0]',
#                                 56)                               'time_distributed_73[0][0]']
#
#  time_distributed_80 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate_4[0][0]']
#  ibuted)                        28)
#
#  time_distributed_81 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_80[0][0]']
#  ibuted)                        28)
#
#  time_distributed_82 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_81[0][0]']
#  ibuted)                        28)
#
#  time_distributed_83 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_82[0][0]']
#  ibuted)                        28)
#
#  time_distributed_84 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_83[0][0]']
#  ibuted)                        4)
#
#  concatenate_5 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_84[0][0]',
#                                 28)                               'time_distributed_68[0][0]']
#
#  time_distributed_85 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_5[0][0]']
#  ibuted)                        4)
#
#  time_distributed_86 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_85[0][0]']
#  ibuted)                        4)
#
#  time_distributed_87 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_86[0][0]']
#  ibuted)                        4)
#
#  time_distributed_88 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_87[0][0]']
#  ibuted)                         32)
#
#  concatenate_6 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_88[0][0]',
#                                  64)                              'time_distributed_63[0][0]']
#
#  time_distributed_89 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_6[0][0]']
#  ibuted)                         32)
#
#  time_distributed_90 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_89[0][0]']
#  ibuted)                         32)
#
#  time_distributed_91 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_90[0][0]']
#  ibuted)                         32)
#
#  time_distributed_92 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_91[0][0]']
#  ibuted)                         32)
#
#  time_distributed_93 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_92[0][0]']
#  ibuted)                         32)
#
#  time_distributed_94 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_93[0][0]']
#  ibuted)                         16)
#
#  concatenate_7 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_94[0][0]',
#                                  32)                              'time_distributed_58[0][0]']
#
#  time_distributed_95 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_7[0][0]']
#  ibuted)                         16)
#
#  time_distributed_96 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_95[0][0]']
#  ibuted)                         16)
#
#  time_distributed_97 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_96[0][0]']
#  ibuted)                         16)
#
#  time_distributed_98 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_97[0][0]']
#  ibuted)                         16)
#
#  bidirectional_3 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_98[0][0]']
#  )                              )
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_3[0][0]']
#                                  32)
#
#  time_distributed_99 (TimeDistr  (None, 1, 256, 256,  128        ['tf.expand_dims_1[0][0]']
#  ibuted)                         32)
#
#  conv2d_43 (Conv2D)             (None, 1, 256, 256,  33          ['time_distributed_99[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,935,329
# Trainable params: 11,932,449
# Non-trainable params: 2,880
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/40
# 248/248 [==============================] - 430s 2s/step - loss: 0.8764 - dice_coefficient: 0.1236 - binary_accuracy: 0.7123 - val_loss: 0.9386 - val_dice_coefficient: 0.0614 - val_binary_accuracy: 0.7259
# Epoch 2/40
# 248/248 [==============================] - 398s 2s/step - loss: 0.8080 - dice_coefficient: 0.1920 - binary_accuracy: 0.8619 - val_loss: 0.8609 - val_dice_coefficient: 0.1391 - val_binary_accuracy: 0.8572
# Epoch 3/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.7458 - dice_coefficient: 0.2542 - binary_accuracy: 0.9053 - val_loss: 0.8779 - val_dice_coefficient: 0.1221 - val_binary_accuracy: 0.9280
# Epoch 4/40
# 248/248 [==============================] - 398s 2s/step - loss: 0.7000 - dice_coefficient: 0.3000 - binary_accuracy: 0.9304 - val_loss: 0.8534 - val_dice_coefficient: 0.1466 - val_binary_accuracy: 0.9372
# Epoch 5/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.6431 - dice_coefficient: 0.3569 - binary_accuracy: 0.9458 - val_loss: 0.8051 - val_dice_coefficient: 0.1949 - val_binary_accuracy: 0.9580
# Epoch 6/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.6051 - dice_coefficient: 0.3949 - binary_accuracy: 0.9559 - val_loss: 0.7684 - val_dice_coefficient: 0.2316 - val_binary_accuracy: 0.9656
# Epoch 7/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.5646 - dice_coefficient: 0.4354 - binary_accuracy: 0.9628 - val_loss: 0.9297 - val_dice_coefficient: 0.0703 - val_binary_accuracy: 0.9833
# Epoch 8/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.5260 - dice_coefficient: 0.4740 - binary_accuracy: 0.9685 - val_loss: 0.7265 - val_dice_coefficient: 0.2735 - val_binary_accuracy: 0.9852
# Epoch 9/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.4694 - dice_coefficient: 0.5306 - binary_accuracy: 0.9732 - val_loss: 0.8015 - val_dice_coefficient: 0.1985 - val_binary_accuracy: 0.9854
# Epoch 10/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.4440 - dice_coefficient: 0.5560 - binary_accuracy: 0.9763 - val_loss: 0.6867 - val_dice_coefficient: 0.3133 - val_binary_accuracy: 0.9836
# Epoch 11/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.4007 - dice_coefficient: 0.5993 - binary_accuracy: 0.9790 - val_loss: 0.7066 - val_dice_coefficient: 0.2934 - val_binary_accuracy: 0.9880
# Epoch 12/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.3734 - dice_coefficient: 0.6266 - binary_accuracy: 0.9809 - val_loss: 0.9439 - val_dice_coefficient: 0.0561 - val_binary_accuracy: 0.9844
# Epoch 13/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.3500 - dice_coefficient: 0.6500 - binary_accuracy: 0.9818 - val_loss: 0.6457 - val_dice_coefficient: 0.3543 - val_binary_accuracy: 0.9835
# Epoch 14/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.3125 - dice_coefficient: 0.6875 - binary_accuracy: 0.9837 - val_loss: 0.7734 - val_dice_coefficient: 0.2266 - val_binary_accuracy: 0.9858
# Epoch 15/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2935 - dice_coefficient: 0.7065 - binary_accuracy: 0.9843 - val_loss: 0.9520 - val_dice_coefficient: 0.0480 - val_binary_accuracy: 0.9854
# Epoch 16/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2902 - dice_coefficient: 0.7098 - binary_accuracy: 0.9844 - val_loss: 0.7867 - val_dice_coefficient: 0.2133 - val_binary_accuracy: 0.9856
# Epoch 17/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2720 - dice_coefficient: 0.7280 - binary_accuracy: 0.9859 - val_loss: 0.8909 - val_dice_coefficient: 0.1091 - val_binary_accuracy: 0.9840
# Epoch 18/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2525 - dice_coefficient: 0.7475 - binary_accuracy: 0.9862 - val_loss: 0.8610 - val_dice_coefficient: 0.1390 - val_binary_accuracy: 0.9848
# Epoch 19/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2494 - dice_coefficient: 0.7506 - binary_accuracy: 0.9869 - val_loss: 0.8164 - val_dice_coefficient: 0.1836 - val_binary_accuracy: 0.9858
# Epoch 20/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.2427 - dice_coefficient: 0.7573 - binary_accuracy: 0.9870 - val_loss: 0.5900 - val_dice_coefficient: 0.4100 - val_binary_accuracy: 0.9874
# Epoch 21/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2219 - dice_coefficient: 0.7781 - binary_accuracy: 0.9875 - val_loss: 0.8796 - val_dice_coefficient: 0.1204 - val_binary_accuracy: 0.9846
# Epoch 22/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.2090 - dice_coefficient: 0.7910 - binary_accuracy: 0.9880 - val_loss: 0.5438 - val_dice_coefficient: 0.4562 - val_binary_accuracy: 0.9882
# Epoch 23/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2131 - dice_coefficient: 0.7869 - binary_accuracy: 0.9875 - val_loss: 0.7948 - val_dice_coefficient: 0.2052 - val_binary_accuracy: 0.9850
# Epoch 24/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2167 - dice_coefficient: 0.7833 - binary_accuracy: 0.9880 - val_loss: 0.7956 - val_dice_coefficient: 0.2044 - val_binary_accuracy: 0.9874
# Epoch 25/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.1905 - dice_coefficient: 0.8095 - binary_accuracy: 0.9883 - val_loss: 0.7009 - val_dice_coefficient: 0.2991 - val_binary_accuracy: 0.9847
# Epoch 26/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.2012 - dice_coefficient: 0.7988 - binary_accuracy: 0.9881 - val_loss: 0.6643 - val_dice_coefficient: 0.3357 - val_binary_accuracy: 0.9868
# Epoch 27/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.1868 - dice_coefficient: 0.8132 - binary_accuracy: 0.9883 - val_loss: 0.9149 - val_dice_coefficient: 0.0851 - val_binary_accuracy: 0.9857
# Epoch 28/40
# 248/248 [==============================] - 395s 2s/step - loss: 0.1885 - dice_coefficient: 0.8115 - binary_accuracy: 0.9892 - val_loss: 0.9692 - val_dice_coefficient: 0.0308 - val_binary_accuracy: 0.9841
# Epoch 29/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.1832 - dice_coefficient: 0.8168 - binary_accuracy: 0.9887 - val_loss: 0.9322 - val_dice_coefficient: 0.0678 - val_binary_accuracy: 0.9864
# Epoch 30/40
# 248/248 [==============================] - 395s 2s/step - loss: 0.1768 - dice_coefficient: 0.8232 - binary_accuracy: 0.9890 - val_loss: 0.5488 - val_dice_coefficient: 0.4512 - val_binary_accuracy: 0.9880
# Epoch 31/40
# 248/248 [==============================] - 395s 2s/step - loss: 0.1710 - dice_coefficient: 0.8290 - binary_accuracy: 0.9891 - val_loss: 0.6198 - val_dice_coefficient: 0.3802 - val_binary_accuracy: 0.9882
# Epoch 32/40
# 248/248 [==============================] - 395s 2s/step - loss: 0.1712 - dice_coefficient: 0.8288 - binary_accuracy: 0.9892 - val_loss: 0.9898 - val_dice_coefficient: 0.0102 - val_binary_accuracy: 0.9851
# Epoch 33/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.1708 - dice_coefficient: 0.8292 - binary_accuracy: 0.9897 - val_loss: 0.6060 - val_dice_coefficient: 0.3940 - val_binary_accuracy: 0.9869
# Epoch 34/40
# 248/248 [==============================] - 395s 2s/step - loss: 0.1780 - dice_coefficient: 0.8220 - binary_accuracy: 0.9892 - val_loss: 0.8150 - val_dice_coefficient: 0.1850 - val_binary_accuracy: 0.9872
# Epoch 35/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.1660 - dice_coefficient: 0.8340 - binary_accuracy: 0.9892 - val_loss: 0.7033 - val_dice_coefficient: 0.2967 - val_binary_accuracy: 0.9872
# Epoch 36/40
# 248/248 [==============================] - 396s 2s/step - loss: 0.1703 - dice_coefficient: 0.8297 - binary_accuracy: 0.9895 - val_loss: 0.8061 - val_dice_coefficient: 0.1939 - val_binary_accuracy: 0.9875
# Epoch 37/40
# 248/248 [==============================] - 395s 2s/step - loss: 0.1756 - dice_coefficient: 0.8244 - binary_accuracy: 0.9895 - val_loss: 0.6901 - val_dice_coefficient: 0.3099 - val_binary_accuracy: 0.9867
# Epoch 38/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.1776 - dice_coefficient: 0.8224 - binary_accuracy: 0.9891 - val_loss: 0.7661 - val_dice_coefficient: 0.2339 - val_binary_accuracy: 0.9874
# Epoch 39/40
# 248/248 [==============================] - 395s 2s/step - loss: 0.1670 - dice_coefficient: 0.8330 - binary_accuracy: 0.9895 - val_loss: 0.8349 - val_dice_coefficient: 0.1651 - val_binary_accuracy: 0.9867
# Epoch 40/40
# 248/248 [==============================] - 397s 2s/step - loss: 0.1638 - dice_coefficient: 0.8362 - binary_accuracy: 0.9898 - val_loss: 0.8753 - val_dice_coefficient: 0.1247 - val_binary_accuracy: 0.9845

# %%
model.save('/gdrive/MyDrive/Sensor40.unet-noaugonvalidation-2510-5e-5-roiadjusted-relu-batch12-2blocks-batcheverywhere-relualsoonbidirectional.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor40.unet-noaugonvalidation-2510-5e-5-roiadjusted-relu-batch12-2blocks-batcheverywhere-relualsoonbidirectional.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')

  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.74708

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48257175
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.5423565
# 1/1 [==============================] - 0s 24ms/step
# 0.5771444
# 1/1 [==============================] - 0s 28ms/step
# 0.47620392
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48721313
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.52880573
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.6410215
# 1/1 [==============================] - 0s 28ms/step
# 0.47958374
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4992752
# 1/1 [==============================] - 0s 29ms/step
# 0.69607675
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.7135262
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.5310309
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.47772217
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48863983
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.4853992
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4877243
# 1/1 [==============================] - 0s 28ms/step
# 0.499794
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49988556
# 1/1 [==============================] - 0s 27ms/step
# 0.48771667
# 1/1 [==============================] - 0s 25ms/step
# 0.5436222
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.4794922
# 1/1 [==============================] - 0s 24ms/step
# 0.48876953
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.5789534
# 1/1 [==============================] - 0s 27ms/step
# 0.6410215
# 1/1 [==============================] - 0s 27ms/step
# 0.47576904
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4788742
# 1/1 [==============================] - 0s 28ms/step
# 0.49414062
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.47958374
# 1/1 [==============================] - 0s 26ms/step
# 0.51787883
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7415619
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.5699408
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.59353554
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4884796
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4743271
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48841095
# 1/1 [==============================] - 0s 27ms/step
# 0.49371338
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.47293854
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47318268
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.47968292
# 1/1 [==============================] - 0s 25ms/step
# 0.4748993
# 1/1 [==============================] - 0s 25ms/step
# 0.48003608
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48516846
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.4881668
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.49990082
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.49999237
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.4739914
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 0.47293854
# 1/1 [==============================] - 0s 28ms/step
# 0.48825836
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.4884796
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.49371338
# 1/1 [==============================] - 0s 30ms/step
# 0.4879303
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.48797607
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 38ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.4790039
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.47335815
# 1/1 [==============================] - 0s 25ms/step
# 0.47214508
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.7461431
# 1/1 [==============================] - 0s 30ms/step
# 0.49996948
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48840332
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7070052
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47620392
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.4998169
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4979477
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.47699738
# 1/1 [==============================] - 0s 29ms/step
# 0.48721313
# 1/1 [==============================] - 0s 31ms/step
# 0.49710846
# 1/1 [==============================] - 0s 25ms/step
# 0.5699408
# 1/1 [==============================] - 0s 28ms/step
# 0.5771444
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.47898102
# 1/1 [==============================] - 0s 28ms/step
# 0.48792267
# 1/1 [==============================] - 0s 30ms/step
# 0.49594116
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.74708
# 1/1 [==============================] - 0s 25ms/step
# 0.48779297
# 1/1 [==============================] - 0s 28ms/step
# 0.47968292
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49958038
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.47699738
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47571564
# 1/1 [==============================] - 0s 26ms/step
# 0.47318268
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.48792267
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.6074815
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4950943
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 37ms/step
# 0.48744202
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.4790039
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.4926628
# 1/1 [==============================] - 0s 32ms/step
# 0.47699738
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.5310309
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48861694
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.47318268
# 1/1 [==============================] - 0s 34ms/step
# 0.47576904
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.4745636
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49991608
# 1/1 [==============================] - 0s 30ms/step
# 0.4883499
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48792267
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.74708
# 1/1 [==============================] - 0s 31ms/step
# 0.48723602
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4791565
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.5416575
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.47859192
# 1/1 [==============================] - 0s 25ms/step
# 0.47912598
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.74708
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.5413201
# 1/1 [==============================] - 0s 29ms/step
# 0.47335815
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.59353554
# 1/1 [==============================] - 0s 25ms/step
# 0.48001862
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4739914
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4783249
# 1/1 [==============================] - 0s 28ms/step
# 0.62423116
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48820496
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.47413635
# 1/1 [==============================] - 0s 27ms/step
# 0.5310309
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.59082276
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48792267
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.48841095
# 1/1 [==============================] - 0s 27ms/step
# 0.499794
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.4872818
# 1/1 [==============================] - 0s 27ms/step
# 0.4998169
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49565125
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.5516191
# 1/1 [==============================] - 0s 25ms/step
# 0.47866058
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4853992
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48877716
# 1/1 [==============================] - 0s 28ms/step
# 0.70883983
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7831435
# 1/1 [==============================] - 0s 28ms/step
# 0.51047367
# 1/1 [==============================] - 0s 27ms/step
# 0.4790039
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49409485
# 1/1 [==============================] - 0s 30ms/step
# 0.48911703
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.6299045
# 1/1 [==============================] - 0s 26ms/step
# 0.48044246
# 1/1 [==============================] - 0s 28ms/step
# 0.47293854
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.48737335
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 41ms/step
# 0.48832703
# 1/1 [==============================] - 0s 28ms/step
# 0.47214508
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 37ms/step
# 0.49800873
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.74781305
# 1/1 [==============================] - 0s 29ms/step
# 0.6997245
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.50086766
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.47436523
# 1/1 [==============================] - 0s 25ms/step
# 0.4748459
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.74708
# 1/1 [==============================] - 0s 25ms/step
# 0.48810577
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47436523
# 1/1 [==============================] - 0s 24ms/step
# 0.4743271
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49964142
# 1/1 [==============================] - 0s 29ms/step
# 0.48841095
# 1/1 [==============================] - 0s 28ms/step
# 0.4885788
# 1/1 [==============================] - 0s 28ms/step
# 0.49414062
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.70883983
# 1/1 [==============================] - 0s 30ms/step
# 0.47421378
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.5789534
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.53286666
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.5189362
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49946594
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.5423565
# 1/1 [==============================] - 0s 27ms/step
# 0.5789534
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4998169
# 1/1 [==============================] - 0s 27ms/step
# 0.49710846
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 38ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.7461431
# 1/1 [==============================] - 0s 31ms/step
# 0.62262726
# 1/1 [==============================] - 0s 30ms/step
# 0.4760437
# 1/1 [==============================] - 0s 27ms/step
# 0.474411
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47436523
# 1/1 [==============================] - 0s 28ms/step
# 0.49958038
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48731995
# 1/1 [==============================] - 0s 29ms/step
# 0.5416575
# 1/1 [==============================] - 0s 28ms/step
# 0.6849662
# 1/1 [==============================] - 0s 24ms/step
# 0.49643707
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.5416575
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.5416575
# 1/1 [==============================] - 0s 25ms/step
# 0.4950943
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.47620392
# 1/1 [==============================] - 0s 37ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48810577
# 1/1 [==============================] - 0s 29ms/step
# 0.49991608
# 1/1 [==============================] - 0s 28ms/step
# 0.47970223
# 1/1 [==============================] - 0s 27ms/step
# 0.48773956
# 1/1 [==============================] - 0s 27ms/step
# 0.70130426
# 1/1 [==============================] - 0s 25ms/step
# 0.47236633
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.49996948
# 1/1 [==============================] - 0s 32ms/step
# 0.48876953
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49957275
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49946594
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48409328
# 1/1 [==============================] - 0s 27ms/step
# 0.48789978
# 1/1 [==============================] - 0s 34ms/step
# 0.64137584
# 1/1 [==============================] - 0s 32ms/step
# 0.47724703
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.47214508
# 1/1 [==============================] - 0s 32ms/step
# 0.5174987
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4877243
# 1/1 [==============================] - 0s 28ms/step
# 0.48847198
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.47898102
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.5861173
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.7073791
# 1/1 [==============================] - 0s 36ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48744202
# 1/1 [==============================] - 0s 26ms/step
# 0.48044246
# 1/1 [==============================] - 0s 31ms/step
# 0.54879224
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4743271
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.4881668
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47236633
# 1/1 [==============================] - 0s 26ms/step
# 0.5174987
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47293854
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47956848
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48880768
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.47970223
# 1/1 [==============================] - 0s 35ms/step
# 0.47968292
# 1/1 [==============================] - 0s 29ms/step
# 0.47968292
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.5088619
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# Mean IoU is:  [0.52129936]
