# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30-unet-noaugonvalidation-5e-5-roiadjusted-relu-3blocksstartingfrom8-recurrentdropout02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
batch_size=12

# %%
x, y = val_loader.__next__()
for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)
conv1 = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv1)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv2)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv5)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation= 'relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation=layers.LeakyReLU() ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

#expanding path

concat1 = layers.concatenate([up1, conv9])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal', activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu') ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up5= layers.TimeDistributed( layers.Conv2DTranspose( 8,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up5, conv1])

x = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(8,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)

model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_42 (TimeDistr  (None, 3, 256, 256,  80         ['input_3[0][0]']
#  ibuted)                         8)
#
#  time_distributed_43 (TimeDistr  (None, 3, 256, 256,  32         ['time_distributed_42[0][0]']
#  ibuted)                         8)
#
#  time_distributed_44 (TimeDistr  (None, 3, 256, 256,  584        ['time_distributed_43[0][0]']
#  ibuted)                         8)
#
#  time_distributed_45 (TimeDistr  (None, 3, 256, 256,  32         ['time_distributed_44[0][0]']
#  ibuted)                         8)
#
#  time_distributed_46 (TimeDistr  (None, 3, 256, 256,  584        ['time_distributed_45[0][0]']
#  ibuted)                         8)
#
#  time_distributed_47 (TimeDistr  (None, 3, 256, 256,  32         ['time_distributed_46[0][0]']
#  ibuted)                         8)
#
#  time_distributed_48 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_47[0][0]']
#  ibuted)                         8)
#
#  time_distributed_49 (TimeDistr  (None, 3, 128, 128,  1168       ['time_distributed_48[0][0]']
#  ibuted)                         16)
#
#  time_distributed_50 (TimeDistr  (None, 3, 128, 128,  64         ['time_distributed_49[0][0]']
#  ibuted)                         16)
#
#  time_distributed_51 (TimeDistr  (None, 3, 128, 128,  2320       ['time_distributed_50[0][0]']
#  ibuted)                         16)
#
#  time_distributed_52 (TimeDistr  (None, 3, 128, 128,  64         ['time_distributed_51[0][0]']
#  ibuted)                         16)
#
#  time_distributed_53 (TimeDistr  (None, 3, 128, 128,  2320       ['time_distributed_52[0][0]']
#  ibuted)                         16)
#
#  time_distributed_54 (TimeDistr  (None, 3, 128, 128,  64         ['time_distributed_53[0][0]']
#  ibuted)                         16)
#
#  time_distributed_55 (TimeDistr  (None, 3, 64, 64, 1  0          ['time_distributed_54[0][0]']
#  ibuted)                        6)
#
#  time_distributed_56 (TimeDistr  (None, 3, 64, 64, 3  4640       ['time_distributed_55[0][0]']
#  ibuted)                        2)
#
#  time_distributed_57 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_56[0][0]']
#  ibuted)                        2)
#
#  time_distributed_58 (TimeDistr  (None, 3, 64, 64, 3  9248       ['time_distributed_57[0][0]']
#  ibuted)                        2)
#
#  time_distributed_59 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_58[0][0]']
#  ibuted)                        2)
#
#  time_distributed_60 (TimeDistr  (None, 3, 64, 64, 3  9248       ['time_distributed_59[0][0]']
#  ibuted)                        2)
#
#  time_distributed_61 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_60[0][0]']
#  ibuted)                        2)
#
#  time_distributed_62 (TimeDistr  (None, 3, 32, 32, 3  0          ['time_distributed_61[0][0]']
#  ibuted)                        2)
#
#  time_distributed_63 (TimeDistr  (None, 3, 32, 32, 6  18496      ['time_distributed_62[0][0]']
#  ibuted)                        4)
#
#  time_distributed_64 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_63[0][0]']
#  ibuted)                        4)
#
#  time_distributed_65 (TimeDistr  (None, 3, 32, 32, 6  36928      ['time_distributed_64[0][0]']
#  ibuted)                        4)
#
#  time_distributed_66 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_65[0][0]']
#  ibuted)                        4)
#
#  time_distributed_67 (TimeDistr  (None, 3, 32, 32, 6  36928      ['time_distributed_66[0][0]']
#  ibuted)                        4)
#
#  time_distributed_68 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_67[0][0]']
#  ibuted)                        4)
#
#  time_distributed_69 (TimeDistr  (None, 3, 16, 16, 6  0          ['time_distributed_68[0][0]']
#  ibuted)                        4)
#
#  time_distributed_70 (TimeDistr  (None, 3, 16, 16, 1  73856      ['time_distributed_69[0][0]']
#  ibuted)                        28)
#
#  time_distributed_71 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_70[0][0]']
#  ibuted)                        28)
#
#  time_distributed_72 (TimeDistr  (None, 3, 16, 16, 1  147584     ['time_distributed_71[0][0]']
#  ibuted)                        28)
#
#  time_distributed_73 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_72[0][0]']
#  ibuted)                        28)
#
#  time_distributed_74 (TimeDistr  (None, 3, 16, 16, 1  147584     ['time_distributed_73[0][0]']
#  ibuted)                        28)
#
#  time_distributed_75 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_74[0][0]']
#  ibuted)                        28)
#
#  time_distributed_76 (TimeDistr  (None, 3, 8, 8, 128  0          ['time_distributed_75[0][0]']
#  ibuted)                        )
#
#  time_distributed_77 (TimeDistr  (None, 3, 8, 8, 256  295168     ['time_distributed_76[0][0]']
#  ibuted)                        )
#
#  time_distributed_78 (TimeDistr  (None, 3, 8, 8, 256  1024       ['time_distributed_77[0][0]']
#  ibuted)                        )
#
#  time_distributed_79 (TimeDistr  (None, 3, 8, 8, 256  590080     ['time_distributed_78[0][0]']
#  ibuted)                        )
#
#  time_distributed_80 (TimeDistr  (None, 3, 8, 8, 256  1024       ['time_distributed_79[0][0]']
#  ibuted)                        )
#
#  time_distributed_81 (TimeDistr  (None, 3, 8, 8, 256  590080     ['time_distributed_80[0][0]']
#  ibuted)                        )
#
#  time_distributed_82 (TimeDistr  (None, 3, 8, 8, 256  1024       ['time_distributed_81[0][0]']
#  ibuted)                        )
#
#  bidirectional (Bidirectional)  (None, 3, 8, 8, 512  9439232     ['time_distributed_82[0][0]']
#                                 )
#
#  time_distributed_83 (TimeDistr  (None, 3, 16, 16, 1  589952     ['bidirectional[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 16, 16, 2  0           ['time_distributed_83[0][0]',
#                                 56)                               'time_distributed_75[0][0]']
#
#  time_distributed_84 (TimeDistr  (None, 3, 16, 16, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_85 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_84[0][0]']
#  ibuted)                        28)
#
#  time_distributed_86 (TimeDistr  (None, 3, 16, 16, 1  147584     ['time_distributed_85[0][0]']
#  ibuted)                        28)
#
#  time_distributed_87 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_86[0][0]']
#  ibuted)                        28)
#
#  time_distributed_88 (TimeDistr  (None, 3, 16, 16, 1  147584     ['time_distributed_87[0][0]']
#  ibuted)                        28)
#
#  time_distributed_89 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_88[0][0]']
#  ibuted)                        28)
#
#  time_distributed_90 (TimeDistr  (None, 3, 32, 32, 6  73792      ['time_distributed_89[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 32, 32, 1  0           ['time_distributed_90[0][0]',
#                                 28)                               'time_distributed_68[0][0]']
#
#  time_distributed_91 (TimeDistr  (None, 3, 32, 32, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_92 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_91[0][0]']
#  ibuted)                        4)
#
#  time_distributed_93 (TimeDistr  (None, 3, 32, 32, 6  36928      ['time_distributed_92[0][0]']
#  ibuted)                        4)
#
#  time_distributed_94 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_93[0][0]']
#  ibuted)                        4)
#
#  time_distributed_95 (TimeDistr  (None, 3, 32, 32, 6  36928      ['time_distributed_94[0][0]']
#  ibuted)                        4)
#
#  time_distributed_96 (TimeDistr  (None, 3, 64, 64, 3  18464      ['time_distributed_95[0][0]']
#  ibuted)                        2)
#
#  concatenate_2 (Concatenate)    (None, 3, 64, 64, 6  0           ['time_distributed_96[0][0]',
#                                 4)                                'time_distributed_61[0][0]']
#
#  time_distributed_97 (TimeDistr  (None, 3, 64, 64, 3  18464      ['concatenate_2[0][0]']
#  ibuted)                        2)
#
#  time_distributed_98 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_97[0][0]']
#  ibuted)                        2)
#
#  time_distributed_99 (TimeDistr  (None, 3, 64, 64, 3  9248       ['time_distributed_98[0][0]']
#  ibuted)                        2)
#
#  time_distributed_100 (TimeDist  (None, 3, 64, 64, 3  128        ['time_distributed_99[0][0]']
#  ributed)                       2)
#
#  time_distributed_101 (TimeDist  (None, 3, 64, 64, 3  9248       ['time_distributed_100[0][0]']
#  ributed)                       2)
#
#  time_distributed_102 (TimeDist  (None, 3, 64, 64, 3  128        ['time_distributed_101[0][0]']
#  ributed)                       2)
#
#  time_distributed_103 (TimeDist  (None, 3, 128, 128,  4624       ['time_distributed_102[0][0]']
#  ributed)                        16)
#
#  concatenate_3 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_103[0][0]',
#                                  32)                              'time_distributed_54[0][0]']
#
#  time_distributed_104 (TimeDist  (None, 3, 128, 128,  4624       ['concatenate_3[0][0]']
#  ributed)                        16)
#
#  time_distributed_105 (TimeDist  (None, 3, 128, 128,  64         ['time_distributed_104[0][0]']
#  ributed)                        16)
#
#  time_distributed_106 (TimeDist  (None, 3, 128, 128,  2320       ['time_distributed_105[0][0]']
#  ributed)                        16)
#
#  time_distributed_107 (TimeDist  (None, 3, 128, 128,  64         ['time_distributed_106[0][0]']
#  ributed)                        16)
#
#  time_distributed_108 (TimeDist  (None, 3, 128, 128,  2320       ['time_distributed_107[0][0]']
#  ributed)                        16)
#
#  time_distributed_109 (TimeDist  (None, 3, 128, 128,  64         ['time_distributed_108[0][0]']
#  ributed)                        16)
#
#  time_distributed_110 (TimeDist  (None, 3, 256, 256,  1160       ['time_distributed_109[0][0]']
#  ributed)                        8)
#
#  concatenate_4 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_110[0][0]',
#                                  16)                              'time_distributed_47[0][0]']
#
#  time_distributed_111 (TimeDist  (None, 3, 256, 256,  1160       ['concatenate_4[0][0]']
#  ributed)                        8)
#
#  time_distributed_112 (TimeDist  (None, 3, 256, 256,  32         ['time_distributed_111[0][0]']
#  ributed)                        8)
#
#  time_distributed_113 (TimeDist  (None, 3, 256, 256,  584        ['time_distributed_112[0][0]']
#  ributed)                        8)
#
#  time_distributed_114 (TimeDist  (None, 3, 256, 256,  32         ['time_distributed_113[0][0]']
#  ributed)                        8)
#
#  time_distributed_115 (TimeDist  (None, 3, 256, 256,  584        ['time_distributed_114[0][0]']
#  ributed)                        8)
#
#  time_distributed_116 (TimeDist  (None, 3, 256, 256,  32         ['time_distributed_115[0][0]']
#  ributed)                        8)
#
#  bidirectional_1 (Bidirectional  (None, 256, 256, 16  9280       ['time_distributed_116[0][0]']
#  )                              )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['bidirectional_1[0][0]']
#                                  16)
#
#  conv2d_51 (Conv2D)             (None, 1, 256, 256,  17          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 12,898,593
# Trainable params: 12,894,209
# Non-trainable params: 4,384
# __________________________________________________________________________________________________

# %%
 from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.75
    return K.pow((1-pt_1), gamma)

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[ dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=[model_checkpoint_callback],
    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 248/248 [==============================] - 283s 1s/step - loss: 0.9413 - dice_coefficient: 0.0587 - binary_accuracy: 0.6122 - val_loss: 0.9269 - val_dice_coefficient: 0.0731 - val_binary_accuracy: 0.4650
# Epoch 2/30
# 248/248 [==============================] - 261s 1s/step - loss: 0.8444 - dice_coefficient: 0.1556 - binary_accuracy: 0.8821 - val_loss: 0.7701 - val_dice_coefficient: 0.2299 - val_binary_accuracy: 0.9551
# Epoch 3/30
# 248/248 [==============================] - 263s 1s/step - loss: 0.6777 - dice_coefficient: 0.3223 - binary_accuracy: 0.9723 - val_loss: 0.6357 - val_dice_coefficient: 0.3643 - val_binary_accuracy: 0.9755
# Epoch 4/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.5683 - dice_coefficient: 0.4317 - binary_accuracy: 0.9794 - val_loss: 0.5375 - val_dice_coefficient: 0.4625 - val_binary_accuracy: 0.9792
# Epoch 5/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.4773 - dice_coefficient: 0.5227 - binary_accuracy: 0.9818 - val_loss: 0.4808 - val_dice_coefficient: 0.5192 - val_binary_accuracy: 0.9815
# Epoch 6/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.4283 - dice_coefficient: 0.5717 - binary_accuracy: 0.9837 - val_loss: 0.5065 - val_dice_coefficient: 0.4935 - val_binary_accuracy: 0.9815
# Epoch 7/30
# 248/248 [==============================] - 263s 1s/step - loss: 0.4043 - dice_coefficient: 0.5957 - binary_accuracy: 0.9850 - val_loss: 0.4760 - val_dice_coefficient: 0.5240 - val_binary_accuracy: 0.9856
# Epoch 8/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.3722 - dice_coefficient: 0.6278 - binary_accuracy: 0.9856 - val_loss: 0.5315 - val_dice_coefficient: 0.4685 - val_binary_accuracy: 0.9816
# Epoch 9/30
# 248/248 [==============================] - 263s 1s/step - loss: 0.3435 - dice_coefficient: 0.6565 - binary_accuracy: 0.9859 - val_loss: 0.4516 - val_dice_coefficient: 0.5484 - val_binary_accuracy: 0.9852
# Epoch 10/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.3071 - dice_coefficient: 0.6929 - binary_accuracy: 0.9866 - val_loss: 0.4658 - val_dice_coefficient: 0.5342 - val_binary_accuracy: 0.9822
# Epoch 11/30
# 248/248 [==============================] - 263s 1s/step - loss: 0.2845 - dice_coefficient: 0.7155 - binary_accuracy: 0.9871 - val_loss: 0.4033 - val_dice_coefficient: 0.5967 - val_binary_accuracy: 0.9826
# Epoch 12/30
# 248/248 [==============================] - 263s 1s/step - loss: 0.2542 - dice_coefficient: 0.7458 - binary_accuracy: 0.9875 - val_loss: 0.3948 - val_dice_coefficient: 0.6052 - val_binary_accuracy: 0.9828
# Epoch 13/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.2570 - dice_coefficient: 0.7430 - binary_accuracy: 0.9874 - val_loss: 0.4709 - val_dice_coefficient: 0.5291 - val_binary_accuracy: 0.9835
# Epoch 14/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.2497 - dice_coefficient: 0.7503 - binary_accuracy: 0.9884 - val_loss: 0.4297 - val_dice_coefficient: 0.5703 - val_binary_accuracy: 0.9830
# Epoch 15/30
# 248/248 [==============================] - 263s 1s/step - loss: 0.2388 - dice_coefficient: 0.7612 - binary_accuracy: 0.9887 - val_loss: 0.3569 - val_dice_coefficient: 0.6431 - val_binary_accuracy: 0.9859
# Epoch 16/30
# 248/248 [==============================] - 263s 1s/step - loss: 0.2347 - dice_coefficient: 0.7653 - binary_accuracy: 0.9885 - val_loss: 0.3304 - val_dice_coefficient: 0.6696 - val_binary_accuracy: 0.9859
# Epoch 17/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.2143 - dice_coefficient: 0.7857 - binary_accuracy: 0.9882 - val_loss: 0.3859 - val_dice_coefficient: 0.6141 - val_binary_accuracy: 0.9834
# Epoch 18/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.2147 - dice_coefficient: 0.7853 - binary_accuracy: 0.9889 - val_loss: 0.4077 - val_dice_coefficient: 0.5923 - val_binary_accuracy: 0.9833
# Epoch 19/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.2228 - dice_coefficient: 0.7772 - binary_accuracy: 0.9890 - val_loss: 0.3574 - val_dice_coefficient: 0.6426 - val_binary_accuracy: 0.9849
# Epoch 20/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.2119 - dice_coefficient: 0.7881 - binary_accuracy: 0.9890 - val_loss: 0.3480 - val_dice_coefficient: 0.6520 - val_binary_accuracy: 0.9856
# Epoch 21/30
# 248/248 [==============================] - 261s 1s/step - loss: 0.2027 - dice_coefficient: 0.7973 - binary_accuracy: 0.9893 - val_loss: 0.5061 - val_dice_coefficient: 0.4939 - val_binary_accuracy: 0.9824
# Epoch 22/30
# 248/248 [==============================] - 262s 1s/step - loss: 0.2094 - dice_coefficient: 0.7906 - binary_accuracy: 0.9892 - val_loss: 0.3120 - val_dice_coefficient: 0.6880 - val_binary_accuracy: 0.9847
# Epoch 23/30
# 248/248 [==============================] - 261s 1s/step - loss: 0.2107 - dice_coefficient: 0.7893 - binary_accuracy: 0.9887 - val_loss: 0.4807 - val_dice_coefficient: 0.5193 - val_binary_accuracy: 0.9804
# Epoch 24/30
# 248/248 [==============================] - 261s 1s/step - loss: 0.1992 - dice_coefficient: 0.8008 - binary_accuracy: 0.9893 - val_loss: 0.4818 - val_dice_coefficient: 0.5182 - val_binary_accuracy: 0.9828
# Epoch 25/30
# 248/248 [==============================] - 263s 1s/step - loss: 0.2044 - dice_coefficient: 0.7956 - binary_accuracy: 0.9895 - val_loss: 0.3936 - val_dice_coefficient: 0.6064 - val_binary_accuracy: 0.9838
# Epoch 26/30
# 248/248 [==============================] - 260s 1s/step - loss: 0.1972 - dice_coefficient: 0.8028 - binary_accuracy: 0.9893 - val_loss: 0.4140 - val_dice_coefficient: 0.5860 - val_binary_accuracy: 0.9837
# Epoch 27/30
# 248/248 [==============================] - 260s 1s/step - loss: 0.1997 - dice_coefficient: 0.8003 - binary_accuracy: 0.9891 - val_loss: 0.4257 - val_dice_coefficient: 0.5743 - val_binary_accuracy: 0.9818
# Epoch 28/30
# 248/248 [==============================] - 261s 1s/step - loss: 0.1946 - dice_coefficient: 0.8054 - binary_accuracy: 0.9894 - val_loss: 0.5139 - val_dice_coefficient: 0.4861 - val_binary_accuracy: 0.9804
# Epoch 29/30
# 248/248 [==============================] - 260s 1s/step - loss: 0.1945 - dice_coefficient: 0.8055 - binary_accuracy: 0.9897 - val_loss: 0.3659 - val_dice_coefficient: 0.6341 - val_binary_accuracy: 0.9851
# Epoch 30/30
# 248/248 [==============================] - 259s 1s/step - loss: 0.1760 - dice_coefficient: 0.8240 - binary_accuracy: 0.9901 - val_loss: 0.5930 - val_dice_coefficient: 0.4070 - val_binary_accuracy: 0.9781

# %%
model.save('/gdrive/MyDrive/Sensor30-unet-noaugonvalidation-5e-5-roiadjusted-relu-3blocksstartingfrom8-recurrentdropout02.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30-unet-noaugonvalidation-5e-5-roiadjusted-relu-3blocksstartingfrom8-recurrentdropout02.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.71220654

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 0.45896912
# 1/1 [==============================] - 0s 27ms/step
# 0.45752716
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.4911728
# 1/1 [==============================] - 0s 28ms/step
# 0.4905014
# 1/1 [==============================] - 0s 31ms/step
# 0.4918213
# 1/1 [==============================] - 0s 29ms/step
# 0.48301697
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.6849133
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.4911499
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.47205353
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.558125
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.47600928
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 0.48213196
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 40ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48929596
# 1/1 [==============================] - 0s 29ms/step
# 0.73851657
# 1/1 [==============================] - 0s 26ms/step
# 0.7467252
# 1/1 [==============================] - 0s 28ms/step
# 0.48169708
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.4881134
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.47070312
# 1/1 [==============================] - 0s 27ms/step
# 0.5230689
# 1/1 [==============================] - 0s 33ms/step
# 0.4977679
# 1/1 [==============================] - 0s 27ms/step
# 0.4919052
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49404907
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.50727504
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48301697
# 1/1 [==============================] - 0s 29ms/step
# 0.8091568
# 1/1 [==============================] - 0s 27ms/step
# 0.6849133
# 1/1 [==============================] - 0s 26ms/step
# 0.7437254
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49556732
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48736572
# 1/1 [==============================] - 0s 28ms/step
# 0.49180603
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.78987277
# 1/1 [==============================] - 0s 29ms/step
# 0.48011565
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.7980759
# 1/1 [==============================] - 0s 26ms/step
# 0.49297333
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.68980867
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.50727504
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49706894
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48983002
# 1/1 [==============================] - 0s 27ms/step
# 0.7586145
# 1/1 [==============================] - 0s 45ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.49004364
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4896927
# 1/1 [==============================] - 0s 25ms/step
# 0.48106384
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48775482
# 1/1 [==============================] - 0s 28ms/step
# 0.6098428
# 1/1 [==============================] - 0s 26ms/step
# 0.79002917
# 1/1 [==============================] - 0s 29ms/step
# 0.48908234
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49082184
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7406647
# 1/1 [==============================] - 0s 27ms/step
# 0.47317505
# 1/1 [==============================] - 0s 29ms/step
# 0.6849133
# 1/1 [==============================] - 0s 27ms/step
# 0.7502326
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.7018313
# 1/1 [==============================] - 0s 26ms/step
# 0.83687234
# 1/1 [==============================] - 0s 34ms/step
# 0.48736572
# 1/1 [==============================] - 0s 29ms/step
# 0.49080306
# 1/1 [==============================] - 0s 31ms/step
# 0.64628196
# 1/1 [==============================] - 0s 28ms/step
# 0.754068
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.70861447
# 1/1 [==============================] - 0s 28ms/step
# 0.4717102
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.8100595
# 1/1 [==============================] - 0s 29ms/step
# 0.48554993
# 1/1 [==============================] - 0s 28ms/step
# 0.48587036
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.70861447
# 1/1 [==============================] - 0s 30ms/step
# 0.8091568
# 1/1 [==============================] - 0s 33ms/step
# 0.8220097
# 1/1 [==============================] - 0s 27ms/step
# 0.4911728
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.45410156
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.4911499
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.45552063
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48215485
# 1/1 [==============================] - 0s 30ms/step
# 0.7941456
# 1/1 [==============================] - 0s 30ms/step
# 0.48309326
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.764327
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.7941456
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4580536
# 1/1 [==============================] - 0s 29ms/step
# 0.7683277
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.5201168
# 1/1 [==============================] - 0s 31ms/step
# 0.4972695
# 1/1 [==============================] - 0s 27ms/step
# 0.4911728
# 1/1 [==============================] - 0s 28ms/step
# 0.7510706
# 1/1 [==============================] - 0s 28ms/step
# 0.48552704
# 1/1 [==============================] - 0s 29ms/step
# 0.71220654
# 1/1 [==============================] - 0s 37ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.