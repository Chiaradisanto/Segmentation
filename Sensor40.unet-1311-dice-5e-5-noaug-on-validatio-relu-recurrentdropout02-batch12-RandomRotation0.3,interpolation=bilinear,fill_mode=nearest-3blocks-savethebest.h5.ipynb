# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor40.unet-1311-dice-5e-5-noaug-on-validatio-relu-recurrentdropout02-batch12-RandomRotation0.3%2Cinterpolation%3Dbilinear%2Cfill_mode%3Dnearest-3blocks-savethebest.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3,interpolation='bilinear',fill_mode='reflect'),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
batch_size=12

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv2)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv5)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv9])
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=(layers.ConvLSTM2D(8,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_4[0][0]']
#  buted)                          16)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_5[0][0]']
#  buted)                          16)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_8[0][0]']
#  buted)                          32)
#
#  time_distributed_10 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_9[0][0]']
#  ibuted)                         32)
#
#  time_distributed_11 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_10[0][0]']
#  ibuted)                         32)
#
#  time_distributed_12 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_11[0][0]']
#  ibuted)                         32)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_12[0][0]']
#  ibuted)                        2)
#
#  time_distributed_14 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_14[0][0]']
#  ibuted)                        4)
#
#  time_distributed_16 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_15[0][0]']
#  ibuted)                        4)
#
#  time_distributed_17 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_16[0][0]']
#  ibuted)                        4)
#
#  time_distributed_18 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_17[0][0]']
#  ibuted)                        4)
#
#  time_distributed_19 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_18[0][0]']
#  ibuted)                        4)
#
#  time_distributed_20 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_19[0][0]']
#  ibuted)                        4)
#
#  time_distributed_21 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_20[0][0]']
#  ibuted)                        28)
#
#  time_distributed_22 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_21[0][0]']
#  ibuted)                        28)
#
#  time_distributed_23 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_22[0][0]']
#  ibuted)                        28)
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_23[0][0]']
#  ibuted)                        28)
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_24[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_26[0][0]']
#  ibuted)                        28)
#
#  time_distributed_28 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_27[0][0]']
#  ibuted)                        56)
#
#  time_distributed_29 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_28[0][0]']
#  ibuted)                        56)
#
#  time_distributed_30 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_29[0][0]']
#  ibuted)                        56)
#
#  time_distributed_31 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_30[0][0]']
#  ibuted)                        56)
#
#  time_distributed_32 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_31[0][0]']
#  ibuted)                        56)
#
#  time_distributed_33 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_32[0][0]']
#  ibuted)                        56)
#
#  conv_lstm2d (ConvLSTM2D)       (None, 3, 16, 16, 2  4719616     ['time_distributed_33[0][0]']
#                                 56)
#
#  time_distributed_34 (TimeDistr  (None, 3, 32, 32, 1  295040     ['conv_lstm2d[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_34[0][0]',
#                                 56)                               'time_distributed_26[0][0]']
#
#  time_distributed_35 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_36 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_35[0][0]']
#  ibuted)                        28)
#
#  time_distributed_37 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_36[0][0]']
#  ibuted)                        28)
#
#  time_distributed_38 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_37[0][0]']
#  ibuted)                        28)
#
#  time_distributed_39 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_38[0][0]']
#  ibuted)                        28)
#
#  time_distributed_40 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_39[0][0]']
#  ibuted)                        28)
#
#  time_distributed_41 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_40[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_41[0][0]',
#                                 28)                               'time_distributed_19[0][0]']
#
#  time_distributed_44 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_45 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_44[0][0]']
#  ibuted)                        4)
#
#  time_distributed_46 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_45[0][0]']
#  ibuted)                        4)
#
#  time_distributed_47 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_46[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_47[0][0]',
#                                  64)                              'time_distributed_12[0][0]']
#
#  time_distributed_48 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_49 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_48[0][0]']
#  ibuted)                         32)
#
#  time_distributed_50 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_49[0][0]']
#  ibuted)                         32)
#
#  time_distributed_51 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_50[0][0]']
#  ibuted)                         32)
#
#  time_distributed_52 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_51[0][0]']
#  ibuted)                         32)
#
#  time_distributed_53 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_52[0][0]']
#  ibuted)                         32)
#
#  time_distributed_54 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_53[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_54[0][0]',
#                                  32)                              'time_distributed_5[0][0]']
#
#  time_distributed_55 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_56 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_55[0][0]']
#  ibuted)                         16)
#
#  time_distributed_57 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_56[0][0]']
#  ibuted)                         16)
#
#  time_distributed_58 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_57[0][0]']
#  ibuted)                         16)
#
#  time_distributed_59 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_58[0][0]']
#  ibuted)                         16)
#
#  time_distributed_60 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_59[0][0]']
#  ibuted)                         16)
#
#  conv_lstm2d_1 (ConvLSTM2D)     (None, 256, 256, 8)  6944        ['time_distributed_60[0][0]']
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['conv_lstm2d_1[0][0]']
#                                  8)
#
#  conv2d_27 (Conv2D)             (None, 1, 256, 256,  9           ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 7,838,601
# Trainable params: 7,834,441
# Non-trainable params: 4,160
# __________________________________________________________________________________________________

# %%
from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.65
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.60
    return K.pow((1-pt_1), gamma)

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/40
# 248/248 [==============================] - 319s 1s/step - loss: 0.9109 - dice_coefficient: 0.0891 - binary_accuracy: 0.6944 - val_loss: 0.9081 - val_dice_coefficient: 0.0919 - val_binary_accuracy: 0.5643
# Epoch 2/40
# 248/248 [==============================] - 292s 1s/step - loss: 0.7510 - dice_coefficient: 0.2490 - binary_accuracy: 0.9557 - val_loss: 0.6511 - val_dice_coefficient: 0.3489 - val_binary_accuracy: 0.9504
# Epoch 3/40
# 248/248 [==============================] - 292s 1s/step - loss: 0.5765 - dice_coefficient: 0.4235 - binary_accuracy: 0.9776 - val_loss: 0.4809 - val_dice_coefficient: 0.5191 - val_binary_accuracy: 0.9851
# Epoch 4/40
# 248/248 [==============================] - 292s 1s/step - loss: 0.4484 - dice_coefficient: 0.5516 - binary_accuracy: 0.9823 - val_loss: 0.4638 - val_dice_coefficient: 0.5362 - val_binary_accuracy: 0.9831
# Epoch 5/40
# 248/248 [==============================] - 291s 1s/step - loss: 0.4091 - dice_coefficient: 0.5909 - binary_accuracy: 0.9847 - val_loss: 0.4095 - val_dice_coefficient: 0.5905 - val_binary_accuracy: 0.9839
# Epoch 6/40
# 248/248 [==============================] - 291s 1s/step - loss: 0.3693 - dice_coefficient: 0.6307 - binary_accuracy: 0.9853 - val_loss: 0.4340 - val_dice_coefficient: 0.5660 - val_binary_accuracy: 0.9855
# Epoch 7/40
# 248/248 [==============================] - 291s 1s/step - loss: 0.3447 - dice_coefficient: 0.6553 - binary_accuracy: 0.9860 - val_loss: 0.3847 - val_dice_coefficient: 0.6153 - val_binary_accuracy: 0.9832
# Epoch 8/40
# 248/248 [==============================] - 291s 1s/step - loss: 0.3424 - dice_coefficient: 0.6576 - binary_accuracy: 0.9876 - val_loss: 0.4037 - val_dice_coefficient: 0.5963 - val_binary_accuracy: 0.9864
# Epoch 9/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.3271 - dice_coefficient: 0.6729 - binary_accuracy: 0.9876 - val_loss: 0.4223 - val_dice_coefficient: 0.5777 - val_binary_accuracy: 0.9851
# Epoch 10/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.3135 - dice_coefficient: 0.6865 - binary_accuracy: 0.9880 - val_loss: 0.3959 - val_dice_coefficient: 0.6041 - val_binary_accuracy: 0.9845
# Epoch 11/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2937 - dice_coefficient: 0.7063 - binary_accuracy: 0.9882 - val_loss: 0.3988 - val_dice_coefficient: 0.6012 - val_binary_accuracy: 0.9859
# Epoch 12/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2967 - dice_coefficient: 0.7033 - binary_accuracy: 0.9883 - val_loss: 0.4754 - val_dice_coefficient: 0.5246 - val_binary_accuracy: 0.9766
# Epoch 13/40
# 248/248 [==============================] - 291s 1s/step - loss: 0.2758 - dice_coefficient: 0.7242 - binary_accuracy: 0.9888 - val_loss: 0.3552 - val_dice_coefficient: 0.6448 - val_binary_accuracy: 0.9846
# Epoch 14/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2682 - dice_coefficient: 0.7318 - binary_accuracy: 0.9885 - val_loss: 0.3905 - val_dice_coefficient: 0.6095 - val_binary_accuracy: 0.9850
# Epoch 15/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2736 - dice_coefficient: 0.7264 - binary_accuracy: 0.9888 - val_loss: 0.3743 - val_dice_coefficient: 0.6257 - val_binary_accuracy: 0.9845
# Epoch 16/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2474 - dice_coefficient: 0.7526 - binary_accuracy: 0.9890 - val_loss: 0.3586 - val_dice_coefficient: 0.6414 - val_binary_accuracy: 0.9832
# Epoch 17/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2450 - dice_coefficient: 0.7550 - binary_accuracy: 0.9892 - val_loss: 0.3769 - val_dice_coefficient: 0.6231 - val_binary_accuracy: 0.9852
# Epoch 18/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2415 - dice_coefficient: 0.7585 - binary_accuracy: 0.9894 - val_loss: 0.4185 - val_dice_coefficient: 0.5815 - val_binary_accuracy: 0.9817
# Epoch 19/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2306 - dice_coefficient: 0.7694 - binary_accuracy: 0.9901 - val_loss: 0.3166 - val_dice_coefficient: 0.6834 - val_binary_accuracy: 0.9858
# Epoch 20/40
# 248/248 [==============================] - 289s 1s/step - loss: 0.2336 - dice_coefficient: 0.7664 - binary_accuracy: 0.9896 - val_loss: 0.5083 - val_dice_coefficient: 0.4917 - val_binary_accuracy: 0.9775
# Epoch 21/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2262 - dice_coefficient: 0.7738 - binary_accuracy: 0.9894 - val_loss: 0.3430 - val_dice_coefficient: 0.6570 - val_binary_accuracy: 0.9839
# Epoch 22/40
# 248/248 [==============================] - 291s 1s/step - loss: 0.2205 - dice_coefficient: 0.7795 - binary_accuracy: 0.9900 - val_loss: 0.3338 - val_dice_coefficient: 0.6662 - val_binary_accuracy: 0.9850
# Epoch 23/40
# 248/248 [==============================] - 291s 1s/step - loss: 0.2079 - dice_coefficient: 0.7921 - binary_accuracy: 0.9903 - val_loss: 0.4041 - val_dice_coefficient: 0.5959 - val_binary_accuracy: 0.9802
# Epoch 24/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2125 - dice_coefficient: 0.7875 - binary_accuracy: 0.9901 - val_loss: 0.3706 - val_dice_coefficient: 0.6294 - val_binary_accuracy: 0.9809
# Epoch 25/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2007 - dice_coefficient: 0.7993 - binary_accuracy: 0.9899 - val_loss: 0.4073 - val_dice_coefficient: 0.5927 - val_binary_accuracy: 0.9805
# Epoch 26/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1950 - dice_coefficient: 0.8050 - binary_accuracy: 0.9903 - val_loss: 0.4175 - val_dice_coefficient: 0.5825 - val_binary_accuracy: 0.9780
# Epoch 27/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1964 - dice_coefficient: 0.8036 - binary_accuracy: 0.9899 - val_loss: 0.3640 - val_dice_coefficient: 0.6360 - val_binary_accuracy: 0.9837
# Epoch 28/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2159 - dice_coefficient: 0.7841 - binary_accuracy: 0.9899 - val_loss: 0.3703 - val_dice_coefficient: 0.6297 - val_binary_accuracy: 0.9840
# Epoch 29/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.2019 - dice_coefficient: 0.7981 - binary_accuracy: 0.9901 - val_loss: 0.3987 - val_dice_coefficient: 0.6013 - val_binary_accuracy: 0.9784
# Epoch 30/40
# 248/248 [==============================] - 291s 1s/step - loss: 0.1946 - dice_coefficient: 0.8054 - binary_accuracy: 0.9896 - val_loss: 0.3785 - val_dice_coefficient: 0.6215 - val_binary_accuracy: 0.9814
# Epoch 31/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1917 - dice_coefficient: 0.8083 - binary_accuracy: 0.9903 - val_loss: 0.3776 - val_dice_coefficient: 0.6224 - val_binary_accuracy: 0.9811
# Epoch 32/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1804 - dice_coefficient: 0.8196 - binary_accuracy: 0.9903 - val_loss: 0.3191 - val_dice_coefficient: 0.6809 - val_binary_accuracy: 0.9847
# Epoch 33/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1793 - dice_coefficient: 0.8207 - binary_accuracy: 0.9904 - val_loss: 0.3445 - val_dice_coefficient: 0.6555 - val_binary_accuracy: 0.9833
# Epoch 34/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1672 - dice_coefficient: 0.8328 - binary_accuracy: 0.9907 - val_loss: 0.3742 - val_dice_coefficient: 0.6258 - val_binary_accuracy: 0.9836
# Epoch 35/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1804 - dice_coefficient: 0.8196 - binary_accuracy: 0.9909 - val_loss: 0.4253 - val_dice_coefficient: 0.5747 - val_binary_accuracy: 0.9811
# Epoch 36/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1863 - dice_coefficient: 0.8137 - binary_accuracy: 0.9906 - val_loss: 0.3780 - val_dice_coefficient: 0.6220 - val_binary_accuracy: 0.9796
# Epoch 37/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1799 - dice_coefficient: 0.8201 - binary_accuracy: 0.9904 - val_loss: 0.3215 - val_dice_coefficient: 0.6785 - val_binary_accuracy: 0.9836
# Epoch 38/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1785 - dice_coefficient: 0.8215 - binary_accuracy: 0.9904 - val_loss: 0.3412 - val_dice_coefficient: 0.6588 - val_binary_accuracy: 0.9853
# Epoch 39/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1663 - dice_coefficient: 0.8337 - binary_accuracy: 0.9908 - val_loss: 0.3496 - val_dice_coefficient: 0.6504 - val_binary_accuracy: 0.9814
# Epoch 40/40
# 248/248 [==============================] - 290s 1s/step - loss: 0.1601 - dice_coefficient: 0.8399 - binary_accuracy: 0.9908 - val_loss: 0.3434 - val_dice_coefficient: 0.6566 - val_binary_accuracy: 0.9843

# %%
model.save('/gdrive/MyDrive/Sensor40.unet-1311-dice-5e-5-noaug-on-validatio-relu-recurrentdropout02-batch12-RandomRotation0.3,interpolation=bilinear,fill_mode=nearest-3blocks-savethebest.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor40.unet-1311-dice-5e-5-noaug-on-validatio-relu-recurrentdropout02-batch12-RandomRotation0.3,interpolation=bilinear,fill_mode=nearest-3blocks-savethebest.h5", compile=False)

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np


class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale", target_size=(256,256)))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale", target_size=(256,256)))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
        x, y = np.array(xs), np.array(ys)
      #  print(x.shape)
      #  print(y.shape)

        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0,a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.9048654

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    

mean_IoU = df.mean().values
boxplot = df.boxplot(grid=False, vert=True,  # vertical box alignment
                     patch_artist=False)  # fill with color)
std=df.std()
print('number of total masks is: ', len(IoU_values))

print("Mean IoU is: ", mean_IoU)
print("standard deviation is ",std)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 0.87579465
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.80612844
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.86205536
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.472821
# 1/1 [==============================] - 0s 25ms/step
# 0.8509658
# 1/1 [==============================] - 0s 23ms/step
# 0.48621368
# 1/1 [==============================] - 0s 26ms/step
# 0.49653625
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.7215357
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48106384
# 1/1 [==============================] - 0s 24ms/step
# 0.80612844
# 1/1 [==============================] - 0s 25ms/step
# 0.8174617
# 1/1 [==============================] - 0s 25ms/step
# 0.49623108
# 1/1 [==============================] - 0s 23ms/step
# 0.85687184
# 1/1 [==============================] - 0s 23ms/step
# 0.8640004
# 1/1 [==============================] - 0s 29ms/step
# 0.4827881
# 1/1 [==============================] - 0s 25ms/step
# 0.482872
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.85815644
# 1/1 [==============================] - 0s 24ms/step
# 0.48106384
# 1/1 [==============================] - 0s 25ms/step
# 0.84611684
# 1/1 [==============================] - 0s 23ms/step
# 0.760517
# 1/1 [==============================] - 0s 23ms/step
# 0.86764854
# 1/1 [==============================] - 0s 25ms/step
# 0.4793625
# 1/1 [==============================] - 0s 23ms/step
# 0.86205536
# 1/1 [==============================] - 0s 24ms/step
# 0.8509658
# 1/1 [==============================] - 0s 25ms/step
# 0.48397827
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.89305127
# 1/1 [==============================] - 0s 25ms/step
# 0.4790268
# 1/1 [==============================] - 0s 26ms/step
# 0.85279775
# 1/1 [==============================] - 0s 26ms/step
# 0.482872
# 1/1 [==============================] - 0s 25ms/step
# 0.47637177
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.6955355
# 1/1 [==============================] - 0s 27ms/step
# 0.48847198
# 1/1 [==============================] - 0s 28ms/step
# 0.8284451
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.8300974
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.48587036
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.47527313
# 1/1 [==============================] - 0s 23ms/step
# 0.83517873
# 1/1 [==============================] - 0s 28ms/step
# 0.8873899
# 1/1 [==============================] - 0s 26ms/step
# 0.4844513
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.84138036
# 1/1 [==============================] - 0s 23ms/step
# 0.48587036
# 1/1 [==============================] - 0s 26ms/step
# 0.51123357
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.80308795
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.87813985
# 1/1 [==============================] - 0s 26ms/step
# 0.7345722
# 1/1 [==============================] - 0s 30ms/step
# 0.48242188
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.8853239
# 1/1 [==============================] - 0s 23ms/step
# 0.79313946
# 1/1 [==============================] - 0s 23ms/step
# 0.49772644
# 1/1 [==============================] - 0s 24ms/step
# 0.8887898
# 1/1 [==============================] - 0s 26ms/step
# 0.8636771
# 1/1 [==============================] - 0s 30ms/step
# 0.85815644
# 1/1 [==============================] - 0s 23ms/step
# 0.86411667
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.86261666
# 1/1 [==============================] - 0s 25ms/step
# 0.4949646
# 1/1 [==============================] - 0s 24ms/step
# 0.8632222
# 1/1 [==============================] - 0s 26ms/step
# 0.5078162
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.85694885
# 1/1 [==============================] - 0s 29ms/step
# 0.4875183
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.89305127
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.85001755
# 1/1 [==============================] - 0s 29ms/step
# 0.8570009
# 1/1 [==============================] - 0s 27ms/step
# 0.49504852
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48138428
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.85815644
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.4790268
# 1/1 [==============================] - 0s 23ms/step
# 0.8636771
# 1/1 [==============================] - 0s 25ms/step
# 0.85267985
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.4884262
# 1/1 [==============================] - 0s 27ms/step
# 0.85302615
# 1/1 [==============================] - 0s 26ms/step
# 0.85279775
# 1/1 [==============================] - 0s 27ms/step
# 0.6800889
# 1/1 [==============================] - 0s 28ms/step
# 0.82577217
# 1/1 [==============================] - 0s 24ms/step
# 0.9048654
# 1/1 [==============================] - 0s 26ms/step
# 0.80308795
# 1/1 [==============================] - 0s 24ms/step
# 0.818285
# 1/1 [==============================] - 0s 23ms/step
# 0.4827423
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.7321725
# 1/1 [==============================] - 0s 23ms/step
# 0.8569578
# 1/1 [==============================] - 0s 26ms/step
# 0.88071823
# 1/1 [==============================] - 0s 26ms/step
# 0.84051
# 1/1 [==============================] - 0s 24ms/step
# 0.812981
# 1/1 [==============================] - 0s 23ms/step
# 0.7215357
# 1/1 [==============================] - 0s 23ms/step
# 0.4855194
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.4827423
# 1/1 [==============================] - 0s 24ms/step
# 0.4793625
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.85001755
# 1/1 [==============================] - 0s 23ms/step
# 0.48169708
# 1/1 [==============================] - 0s 24ms/step
# 0.8766136
# 1/1 [==============================] - 0s 24ms/step
# 0.81281024
# 1/1 [==============================] - 0s 23ms/step
# 0.4839859
# 1/1 [==============================] - 0s 30ms/step
# 0.808552
# 1/1 [==============================] - 0s 24ms/step
# 0.872059
# 1/1 [==============================] - 0s 26ms/step
# 0.8569578
# 1/1 [==============================] - 0s 24ms/step
# 0.568826
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48163605
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.79313946
# 1/1 [==============================] - 0s 23ms/step
# 0.872059
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.48213196
# 1/1 [==============================] - 0s 31ms/step
# 0.7726908
# 1/1 [==============================] - 0s 40ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.85302615
# 1/1 [==============================] - 0s 26ms/step
# 0.48207855
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.9048654
# 1/1 [==============================] - 0s 26ms/step
# 0.47637177
# 1/1 [==============================] - 0s 28ms/step
# 0.78555304
# 1/1 [==============================] - 0s 29ms/step
# 0.85538876
# 1/1 [==============================] - 0s 27ms/step
# 0.51933265
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.7983498
# 1/1 [==============================] - 0s 27ms/step
# 0.8269647
# 1/1 [==============================] - 0s 25ms/step
# 0.4942398
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8606108
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.49504852
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.81173754
# 1/1 [==============================] - 0s 26ms/step
# 0.49653625
# 1/1 [==============================] - 0s 24ms/step
# 0.49757385
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.85302615
# 1/1 [==============================] - 0s 29ms/step
# 0.4717331
# 1/1 [==============================] - 0s 23ms/step
# 0.4941635
# 1/1 [==============================] - 0s 26ms/step
# 0.48175812
# 1/1 [==============================] - 0s 26ms/step
# 0.82577217
# 1/1 [==============================] - 0s 26ms/step
# 0.85392463
# 1/1 [==============================] - 0s 27ms/step
# 0.85082287
# 1/1 [==============================] - 0s 23ms/step
# 0.49900818
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.78378886
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8111322
# 1/1 [==============================] - 0s 25ms/step
# 0.80413073
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.864277
# 1/1 [==============================] - 0s 115ms/step
# 0.8490376
# 1/1 [==============================] - 0s 23ms/step
# 0.84458625
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.49999237
# 1/1 [==============================] - 0s 25ms/step
# 0.4941635
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.48175812
# 1/1 [==============================] - 0s 23ms/step
# 0.48242188
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.84051
# 1/1 [==============================] - 0s 31ms/step
# 0.48587036
# 1/1 [==============================] - 0s 26ms/step
# 0.4773178
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.89758134
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.49757385
# 1/1 [==============================] - 0s 22ms/step
# 0.82580197
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.49757385
# 1/1 [==============================] - 0s 25ms/step
# 0.88203216
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.84377795
# 1/1 [==============================] - 0s 24ms/step
# 0.4847641
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8839297
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.6800889
# 1/1 [==============================] - 0s 23ms/step
# 0.48413086
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.8496945
# 1/1 [==============================] - 0s 26ms/step
# 0.47190094
# 1/1 [==============================] - 0s 28ms/step
# 0.4803772
# 1/1 [==============================] - 0s 24ms/step
# 0.8680116
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.864277
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.48317719
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.80308795
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8643032
# 1/1 [==============================] - 0s 25ms/step
# 0.4964218
# 1/1 [==============================] - 0s 23ms/step
# 0.48900604
# 1/1 [==============================] - 0s 25ms/step
# 0.85495317
# 1/1 [==============================] - 0s 27ms/step
# 0.48918152
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.8873899
# 1/1 [==============================] - 0s 25ms/step
# 0.89305127
# 1/1 [==============================] - 0s 28ms/step
# 0.83517873
# 1/1 [==============================] - 0s 38ms/step
# 0.8028698
# 1/1 [==============================] - 0s 33ms/step
# 0.8382851
# 1/1 [==============================] - 0s 37ms/step
# 0.4773178
# 1/1 [==============================] - 0s 37ms/step
# 0.59171295
# 1/1 [==============================] - 0s 38ms/step
# 0.6018831
# 1/1 [==============================] - 0s 40ms/step
# 0.4756775
# 1/1 [==============================] - 0s 39ms/step
# 0.4860382
# 1/1 [==============================] - 0s 43ms/step
# 0.8031253
# 1/1 [==============================] - 0s 44ms/step
# 1.0
# 1/1 [==============================] - 0s 37ms/step
# 0.48242188
# 1/1 [==============================] - 0s 47ms/step
# 0.48207855
# 1/1 [==============================] - 0s 38ms/step
# 0.4877472
# 1/1 [==============================] - 0s 36ms/step
# 1.0
# 1/1 [==============================] - 0s 38ms/step
# 0.48417664
# 1/1 [==============================] - 0s 35ms/step
# 0.85302615
# 1/1 [==============================] - 0s 34ms/step
# 0.8627964
# 1/1 [==============================] - 0s 42ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.49897766
# 1/1 [==============================] - 0s 43ms/step
# 0.8789512
# 1/1 [==============================] - 0s 37ms/step
# 0.85629284
# 1/1 [==============================] - 0s 42ms/step
# 0.88076407
# 1/1 [==============================] - 0s 41ms/step
# 1.0
# 1/1 [==============================] - 0s 41ms/step
# 0.5409523
# 1/1 [==============================] - 0s 42ms/step
# 1.0
# 1/1 [==============================] - 0s 42ms/step
# 0.78378886
# 1/1 [==============================] - 0s 41ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.4726181
# 1/1 [==============================] - 0s 27ms/step
# 0.8789512
# 1/1 [==============================] - 0s 24ms/step
# 0.49653625
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8174617
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.4949646
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8887898
# 1/1 [==============================] - 0s 24ms/step
# 0.4884262
# 1/1 [==============================] - 0s 26ms/step
# 0.85082287
# 1/1 [==============================] - 0s 26ms/step
# 0.8297925
# 1/1 [==============================] - 0s 23ms/step
# 0.7031781
# 1/1 [==============================] - 0s 24ms/step
# 0.837875
# 1/1 [==============================] - 0s 26ms/step
# 0.79418343
# 1/1 [==============================] - 0s 23ms/step
# 0.8246679
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.9063263
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.70944655
# 1/1 [==============================] - 0s 28ms/step
# 0.8837101
# 1/1 [==============================] - 0s 27ms/step
# 0.8490376
# 1/1 [==============================] - 0s 31ms/step
# 0.48621368
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.5524422
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48213196
# 1/1 [==============================] - 0s 25ms/step
# 0.87942505
# 1/1 [==============================] - 0s 27ms/step
# 0.88071823
# 1/1 [==============================] - 0s 29ms/step
# 0.8837101
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.4717331
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.48413086
# 1/1 [==============================] - 0s 24ms/step
# 0.8111322
# 1/1 [==============================] - 0s 29ms/step
# 0.4820404
# 1/1 [==============================] - 0s 28ms/step
# 0.8797994
# 1/1 [==============================] - 0s 30ms/step
# 0.88203216
# 1/1 [==============================] - 0s 30ms/step
# 0.4908676
# 1/1 [==============================] - 0s 25ms/step
# 0.85012996
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.58067685
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.83845913
# 1/1 [==============================] - 0s 26ms/step
# 0.6955355
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8518673
# 1/1 [==============================] - 0s 24ms/step
# 0.51172936
# 1/1 [==============================] - 0s 25ms/step
# 0.87946963
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4825058
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.83424115
# 1/1 [==============================] - 0s 27ms/step
# 0.48628235
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.86205536
# 1/1 [==============================] - 0s 23ms/step
# 0.8005293
# 1/1 [==============================] - 0s 27ms/step
# 0.8633807
# 1/1 [==============================] - 0s 28ms/step
# 0.85718423
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.48138428
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.7224033
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.80463386
# 1/1 [==============================] - 0s 23ms/step
# 0.85694885
# 1/1 [==============================] - 0s 23ms/step
# 0.472821
# 1/1 [==============================] - 0s 24ms/step
# 0.49900818
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.48621368
# 1/1 [==============================] - 0s 25ms/step
# 0.48343658
# 1/1 [==============================] - 0s 25ms/step
# 0.82623374
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8246679
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.6955355
# 1/1 [==============================] - 0s 27ms/step
# 0.86411667
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.87175834
# 1/1 [==============================] - 0s 22ms/step
# 0.8028698
# 1/1 [==============================] - 0s 23ms/step
# 0.49189758
# 1/1 [==============================] - 0s 25ms/step
# 0.88993394
# 1/1 [==============================] - 0s 24ms/step
# 0.9060123
# 1/1 [==============================] - 0s 27ms/step
# 0.5922917
# 1/1 [==============================] - 0s 25ms/step
# 0.48413086
# 1/1 [==============================] - 0s 26ms/step
# 0.84359145
# 1/1 [==============================] - 0s 23ms/step
# 0.48621368
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.5989312
# 1/1 [==============================] - 0s 25ms/step
# 0.4827423
# 1/1 [==============================] - 0s 27ms/step
# 0.49757385
# 1/1 [==============================] - 0s 22ms/step
# 0.48213196
# 1/1 [==============================] - 0s 28ms/step
# 0.87257123
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8579457
# 1/1 [==============================] - 0s 26ms/step
# 0.86764854
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8516913
# 1/1 [==============================] - 0s 29ms/step
# 0.7319333
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.85800123
# 1/1 [==============================] - 0s 23ms/step
# 0.60398835
# 1/1 [==============================] - 0s 22ms/step
# 0.8516913
# 1/1 [==============================] - 0s 26ms/step
# 0.59171295
# 1/1 [==============================] - 0s 27ms/step
# 0.4773178
# 1/1 [==============================] - 0s 26ms/step
# 0.4908676
# 1/1 [==============================] - 0s 25ms/step
# 0.48397827
# 1/1 [==============================] - 0s 25ms/step
# 0.87813985
# 1/1 [==============================] - 0s 24ms/step
# 0.80463386
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.5542969
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8227904
# 1/1 [==============================] - 0s 26ms/step
# 0.8632222
# 1/1 [==============================] - 0s 27ms/step
# 0.8570009
# 1/1 [==============================] - 0s 23ms/step
# 0.86243844
# 1/1 [==============================] - 0s 25ms/step
# 0.48213196
# 1/1 [==============================] - 0s 25ms/step
# 0.8570009
# 1/1 [==============================] - 0s 23ms/step
# 0.85392463
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.7345722
# 1/1 [==============================] - 0s 25ms/step
# 0.48106384
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.5542969
# 1/1 [==============================] - 0s 22ms/step
# 0.48348236
# 1/1 [==============================] - 0s 25ms/step
# 0.49504852
# 1/1 [==============================] - 0s 26ms/step
# 0.51123357
# 1/1 [==============================] - 0s 24ms/step
# 0.4805374
# 1/1 [==============================] - 0s 22ms/step
# 0.49182892
# 1/1 [==============================] - 0s 25ms/step
# 0.48027802
# 1/1 [==============================] - 0s 24ms/step
# 0.7726908
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.84458625
# 1/1 [==============================] - 0s 25ms/step
# 0.83845913
# 1/1 [==============================] - 0s 22ms/step
# 0.8509658
# 1/1 [==============================] - 0s 22ms/step
# 0.50234115
# 1/1 [==============================] - 0s 22ms/step
# 0.482872
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.7983498
# 1/1 [==============================] - 0s 26ms/step
# 0.6955355
# 1/1 [==============================] - 0s 26ms/step
# 0.4999466
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49332428
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4726181
# 1/1 [==============================] - 0s 21ms/step
# 0.84458625
# 1/1 [==============================] - 0s 21ms/step
# 0.71038616
# 1/1 [==============================] - 0s 23ms/step
# 0.86577946
# 1/1 [==============================] - 0s 25ms/step
# 0.7922615
# 1/1 [==============================] - 0s 23ms/step
# 0.87942505
# 1/1 [==============================] - 0s 24ms/step
# 0.8837101
# 1/1 [==============================] - 0s 24ms/step
# 0.49900818
# 1/1 [==============================] - 0s 29ms/step
# 0.85267985
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.7922615
# 1/1 [==============================] - 0s 23ms/step
# 0.8607746
# 1/1 [==============================] - 0s 23ms/step
# 0.86387134
# 1/1 [==============================] - 0s 25ms/step
# 0.47329712
# 1/1 [==============================] - 0s 23ms/step
# 0.49757385
# 1/1 [==============================] - 0s 25ms/step
# 0.48220062
# 1/1 [==============================] - 0s 23ms/step
# 0.47341156
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.76606727
# 1/1 [==============================] - 0s 23ms/step
# 0.7703068
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.48207855
# 1/1 [==============================] - 0s 23ms/step
# 0.85302615
# 1/1 [==============================] - 0s 24ms/step
# 0.86577946
# 1/1 [==============================] - 0s 27ms/step
# 0.49368286
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.86411667
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.47637177
# 1/1 [==============================] - 0s 26ms/step
# 0.87813985
# 1/1 [==============================] - 0s 24ms/step
# 0.7388135
# 1/1 [==============================] - 0s 25ms/step
# 0.4756775
# 1/1 [==============================] - 0s 23ms/step
# 0.4910202
# 1/1 [==============================] - 0s 26ms/step
# 0.48628235
# 1/1 [==============================] - 0s 24ms/step
# 0.8509658
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.83845913
# 1/1 [==============================] - 0s 24ms/step
# 0.47527313
# 1/1 [==============================] - 0s 24ms/step
# 0.9056221
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.7534274
# 1/1 [==============================] - 0s 23ms/step
# 0.78378886
# 1/1 [==============================] - 0s 24ms/step
# 0.8335309
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49999237
# 1/1 [==============================] - 0s 34ms/step
# 0.49510056
# 1/1 [==============================] - 0s 25ms/step
# 0.73339474
# 1/1 [==============================] - 0s 31ms/step
# 0.48554993
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.48175812
# 1/1 [==============================] - 0s 25ms/step
# 0.8739058
# 1/1 [==============================] - 0s 27ms/step
# 0.6955355
# 1/1 [==============================] - 0s 24ms/step
# 0.818285
# 1/1 [==============================] - 0s 23ms/step
# 0.8284451
# 1/1 [==============================] - 0s 22ms/step
# 0.9202528
# 1/1 [==============================] - 0s 30ms/step
# 0.5351571
# 1/1 [==============================] - 0s 22ms/step
# 0.6018831
# 1/1 [==============================] - 0s 27ms/step
# 0.48301697
# number of total masks is:  477
# Mean IoU is:  [0.6926833]
# standard deviation is  IoU    0.17264
# dtype: float32
