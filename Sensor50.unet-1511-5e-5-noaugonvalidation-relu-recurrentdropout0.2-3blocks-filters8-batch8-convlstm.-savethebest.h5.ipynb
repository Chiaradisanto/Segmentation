# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor50.unet-1511-5e-5-noaugonvalidation-relu-recurrentdropout0.2-3blocks-filters8-batch8-convlstm.-savethebest.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 8,
        squeeze=False,
        augmentation=True,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2, interpolation='bilinear', fill_mode='reflect'),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=8,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=8,
    squeeze=False,

)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=8

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x =  (layers.TimeDistributed(layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 =  (layers.TimeDistributed(layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)


x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv3 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)

conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu')) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv6 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv6 =layers.TimeDistributed(layers.BatchNormalization())(conv6)
x=(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True, recurrent_dropout=0.2))(conv6)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv5])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv4])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat3 = layers.concatenate([up3, conv3])

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu') ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])

x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up5 = layers.TimeDistributed( layers.Conv2DTranspose( 8,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat5 = layers.concatenate([up5, conv1])

x = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat5)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 8, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=(layers.ConvLSTM2D(8,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)
out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_70 (TimeDistr  (None, 3, 256, 256,  80         ['input_2[0][0]']
#  ibuted)                         8)
#
#  time_distributed_71 (TimeDistr  (None, 3, 256, 256,  32         ['time_distributed_70[0][0]']
#  ibuted)                         8)
#
#  time_distributed_72 (TimeDistr  (None, 3, 256, 256,  584        ['time_distributed_71[0][0]']
#  ibuted)                         8)
#
#  time_distributed_73 (TimeDistr  (None, 3, 256, 256,  32         ['time_distributed_72[0][0]']
#  ibuted)                         8)
#
#  time_distributed_74 (TimeDistr  (None, 3, 256, 256,  584        ['time_distributed_73[0][0]']
#  ibuted)                         8)
#
#  time_distributed_75 (TimeDistr  (None, 3, 256, 256,  32         ['time_distributed_74[0][0]']
#  ibuted)                         8)
#
#  time_distributed_76 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_75[0][0]']
#  ibuted)                         8)
#
#  time_distributed_77 (TimeDistr  (None, 3, 128, 128,  1168       ['time_distributed_76[0][0]']
#  ibuted)                         16)
#
#  time_distributed_78 (TimeDistr  (None, 3, 128, 128,  64         ['time_distributed_77[0][0]']
#  ibuted)                         16)
#
#  time_distributed_79 (TimeDistr  (None, 3, 128, 128,  2320       ['time_distributed_78[0][0]']
#  ibuted)                         16)
#
#  time_distributed_80 (TimeDistr  (None, 3, 128, 128,  64         ['time_distributed_79[0][0]']
#  ibuted)                         16)
#
#  time_distributed_81 (TimeDistr  (None, 3, 128, 128,  2320       ['time_distributed_80[0][0]']
#  ibuted)                         16)
#
#  time_distributed_82 (TimeDistr  (None, 3, 128, 128,  64         ['time_distributed_81[0][0]']
#  ibuted)                         16)
#
#  time_distributed_83 (TimeDistr  (None, 3, 64, 64, 1  0          ['time_distributed_82[0][0]']
#  ibuted)                        6)
#
#  time_distributed_84 (TimeDistr  (None, 3, 64, 64, 3  4640       ['time_distributed_83[0][0]']
#  ibuted)                        2)
#
#  time_distributed_85 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_84[0][0]']
#  ibuted)                        2)
#
#  time_distributed_86 (TimeDistr  (None, 3, 64, 64, 3  9248       ['time_distributed_85[0][0]']
#  ibuted)                        2)
#
#  time_distributed_87 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_86[0][0]']
#  ibuted)                        2)
#
#  time_distributed_88 (TimeDistr  (None, 3, 64, 64, 3  9248       ['time_distributed_87[0][0]']
#  ibuted)                        2)
#
#  time_distributed_89 (TimeDistr  (None, 3, 64, 64, 3  128        ['time_distributed_88[0][0]']
#  ibuted)                        2)
#
#  time_distributed_90 (TimeDistr  (None, 3, 32, 32, 3  0          ['time_distributed_89[0][0]']
#  ibuted)                        2)
#
#  time_distributed_91 (TimeDistr  (None, 3, 32, 32, 6  18496      ['time_distributed_90[0][0]']
#  ibuted)                        4)
#
#  time_distributed_92 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_91[0][0]']
#  ibuted)                        4)
#
#  time_distributed_93 (TimeDistr  (None, 3, 32, 32, 6  36928      ['time_distributed_92[0][0]']
#  ibuted)                        4)
#
#  time_distributed_94 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_93[0][0]']
#  ibuted)                        4)
#
#  time_distributed_95 (TimeDistr  (None, 3, 32, 32, 6  36928      ['time_distributed_94[0][0]']
#  ibuted)                        4)
#
#  time_distributed_96 (TimeDistr  (None, 3, 32, 32, 6  256        ['time_distributed_95[0][0]']
#  ibuted)                        4)
#
#  time_distributed_97 (TimeDistr  (None, 3, 16, 16, 6  0          ['time_distributed_96[0][0]']
#  ibuted)                        4)
#
#  time_distributed_98 (TimeDistr  (None, 3, 16, 16, 1  73856      ['time_distributed_97[0][0]']
#  ibuted)                        28)
#
#  time_distributed_99 (TimeDistr  (None, 3, 16, 16, 1  512        ['time_distributed_98[0][0]']
#  ibuted)                        28)
#
#  time_distributed_100 (TimeDist  (None, 3, 16, 16, 1  147584     ['time_distributed_99[0][0]']
#  ributed)                       28)
#
#  time_distributed_101 (TimeDist  (None, 3, 16, 16, 1  512        ['time_distributed_100[0][0]']
#  ributed)                       28)
#
#  time_distributed_102 (TimeDist  (None, 3, 16, 16, 1  147584     ['time_distributed_101[0][0]']
#  ributed)                       28)
#
#  time_distributed_103 (TimeDist  (None, 3, 16, 16, 1  512        ['time_distributed_102[0][0]']
#  ributed)                       28)
#
#  time_distributed_104 (TimeDist  (None, 3, 8, 8, 128  0          ['time_distributed_103[0][0]']
#  ributed)                       )
#
#  time_distributed_105 (TimeDist  (None, 3, 8, 8, 256  295168     ['time_distributed_104[0][0]']
#  ributed)                       )
#
#  time_distributed_106 (TimeDist  (None, 3, 8, 8, 256  1024       ['time_distributed_105[0][0]']
#  ributed)                       )
#
#  time_distributed_107 (TimeDist  (None, 3, 8, 8, 256  590080     ['time_distributed_106[0][0]']
#  ributed)                       )
#
#  time_distributed_108 (TimeDist  (None, 3, 8, 8, 256  1024       ['time_distributed_107[0][0]']
#  ributed)                       )
#
#  time_distributed_109 (TimeDist  (None, 3, 8, 8, 256  590080     ['time_distributed_108[0][0]']
#  ributed)                       )
#
#  time_distributed_110 (TimeDist  (None, 3, 8, 8, 256  1024       ['time_distributed_109[0][0]']
#  ributed)                       )
#
#  conv_lstm2d_2 (ConvLSTM2D)     (None, 3, 8, 8, 256  4719616     ['time_distributed_110[0][0]']
#                                 )
#
#  time_distributed_111 (TimeDist  (None, 3, 16, 16, 1  295040     ['conv_lstm2d_2[0][0]']
#  ributed)                       28)
#
#  concatenate_5 (Concatenate)    (None, 3, 16, 16, 2  0           ['time_distributed_111[0][0]',
#                                 56)                               'time_distributed_103[0][0]']
#
#  time_distributed_112 (TimeDist  (None, 3, 16, 16, 1  295040     ['concatenate_5[0][0]']
#  ributed)                       28)
#
#  time_distributed_113 (TimeDist  (None, 3, 16, 16, 1  512        ['time_distributed_112[0][0]']
#  ributed)                       28)
#
#  time_distributed_114 (TimeDist  (None, 3, 16, 16, 1  147584     ['time_distributed_113[0][0]']
#  ributed)                       28)
#
#  time_distributed_115 (TimeDist  (None, 3, 16, 16, 1  512        ['time_distributed_114[0][0]']
#  ributed)                       28)
#
#  time_distributed_116 (TimeDist  (None, 3, 16, 16, 1  147584     ['time_distributed_115[0][0]']
#  ributed)                       28)
#
#  time_distributed_117 (TimeDist  (None, 3, 16, 16, 1  512        ['time_distributed_116[0][0]']
#  ributed)                       28)
#
#  time_distributed_118 (TimeDist  (None, 3, 32, 32, 6  73792      ['time_distributed_117[0][0]']
#  ributed)                       4)
#
#  concatenate_6 (Concatenate)    (None, 3, 32, 32, 1  0           ['time_distributed_118[0][0]',
#                                 28)                               'time_distributed_96[0][0]']
#
#  time_distributed_119 (TimeDist  (None, 3, 32, 32, 6  73792      ['concatenate_6[0][0]']
#  ributed)                       4)
#
#  time_distributed_120 (TimeDist  (None, 3, 32, 32, 6  256        ['time_distributed_119[0][0]']
#  ributed)                       4)
#
#  time_distributed_121 (TimeDist  (None, 3, 32, 32, 6  36928      ['time_distributed_120[0][0]']
#  ributed)                       4)
#
#  time_distributed_122 (TimeDist  (None, 3, 32, 32, 6  256        ['time_distributed_121[0][0]']
#  ributed)                       4)
#
#  time_distributed_123 (TimeDist  (None, 3, 32, 32, 6  36928      ['time_distributed_122[0][0]']
#  ributed)                       4)
#
#  time_distributed_124 (TimeDist  (None, 3, 32, 32, 6  256        ['time_distributed_123[0][0]']
#  ributed)                       4)
#
#  time_distributed_125 (TimeDist  (None, 3, 64, 64, 3  18464      ['time_distributed_124[0][0]']
#  ributed)                       2)
#
#  concatenate_7 (Concatenate)    (None, 3, 64, 64, 6  0           ['time_distributed_125[0][0]',
#                                 4)                                'time_distributed_89[0][0]']
#
#  time_distributed_126 (TimeDist  (None, 3, 64, 64, 3  18464      ['concatenate_7[0][0]']
#  ributed)                       2)
#
#  time_distributed_127 (TimeDist  (None, 3, 64, 64, 3  128        ['time_distributed_126[0][0]']
#  ributed)                       2)
#
#  time_distributed_128 (TimeDist  (None, 3, 64, 64, 3  9248       ['time_distributed_127[0][0]']
#  ributed)                       2)
#
#  time_distributed_129 (TimeDist  (None, 3, 64, 64, 3  128        ['time_distributed_128[0][0]']
#  ributed)                       2)
#
#  time_distributed_130 (TimeDist  (None, 3, 64, 64, 3  9248       ['time_distributed_129[0][0]']
#  ributed)                       2)
#
#  time_distributed_131 (TimeDist  (None, 3, 64, 64, 3  128        ['time_distributed_130[0][0]']
#  ributed)                       2)
#
#  time_distributed_132 (TimeDist  (None, 3, 128, 128,  4624       ['time_distributed_131[0][0]']
#  ributed)                        16)
#
#  concatenate_8 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_132[0][0]',
#                                  32)                              'time_distributed_82[0][0]']
#
#  time_distributed_133 (TimeDist  (None, 3, 128, 128,  4624       ['concatenate_8[0][0]']
#  ributed)                        16)
#
#  time_distributed_134 (TimeDist  (None, 3, 128, 128,  64         ['time_distributed_133[0][0]']
#  ributed)                        16)
#
#  time_distributed_135 (TimeDist  (None, 3, 128, 128,  2320       ['time_distributed_134[0][0]']
#  ributed)                        16)
#
#  time_distributed_136 (TimeDist  (None, 3, 128, 128,  64         ['time_distributed_135[0][0]']
#  ributed)                        16)
#
#  time_distributed_137 (TimeDist  (None, 3, 128, 128,  2320       ['time_distributed_136[0][0]']
#  ributed)                        16)
#
#  time_distributed_138 (TimeDist  (None, 3, 128, 128,  64         ['time_distributed_137[0][0]']
#  ributed)                        16)
#
#  time_distributed_139 (TimeDist  (None, 3, 256, 256,  1160       ['time_distributed_138[0][0]']
#  ributed)                        8)
#
#  concatenate_9 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_139[0][0]',
#                                  16)                              'time_distributed_75[0][0]']
#
#  time_distributed_140 (TimeDist  (None, 3, 256, 256,  1160       ['concatenate_9[0][0]']
#  ributed)                        8)
#
#  time_distributed_141 (TimeDist  (None, 3, 256, 256,  32         ['time_distributed_140[0][0]']
#  ributed)                        8)
#
#  time_distributed_142 (TimeDist  (None, 3, 256, 256,  584        ['time_distributed_141[0][0]']
#  ributed)                        8)
#
#  time_distributed_143 (TimeDist  (None, 3, 256, 256,  32         ['time_distributed_142[0][0]']
#  ributed)                        8)
#
#  time_distributed_144 (TimeDist  (None, 3, 256, 256,  584        ['time_distributed_143[0][0]']
#  ributed)                        8)
#
#  time_distributed_145 (TimeDist  (None, 3, 256, 256,  32         ['time_distributed_144[0][0]']
#  ributed)                        8)
#
#  conv_lstm2d_3 (ConvLSTM2D)     (None, 256, 256, 8)  4640        ['time_distributed_145[0][0]']
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256, 256,  0           ['conv_lstm2d_3[0][0]']
#                                  8)
#
#  conv2d_64 (Conv2D)             (None, 1, 256, 256,  9           ['tf.expand_dims_1[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 7,879,673
# Trainable params: 7,875,161
# Non-trainable params: 4,512
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=50,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/50
# 372/372 [==============================] - 223s 544ms/step - loss: 0.9250 - dice_coefficient: 0.0750 - binary_accuracy: 0.6869 - val_loss: 0.9289 - val_dice_coefficient: 0.0711 - val_binary_accuracy: 0.2358
# Epoch 2/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.7049 - dice_coefficient: 0.2951 - binary_accuracy: 0.9447 - val_loss: 0.5538 - val_dice_coefficient: 0.4462 - val_binary_accuracy: 0.9771
# Epoch 3/50
# 372/372 [==============================] - 206s 554ms/step - loss: 0.5010 - dice_coefficient: 0.4990 - binary_accuracy: 0.9772 - val_loss: 0.5736 - val_dice_coefficient: 0.4264 - val_binary_accuracy: 0.9798
# Epoch 4/50
# 372/372 [==============================] - 206s 555ms/step - loss: 0.4510 - dice_coefficient: 0.5490 - binary_accuracy: 0.9809 - val_loss: 0.4953 - val_dice_coefficient: 0.5047 - val_binary_accuracy: 0.9799
# Epoch 5/50
# 372/372 [==============================] - 206s 553ms/step - loss: 0.4248 - dice_coefficient: 0.5752 - binary_accuracy: 0.9827 - val_loss: 0.5649 - val_dice_coefficient: 0.4351 - val_binary_accuracy: 0.9812
# Epoch 6/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.3906 - dice_coefficient: 0.6094 - binary_accuracy: 0.9841 - val_loss: 0.4963 - val_dice_coefficient: 0.5037 - val_binary_accuracy: 0.9775
# Epoch 7/50
# 372/372 [==============================] - 205s 550ms/step - loss: 0.3718 - dice_coefficient: 0.6282 - binary_accuracy: 0.9851 - val_loss: 0.5290 - val_dice_coefficient: 0.4710 - val_binary_accuracy: 0.9820
# Epoch 8/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.3575 - dice_coefficient: 0.6425 - binary_accuracy: 0.9852 - val_loss: 0.4839 - val_dice_coefficient: 0.5161 - val_binary_accuracy: 0.9805
# Epoch 9/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.3394 - dice_coefficient: 0.6606 - binary_accuracy: 0.9858 - val_loss: 0.5013 - val_dice_coefficient: 0.4987 - val_binary_accuracy: 0.9788
# Epoch 10/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.3294 - dice_coefficient: 0.6706 - binary_accuracy: 0.9860 - val_loss: 0.5990 - val_dice_coefficient: 0.4010 - val_binary_accuracy: 0.9768
# Epoch 11/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.3326 - dice_coefficient: 0.6674 - binary_accuracy: 0.9862 - val_loss: 0.4777 - val_dice_coefficient: 0.5223 - val_binary_accuracy: 0.9820
# Epoch 12/50
# 372/372 [==============================] - 205s 550ms/step - loss: 0.3126 - dice_coefficient: 0.6874 - binary_accuracy: 0.9868 - val_loss: 0.6639 - val_dice_coefficient: 0.3361 - val_binary_accuracy: 0.9804
# Epoch 13/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2908 - dice_coefficient: 0.7092 - binary_accuracy: 0.9867 - val_loss: 0.4488 - val_dice_coefficient: 0.5512 - val_binary_accuracy: 0.9844
# Epoch 14/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.3022 - dice_coefficient: 0.6978 - binary_accuracy: 0.9876 - val_loss: 0.4406 - val_dice_coefficient: 0.5594 - val_binary_accuracy: 0.9848
# Epoch 15/50
# 372/372 [==============================] - 204s 549ms/step - loss: 0.2796 - dice_coefficient: 0.7204 - binary_accuracy: 0.9871 - val_loss: 0.5324 - val_dice_coefficient: 0.4676 - val_binary_accuracy: 0.9831
# Epoch 16/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2827 - dice_coefficient: 0.7173 - binary_accuracy: 0.9874 - val_loss: 0.3951 - val_dice_coefficient: 0.6049 - val_binary_accuracy: 0.9844
# Epoch 17/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2654 - dice_coefficient: 0.7346 - binary_accuracy: 0.9883 - val_loss: 0.4213 - val_dice_coefficient: 0.5787 - val_binary_accuracy: 0.9824
# Epoch 18/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2797 - dice_coefficient: 0.7203 - binary_accuracy: 0.9880 - val_loss: 0.4747 - val_dice_coefficient: 0.5253 - val_binary_accuracy: 0.9823
# Epoch 19/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2753 - dice_coefficient: 0.7247 - binary_accuracy: 0.9874 - val_loss: 0.3983 - val_dice_coefficient: 0.6017 - val_binary_accuracy: 0.9863
# Epoch 20/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2617 - dice_coefficient: 0.7383 - binary_accuracy: 0.9882 - val_loss: 0.4447 - val_dice_coefficient: 0.5553 - val_binary_accuracy: 0.9832
# Epoch 21/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2527 - dice_coefficient: 0.7473 - binary_accuracy: 0.9881 - val_loss: 0.4618 - val_dice_coefficient: 0.5382 - val_binary_accuracy: 0.9844
# Epoch 22/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2380 - dice_coefficient: 0.7620 - binary_accuracy: 0.9887 - val_loss: 0.4503 - val_dice_coefficient: 0.5497 - val_binary_accuracy: 0.9795
# Epoch 23/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2511 - dice_coefficient: 0.7489 - binary_accuracy: 0.9882 - val_loss: 0.3906 - val_dice_coefficient: 0.6094 - val_binary_accuracy: 0.9818
# Epoch 24/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2445 - dice_coefficient: 0.7555 - binary_accuracy: 0.9886 - val_loss: 0.4943 - val_dice_coefficient: 0.5057 - val_binary_accuracy: 0.9812
# Epoch 25/50
# 372/372 [==============================] - 206s 553ms/step - loss: 0.2291 - dice_coefficient: 0.7709 - binary_accuracy: 0.9889 - val_loss: 0.3672 - val_dice_coefficient: 0.6328 - val_binary_accuracy: 0.9857
# Epoch 26/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2392 - dice_coefficient: 0.7609 - binary_accuracy: 0.9886 - val_loss: 0.4615 - val_dice_coefficient: 0.5385 - val_binary_accuracy: 0.9826
# Epoch 27/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2467 - dice_coefficient: 0.7533 - binary_accuracy: 0.9885 - val_loss: 0.3873 - val_dice_coefficient: 0.6127 - val_binary_accuracy: 0.9834
# Epoch 28/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2275 - dice_coefficient: 0.7725 - binary_accuracy: 0.9884 - val_loss: 0.4651 - val_dice_coefficient: 0.5349 - val_binary_accuracy: 0.9830
# Epoch 29/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2265 - dice_coefficient: 0.7735 - binary_accuracy: 0.9893 - val_loss: 0.4355 - val_dice_coefficient: 0.5645 - val_binary_accuracy: 0.9814
# Epoch 30/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2189 - dice_coefficient: 0.7811 - binary_accuracy: 0.9891 - val_loss: 0.4366 - val_dice_coefficient: 0.5634 - val_binary_accuracy: 0.9803
# Epoch 31/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2261 - dice_coefficient: 0.7739 - binary_accuracy: 0.9895 - val_loss: 0.3394 - val_dice_coefficient: 0.6606 - val_binary_accuracy: 0.9846
# Epoch 32/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2208 - dice_coefficient: 0.7792 - binary_accuracy: 0.9887 - val_loss: 0.4664 - val_dice_coefficient: 0.5336 - val_binary_accuracy: 0.9821
# Epoch 33/50
# 372/372 [==============================] - 205s 550ms/step - loss: 0.2182 - dice_coefficient: 0.7818 - binary_accuracy: 0.9894 - val_loss: 0.4200 - val_dice_coefficient: 0.5800 - val_binary_accuracy: 0.9837
# Epoch 34/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2146 - dice_coefficient: 0.7854 - binary_accuracy: 0.9893 - val_loss: 0.4035 - val_dice_coefficient: 0.5965 - val_binary_accuracy: 0.9815
# Epoch 35/50
# 372/372 [==============================] - 205s 550ms/step - loss: 0.2154 - dice_coefficient: 0.7846 - binary_accuracy: 0.9892 - val_loss: 0.4627 - val_dice_coefficient: 0.5373 - val_binary_accuracy: 0.9814
# Epoch 36/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.1968 - dice_coefficient: 0.8032 - binary_accuracy: 0.9898 - val_loss: 0.4676 - val_dice_coefficient: 0.5324 - val_binary_accuracy: 0.9793
# Epoch 37/50
# 372/372 [==============================] - 205s 550ms/step - loss: 0.2208 - dice_coefficient: 0.7792 - binary_accuracy: 0.9887 - val_loss: 0.3754 - val_dice_coefficient: 0.6246 - val_binary_accuracy: 0.9837
# Epoch 38/50
# 372/372 [==============================] - 205s 550ms/step - loss: 0.2074 - dice_coefficient: 0.7926 - binary_accuracy: 0.9893 - val_loss: 0.5541 - val_dice_coefficient: 0.4459 - val_binary_accuracy: 0.9799
# Epoch 39/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2132 - dice_coefficient: 0.7868 - binary_accuracy: 0.9893 - val_loss: 0.4578 - val_dice_coefficient: 0.5422 - val_binary_accuracy: 0.9837
# Epoch 40/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.1956 - dice_coefficient: 0.8044 - binary_accuracy: 0.9898 - val_loss: 0.5833 - val_dice_coefficient: 0.4167 - val_binary_accuracy: 0.9791
# Epoch 41/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2015 - dice_coefficient: 0.7985 - binary_accuracy: 0.9897 - val_loss: 0.3458 - val_dice_coefficient: 0.6542 - val_binary_accuracy: 0.9817
# Epoch 42/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2088 - dice_coefficient: 0.7912 - binary_accuracy: 0.9889 - val_loss: 0.4137 - val_dice_coefficient: 0.5863 - val_binary_accuracy: 0.9794
# Epoch 43/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.2032 - dice_coefficient: 0.7968 - binary_accuracy: 0.9893 - val_loss: 0.4346 - val_dice_coefficient: 0.5654 - val_binary_accuracy: 0.9827
# Epoch 44/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.1895 - dice_coefficient: 0.8105 - binary_accuracy: 0.9895 - val_loss: 0.4264 - val_dice_coefficient: 0.5736 - val_binary_accuracy: 0.9837
# Epoch 45/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.1854 - dice_coefficient: 0.8146 - binary_accuracy: 0.9898 - val_loss: 0.4588 - val_dice_coefficient: 0.5412 - val_binary_accuracy: 0.9824
# Epoch 46/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.1990 - dice_coefficient: 0.8010 - binary_accuracy: 0.9895 - val_loss: 0.3853 - val_dice_coefficient: 0.6147 - val_binary_accuracy: 0.9818
# Epoch 47/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.1969 - dice_coefficient: 0.8031 - binary_accuracy: 0.9897 - val_loss: 0.3976 - val_dice_coefficient: 0.6024 - val_binary_accuracy: 0.9825
# Epoch 48/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.1837 - dice_coefficient: 0.8163 - binary_accuracy: 0.9901 - val_loss: 0.4208 - val_dice_coefficient: 0.5792 - val_binary_accuracy: 0.9835
# Epoch 49/50
# 372/372 [==============================] - 205s 551ms/step - loss: 0.2010 - dice_coefficient: 0.7990 - binary_accuracy: 0.9900 - val_loss: 0.4801 - val_dice_coefficient: 0.5199 - val_binary_accuracy: 0.9824
# Epoch 50/50
# 372/372 [==============================] - 205s 552ms/step - loss: 0.1955 - dice_coefficient: 0.8045 - binary_accuracy: 0.9898 - val_loss: 0.4076 - val_dice_coefficient: 0.5924 - val_binary_accuracy: 0.9839

# %%
model.save('/gdrive/MyDrive/Sensor50.unet-1511-5e-5-noaugonvalidation-relu-recurrentdropout0.2-3blocks-filters8-batch8-convlstm.-savethebest.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor50.unet-1511-5e-5-noaugonvalidation-relu-recurrentdropout0.2-3blocks-filters8-batch8-convlstm.-savethebest.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=False,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  import random
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')

  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.82392114
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.4747162
# 1/1 [==============================] - 0s 27ms/step
# 0.49097443
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 38ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.49012756
# 1/1 [==============================] - 0s 25ms/step
# 0.48995972
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49097443
# 1/1 [==============================] - 0s 25ms/step
# 0.4918213
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4857025
# 1/1 [==============================] - 0s 26ms/step
# 0.49996948
# 1/1 [==============================] - 0s 27ms/step
# 0.64101154
# 1/1 [==============================] - 0s 31ms/step
# 0.7563753
# 1/1 [==============================] - 0s 25ms/step
# 0.6618983
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8156781
# 1/1 [==============================] - 0s 28ms/step
# 0.49830627
# 1/1 [==============================] - 0s 27ms/step
# 0.48392487
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.76242447
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.8649477
# 1/1 [==============================] - 0s 29ms/step
# 0.66714126
# 1/1 [==============================] - 0s 25ms/step
# 0.7397032
# 1/1 [==============================] - 0s 31ms/step
# 0.49942017
# 1/1 [==============================] - 0s 25ms/step
# 0.48612213
# 1/1 [==============================] - 0s 31ms/step
# 0.74552166
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.78714347
# 1/1 [==============================] - 0s 27ms/step
# 0.7769625
# 1/1 [==============================] - 0s 26ms/step
# 0.7409308
# 1/1 [==============================] - 0s 33ms/step
# 0.48348236
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.746194
# 1/1 [==============================] - 0s 25ms/step
# 0.48466492
# 1/1 [==============================] - 0s 27ms/step
# 0.8420867
# 1/1 [==============================] - 0s 26ms/step
# 0.8479712
# 1/1 [==============================] - 0s 29ms/step
# 0.7705858
# 1/1 [==============================] - 0s 30ms/step
# 0.49004364
# 1/1 [==============================] - 0s 25ms/step
# 0.7707146
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.48535156
# 1/1 [==============================] - 0s 24ms/step
# 0.7980516
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.7047714
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.78779155
# 1/1 [==============================] - 0s 25ms/step
# 0.8016164
# 1/1 [==============================] - 0s 29ms/step
# 0.75722075
# 1/1 [==============================] - 0s 26ms/step
# 0.7986728
# 1/1 [==============================] - 0s 33ms/step
# 0.78779155
# 1/1 [==============================] - 0s 26ms/step
# 0.50302184
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4911728
# 1/1 [==============================] - 0s 27ms/step
# 0.48138428
# 1/1 [==============================] - 0s 28ms/step
# 0.4747162
# 1/1 [==============================] - 0s 27ms/step
# 0.6632402
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.47547913
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.7501004
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.6643767
# 1/1 [==============================] - 0s 36ms/step
# 0.64429057
# 1/1 [==============================] - 0s 28ms/step
# 0.48535156
# 1/1 [==============================] - 0s 26ms/step
# 0.50923014
# 1/1 [==============================] - 0s 32ms/step
# 0.50923014
# 1/1 [==============================] - 0s 29ms/step
# 0.8016164
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.5486821
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.48207855
# 1/1 [==============================] - 0s 32ms/step
# 0.8208432
# 1/1 [==============================] - 0s 37ms/step
# 0.7758109
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7124438
# 1/1 [==============================] - 0s 27ms/step
# 0.7561871
# 1/1 [==============================] - 0s 25ms/step
# 0.8208432
# 1/1 [==============================] - 0s 25ms/step
# 0.8130972
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.63763344
# 1/1 [==============================] - 0s 26ms/step
# 0.4798813
# 1/1 [==============================] - 0s 25ms/step
# 0.72092843
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.4918213
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.85712886
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.82392114
# 1/1 [==============================] - 0s 26ms/step
# 0.7344971
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# Mean IoU is:  [0.6601834]
