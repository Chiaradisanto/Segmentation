# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor_unet0.6584.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = 8
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
  

            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=8,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
train_loader, val_loader = DataLoader("/gdrive/MyDrive/adjustedROI/final_output", squeeze=False).get_loaders()

# %%
x, y = val_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
x.shape
# Out:
# TensorShape([8, 3, 256, 256, 1])

# %%
batch_size=8

# %%
input_shape=(3,256,256,1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)


x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose( 128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat1 = layers.concatenate([up1, conv9])
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal') ) (concat1)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal') ) (concat1)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal') ) (concat2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (concat3)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal') ) (concat4)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ) ) (x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_4[0][0]']
#  buted)                          32)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_5[0][0]']
#  buted)                          32)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 64, 64, 3  0          ['time_distributed_8[0][0]']
#  buted)                         2)
#
#  time_distributed_10 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_9[0][0]']
#  ibuted)                        4)
#
#  time_distributed_11 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_10[0][0]']
#  ibuted)                        4)
#
#  time_distributed_12 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_11[0][0]']
#  ibuted)                        4)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_12[0][0]']
#  ibuted)                        4)
#
#  time_distributed_14 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_14[0][0]']
#  ibuted)                        28)
#
#  time_distributed_16 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_15[0][0]']
#  ibuted)                        28)
#
#  time_distributed_17 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_16[0][0]']
#  ibuted)                        28)
#
#  time_distributed_18 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_17[0][0]']
#  ibuted)                        28)
#
#  time_distributed_19 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_18[0][0]']
#  ibuted)                        28)
#
#  time_distributed_20 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_19[0][0]']
#  ibuted)                        56)
#
#  time_distributed_21 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_20[0][0]']
#  ibuted)                        56)
#
#  time_distributed_22 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_21[0][0]']
#  ibuted)                        56)
#
#  time_distributed_23 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_22[0][0]']
#  ibuted)                        56)
#
#  bidirectional (Bidirectional)  (None, 3, 16, 16, 5  9439232     ['time_distributed_23[0][0]']
#                                 12)
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_24[0][0]',
#                                 56)                               'time_distributed_18[0][0]']
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_26[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_27[0][0]',
#                                 28)                               'time_distributed_13[0][0]']
#
#  time_distributed_28 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_29 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_28[0][0]']
#  ibuted)                        4)
#
#  time_distributed_30 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_29[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_30[0][0]',
#                                  64)                              'time_distributed_8[0][0]']
#
#  time_distributed_31 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_32 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_31[0][0]']
#  ibuted)                         32)
#
#  time_distributed_33 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_32[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_33[0][0]',
#                                  32)                              'time_distributed_3[0][0]']
#
#  time_distributed_34 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_35 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_34[0][0]']
#  ibuted)                         16)
#
#  bidirectional_1 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_35[0][0]']
#  )                              )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['bidirectional_1[0][0]']
#                                  32)
#
#  conv2d_18 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,785,953
# Trainable params: 11,783,969
# Non-trainable params: 1,984
# __________________________________________________________________________________________________

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)


x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose( 128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat1 = layers.concatenate([up1, conv9])
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_36 (TimeDistr  (None, 3, 256, 256,  160        ['input_2[0][0]']
#  ibuted)                         16)
#
#  time_distributed_37 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_36[0][0]']
#  ibuted)                         16)
#
#  time_distributed_38 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_37[0][0]']
#  ibuted)                         16)
#
#  time_distributed_39 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_38[0][0]']
#  ibuted)                         16)
#
#  time_distributed_40 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_39[0][0]']
#  ibuted)                         16)
#
#  time_distributed_41 (TimeDistr  (None, 3, 128, 128,  4640       ['time_distributed_40[0][0]']
#  ibuted)                         32)
#
#  time_distributed_42 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_41[0][0]']
#  ibuted)                         32)
#
#  time_distributed_43 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_42[0][0]']
#  ibuted)                         32)
#
#  time_distributed_44 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_43[0][0]']
#  ibuted)                         32)
#
#  time_distributed_45 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_44[0][0]']
#  ibuted)                        2)
#
#  time_distributed_46 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_45[0][0]']
#  ibuted)                        4)
#
#  time_distributed_47 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_46[0][0]']
#  ibuted)                        4)
#
#  time_distributed_48 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_47[0][0]']
#  ibuted)                        4)
#
#  time_distributed_49 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_48[0][0]']
#  ibuted)                        4)
#
#  time_distributed_50 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_49[0][0]']
#  ibuted)                        4)
#
#  time_distributed_51 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_50[0][0]']
#  ibuted)                        28)
#
#  time_distributed_52 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_51[0][0]']
#  ibuted)                        28)
#
#  time_distributed_53 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_52[0][0]']
#  ibuted)                        28)
#
#  time_distributed_54 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_53[0][0]']
#  ibuted)                        28)
#
#  time_distributed_55 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_54[0][0]']
#  ibuted)                        28)
#
#  time_distributed_56 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_55[0][0]']
#  ibuted)                        56)
#
#  time_distributed_57 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_56[0][0]']
#  ibuted)                        56)
#
#  time_distributed_58 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_57[0][0]']
#  ibuted)                        56)
#
#  time_distributed_59 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_58[0][0]']
#  ibuted)                        56)
#
#  bidirectional_2 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_59[0][0]']
#  )                              12)
#
#  time_distributed_60 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional_2[0][0]']
#  ibuted)                        28)
#
#  concatenate_4 (Concatenate)    (None, 3, 32, 32, 2  0           ['time_distributed_60[0][0]',
#                                 56)                               'time_distributed_54[0][0]']
#
#  time_distributed_61 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate_4[0][0]']
#  ibuted)                        28)
#
#  time_distributed_62 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_61[0][0]']
#  ibuted)                        28)
#
#  time_distributed_63 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_62[0][0]']
#  ibuted)                        4)
#
#  concatenate_5 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_63[0][0]',
#                                 28)                               'time_distributed_49[0][0]']
#
#  time_distributed_64 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_5[0][0]']
#  ibuted)                        4)
#
#  time_distributed_65 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_64[0][0]']
#  ibuted)                        4)
#
#  time_distributed_66 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_65[0][0]']
#  ibuted)                         32)
#
#  concatenate_6 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_66[0][0]',
#                                  64)                              'time_distributed_44[0][0]']
#
#  time_distributed_67 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_6[0][0]']
#  ibuted)                         32)
#
#  time_distributed_68 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_67[0][0]']
#  ibuted)                         32)
#
#  time_distributed_69 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_68[0][0]']
#  ibuted)                         16)
#
#  concatenate_7 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_69[0][0]',
#                                  32)                              'time_distributed_39[0][0]']
#
#  time_distributed_70 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_7[0][0]']
#  ibuted)                         16)
#
#  time_distributed_71 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_70[0][0]']
#  ibuted)                         16)
#
#  bidirectional_3 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_71[0][0]']
#  )                              )
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_3[0][0]']
#                                  32)
#
#  conv2d_37 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims_1[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,933,537
# Trainable params: 11,931,553
# Non-trainable params: 1,984
# __________________________________________________________________________________________________

# %%
x.shape
# Out:
# TensorShape([None, 1, 256, 256, 32])

# %%
batch_size=8

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
steps_per_epoch
# Out:
# 372

# %%
input_shape=(3,256,256,1)

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[ dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=15,
          verbose=1,
          validation_data=val_loader,
          callbacks= model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/15
# 372/372 [==============================] - 397s 1s/step - loss: 0.6385 - dice_coefficient: 0.3615 - binary_accuracy: 0.9575 - val_loss: 0.6395 - val_dice_coefficient: 0.3605 - val_binary_accuracy: 0.9605
# Epoch 2/15
# 372/372 [==============================] - 372s 1s/step - loss: 0.4334 - dice_coefficient: 0.5666 - binary_accuracy: 0.9788 - val_loss: 0.4078 - val_dice_coefficient: 0.5922 - val_binary_accuracy: 0.9773
# Epoch 3/15
# 372/372 [==============================] - 372s 1s/step - loss: 0.3996 - dice_coefficient: 0.6004 - binary_accuracy: 0.9816 - val_loss: 0.3711 - val_dice_coefficient: 0.6289 - val_binary_accuracy: 0.9752
# Epoch 4/15
# 372/372 [==============================] - 373s 1s/step - loss: 0.3551 - dice_coefficient: 0.6449 - binary_accuracy: 0.9824 - val_loss: 0.3216 - val_dice_coefficient: 0.6784 - val_binary_accuracy: 0.9802
# Epoch 5/15
# 372/372 [==============================] - 372s 1000ms/step - loss: 0.3449 - dice_coefficient: 0.6551 - binary_accuracy: 0.9837 - val_loss: 0.3037 - val_dice_coefficient: 0.6963 - val_binary_accuracy: 0.9818
# Epoch 6/15
# 372/372 [==============================] - 372s 999ms/step - loss: 0.3147 - dice_coefficient: 0.6853 - binary_accuracy: 0.9843 - val_loss: 0.3059 - val_dice_coefficient: 0.6941 - val_binary_accuracy: 0.9810
# Epoch 7/15
# 372/372 [==============================] - 371s 998ms/step - loss: 0.2886 - dice_coefficient: 0.7114 - binary_accuracy: 0.9851 - val_loss: 0.3410 - val_dice_coefficient: 0.6590 - val_binary_accuracy: 0.9809
# Epoch 8/15
# 372/372 [==============================] - 371s 997ms/step - loss: 0.2976 - dice_coefficient: 0.7024 - binary_accuracy: 0.9857 - val_loss: 0.3108 - val_dice_coefficient: 0.6892 - val_binary_accuracy: 0.9807
# Epoch 9/15
# 372/372 [==============================] - 371s 997ms/step - loss: 0.2833 - dice_coefficient: 0.7167 - binary_accuracy: 0.9864 - val_loss: 0.3130 - val_dice_coefficient: 0.6870 - val_binary_accuracy: 0.9816
# Epoch 10/15
# 372/372 [==============================] - 371s 997ms/step - loss: 0.2746 - dice_coefficient: 0.7254 - binary_accuracy: 0.9866 - val_loss: 0.3589 - val_dice_coefficient: 0.6411 - val_binary_accuracy: 0.9819
# Epoch 11/15
# 372/372 [==============================] - 371s 998ms/step - loss: 0.2514 - dice_coefficient: 0.7486 - binary_accuracy: 0.9875 - val_loss: 0.3045 - val_dice_coefficient: 0.6955 - val_binary_accuracy: 0.9815
# Epoch 12/15
# 372/372 [==============================] - 371s 998ms/step - loss: 0.2504 - dice_coefficient: 0.7496 - binary_accuracy: 0.9875 - val_loss: 0.3361 - val_dice_coefficient: 0.6639 - val_binary_accuracy: 0.9827
# Epoch 13/15
# 372/372 [==============================] - 371s 998ms/step - loss: 0.2602 - dice_coefficient: 0.7398 - binary_accuracy: 0.9869 - val_loss: 0.3781 - val_dice_coefficient: 0.6219 - val_binary_accuracy: 0.9812
# Epoch 14/15
# 372/372 [==============================] - 372s 1s/step - loss: 0.2400 - dice_coefficient: 0.7600 - binary_accuracy: 0.9877 - val_loss: 0.2902 - val_dice_coefficient: 0.7098 - val_binary_accuracy: 0.9827
# Epoch 15/15
# 372/372 [==============================] - 372s 1s/step - loss: 0.2424 - dice_coefficient: 0.7576 - binary_accuracy: 0.9880 - val_loss: 0.3044 - val_dice_coefficient: 0.6956 - val_binary_accuracy: 0.9809

# %%
model.save('/gdrive/MyDrive/Sensor15-unet-5e-5-roiadjusted-kernelinitializer-recurrentdropout02-nodropout-8batch.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor15-unet-5e-5-roiadjusted-kernelinitializer-recurrentdropout02-nodropout-8batch.h5", compile=False)

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=400,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
data_folder = "/gdrive/MyDrive/adjustedROI/final_output"
train,val_loader = DataLoader(data_folder, batch_size=477).get_loaders()

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.8764669

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 0.8089725
# 0.78141046
# 0.8094573
# 0.8667311
# 0.7899089
# 0.4924955
# 0.847752
# 1.0
# 0.49983215
# 0.77618
# 0.48425293
# 0.52911425
# 0.49201965
# 0.55328256
# 0.7768278
# 0.84852976
# 0.4864502
# 0.818782
# 0.7997956
# 0.80977654
# 0.7862893
# 0.84063697
# 0.4996643
# 0.4933014
# 0.78954476
# 0.8764669
# 1.0
# 0.49207306
# 0.5182818
# 1.0
# 1.0
# 0.49639893
# 0.83126485
# 0.49207306
# 0.49201965
# 0.5002514
# 0.54008096
# 0.84461063
# 1.0
