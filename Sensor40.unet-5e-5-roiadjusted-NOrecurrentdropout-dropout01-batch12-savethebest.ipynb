# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor40.unet-5e-5-roiadjusted-NOrecurrentdropout-dropout01-batch12-savethebest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),


            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=12,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
train_loader, val_loader = DataLoader("/gdrive/MyDrive/TESI/adjustedROI/final_output", squeeze=False).get_loaders()

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/TESI/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/TESI/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1)))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)

conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)

conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)

conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose( 128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path

concat1 = layers.concatenate([up1, conv9])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (concat1)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1)) ) (x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat2 = layers.concatenate([up2, conv8])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (concat2)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1)) ) (concat3)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1)) ) (concat4)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)

x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1)) ) (x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_54 (TimeDistr  (None, 3, 256, 256,  160        ['input_2[0][0]']
#  ibuted)                         16)
#
#  time_distributed_55 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_54[0][0]']
#  ibuted)                         16)
#
#  time_distributed_56 (TimeDistr  (None, 3, 256, 256,  0          ['time_distributed_55[0][0]']
#  ibuted)                         16)
#
#  time_distributed_57 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_56[0][0]']
#  ibuted)                         16)
#
#  time_distributed_58 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_57[0][0]']
#  ibuted)                         16)
#
#  time_distributed_59 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_58[0][0]']
#  ibuted)                         16)
#
#  time_distributed_60 (TimeDistr  (None, 3, 128, 128,  4640       ['time_distributed_59[0][0]']
#  ibuted)                         32)
#
#  time_distributed_61 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_60[0][0]']
#  ibuted)                         32)
#
#  time_distributed_62 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_61[0][0]']
#  ibuted)                         32)
#
#  time_distributed_63 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_62[0][0]']
#  ibuted)                         32)
#
#  time_distributed_64 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_63[0][0]']
#  ibuted)                         32)
#
#  time_distributed_65 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_64[0][0]']
#  ibuted)                        2)
#
#  time_distributed_66 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_65[0][0]']
#  ibuted)                        4)
#
#  time_distributed_67 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_66[0][0]']
#  ibuted)                        4)
#
#  time_distributed_68 (TimeDistr  (None, 3, 64, 64, 6  0          ['time_distributed_67[0][0]']
#  ibuted)                        4)
#
#  time_distributed_69 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_68[0][0]']
#  ibuted)                        4)
#
#  time_distributed_70 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_69[0][0]']
#  ibuted)                        4)
#
#  time_distributed_71 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_70[0][0]']
#  ibuted)                        4)
#
#  time_distributed_72 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_71[0][0]']
#  ibuted)                        28)
#
#  time_distributed_73 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_72[0][0]']
#  ibuted)                        28)
#
#  time_distributed_74 (TimeDistr  (None, 3, 32, 32, 1  0          ['time_distributed_73[0][0]']
#  ibuted)                        28)
#
#  time_distributed_75 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_74[0][0]']
#  ibuted)                        28)
#
#  time_distributed_76 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_75[0][0]']
#  ibuted)                        28)
#
#  time_distributed_77 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_76[0][0]']
#  ibuted)                        56)
#
#  time_distributed_78 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_77[0][0]']
#  ibuted)                        56)
#
#  time_distributed_79 (TimeDistr  (None, 3, 16, 16, 2  0          ['time_distributed_78[0][0]']
#  ibuted)                        56)
#
#  time_distributed_80 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_79[0][0]']
#  ibuted)                        56)
#
#  time_distributed_81 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_80[0][0]']
#  ibuted)                        56)
#
#  bidirectional_2 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_81[0][0]']
#  )                              12)
#
#  time_distributed_82 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional_2[0][0]']
#  ibuted)                        28)
#
#  concatenate_5 (Concatenate)    (None, 3, 32, 32, 2  0           ['time_distributed_82[0][0]',
#                                 56)                               'time_distributed_75[0][0]']
#
#  time_distributed_83 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate_5[0][0]']
#  ibuted)                        28)
#
#  time_distributed_84 (TimeDistr  (None, 3, 32, 32, 1  0          ['time_distributed_83[0][0]']
#  ibuted)                        28)
#
#  time_distributed_85 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_84[0][0]']
#  ibuted)                        28)
#
#  time_distributed_86 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_85[0][0]']
#  ibuted)                        4)
#
#  concatenate_6 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_86[0][0]',
#                                 28)                               'time_distributed_70[0][0]']
#
#  time_distributed_87 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_6[0][0]']
#  ibuted)                        4)
#
#  time_distributed_88 (TimeDistr  (None, 3, 64, 64, 6  0          ['time_distributed_87[0][0]']
#  ibuted)                        4)
#
#  time_distributed_89 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_88[0][0]']
#  ibuted)                        4)
#
#  time_distributed_90 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_89[0][0]']
#  ibuted)                         32)
#
#  concatenate_7 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_90[0][0]',
#                                  64)                              'time_distributed_64[0][0]']
#
#  time_distributed_91 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_7[0][0]']
#  ibuted)                         32)
#
#  time_distributed_92 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_91[0][0]']
#  ibuted)                         32)
#
#  time_distributed_93 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_92[0][0]']
#  ibuted)                         32)
#
#  time_distributed_94 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_93[0][0]']
#  ibuted)                         16)
#
#  concatenate_8 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_94[0][0]',
#                                  32)                              'time_distributed_58[0][0]']
#
#  time_distributed_95 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_8[0][0]']
#  ibuted)                         16)
#
#  time_distributed_96 (TimeDistr  (None, 3, 256, 256,  0          ['time_distributed_95[0][0]']
#  ibuted)                         16)
#
#  time_distributed_97 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_96[0][0]']
#  ibuted)                         16)
#
#  bidirectional_3 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_97[0][0]']
#  )                              )
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_3[0][0]']
#                                  32)
#
#  conv2d_41 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims_1[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,933,025
# Trainable params: 11,931,297
# Non-trainable params: 1,728
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/40
# 248/248 [==============================] - 367s 1s/step - loss: 0.7581 - dice_coefficient: 0.2419 - binary_accuracy: 0.9168 - val_loss: 0.9779 - val_dice_coefficient: 0.0221 - val_binary_accuracy: 0.9675
# Epoch 2/40
# 248/248 [==============================] - 338s 1s/step - loss: 0.5822 - dice_coefficient: 0.4178 - binary_accuracy: 0.9725 - val_loss: 0.9856 - val_dice_coefficient: 0.0144 - val_binary_accuracy: 0.9686
# Epoch 3/40
# 248/248 [==============================] - 338s 1s/step - loss: 0.5074 - dice_coefficient: 0.4926 - binary_accuracy: 0.9760 - val_loss: 0.6110 - val_dice_coefficient: 0.3890 - val_binary_accuracy: 0.9712
# Epoch 4/40
# 248/248 [==============================] - 338s 1s/step - loss: 0.4636 - dice_coefficient: 0.5364 - binary_accuracy: 0.9776 - val_loss: 0.5152 - val_dice_coefficient: 0.4848 - val_binary_accuracy: 0.9733
# Epoch 5/40
# 248/248 [==============================] - 338s 1s/step - loss: 0.4216 - dice_coefficient: 0.5784 - binary_accuracy: 0.9791 - val_loss: 0.5796 - val_dice_coefficient: 0.4204 - val_binary_accuracy: 0.9738
# Epoch 6/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.3913 - dice_coefficient: 0.6087 - binary_accuracy: 0.9799 - val_loss: 0.6544 - val_dice_coefficient: 0.3456 - val_binary_accuracy: 0.9711
# Epoch 7/40
# 248/248 [==============================] - 338s 1s/step - loss: 0.3705 - dice_coefficient: 0.6295 - binary_accuracy: 0.9809 - val_loss: 0.6420 - val_dice_coefficient: 0.3580 - val_binary_accuracy: 0.9741
# Epoch 8/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.3593 - dice_coefficient: 0.6407 - binary_accuracy: 0.9823 - val_loss: 0.5051 - val_dice_coefficient: 0.4949 - val_binary_accuracy: 0.9745
# Epoch 9/40
# 248/248 [==============================] - 338s 1s/step - loss: 0.3449 - dice_coefficient: 0.6551 - binary_accuracy: 0.9834 - val_loss: 0.5340 - val_dice_coefficient: 0.4660 - val_binary_accuracy: 0.9712
# Epoch 10/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.3314 - dice_coefficient: 0.6686 - binary_accuracy: 0.9830 - val_loss: 0.5504 - val_dice_coefficient: 0.4496 - val_binary_accuracy: 0.9721
# Epoch 11/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.3152 - dice_coefficient: 0.6848 - binary_accuracy: 0.9831 - val_loss: 0.5363 - val_dice_coefficient: 0.4637 - val_binary_accuracy: 0.9729
# Epoch 12/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.3068 - dice_coefficient: 0.6932 - binary_accuracy: 0.9840 - val_loss: 0.5000 - val_dice_coefficient: 0.5000 - val_binary_accuracy: 0.9732
# Epoch 13/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2904 - dice_coefficient: 0.7096 - binary_accuracy: 0.9845 - val_loss: 0.4849 - val_dice_coefficient: 0.5151 - val_binary_accuracy: 0.9725
# Epoch 14/40
# 248/248 [==============================] - 340s 1s/step - loss: 0.2933 - dice_coefficient: 0.7067 - binary_accuracy: 0.9851 - val_loss: 0.4768 - val_dice_coefficient: 0.5232 - val_binary_accuracy: 0.9726
# Epoch 15/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2892 - dice_coefficient: 0.7108 - binary_accuracy: 0.9845 - val_loss: 0.5767 - val_dice_coefficient: 0.4233 - val_binary_accuracy: 0.9720
# Epoch 16/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2632 - dice_coefficient: 0.7368 - binary_accuracy: 0.9855 - val_loss: 0.4933 - val_dice_coefficient: 0.5067 - val_binary_accuracy: 0.9737
# Epoch 17/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2723 - dice_coefficient: 0.7277 - binary_accuracy: 0.9859 - val_loss: 0.5445 - val_dice_coefficient: 0.4555 - val_binary_accuracy: 0.9749
# Epoch 18/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2863 - dice_coefficient: 0.7137 - binary_accuracy: 0.9858 - val_loss: 0.6647 - val_dice_coefficient: 0.3353 - val_binary_accuracy: 0.9704
# Epoch 19/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2683 - dice_coefficient: 0.7317 - binary_accuracy: 0.9860 - val_loss: 0.5141 - val_dice_coefficient: 0.4859 - val_binary_accuracy: 0.9723
# Epoch 20/40
# 248/248 [==============================] - 340s 1s/step - loss: 0.2556 - dice_coefficient: 0.7444 - binary_accuracy: 0.9866 - val_loss: 0.3944 - val_dice_coefficient: 0.6056 - val_binary_accuracy: 0.9782
# Epoch 21/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2602 - dice_coefficient: 0.7398 - binary_accuracy: 0.9865 - val_loss: 0.4531 - val_dice_coefficient: 0.5469 - val_binary_accuracy: 0.9766
# Epoch 22/40
# 248/248 [==============================] - 340s 1s/step - loss: 0.2466 - dice_coefficient: 0.7534 - binary_accuracy: 0.9865 - val_loss: 0.4806 - val_dice_coefficient: 0.5194 - val_binary_accuracy: 0.9747
# Epoch 23/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2446 - dice_coefficient: 0.7554 - binary_accuracy: 0.9870 - val_loss: 0.4808 - val_dice_coefficient: 0.5192 - val_binary_accuracy: 0.9743
# Epoch 24/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2328 - dice_coefficient: 0.7672 - binary_accuracy: 0.9874 - val_loss: 0.4235 - val_dice_coefficient: 0.5765 - val_binary_accuracy: 0.9773
# Epoch 25/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2404 - dice_coefficient: 0.7596 - binary_accuracy: 0.9875 - val_loss: 0.4615 - val_dice_coefficient: 0.5385 - val_binary_accuracy: 0.9759
# Epoch 26/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2373 - dice_coefficient: 0.7627 - binary_accuracy: 0.9880 - val_loss: 0.4726 - val_dice_coefficient: 0.5274 - val_binary_accuracy: 0.9713
# Epoch 27/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2275 - dice_coefficient: 0.7725 - binary_accuracy: 0.9876 - val_loss: 0.5970 - val_dice_coefficient: 0.4030 - val_binary_accuracy: 0.9757
# Epoch 28/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2303 - dice_coefficient: 0.7697 - binary_accuracy: 0.9881 - val_loss: 0.6571 - val_dice_coefficient: 0.3429 - val_binary_accuracy: 0.9710
# Epoch 29/40
# 248/248 [==============================] - 340s 1s/step - loss: 0.2173 - dice_coefficient: 0.7827 - binary_accuracy: 0.9883 - val_loss: 0.5705 - val_dice_coefficient: 0.4295 - val_binary_accuracy: 0.9735
# Epoch 30/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2288 - dice_coefficient: 0.7712 - binary_accuracy: 0.9880 - val_loss: 0.4329 - val_dice_coefficient: 0.5671 - val_binary_accuracy: 0.9726
# Epoch 31/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2160 - dice_coefficient: 0.7840 - binary_accuracy: 0.9883 - val_loss: 0.4941 - val_dice_coefficient: 0.5059 - val_binary_accuracy: 0.9741
# Epoch 32/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2369 - dice_coefficient: 0.7631 - binary_accuracy: 0.9877 - val_loss: 0.6365 - val_dice_coefficient: 0.3635 - val_binary_accuracy: 0.9721
# Epoch 33/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2134 - dice_coefficient: 0.7866 - binary_accuracy: 0.9883 - val_loss: 0.4819 - val_dice_coefficient: 0.5181 - val_binary_accuracy: 0.9759
# Epoch 34/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2180 - dice_coefficient: 0.7820 - binary_accuracy: 0.9884 - val_loss: 0.5388 - val_dice_coefficient: 0.4612 - val_binary_accuracy: 0.9724
# Epoch 35/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2080 - dice_coefficient: 0.7920 - binary_accuracy: 0.9886 - val_loss: 0.5686 - val_dice_coefficient: 0.4314 - val_binary_accuracy: 0.9732
# Epoch 36/40
# 248/248 [==============================] - 340s 1s/step - loss: 0.1980 - dice_coefficient: 0.8020 - binary_accuracy: 0.9888 - val_loss: 0.6803 - val_dice_coefficient: 0.3197 - val_binary_accuracy: 0.9722
# Epoch 37/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2076 - dice_coefficient: 0.7924 - binary_accuracy: 0.9883 - val_loss: 0.5959 - val_dice_coefficient: 0.4041 - val_binary_accuracy: 0.9737
# Epoch 38/40
# 248/248 [==============================] - 339s 1s/step - loss: 0.2136 - dice_coefficient: 0.7864 - binary_accuracy: 0.9885 - val_loss: 0.7243 - val_dice_coefficient: 0.2757 - val_binary_accuracy: 0.9705
# Epoch 39/40
# 248/248 [==============================] - 340s 1s/step - loss: 0.2205 - dice_coefficient: 0.7795 - binary_accuracy: 0.9888 - val_loss: 0.6037 - val_dice_coefficient: 0.3963 - val_binary_accuracy: 0.9753
# Epoch 40/40
# 248/248 [==============================] - 340s 1s/step - loss: 0.2030 - dice_coefficient: 0.7970 - binary_accuracy: 0.9891 - val_loss: 0.6319 - val_dice_coefficient: 0.3681 - val_binary_accuracy: 0.9725

# %%
model.save('/gdrive/MyDrive/Sensor40.unet-5e-5-roiadjusted-NOrecurrentdropout-dropout01-batch12-savethebest.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor40.unet-5e-5-roiadjusted-NOrecurrentdropout-dropout01-batch12-savethebest.h5", compile=False)

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=400,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
data_folder = "/gdrive/MyDrive/TESI/adjustedROI/final_output"
train,val_loader = DataLoader(data_folder, batch_size=477).get_loaders()

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.6829208

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 0.49704742
# 0.53086126
# 1.0
# 0.68489456
# 0.5580186
# 1.0
# 0.5818123
# 0.58655286
# 0.7542089
# 0.51370436
# 0.49801636
# 0.73543274
# 0.69051635
# 1.0
# 0.6751558
# 0.49556732
# 1.0
# 0.48301697
# 0.56866026
# 0.49077606
# 1.0
# 0.5549308
# 1.0
# 0.62096757
# 0.49234483
# 0.56969875
# 0.55114496
# 0.4976377
# 1.0
# 0.5545306
# 0.55114496
# 1.0
# 0.52255476
# 0.7810354
# 1.0
# 1.0
# 0.5286601
# 0.5998604
# 0.47994122
# 1.0
# 0.78791285
# 0.49654388
# 0.5547208
# 1.0
# 0.52172047
# 0.8143438
# 0.5287476
# 0.49877167
# 0.4790986
# 0.8183861
# 0.5573013
# 1.0
# 1.0
# 1.0
# 1.0
# 0.6400509
# 0.6092361
# 0.5924812
# 0.49623108
# 1.0
# 0.69051635
# 1.0
# 0.5318508
# 1.0
# 0.489192
# 1.0
# 1.0
# 0.74566525
# 0.49990082
# 0.4981842
# 0.4981842
# 0.658909
# 0.5701945
# 0.6092361
# 0.4790986
# 0.567024
# 0.55769706
# 0.82189876
# 0.57525885
# 0.5573013
# 1.0
# 0.7544701
