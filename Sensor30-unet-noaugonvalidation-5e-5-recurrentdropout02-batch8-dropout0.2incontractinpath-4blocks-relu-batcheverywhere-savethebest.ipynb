# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30-unet-noaugonvalidation-5e-5-recurrentdropout02-batch8-dropout0.2incontractinpath-4blocks-relu-batcheverywhere-savethebest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 8
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,

)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([8, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
batch_size=8

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
num_val_images
# Out:
# 477

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv2)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv2)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv5)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv5)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)
conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

#expanding path
concat1 = layers.concatenate([up1, conv9])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)

concat2 = layers.concatenate([up2, conv8])

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.TimeDistributed(layers.Dropout(0.2))(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_4[0][0]']
#  buted)                          16)
#
#  time_distributed_6 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_5[0][0]']
#  buted)                          16)
#
#  time_distributed_7 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_6[0][0]']
#  buted)                          16)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_7[0][0]']
#  buted)                          16)
#
#  time_distributed_9 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_8[0][0]']
#  buted)                          32)
#
#  time_distributed_10 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_9[0][0]']
#  ibuted)                         32)
#
#  time_distributed_11 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_10[0][0]']
#  ibuted)                         32)
#
#  time_distributed_12 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_11[0][0]']
#  ibuted)                         32)
#
#  time_distributed_13 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_12[0][0]']
#  ibuted)                         32)
#
#  time_distributed_14 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_13[0][0]']
#  ibuted)                         32)
#
#  time_distributed_15 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_14[0][0]']
#  ibuted)                         32)
#
#  time_distributed_16 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_15[0][0]']
#  ibuted)                         32)
#
#  time_distributed_17 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_16[0][0]']
#  ibuted)                        2)
#
#  time_distributed_18 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_17[0][0]']
#  ibuted)                        4)
#
#  time_distributed_19 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_18[0][0]']
#  ibuted)                        4)
#
#  time_distributed_20 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_19[0][0]']
#  ibuted)                        4)
#
#  time_distributed_21 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_20[0][0]']
#  ibuted)                        4)
#
#  time_distributed_24 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_21[0][0]']
#  ibuted)                        4)
#
#  time_distributed_25 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_24[0][0]']
#  ibuted)                        4)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_25[0][0]']
#  ibuted)                        4)
#
#  time_distributed_27 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_26[0][0]']
#  ibuted)                        28)
#
#  time_distributed_28 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_27[0][0]']
#  ibuted)                        28)
#
#  time_distributed_29 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_28[0][0]']
#  ibuted)                        28)
#
#  time_distributed_30 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_29[0][0]']
#  ibuted)                        28)
#
#  time_distributed_33 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_30[0][0]']
#  ibuted)                        28)
#
#  time_distributed_34 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_33[0][0]']
#  ibuted)                        28)
#
#  time_distributed_35 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_34[0][0]']
#  ibuted)                        28)
#
#  time_distributed_36 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_35[0][0]']
#  ibuted)                        56)
#
#  time_distributed_37 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_36[0][0]']
#  ibuted)                        56)
#
#  time_distributed_38 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_37[0][0]']
#  ibuted)                        56)
#
#  time_distributed_39 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_38[0][0]']
#  ibuted)                        56)
#
#  time_distributed_40 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_39[0][0]']
#  ibuted)                        56)
#
#  time_distributed_41 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_40[0][0]']
#  ibuted)                        56)
#
#  time_distributed_42 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_41[0][0]']
#  ibuted)                        56)
#
#  time_distributed_43 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_42[0][0]']
#  ibuted)                        56)
#
#  bidirectional (Bidirectional)  (None, 3, 16, 16, 5  9439232     ['time_distributed_43[0][0]']
#                                 12)
#
#  time_distributed_44 (TimeDistr  (None, 3, 32, 32, 1  589952     ['bidirectional[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_44[0][0]',
#                                 56)                               'time_distributed_34[0][0]']
#
#  time_distributed_45 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_46 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_45[0][0]']
#  ibuted)                        28)
#
#  time_distributed_47 (TimeDistr  (None, 3, 32, 32, 1  0          ['time_distributed_46[0][0]']
#  ibuted)                        28)
#
#  time_distributed_48 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_47[0][0]']
#  ibuted)                        28)
#
#  time_distributed_49 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_48[0][0]']
#  ibuted)                        28)
#
#  time_distributed_50 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_49[0][0]']
#  ibuted)                        28)
#
#  time_distributed_51 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_50[0][0]']
#  ibuted)                        28)
#
#  time_distributed_52 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_51[0][0]']
#  ibuted)                        28)
#
#  time_distributed_53 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_52[0][0]']
#  ibuted)                        28)
#
#  time_distributed_54 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_53[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_54[0][0]',
#                                 28)                               'time_distributed_25[0][0]']
#
#  time_distributed_55 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_56 (TimeDistr  (None, 3, 64, 64, 6  0          ['time_distributed_55[0][0]']
#  ibuted)                        4)
#
#  time_distributed_57 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_56[0][0]']
#  ibuted)                        4)
#
#  time_distributed_58 (TimeDistr  (None, 3, 64, 64, 6  0          ['time_distributed_57[0][0]']
#  ibuted)                        4)
#
#  time_distributed_59 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_58[0][0]']
#  ibuted)                        4)
#
#  time_distributed_60 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_59[0][0]']
#  ibuted)                        4)
#
#  time_distributed_61 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_60[0][0]']
#  ibuted)                        4)
#
#  time_distributed_62 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_61[0][0]']
#  ibuted)                        4)
#
#  time_distributed_63 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_62[0][0]']
#  ibuted)                        4)
#
#  time_distributed_64 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_63[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_64[0][0]',
#                                  64)                              'time_distributed_16[0][0]']
#
#  time_distributed_65 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_66 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_65[0][0]']
#  ibuted)                         32)
#
#  time_distributed_67 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_66[0][0]']
#  ibuted)                         32)
#
#  time_distributed_68 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_67[0][0]']
#  ibuted)                         32)
#
#  time_distributed_69 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_68[0][0]']
#  ibuted)                         32)
#
#  time_distributed_70 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_69[0][0]']
#  ibuted)                         32)
#
#  time_distributed_71 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_70[0][0]']
#  ibuted)                         32)
#
#  time_distributed_72 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_71[0][0]']
#  ibuted)                         32)
#
#  time_distributed_73 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_72[0][0]']
#  ibuted)                         32)
#
#  time_distributed_74 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_73[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_74[0][0]',
#                                  32)                              'time_distributed_7[0][0]']
#
#  time_distributed_75 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_76 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_75[0][0]']
#  ibuted)                         16)
#
#  time_distributed_77 (TimeDistr  (None, 3, 256, 256,  0          ['time_distributed_76[0][0]']
#  ibuted)                         16)
#
#  time_distributed_78 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_77[0][0]']
#  ibuted)                         16)
#
#  time_distributed_79 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_78[0][0]']
#  ibuted)                         16)
#
#  time_distributed_80 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_79[0][0]']
#  ibuted)                         16)
#
#  time_distributed_81 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_80[0][0]']
#  ibuted)                         16)
#
#  time_distributed_82 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_81[0][0]']
#  ibuted)                         16)
#
#  time_distributed_83 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_82[0][0]']
#  ibuted)                         16)
#
#  bidirectional_1 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_83[0][0]']
#  )                              )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['bidirectional_1[0][0]']
#                                  32)
#
#  conv2d_36 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 13,720,289
# Trainable params: 13,714,913
# Non-trainable params: 5,376
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 372/372 [==============================] - 551s 1s/step - loss: 0.7673 - dice_coefficient: 0.2327 - binary_accuracy: 0.8300 - val_loss: 0.9115 - val_dice_coefficient: 0.0885 - val_binary_accuracy: 0.6667
# Epoch 2/30
# 372/372 [==============================] - 517s 1s/step - loss: 0.4203 - dice_coefficient: 0.5797 - binary_accuracy: 0.9767 - val_loss: 0.6317 - val_dice_coefficient: 0.3683 - val_binary_accuracy: 0.9748
# Epoch 3/30
# 372/372 [==============================] - 515s 1s/step - loss: 0.3516 - dice_coefficient: 0.6484 - binary_accuracy: 0.9813 - val_loss: 0.9174 - val_dice_coefficient: 0.0826 - val_binary_accuracy: 0.9841
# Epoch 4/30
# 372/372 [==============================] - 516s 1s/step - loss: 0.3204 - dice_coefficient: 0.6796 - binary_accuracy: 0.9824 - val_loss: 0.5785 - val_dice_coefficient: 0.4215 - val_binary_accuracy: 0.9841
# Epoch 5/30
# 372/372 [==============================] - 515s 1s/step - loss: 0.3109 - dice_coefficient: 0.6891 - binary_accuracy: 0.9834 - val_loss: 0.6388 - val_dice_coefficient: 0.3612 - val_binary_accuracy: 0.9887
# Epoch 6/30
# 372/372 [==============================] - 515s 1s/step - loss: 0.2906 - dice_coefficient: 0.7094 - binary_accuracy: 0.9839 - val_loss: 0.5294 - val_dice_coefficient: 0.4706 - val_binary_accuracy: 0.9890
# Epoch 7/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.2945 - dice_coefficient: 0.7055 - binary_accuracy: 0.9843 - val_loss: 0.5972 - val_dice_coefficient: 0.4028 - val_binary_accuracy: 0.9856
# Epoch 8/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2844 - dice_coefficient: 0.7156 - binary_accuracy: 0.9848 - val_loss: 0.5729 - val_dice_coefficient: 0.4271 - val_binary_accuracy: 0.9876
# Epoch 9/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2655 - dice_coefficient: 0.7345 - binary_accuracy: 0.9849 - val_loss: 0.5955 - val_dice_coefficient: 0.4045 - val_binary_accuracy: 0.9730
# Epoch 10/30
# 372/372 [==============================] - 515s 1s/step - loss: 0.2741 - dice_coefficient: 0.7259 - binary_accuracy: 0.9853 - val_loss: 0.4886 - val_dice_coefficient: 0.5114 - val_binary_accuracy: 0.9862
# Epoch 11/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.2481 - dice_coefficient: 0.7519 - binary_accuracy: 0.9859 - val_loss: 0.7925 - val_dice_coefficient: 0.2075 - val_binary_accuracy: 0.9863
# Epoch 12/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.2498 - dice_coefficient: 0.7502 - binary_accuracy: 0.9863 - val_loss: 0.7615 - val_dice_coefficient: 0.2385 - val_binary_accuracy: 0.9851
# Epoch 13/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.2309 - dice_coefficient: 0.7691 - binary_accuracy: 0.9874 - val_loss: 0.6080 - val_dice_coefficient: 0.3920 - val_binary_accuracy: 0.9860
# Epoch 14/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.2478 - dice_coefficient: 0.7522 - binary_accuracy: 0.9864 - val_loss: 0.4144 - val_dice_coefficient: 0.5856 - val_binary_accuracy: 0.9888
# Epoch 15/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2349 - dice_coefficient: 0.7651 - binary_accuracy: 0.9867 - val_loss: 0.7706 - val_dice_coefficient: 0.2294 - val_binary_accuracy: 0.9875
# Epoch 16/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2348 - dice_coefficient: 0.7652 - binary_accuracy: 0.9866 - val_loss: 0.8989 - val_dice_coefficient: 0.1011 - val_binary_accuracy: 0.9875
# Epoch 17/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2318 - dice_coefficient: 0.7682 - binary_accuracy: 0.9872 - val_loss: 0.4754 - val_dice_coefficient: 0.5246 - val_binary_accuracy: 0.9866
# Epoch 18/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2151 - dice_coefficient: 0.7849 - binary_accuracy: 0.9879 - val_loss: 0.6523 - val_dice_coefficient: 0.3477 - val_binary_accuracy: 0.9856
# Epoch 19/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2009 - dice_coefficient: 0.7991 - binary_accuracy: 0.9878 - val_loss: 0.6383 - val_dice_coefficient: 0.3617 - val_binary_accuracy: 0.9831
# Epoch 20/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2153 - dice_coefficient: 0.7847 - binary_accuracy: 0.9876 - val_loss: 0.4548 - val_dice_coefficient: 0.5452 - val_binary_accuracy: 0.9889
# Epoch 21/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.2185 - dice_coefficient: 0.7815 - binary_accuracy: 0.9874 - val_loss: 0.4435 - val_dice_coefficient: 0.5565 - val_binary_accuracy: 0.9874
# Epoch 22/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2028 - dice_coefficient: 0.7972 - binary_accuracy: 0.9882 - val_loss: 0.4656 - val_dice_coefficient: 0.5344 - val_binary_accuracy: 0.9861
# Epoch 23/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2056 - dice_coefficient: 0.7944 - binary_accuracy: 0.9881 - val_loss: 0.5208 - val_dice_coefficient: 0.4792 - val_binary_accuracy: 0.9834
# Epoch 24/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.2180 - dice_coefficient: 0.7820 - binary_accuracy: 0.9881 - val_loss: 0.4012 - val_dice_coefficient: 0.5988 - val_binary_accuracy: 0.9887
# Epoch 25/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.2075 - dice_coefficient: 0.7925 - binary_accuracy: 0.9879 - val_loss: 0.5107 - val_dice_coefficient: 0.4893 - val_binary_accuracy: 0.9891
# Epoch 26/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.2009 - dice_coefficient: 0.7991 - binary_accuracy: 0.9884 - val_loss: 0.4988 - val_dice_coefficient: 0.5012 - val_binary_accuracy: 0.9852
# Epoch 27/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.1896 - dice_coefficient: 0.8104 - binary_accuracy: 0.9892 - val_loss: 0.4835 - val_dice_coefficient: 0.5165 - val_binary_accuracy: 0.9879
# Epoch 28/30
# 372/372 [==============================] - 513s 1s/step - loss: 0.1892 - dice_coefficient: 0.8108 - binary_accuracy: 0.9884 - val_loss: 0.5311 - val_dice_coefficient: 0.4689 - val_binary_accuracy: 0.9843
# Epoch 29/30
# 372/372 [==============================] - 514s 1s/step - loss: 0.1845 - dice_coefficient: 0.8155 - binary_accuracy: 0.9884 - val_loss: 0.4006 - val_dice_coefficient: 0.5994 - val_binary_accuracy: 0.9915
# Epoch 30/30
# 372/372 [==============================] - 518s 1s/step - loss: 0.1769 - dice_coefficient: 0.8231 - binary_accuracy: 0.9895 - val_loss: 0.4879 - val_dice_coefficient: 0.5121 - val_binary_accuracy: 0.9876

# %%
model.save('/gdrive/MyDrive/Sensor30-unet-noaugonvalidation-5e-5-recurrentdropout02-batch8-dropout0.2incontractinpath-4blocks-relu-batcheverywhere-savethebest.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30-unet-noaugonvalidation-5e-5-recurrentdropout02-batch8-dropout0.2incontractinpath-4blocks-relu-batcheverywhere-savethebest.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 477
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 1.0

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1.0
# 1/1 [==============================] - 0s 39ms/step
# 0.88180864
# 1/1 [==============================] - 0s 40ms/step
# 0.5374149
# 1/1 [==============================] - 0s 41ms/step
# 0.7649583
# 1/1 [==============================] - 0s 42ms/step
# 0.61745584
# 1/1 [==============================] - 0s 54ms/step
# 0.49150085
# 1/1 [==============================] - 0s 46ms/step
# 0.49887848
# 1/1 [==============================] - 0s 45ms/step
# 0.8632853
# 1/1 [==============================] - 0s 38ms/step
# 0.6971397
# 1/1 [==============================] - 0s 45ms/step
# 1.0
# 1/1 [==============================] - 0s 43ms/step
# 0.49791718
# 1/1 [==============================] - 0s 45ms/step
# 0.48068237
# 1/1 [==============================] - 0s 47ms/step
# 0.79175436
# 1/1 [==============================] - 0s 53ms/step
# 0.4934082
# 1/1 [==============================] - 0s 41ms/step
# 1.0
# 1/1 [==============================] - 0s 51ms/step
# 1.0
# 1/1 [==============================] - 0s 43ms/step
# 0.6514838
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.77714574
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 40ms/step
# 0.81701314
# 1/1 [==============================] - 0s 31ms/step
# 0.7141373
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48675537
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.6556711
# 1/1 [==============================] - 0s 26ms/step
# 0.804613
# 1/1 [==============================] - 0s 29ms/step
# 0.74491143
# 1/1 [==============================] - 0s 33ms/step
# 0.83142316
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.7141373
# 1/1 [==============================] - 0s 29ms/step
# 0.81588924
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.4987793
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.6604835
# 1/1 [==============================] - 0s 32ms/step
# 0.4973297
# 1/1 [==============================] - 0s 30ms/step
# 0.8339666
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.70860815
# 1/1 [==============================] - 0s 28ms/step
# 0.49946594
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.74402934
# 1/1 [==============================] - 0s 28ms/step
# 0.49705505
# 1/1 [==============================] - 0s 28ms/step
# 0.48892212
# 1/1 [==============================] - 0s 30ms/step
# 0.8611978
# 1/1 [==============================] - 0s 26ms/step
# 0.49617004
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.48068237
# 1/1 [==============================] - 0s 27ms/step
# 0.52669543
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.49996948
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.8183339
# 1/1 [==============================] - 0s 32ms/step
# 0.49506378
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.618531
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.66425097
# 1/1 [==============================] - 0s 31ms/step
# 0.62566435
# 1/1 [==============================] - 0s 34ms/step
# 0.4999466
# 1/1 [==============================] - 0s 30ms/step
# 0.4987259
# 1/1 [==============================] - 0s 39ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.85369116
# 1/1 [==============================] - 0s 32ms/step
# 0.61745584
# 1/1 [==============================] - 0s 32ms/step
# 0.4792862
# 1/1 [==============================] - 0s 37ms/step
# 0.48571014
# 1/1 [==============================] - 0s 36ms/step
# 0.67374474
# 1/1 [==============================] - 0s 31ms/step
# 0.4887675
# 1/1 [==============================] - 0s 37ms/step
# 0.6925268
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.8619108
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 0.48758698
# 1/1 [==============================] - 0s 38ms/step
# 0.6702152
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.7803421
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.48033905
# 1/1 [==============================] - 0s 30ms/step
# 0.6752125
# 1/1 [==============================] - 0s 28ms/step
# 0.49362946
# 1/1 [==============================] - 0s 27ms/step
# 0.48892212
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.7870915
# 1/1 [==============================] - 0s 28ms/step
# 0.7141373
# 1/1 [==============================] - 0s 32ms/step
# 0.49175262
# 1/1 [==============================] - 0s 32ms/step
# 0.6255523
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.6267053
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 61ms/step
# 0.6556711
# 1/1 [==============================] - 0s 32ms/step
# 0.4976654
# 1/1 [==============================] - 0s 29ms/step
# 0.6983187
# 1/1 [==============================] - 0s 30ms/step
# 0.49977875
# 1/1 [==============================] - 0s 27ms/step
# 0.68966866
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.4994583
# 1/1 [==============================] - 0s 32ms/step
# 0.4877243
# 1/1 [==============================] - 0s 31ms/step
# 0.78589547
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.6360561
# 1/1 [==============================] - 0s 28ms/step
# 0.81588924
# 1/1 [==============================] - 0s 27ms/step
# 0.694821
# 1/1 [==============================] - 0s 33ms/step
# 0.8611978
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 33ms/step
# 0.6788818
# 1/1 [==============================] - 0s 29ms/step
# 0.49812317
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.49786377
# 1/1 [==============================] - 0s 38ms/step
# 1.0
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49126434
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 35ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48742676
# 1/1 [==============================] - 0s 30ms/step
# 0.7141373
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7525283
# 1/1 [==============================] - 0s 30ms/step
# 0.49876404
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.8621926
# 1/1 [==============================] - 0s 30ms/step
# 0.4998932
# 1/1 [==============================] - 0s 26ms/step
# 0.612527
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49755096
# 1/1 [==============================] - 0s 26ms/step
# 0.48386383
# 1/1 [==============================] - 0s 26ms/step
# 0.81886756
# 1/1 [==============================] - 0s 28ms/step
# 0.48068237
# 1/1 [==============================] - 0s 26ms/step
# 0.74402934
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.72432005
# 1/1 [==============================] - 0s 26ms/step
# 0.8524885
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.82388395
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4840088
# 1/1 [==============================] - 0s 28ms/step
# 0.6310177
# 1/1 [==============================] - 0s 29ms/step
# 0.49102783
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.48423767
# 1/1 [==============================] - 0s 28ms/step
# 0.8593186
# 1/1 [==============================] - 0s 31ms/step
# 0.48604584
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.7472595
# 1/1 [==============================] - 0s 28ms/step
# 0.81886756
# 1/1 [==============================] - 0s 31ms/step
# 0.48255157
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 36ms/step
# 0.49628448
# 1/1 [==============================] - 0s 35ms/step
# 0.8619108
# 1/1 [==============================] - 0s 33ms/step
# 0.49791718
# 1/1 [==============================] - 0s 32ms/step
# 0.49705505
# 1/1 [==============================] - 0s 30ms/step
# 0.4987793
# 1/1 [==============================] - 0s 29ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.7824432
# 1/1 [==============================] - 0s 30ms/step
# 0.49977875
# 1/1 [==============================] - 0s 31ms/step
# 0.7141373
# 1/1 [==============================] - 0s 29ms/step
# 0.63467336
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
