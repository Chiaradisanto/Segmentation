# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor40.unet-1211-dice-5e-5-noaug-on-validatio-relu-recurrentdropout02-batch12-RandomRotation0.3%2Cinterpolation%3Dbilinear%2Cfill_mode%3Dnearest-3blocks-savethebest.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=True,
        sort_method="natsort" # oppure "number"
    ):

        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = 12
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        def sort_by_number(file_names:str):
            return sorted(names, key=lambda x: int(x.split('/')[-1].split('.')[0]))

        train_img_file_names = natsorted(train_img_file_names) if sort_method == "natsort" else sort_by_number(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3,interpolation='bilinear',fill_mode='reflect'),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,12):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
batch_size=12

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv2)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (conv5)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv9])
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=(layers.ConvLSTM2D(8,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_4[0][0]']
#  buted)                          16)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_5[0][0]']
#  buted)                          16)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_8[0][0]']
#  buted)                          32)
#
#  time_distributed_10 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_9[0][0]']
#  ibuted)                         32)
#
#  time_distributed_11 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_10[0][0]']
#  ibuted)                         32)
#
#  time_distributed_12 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_11[0][0]']
#  ibuted)                         32)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 3  0          ['time_distributed_12[0][0]']
#  ibuted)                        2)
#
#  time_distributed_14 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_14[0][0]']
#  ibuted)                        4)
#
#  time_distributed_16 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_15[0][0]']
#  ibuted)                        4)
#
#  time_distributed_17 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_16[0][0]']
#  ibuted)                        4)
#
#  time_distributed_18 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_17[0][0]']
#  ibuted)                        4)
#
#  time_distributed_19 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_18[0][0]']
#  ibuted)                        4)
#
#  time_distributed_20 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_19[0][0]']
#  ibuted)                        4)
#
#  time_distributed_21 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_20[0][0]']
#  ibuted)                        28)
#
#  time_distributed_22 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_21[0][0]']
#  ibuted)                        28)
#
#  time_distributed_23 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_22[0][0]']
#  ibuted)                        28)
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_23[0][0]']
#  ibuted)                        28)
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_24[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_26[0][0]']
#  ibuted)                        28)
#
#  time_distributed_28 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_27[0][0]']
#  ibuted)                        56)
#
#  time_distributed_29 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_28[0][0]']
#  ibuted)                        56)
#
#  time_distributed_30 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_29[0][0]']
#  ibuted)                        56)
#
#  time_distributed_31 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_30[0][0]']
#  ibuted)                        56)
#
#  time_distributed_32 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_31[0][0]']
#  ibuted)                        56)
#
#  time_distributed_33 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_32[0][0]']
#  ibuted)                        56)
#
#  conv_lstm2d (ConvLSTM2D)       (None, 3, 16, 16, 2  4719616     ['time_distributed_33[0][0]']
#                                 56)
#
#  time_distributed_34 (TimeDistr  (None, 3, 32, 32, 1  295040     ['conv_lstm2d[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_34[0][0]',
#                                 56)                               'time_distributed_26[0][0]']
#
#  time_distributed_35 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_36 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_35[0][0]']
#  ibuted)                        28)
#
#  time_distributed_37 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_36[0][0]']
#  ibuted)                        28)
#
#  time_distributed_38 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_37[0][0]']
#  ibuted)                        28)
#
#  time_distributed_39 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_38[0][0]']
#  ibuted)                        28)
#
#  time_distributed_40 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_39[0][0]']
#  ibuted)                        28)
#
#  time_distributed_41 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_40[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_41[0][0]',
#                                 28)                               'time_distributed_19[0][0]']
#
#  time_distributed_44 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_45 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_44[0][0]']
#  ibuted)                        4)
#
#  time_distributed_46 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_45[0][0]']
#  ibuted)                        4)
#
#  time_distributed_47 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_46[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_47[0][0]',
#                                  64)                              'time_distributed_12[0][0]']
#
#  time_distributed_48 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_49 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_48[0][0]']
#  ibuted)                         32)
#
#  time_distributed_50 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_49[0][0]']
#  ibuted)                         32)
#
#  time_distributed_51 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_50[0][0]']
#  ibuted)                         32)
#
#  time_distributed_52 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_51[0][0]']
#  ibuted)                         32)
#
#  time_distributed_53 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_52[0][0]']
#  ibuted)                         32)
#
#  time_distributed_54 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_53[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_54[0][0]',
#                                  32)                              'time_distributed_5[0][0]']
#
#  time_distributed_55 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_56 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_55[0][0]']
#  ibuted)                         16)
#
#  time_distributed_57 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_56[0][0]']
#  ibuted)                         16)
#
#  time_distributed_58 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_57[0][0]']
#  ibuted)                         16)
#
#  time_distributed_59 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_58[0][0]']
#  ibuted)                         16)
#
#  time_distributed_60 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_59[0][0]']
#  ibuted)                         16)
#
#  conv_lstm2d_1 (ConvLSTM2D)     (None, 256, 256, 8)  6944        ['time_distributed_60[0][0]']
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['conv_lstm2d_1[0][0]']
#                                  8)
#
#  conv2d_27 (Conv2D)             (None, 1, 256, 256,  9           ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 7,838,601
# Trainable params: 7,834,441
# Non-trainable params: 4,160
# __________________________________________________________________________________________________

# %%
from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.65
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.60
    return K.pow((1-pt_1), gamma)

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=40,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/40
# 248/248 [==============================] - 296s 1s/step - loss: 0.9104 - dice_coefficient: 0.0896 - binary_accuracy: 0.7299 - val_loss: 0.7883 - val_dice_coefficient: 0.2117 - val_binary_accuracy: 0.9369
# Epoch 2/40
# 248/248 [==============================] - 273s 1s/step - loss: 0.7032 - dice_coefficient: 0.2968 - binary_accuracy: 0.9601 - val_loss: 0.6113 - val_dice_coefficient: 0.3887 - val_binary_accuracy: 0.9778
# Epoch 3/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.5015 - dice_coefficient: 0.4985 - binary_accuracy: 0.9799 - val_loss: 0.5460 - val_dice_coefficient: 0.4540 - val_binary_accuracy: 0.9827
# Epoch 4/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.4402 - dice_coefficient: 0.5598 - binary_accuracy: 0.9827 - val_loss: 0.4941 - val_dice_coefficient: 0.5059 - val_binary_accuracy: 0.9844
# Epoch 5/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.4145 - dice_coefficient: 0.5855 - binary_accuracy: 0.9840 - val_loss: 0.3984 - val_dice_coefficient: 0.6016 - val_binary_accuracy: 0.9868
# Epoch 6/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.3931 - dice_coefficient: 0.6069 - binary_accuracy: 0.9848 - val_loss: 0.5004 - val_dice_coefficient: 0.4996 - val_binary_accuracy: 0.9849
# Epoch 7/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.3914 - dice_coefficient: 0.6086 - binary_accuracy: 0.9858 - val_loss: 0.3932 - val_dice_coefficient: 0.6068 - val_binary_accuracy: 0.9855
# Epoch 8/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.3466 - dice_coefficient: 0.6534 - binary_accuracy: 0.9863 - val_loss: 0.4199 - val_dice_coefficient: 0.5801 - val_binary_accuracy: 0.9855
# Epoch 9/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.3248 - dice_coefficient: 0.6752 - binary_accuracy: 0.9871 - val_loss: 0.4789 - val_dice_coefficient: 0.5211 - val_binary_accuracy: 0.9833
# Epoch 10/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.3270 - dice_coefficient: 0.6730 - binary_accuracy: 0.9875 - val_loss: 0.5217 - val_dice_coefficient: 0.4783 - val_binary_accuracy: 0.9829
# Epoch 11/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.3128 - dice_coefficient: 0.6872 - binary_accuracy: 0.9875 - val_loss: 0.4016 - val_dice_coefficient: 0.5984 - val_binary_accuracy: 0.9778
# Epoch 12/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.2990 - dice_coefficient: 0.7010 - binary_accuracy: 0.9879 - val_loss: 0.3904 - val_dice_coefficient: 0.6096 - val_binary_accuracy: 0.9839
# Epoch 13/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.3003 - dice_coefficient: 0.6997 - binary_accuracy: 0.9879 - val_loss: 0.3800 - val_dice_coefficient: 0.6200 - val_binary_accuracy: 0.9858
# Epoch 14/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.2666 - dice_coefficient: 0.7334 - binary_accuracy: 0.9884 - val_loss: 0.4229 - val_dice_coefficient: 0.5771 - val_binary_accuracy: 0.9844
# Epoch 15/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2623 - dice_coefficient: 0.7377 - binary_accuracy: 0.9885 - val_loss: 0.3934 - val_dice_coefficient: 0.6066 - val_binary_accuracy: 0.9837
# Epoch 16/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2681 - dice_coefficient: 0.7319 - binary_accuracy: 0.9888 - val_loss: 0.4797 - val_dice_coefficient: 0.5203 - val_binary_accuracy: 0.9782
# Epoch 17/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.2593 - dice_coefficient: 0.7407 - binary_accuracy: 0.9885 - val_loss: 0.3715 - val_dice_coefficient: 0.6285 - val_binary_accuracy: 0.9839
# Epoch 18/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2340 - dice_coefficient: 0.7660 - binary_accuracy: 0.9894 - val_loss: 0.4247 - val_dice_coefficient: 0.5753 - val_binary_accuracy: 0.9774
# Epoch 19/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.2362 - dice_coefficient: 0.7638 - binary_accuracy: 0.9893 - val_loss: 0.3622 - val_dice_coefficient: 0.6378 - val_binary_accuracy: 0.9845
# Epoch 20/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2322 - dice_coefficient: 0.7678 - binary_accuracy: 0.9896 - val_loss: 0.3777 - val_dice_coefficient: 0.6223 - val_binary_accuracy: 0.9823
# Epoch 21/40
# 248/248 [==============================] - 272s 1s/step - loss: 0.2183 - dice_coefficient: 0.7817 - binary_accuracy: 0.9896 - val_loss: 0.3257 - val_dice_coefficient: 0.6743 - val_binary_accuracy: 0.9867
# Epoch 22/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2167 - dice_coefficient: 0.7833 - binary_accuracy: 0.9897 - val_loss: 0.3544 - val_dice_coefficient: 0.6456 - val_binary_accuracy: 0.9873
# Epoch 23/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2190 - dice_coefficient: 0.7810 - binary_accuracy: 0.9899 - val_loss: 0.3456 - val_dice_coefficient: 0.6544 - val_binary_accuracy: 0.9825
# Epoch 24/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2004 - dice_coefficient: 0.7996 - binary_accuracy: 0.9900 - val_loss: 0.3830 - val_dice_coefficient: 0.6170 - val_binary_accuracy: 0.9805
# Epoch 25/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2051 - dice_coefficient: 0.7949 - binary_accuracy: 0.9898 - val_loss: 0.3454 - val_dice_coefficient: 0.6546 - val_binary_accuracy: 0.9821
# Epoch 26/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1920 - dice_coefficient: 0.8080 - binary_accuracy: 0.9905 - val_loss: 0.3596 - val_dice_coefficient: 0.6404 - val_binary_accuracy: 0.9833
# Epoch 27/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.2050 - dice_coefficient: 0.7950 - binary_accuracy: 0.9899 - val_loss: 0.3918 - val_dice_coefficient: 0.6082 - val_binary_accuracy: 0.9820
# Epoch 28/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1994 - dice_coefficient: 0.8006 - binary_accuracy: 0.9902 - val_loss: 0.3961 - val_dice_coefficient: 0.6039 - val_binary_accuracy: 0.9814
# Epoch 29/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1897 - dice_coefficient: 0.8103 - binary_accuracy: 0.9905 - val_loss: 0.3669 - val_dice_coefficient: 0.6331 - val_binary_accuracy: 0.9823
# Epoch 30/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1885 - dice_coefficient: 0.8115 - binary_accuracy: 0.9902 - val_loss: 0.3496 - val_dice_coefficient: 0.6504 - val_binary_accuracy: 0.9806
# Epoch 31/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1972 - dice_coefficient: 0.8028 - binary_accuracy: 0.9905 - val_loss: 0.3819 - val_dice_coefficient: 0.6181 - val_binary_accuracy: 0.9845
# Epoch 32/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1755 - dice_coefficient: 0.8245 - binary_accuracy: 0.9906 - val_loss: 0.4261 - val_dice_coefficient: 0.5739 - val_binary_accuracy: 0.9816
# Epoch 33/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1723 - dice_coefficient: 0.8277 - binary_accuracy: 0.9907 - val_loss: 0.3340 - val_dice_coefficient: 0.6660 - val_binary_accuracy: 0.9821
# Epoch 34/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1846 - dice_coefficient: 0.8154 - binary_accuracy: 0.9899 - val_loss: 0.3627 - val_dice_coefficient: 0.6373 - val_binary_accuracy: 0.9848
# Epoch 35/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1864 - dice_coefficient: 0.8136 - binary_accuracy: 0.9903 - val_loss: 0.3541 - val_dice_coefficient: 0.6459 - val_binary_accuracy: 0.9845
# Epoch 36/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1741 - dice_coefficient: 0.8259 - binary_accuracy: 0.9907 - val_loss: 0.4451 - val_dice_coefficient: 0.5549 - val_binary_accuracy: 0.9809
# Epoch 37/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1729 - dice_coefficient: 0.8271 - binary_accuracy: 0.9907 - val_loss: 0.3364 - val_dice_coefficient: 0.6636 - val_binary_accuracy: 0.9863
# Epoch 38/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1735 - dice_coefficient: 0.8265 - binary_accuracy: 0.9908 - val_loss: 0.4448 - val_dice_coefficient: 0.5552 - val_binary_accuracy: 0.9828
# Epoch 39/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1581 - dice_coefficient: 0.8419 - binary_accuracy: 0.9913 - val_loss: 0.3686 - val_dice_coefficient: 0.6314 - val_binary_accuracy: 0.9848
# Epoch 40/40
# 248/248 [==============================] - 271s 1s/step - loss: 0.1678 - dice_coefficient: 0.8322 - binary_accuracy: 0.9910 - val_loss: 0.3620 - val_dice_coefficient: 0.6380 - val_binary_accuracy: 0.9831

# %%
model.save('/gdrive/MyDrive/Sensor40.unet-1211-dice-5e-5-noaug-on-validatio-relu-recurrentdropout02-batch12-RandomRotation0.3,interpolation=bilinear,fill_mode=nearest-3blocks-savethebest.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor40.unet-1211-dice-5e-5-noaug-on-validatio-relu-recurrentdropout02-batch12-RandomRotation0.3,interpolation=bilinear,fill_mode=nearest-3blocks-savethebest.h5", compile=False)

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np


class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale", target_size=(256,256)))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale", target_size=(256,256)))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
        x, y = np.array(xs), np.array(ys)
      #  print(x.shape)
      #  print(y.shape)

        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    
    augmentation=False,
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0,a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.8253665

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    

mean_IoU = df.mean().values
boxplot = df.boxplot(grid=False, vert=True,  # vertical box alignment
                     patch_artist=False)  # fill with color)
std=df.std()
print('number of total masks is: ', len(IoU_values))

print("Mean IoU is: ", mean_IoU)
print("standard deviation is ",std)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.7983059
# 1/1 [==============================] - 0s 22ms/step
# 0.81987476
# 1/1 [==============================] - 0s 24ms/step
# 0.8253665
# 1/1 [==============================] - 0s 24ms/step
# 0.49114227
# 1/1 [==============================] - 0s 23ms/step
# 0.7351103
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.47724915
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.75933933
# 1/1 [==============================] - 0s 22ms/step
# 0.83379424
# 1/1 [==============================] - 0s 25ms/step
# 0.8546766
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.86590564
# 1/1 [==============================] - 0s 23ms/step
# 0.46684265
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.49139404
# 1/1 [==============================] - 0s 24ms/step
# 0.48594007
# 1/1 [==============================] - 0s 23ms/step
# 0.7602029
# 1/1 [==============================] - 0s 25ms/step
# 0.85028505
# 1/1 [==============================] - 0s 26ms/step
# 0.48594007
# 1/1 [==============================] - 0s 24ms/step
# 0.7644681
# 1/1 [==============================] - 0s 23ms/step
# 0.48242188
# 1/1 [==============================] - 0s 28ms/step
# 0.48207855
# 1/1 [==============================] - 0s 25ms/step
# 0.48843384
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.7891959
# 1/1 [==============================] - 0s 26ms/step
# 0.8353301
# 1/1 [==============================] - 0s 21ms/step
# 0.47103179
# 1/1 [==============================] - 0s 23ms/step
# 0.81660336
# 1/1 [==============================] - 0s 27ms/step
# 0.8320295
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.49095154
# 1/1 [==============================] - 0s 22ms/step
# 0.7716046
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.74480736
# 1/1 [==============================] - 0s 90ms/step
# 0.76636183
# 1/1 [==============================] - 0s 91ms/step
# 0.48207855
# 1/1 [==============================] - 0s 23ms/step
# 0.8090873
# 1/1 [==============================] - 0s 23ms/step
# 0.7938067
# 1/1 [==============================] - 0s 24ms/step
# 0.7397952
# 1/1 [==============================] - 0s 23ms/step
# 0.5138634
# 1/1 [==============================] - 0s 23ms/step
# 0.4695816
# 1/1 [==============================] - 0s 23ms/step
# 0.46971893
# 1/1 [==============================] - 0s 75ms/step
# 0.75447047
# 1/1 [==============================] - 0s 84ms/step
# 0.87428284
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.6794989
# 1/1 [==============================] - 0s 23ms/step
# 0.84493876
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.45947266
# 1/1 [==============================] - 0s 102ms/step
# 0.82609874
# 1/1 [==============================] - 0s 96ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8554572
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.46858978
# 1/1 [==============================] - 0s 23ms/step
# 0.86715674
# 1/1 [==============================] - 0s 25ms/step
# 0.49910736
# 1/1 [==============================] - 0s 26ms/step
# 0.48594007
# 1/1 [==============================] - 0s 27ms/step
# 0.4922943
# 1/1 [==============================] - 0s 32ms/step
# 0.8532599
# 1/1 [==============================] - 0s 24ms/step
# 0.76385915
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8168081
# 1/1 [==============================] - 0s 23ms/step
# 0.82609874
# 1/1 [==============================] - 0s 22ms/step
# 0.8206351
# 1/1 [==============================] - 0s 24ms/step
# 0.7202188
# 1/1 [==============================] - 0s 24ms/step
# 0.8057627
# 1/1 [==============================] - 0s 23ms/step
# 0.7867632
# 1/1 [==============================] - 0s 22ms/step
# 0.78530717
# 1/1 [==============================] - 0s 22ms/step
# 0.8307141
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.78874934
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.7986159
# 1/1 [==============================] - 0s 23ms/step
# 0.77264845
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.7537033
# 1/1 [==============================] - 0s 27ms/step
# 0.49580383
# 1/1 [==============================] - 0s 22ms/step
# 0.49222565
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8637301
# 1/1 [==============================] - 0s 22ms/step
# 0.76255345
# 1/1 [==============================] - 0s 22ms/step
# 0.7853095
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.74652874
# 1/1 [==============================] - 0s 24ms/step
# 0.8485644
# 1/1 [==============================] - 0s 22ms/step
# 0.85757273
# 1/1 [==============================] - 0s 24ms/step
# 0.86202085
# 1/1 [==============================] - 0s 23ms/step
# 0.8712798
# 1/1 [==============================] - 0s 28ms/step
# 0.8566541
# 1/1 [==============================] - 0s 22ms/step
# 0.49975586
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.7602029
# 1/1 [==============================] - 0s 22ms/step
# 0.7679469
# 1/1 [==============================] - 0s 22ms/step
# 0.8509971
# 1/1 [==============================] - 0s 25ms/step
# 0.4922943
# 1/1 [==============================] - 0s 23ms/step
# 0.84751934
# 1/1 [==============================] - 0s 25ms/step
# 0.88026655
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.48138428
# 1/1 [==============================] - 0s 25ms/step
# 0.8886132
# 1/1 [==============================] - 0s 27ms/step
# 0.8416929
# 1/1 [==============================] - 0s 26ms/step
# 0.48026276
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.8456479
# 1/1 [==============================] - 0s 27ms/step
# 0.47570038
# 1/1 [==============================] - 0s 25ms/step
# 0.47096252
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.85757273
# 1/1 [==============================] - 0s 23ms/step
# 0.49325562
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.84366024
# 1/1 [==============================] - 0s 37ms/step
# 0.5426188
# 1/1 [==============================] - 0s 23ms/step
# 0.7258804
# 1/1 [==============================] - 0s 24ms/step
# 0.7800696
# 1/1 [==============================] - 0s 23ms/step
# 0.82571936
# 1/1 [==============================] - 0s 23ms/step
# 0.53917694
# 1/1 [==============================] - 0s 26ms/step
# 0.86715674
# 1/1 [==============================] - 0s 24ms/step
# 0.7978905
# 1/1 [==============================] - 0s 23ms/step
# 0.74652874
# 1/1 [==============================] - 0s 26ms/step
# 0.48564148
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.56816643
# 1/1 [==============================] - 0s 40ms/step
# 0.6444122
# 1/1 [==============================] - 0s 22ms/step
# 0.74636966
# 1/1 [==============================] - 0s 23ms/step
# 0.4999237
# 1/1 [==============================] - 0s 27ms/step
# 0.72944295
# number of total masks is:  477
# Mean IoU is:  [0.6969322]
# standard deviation is  IoU    0.158596
# dtype: float32
