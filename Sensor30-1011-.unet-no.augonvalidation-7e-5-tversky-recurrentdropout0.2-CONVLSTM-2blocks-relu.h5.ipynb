# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30-1011-.unet-no.augonvalidation-7e-5-tversky-recurrentdropout0.2-CONVLSTM-2blocks-relu.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 12,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
                np.array(
                    [
                        img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_img_file_names
                    ]
                )
                / 255
            )
        self.masks = (
                np.array(
                    [
                      img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_mask_file_names
                    ]
                )
                / 255
                > 0.5
            ).astype(float)

        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2,interpolation='bilinear',fill_mode='reflect'),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
            if self.index >= len(self.imgs) - self.timesteps - self.batch_size:
                self.index = 0
                raise StopIteration
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=12,
    shuffle=True,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=12,
    squeeze=False,
    shuffle=True,

    augmentation=True,
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()
for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=12

# %%
x.shape
# Out:
# TensorShape([12, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([12, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True)(conv5)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv4])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat1)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv3])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat2)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)

up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv2])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat3)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv1])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat4)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

x=layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False)(x)
x=tf.expand_dims(x,axis=1)
out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_4[0][0]']
#  buted)                          32)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_5[0][0]']
#  buted)                          32)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 64, 64, 3  0          ['time_distributed_8[0][0]']
#  buted)                         2)
#
#  time_distributed_10 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_9[0][0]']
#  ibuted)                        4)
#
#  time_distributed_11 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_10[0][0]']
#  ibuted)                        4)
#
#  time_distributed_12 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_11[0][0]']
#  ibuted)                        4)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_12[0][0]']
#  ibuted)                        4)
#
#  time_distributed_14 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_14[0][0]']
#  ibuted)                        28)
#
#  time_distributed_16 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_15[0][0]']
#  ibuted)                        28)
#
#  time_distributed_17 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_16[0][0]']
#  ibuted)                        28)
#
#  time_distributed_18 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_17[0][0]']
#  ibuted)                        28)
#
#  time_distributed_19 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_18[0][0]']
#  ibuted)                        28)
#
#  time_distributed_20 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_19[0][0]']
#  ibuted)                        56)
#
#  time_distributed_21 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_20[0][0]']
#  ibuted)                        56)
#
#  time_distributed_22 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_21[0][0]']
#  ibuted)                        56)
#
#  time_distributed_23 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_22[0][0]']
#  ibuted)                        56)
#
#  conv_lstm2d (ConvLSTM2D)       (None, 3, 16, 16, 2  4719616     ['time_distributed_23[0][0]']
#                                 56)
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  295040     ['conv_lstm2d[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_24[0][0]',
#                                 56)                               'time_distributed_18[0][0]']
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_26[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_27[0][0]',
#                                 28)                               'time_distributed_13[0][0]']
#
#  time_distributed_28 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_29 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_28[0][0]']
#  ibuted)                        4)
#
#  time_distributed_30 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_29[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_30[0][0]',
#                                  64)                              'time_distributed_8[0][0]']
#
#  time_distributed_31 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_32 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_31[0][0]']
#  ibuted)                         32)
#
#  time_distributed_33 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_32[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_33[0][0]',
#                                  32)                              'time_distributed_3[0][0]']
#
#  time_distributed_34 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_35 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_34[0][0]']
#  ibuted)                         16)
#
#  conv_lstm2d_1 (ConvLSTM2D)     (None, 256, 256, 16  18496       ['time_distributed_35[0][0]']
#                                 )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['conv_lstm2d_1[0][0]']
#                                  16)
#
#  conv2d_18 (Conv2D)             (None, 1, 256, 256,  17          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 6,900,497
# Trainable params: 6,898,513
# Non-trainable params: 1,984
# __________________________________________________________________________________________________

# %%
from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.75
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.60
    return K.pow((1-pt_1), gamma)

# %%
LR = 7e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=tversky_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 248/248 [==============================] - 263s 979ms/step - loss: 0.6148 - dice_coefficient: 0.2884 - binary_accuracy: 0.8551 - val_loss: 0.5646 - val_dice_coefficient: 0.2943 - val_binary_accuracy: 0.8876
# Epoch 2/30
# 248/248 [==============================] - 238s 959ms/step - loss: 0.4117 - dice_coefficient: 0.4824 - binary_accuracy: 0.9723 - val_loss: 0.4576 - val_dice_coefficient: 0.4091 - val_binary_accuracy: 0.9467
# Epoch 3/30
# 248/248 [==============================] - 237s 956ms/step - loss: 0.3587 - dice_coefficient: 0.5356 - binary_accuracy: 0.9764 - val_loss: 0.3641 - val_dice_coefficient: 0.5187 - val_binary_accuracy: 0.9637
# Epoch 4/30
# 248/248 [==============================] - 238s 959ms/step - loss: 0.3188 - dice_coefficient: 0.5812 - binary_accuracy: 0.9775 - val_loss: 0.3547 - val_dice_coefficient: 0.6319 - val_binary_accuracy: 0.9821
# Epoch 5/30
# 248/248 [==============================] - 237s 955ms/step - loss: 0.2898 - dice_coefficient: 0.6153 - binary_accuracy: 0.9802 - val_loss: 0.3510 - val_dice_coefficient: 0.6289 - val_binary_accuracy: 0.9832
# Epoch 6/30
# 248/248 [==============================] - 237s 956ms/step - loss: 0.2826 - dice_coefficient: 0.6276 - binary_accuracy: 0.9809 - val_loss: 0.3233 - val_dice_coefficient: 0.6685 - val_binary_accuracy: 0.9856
# Epoch 7/30
# 248/248 [==============================] - 237s 956ms/step - loss: 0.2560 - dice_coefficient: 0.6552 - binary_accuracy: 0.9817 - val_loss: 0.2941 - val_dice_coefficient: 0.7030 - val_binary_accuracy: 0.9857
# Epoch 8/30
# 248/248 [==============================] - 237s 954ms/step - loss: 0.2345 - dice_coefficient: 0.6822 - binary_accuracy: 0.9827 - val_loss: 0.3291 - val_dice_coefficient: 0.6869 - val_binary_accuracy: 0.9837
# Epoch 9/30
# 248/248 [==============================] - 236s 953ms/step - loss: 0.2234 - dice_coefficient: 0.6979 - binary_accuracy: 0.9833 - val_loss: 0.3059 - val_dice_coefficient: 0.6363 - val_binary_accuracy: 0.9773
# Epoch 10/30
# 248/248 [==============================] - 236s 953ms/step - loss: 0.2167 - dice_coefficient: 0.7057 - binary_accuracy: 0.9836 - val_loss: 0.3551 - val_dice_coefficient: 0.6429 - val_binary_accuracy: 0.9818
# Epoch 11/30
# 248/248 [==============================] - 236s 953ms/step - loss: 0.2114 - dice_coefficient: 0.7120 - binary_accuracy: 0.9843 - val_loss: 0.3647 - val_dice_coefficient: 0.5645 - val_binary_accuracy: 0.9709
# Epoch 12/30
# 248/248 [==============================] - 236s 952ms/step - loss: 0.2089 - dice_coefficient: 0.7195 - binary_accuracy: 0.9846 - val_loss: 0.3115 - val_dice_coefficient: 0.6647 - val_binary_accuracy: 0.9838
# Epoch 13/30
# 248/248 [==============================] - 236s 952ms/step - loss: 0.2126 - dice_coefficient: 0.7139 - binary_accuracy: 0.9845 - val_loss: 0.2741 - val_dice_coefficient: 0.6820 - val_binary_accuracy: 0.9806
# Epoch 14/30
# 248/248 [==============================] - 236s 952ms/step - loss: 0.1910 - dice_coefficient: 0.7439 - binary_accuracy: 0.9864 - val_loss: 0.2839 - val_dice_coefficient: 0.7012 - val_binary_accuracy: 0.9861
# Epoch 15/30
# 248/248 [==============================] - 236s 953ms/step - loss: 0.1922 - dice_coefficient: 0.7399 - binary_accuracy: 0.9858 - val_loss: 0.3001 - val_dice_coefficient: 0.6902 - val_binary_accuracy: 0.9827
# Epoch 16/30
# 248/248 [==============================] - 236s 953ms/step - loss: 0.1743 - dice_coefficient: 0.7585 - binary_accuracy: 0.9862 - val_loss: 0.3313 - val_dice_coefficient: 0.6185 - val_binary_accuracy: 0.9763
# Epoch 17/30
# 248/248 [==============================] - 236s 953ms/step - loss: 0.1717 - dice_coefficient: 0.7638 - binary_accuracy: 0.9857 - val_loss: 0.3458 - val_dice_coefficient: 0.6489 - val_binary_accuracy: 0.9827
# Epoch 18/30
# 248/248 [==============================] - 236s 954ms/step - loss: 0.1682 - dice_coefficient: 0.7688 - binary_accuracy: 0.9865 - val_loss: 0.3029 - val_dice_coefficient: 0.6711 - val_binary_accuracy: 0.9838
# Epoch 19/30
# 248/248 [==============================] - 237s 956ms/step - loss: 0.1709 - dice_coefficient: 0.7669 - binary_accuracy: 0.9865 - val_loss: 0.2638 - val_dice_coefficient: 0.7127 - val_binary_accuracy: 0.9834
# Epoch 20/30
# 248/248 [==============================] - 237s 955ms/step - loss: 0.1661 - dice_coefficient: 0.7724 - binary_accuracy: 0.9865 - val_loss: 0.3048 - val_dice_coefficient: 0.6607 - val_binary_accuracy: 0.9802
# Epoch 21/30
# 248/248 [==============================] - 236s 954ms/step - loss: 0.1693 - dice_coefficient: 0.7698 - binary_accuracy: 0.9868 - val_loss: 0.2966 - val_dice_coefficient: 0.6678 - val_binary_accuracy: 0.9799
# Epoch 22/30
# 248/248 [==============================] - 236s 954ms/step - loss: 0.1667 - dice_coefficient: 0.7733 - binary_accuracy: 0.9869 - val_loss: 0.2577 - val_dice_coefficient: 0.7060 - val_binary_accuracy: 0.9835
# Epoch 23/30
# 248/248 [==============================] - 237s 955ms/step - loss: 0.1661 - dice_coefficient: 0.7737 - binary_accuracy: 0.9870 - val_loss: 0.2974 - val_dice_coefficient: 0.6631 - val_binary_accuracy: 0.9799
# Epoch 24/30
# 248/248 [==============================] - 237s 955ms/step - loss: 0.1539 - dice_coefficient: 0.7894 - binary_accuracy: 0.9879 - val_loss: 0.3074 - val_dice_coefficient: 0.6839 - val_binary_accuracy: 0.9835
# Epoch 25/30
# 248/248 [==============================] - 237s 956ms/step - loss: 0.1522 - dice_coefficient: 0.7899 - binary_accuracy: 0.9873 - val_loss: 0.2980 - val_dice_coefficient: 0.7054 - val_binary_accuracy: 0.9854
# Epoch 26/30
# 248/248 [==============================] - 237s 955ms/step - loss: 0.1515 - dice_coefficient: 0.7881 - binary_accuracy: 0.9873 - val_loss: 0.3387 - val_dice_coefficient: 0.6723 - val_binary_accuracy: 0.9841
# Epoch 27/30
# 248/248 [==============================] - 237s 957ms/step - loss: 0.1447 - dice_coefficient: 0.7994 - binary_accuracy: 0.9874 - val_loss: 0.2734 - val_dice_coefficient: 0.7327 - val_binary_accuracy: 0.9874
# Epoch 28/30
# 248/248 [==============================] - 237s 954ms/step - loss: 0.1483 - dice_coefficient: 0.7972 - binary_accuracy: 0.9880 - val_loss: 0.2858 - val_dice_coefficient: 0.6839 - val_binary_accuracy: 0.9805
# Epoch 29/30
# 248/248 [==============================] - 237s 956ms/step - loss: 0.1474 - dice_coefficient: 0.7966 - binary_accuracy: 0.9881 - val_loss: 0.4383 - val_dice_coefficient: 0.5676 - val_binary_accuracy: 0.9757
# Epoch 30/30
# 248/248 [==============================] - 240s 969ms/step - loss: 0.1472 - dice_coefficient: 0.7956 - binary_accuracy: 0.9875 - val_loss: 0.2873 - val_dice_coefficient: 0.6616 - val_binary_accuracy: 0.9777

# %%
model.save('/gdrive/MyDrive/Sensor30-1011-.unet-no.augonvalidation-7e-5-tversky-recurrentdropout0.2-CONVLSTM-2blocks-relu.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30-1011-.unet-no.augonvalidation-7e-5-tversky-recurrentdropout0.2-CONVLSTM-2blocks-relu.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
                np.array(
                    [
                        img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_img_file_names
                    ]
                )
                / 255
            )
        self.masks = (
                np.array(
                    [
                      img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_mask_file_names
                    ]
                )
                / 255
                > 0.5
            ).astype(float)

        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.3,interpolation='bilinear',fill_mode='nearest'),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
            if self.index >= len(self.imgs) - self.timesteps - self.batch_size:
                self.index = 0
                raise StopIteration
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,

)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.85988355

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)

    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    

mean_IoU = df.mean().values
boxplot = df.boxplot(grid=False, vert=True,  # vertical box alignment
                     patch_artist=False)  # fill with color)
std=df.std()
print('number of total masks is: ', len(IoU_values))

print("Mean IoU is: ", mean_IoU)
print("standard deviation is ",std)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 0.8706901
# 1/1 [==============================] - 0s 50ms/step
# 1.0
# 1/1 [==============================] - 0s 41ms/step
# 0.8830943
# 1/1 [==============================] - 0s 43ms/step
# 0.8040761
# 1/1 [==============================] - 0s 44ms/step
# 0.8619144
# 1/1 [==============================] - 0s 45ms/step
# 0.8808648
# 1/1 [==============================] - 0s 51ms/step
# 0.70721716
# 1/1 [==============================] - 0s 39ms/step
# 1.0
# 1/1 [==============================] - 0s 41ms/step
# 0.8625188
# 1/1 [==============================] - 0s 35ms/step
# 0.80931735
# 1/1 [==============================] - 0s 91ms/step
# 1.0
# 1/1 [==============================] - 0s 111ms/step
# 1.0
# 1/1 [==============================] - 0s 81ms/step
# 0.85476106
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.47875977
# 1/1 [==============================] - 0s 23ms/step
# 0.45572662
# 1/1 [==============================] - 0s 26ms/step
# 0.79544795
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.7875832
# 1/1 [==============================] - 0s 23ms/step
# 0.89599323
# 1/1 [==============================] - 0s 23ms/step
# 0.78759885
# 1/1 [==============================] - 0s 23ms/step
# 0.75476944
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.850844
# 1/1 [==============================] - 0s 21ms/step
# 0.7206144
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.46473694
# 1/1 [==============================] - 0s 21ms/step
# 0.7513984
# 1/1 [==============================] - 0s 26ms/step
# 0.74900913
# 1/1 [==============================] - 0s 23ms/step
# 0.50618607
# 1/1 [==============================] - 0s 23ms/step
# 0.4731369
# 1/1 [==============================] - 0s 25ms/step
# 0.76351947
# 1/1 [==============================] - 0s 25ms/step
# 0.71271455
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48986816
# 1/1 [==============================] - 0s 20ms/step
# 0.43088531
# 1/1 [==============================] - 0s 20ms/step
# 0.85743415
# 1/1 [==============================] - 0s 21ms/step
# 0.42121887
# 1/1 [==============================] - 0s 26ms/step
# 0.48229876
# 1/1 [==============================] - 0s 21ms/step
# 0.8928
# 1/1 [==============================] - 0s 24ms/step
# 0.47872925
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.46694183
# 1/1 [==============================] - 0s 23ms/step
# 0.46753693
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8730567
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8428035
# 1/1 [==============================] - 0s 24ms/step
# 0.8612268
# 1/1 [==============================] - 0s 32ms/step
# 0.4773178
# 1/1 [==============================] - 0s 23ms/step
# 0.74419725
# 1/1 [==============================] - 0s 26ms/step
# 0.42881012
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.75588787
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.47621918
# 1/1 [==============================] - 0s 21ms/step
# 0.4773178
# 1/1 [==============================] - 0s 21ms/step
# 0.42614746
# 1/1 [==============================] - 0s 22ms/step
# 0.48329926
# 1/1 [==============================] - 0s 21ms/step
# 0.86970806
# 1/1 [==============================] - 0s 23ms/step
# 0.8747426
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.7170517
# 1/1 [==============================] - 0s 22ms/step
# 0.78601027
# 1/1 [==============================] - 0s 27ms/step
# 0.8118156
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.7557272
# 1/1 [==============================] - 0s 22ms/step
# 0.86688805
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.9042656
# 1/1 [==============================] - 0s 36ms/step
# 0.8808648
# 1/1 [==============================] - 0s 25ms/step
# 0.46985626
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8817341
# 1/1 [==============================] - 0s 25ms/step
# 0.4907837
# 1/1 [==============================] - 0s 22ms/step
# 0.86418855
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.4773178
# 1/1 [==============================] - 0s 21ms/step
# 0.8617965
# 1/1 [==============================] - 0s 24ms/step
# 0.45923615
# 1/1 [==============================] - 0s 25ms/step
# 0.76351947
# 1/1 [==============================] - 0s 30ms/step
# 0.872373
# 1/1 [==============================] - 0s 21ms/step
# 0.84127015
# 1/1 [==============================] - 0s 22ms/step
# 0.4907837
# 1/1 [==============================] - 0s 23ms/step
# 0.88873315
# 1/1 [==============================] - 0s 22ms/step
# 0.48229876
# 1/1 [==============================] - 0s 23ms/step
# 0.78759885
# 1/1 [==============================] - 0s 21ms/step
# 0.7424562
# 1/1 [==============================] - 0s 20ms/step
# 0.8778887
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.47935486
# 1/1 [==============================] - 0s 21ms/step
# 0.8830943
# 1/1 [==============================] - 0s 26ms/step
# 0.7490066
# 1/1 [==============================] - 0s 29ms/step
# 0.8776173
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.8518334
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.4784851
# 1/1 [==============================] - 0s 23ms/step
# 0.48329926
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 20ms/step
# 0.47621918
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.80098295
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8798989
# 1/1 [==============================] - 0s 20ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.8479821
# 1/1 [==============================] - 0s 21ms/step
# 0.86652637
# 1/1 [==============================] - 0s 27ms/step
# 0.7951703
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.68354684
# 1/1 [==============================] - 0s 22ms/step
# 0.8612268
# 1/1 [==============================] - 0s 24ms/step
# 0.8479821
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.47872925
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 21ms/step
# 0.7857645
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.43971252
# 1/1 [==============================] - 0s 21ms/step
# 0.87078965
# 1/1 [==============================] - 0s 21ms/step
# 1.0
# 1/1 [==============================] - 0s 20ms/step
# 0.873523
# 1/1 [==============================] - 0s 23ms/step
# 0.8730567
# 1/1 [==============================] - 0s 21ms/step
# 0.87990224
# 1/1 [==============================] - 0s 23ms/step
# 0.8747426
# 1/1 [==============================] - 0s 23ms/step
# 0.8729411
# 1/1 [==============================] - 0s 23ms/step
# 0.47935486
# 1/1 [==============================] - 0s 24ms/step
# 0.49037933
# number of total masks is:  477
# Mean IoU is:  [0.704947]
# standard deviation is  IoU    0.172504
# dtype: float32
