# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30-unet-corrected-5e-5-roiadjusted-kernelinitializer-relu-recurrentdropout02-filters16-batch8-savethebest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = 8
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),

            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=4,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
train_loader, val_loader = DataLoader("/gdrive/MyDrive/adjustedROI/final_output", squeeze=False).get_loaders()

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=8

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
num_val_images
# Out:
# 477

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu'))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv1 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv1=layers.TimeDistributed(layers.BatchNormalization())(conv1)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv1)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv3 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv3=layers.TimeDistributed(layers.BatchNormalization())(conv3)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv3)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv4 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv4=layers.TimeDistributed(layers.BatchNormalization())(conv4)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv4)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.Bidirectional(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True))(conv5)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
#expanding path
concat1 = layers.concatenate([up1, conv4])

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat1)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat2 = layers.concatenate([up2, conv3])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (concat2)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu' ) ) (x)

up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat3 = layers.concatenate([up3, conv2])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat3)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2)))(x)
concat4 = layers.concatenate([up4, conv1])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (concat4)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal', activation='relu') ) (x)

x=layers.Bidirectional(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False))(x)
x=tf.expand_dims(x,axis=1)
out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed_97 (TimeDistr  (None, 3, 256, 256,  160        ['input_4[0][0]']
#  ibuted)                         16)
#
#  time_distributed_98 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_97[0][0]']
#  ibuted)                         16)
#
#  time_distributed_99 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_98[0][0]']
#  ibuted)                         16)
#
#  time_distributed_100 (TimeDist  (None, 3, 256, 256,  64         ['time_distributed_99[0][0]']
#  ributed)                        16)
#
#  time_distributed_101 (TimeDist  (None, 3, 128, 128,  0          ['time_distributed_100[0][0]']
#  ributed)                        16)
#
#  time_distributed_102 (TimeDist  (None, 3, 128, 128,  4640       ['time_distributed_101[0][0]']
#  ributed)                        32)
#
#  time_distributed_103 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_102[0][0]']
#  ributed)                        32)
#
#  time_distributed_104 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_103[0][0]']
#  ributed)                        32)
#
#  time_distributed_105 (TimeDist  (None, 3, 128, 128,  128        ['time_distributed_104[0][0]']
#  ributed)                        32)
#
#  time_distributed_106 (TimeDist  (None, 3, 64, 64, 3  0          ['time_distributed_105[0][0]']
#  ributed)                       2)
#
#  time_distributed_107 (TimeDist  (None, 3, 64, 64, 6  18496      ['time_distributed_106[0][0]']
#  ributed)                       4)
#
#  time_distributed_108 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_107[0][0]']
#  ributed)                       4)
#
#  time_distributed_109 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_108[0][0]']
#  ributed)                       4)
#
#  time_distributed_110 (TimeDist  (None, 3, 64, 64, 6  256        ['time_distributed_109[0][0]']
#  ributed)                       4)
#
#  time_distributed_111 (TimeDist  (None, 3, 32, 32, 6  0          ['time_distributed_110[0][0]']
#  ributed)                       4)
#
#  time_distributed_112 (TimeDist  (None, 3, 32, 32, 1  73856      ['time_distributed_111[0][0]']
#  ributed)                       28)
#
#  time_distributed_113 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_112[0][0]']
#  ributed)                       28)
#
#  time_distributed_114 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_113[0][0]']
#  ributed)                       28)
#
#  time_distributed_115 (TimeDist  (None, 3, 32, 32, 1  512        ['time_distributed_114[0][0]']
#  ributed)                       28)
#
#  time_distributed_116 (TimeDist  (None, 3, 16, 16, 1  0          ['time_distributed_115[0][0]']
#  ributed)                       28)
#
#  time_distributed_117 (TimeDist  (None, 3, 16, 16, 2  295168     ['time_distributed_116[0][0]']
#  ributed)                       56)
#
#  time_distributed_118 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_117[0][0]']
#  ributed)                       56)
#
#  time_distributed_119 (TimeDist  (None, 3, 16, 16, 2  590080     ['time_distributed_118[0][0]']
#  ributed)                       56)
#
#  time_distributed_120 (TimeDist  (None, 3, 16, 16, 2  1024       ['time_distributed_119[0][0]']
#  ributed)                       56)
#
#  bidirectional_5 (Bidirectional  (None, 3, 16, 16, 5  9439232    ['time_distributed_120[0][0]']
#  )                              12)
#
#  time_distributed_121 (TimeDist  (None, 3, 32, 32, 1  589952     ['bidirectional_5[0][0]']
#  ributed)                       28)
#
#  concatenate_9 (Concatenate)    (None, 3, 32, 32, 2  0           ['time_distributed_121[0][0]',
#                                 56)                               'time_distributed_115[0][0]']
#
#  time_distributed_122 (TimeDist  (None, 3, 32, 32, 1  295040     ['concatenate_9[0][0]']
#  ributed)                       28)
#
#  time_distributed_123 (TimeDist  (None, 3, 32, 32, 1  147584     ['time_distributed_122[0][0]']
#  ributed)                       28)
#
#  time_distributed_124 (TimeDist  (None, 3, 64, 64, 6  73792      ['time_distributed_123[0][0]']
#  ributed)                       4)
#
#  concatenate_10 (Concatenate)   (None, 3, 64, 64, 1  0           ['time_distributed_124[0][0]',
#                                 28)                               'time_distributed_110[0][0]']
#
#  time_distributed_125 (TimeDist  (None, 3, 64, 64, 6  73792      ['concatenate_10[0][0]']
#  ributed)                       4)
#
#  time_distributed_126 (TimeDist  (None, 3, 64, 64, 6  36928      ['time_distributed_125[0][0]']
#  ributed)                       4)
#
#  time_distributed_127 (TimeDist  (None, 3, 128, 128,  18464      ['time_distributed_126[0][0]']
#  ributed)                        32)
#
#  concatenate_11 (Concatenate)   (None, 3, 128, 128,  0           ['time_distributed_127[0][0]',
#                                  64)                              'time_distributed_105[0][0]']
#
#  time_distributed_128 (TimeDist  (None, 3, 128, 128,  18464      ['concatenate_11[0][0]']
#  ributed)                        32)
#
#  time_distributed_129 (TimeDist  (None, 3, 128, 128,  9248       ['time_distributed_128[0][0]']
#  ributed)                        32)
#
#  time_distributed_130 (TimeDist  (None, 3, 256, 256,  4624       ['time_distributed_129[0][0]']
#  ributed)                        16)
#
#  concatenate_12 (Concatenate)   (None, 3, 256, 256,  0           ['time_distributed_130[0][0]',
#                                  32)                              'time_distributed_100[0][0]']
#
#  time_distributed_131 (TimeDist  (None, 3, 256, 256,  4624       ['concatenate_12[0][0]']
#  ributed)                        16)
#
#  time_distributed_132 (TimeDist  (None, 3, 256, 256,  2320       ['time_distributed_131[0][0]']
#  ributed)                        16)
#
#  bidirectional_6 (Bidirectional  (None, 256, 256, 32  36992      ['time_distributed_132[0][0]']
#  )                              )
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 1, 256, 256,  0           ['bidirectional_6[0][0]']
#                                  32)
#
#  conv2d_66 (Conv2D)             (None, 1, 256, 256,  33          ['tf.expand_dims_2[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 11,933,537
# Trainable params: 11,931,553
# Non-trainable params: 1,984
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=dice_coefficient_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 372/372 [==============================] - 382s 994ms/step - loss: 0.6382 - dice_coefficient: 0.3618 - binary_accuracy: 0.8368 - val_loss: 0.5392 - val_dice_coefficient: 0.4608 - val_binary_accuracy: 0.9680
# Epoch 2/30
# 372/372 [==============================] - 362s 972ms/step - loss: 0.4067 - dice_coefficient: 0.5933 - binary_accuracy: 0.9804 - val_loss: 0.3895 - val_dice_coefficient: 0.6105 - val_binary_accuracy: 0.9748
# Epoch 3/30
# 372/372 [==============================] - 361s 971ms/step - loss: 0.3705 - dice_coefficient: 0.6295 - binary_accuracy: 0.9828 - val_loss: 0.3268 - val_dice_coefficient: 0.6732 - val_binary_accuracy: 0.9784
# Epoch 4/30
# 372/372 [==============================] - 361s 970ms/step - loss: 0.3460 - dice_coefficient: 0.6540 - binary_accuracy: 0.9836 - val_loss: 0.3374 - val_dice_coefficient: 0.6626 - val_binary_accuracy: 0.9807
# Epoch 5/30
# 372/372 [==============================] - 360s 968ms/step - loss: 0.3173 - dice_coefficient: 0.6827 - binary_accuracy: 0.9841 - val_loss: 0.3160 - val_dice_coefficient: 0.6840 - val_binary_accuracy: 0.9796
# Epoch 6/30
# 372/372 [==============================] - 359s 965ms/step - loss: 0.2933 - dice_coefficient: 0.7067 - binary_accuracy: 0.9852 - val_loss: 0.3333 - val_dice_coefficient: 0.6667 - val_binary_accuracy: 0.9824
# Epoch 7/30
# 372/372 [==============================] - 359s 966ms/step - loss: 0.2905 - dice_coefficient: 0.7095 - binary_accuracy: 0.9858 - val_loss: 0.3434 - val_dice_coefficient: 0.6566 - val_binary_accuracy: 0.9790
# Epoch 8/30
# Epoch 22/30
# 372/372 [==============================] - 359s 966ms/step - loss: 0.2036 - dice_coefficient: 0.7964 - binary_accuracy: 0.9890 - val_loss: 0.2639 - val_dice_coefficient: 0.7361 - val_binary_accuracy: 0.9824
# Epoch 23/30
# 372/372 [==============================] - 359s 966ms/step - loss: 0.1892 - dice_coefficient: 0.8108 - binary_accuracy: 0.9894 - val_loss: 0.2991 - val_dice_coefficient: 0.7009 - val_binary_accuracy: 0.9830
# Epoch 24/30
# 372/372 [==============================] - 355s 956ms/step - loss: 0.2113 - dice_coefficient: 0.7887 - binary_accuracy: 0.9888 - val_loss: 0.2983 - val_dice_coefficient: 0.7017 - val_binary_accuracy: 0.9818
# Epoch 25/30
# 372/372 [==============================] - 354s 953ms/step - loss: 0.1920 - dice_coefficient: 0.8080 - binary_accuracy: 0.9896 - val_loss: 0.3819 - val_dice_coefficient: 0.6181 - val_binary_accuracy: 0.9770
# Epoch 26/30
# 372/372 [==============================] - 355s 955ms/step - loss: 0.1911 - dice_coefficient: 0.8089 - binary_accuracy: 0.9895 - val_loss: 0.3147 - val_dice_coefficient: 0.6853 - val_binary_accuracy: 0.9814
# Epoch 27/30
# 372/372 [==============================] - 358s 962ms/step - loss: 0.1888 - dice_coefficient: 0.8112 - binary_accuracy: 0.9901 - val_loss: 0.2771 - val_dice_coefficient: 0.7229 - val_binary_accuracy: 0.9834
# Epoch 28/30
# 372/372 [==============================] - 355s 955ms/step - loss: 0.1951 - dice_coefficient: 0.8049 - binary_accuracy: 0.9897 - val_loss: 0.3147 - val_dice_coefficient: 0.6853 - val_binary_accuracy: 0.9835
# Epoch 29/30
# 372/372 [==============================] - 355s 954ms/step - loss: 0.1900 - dice_coefficient: 0.8100 - binary_accuracy: 0.9899 - val_loss: 0.3454 - val_dice_coefficient: 0.6546 - val_binary_accuracy: 0.9792
# Epoch 30/30
# 372/372 [==============================] - 356s 958ms/step - loss: 0.1937 - dice_coefficient: 0.8063 - binary_accuracy: 0.9903 - val_loss: 0.3206 - val_dice_coefficient: 0.6794 - val_binary_accuracy: 0.9820

# %%
model.save('/gdrive/MyDrive/Sensor30-unet-corrected-5e-5-roiadjusted-kernelinitializer-relu-recurrentdropout02-filters16-batch8-savethebest.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30-unet-corrected-5e-5-roiadjusted-kernelinitializer-relu-recurrentdropout02-filters16-batch8-savethebest.h5", compile=False)

# %%
class GetLoader:
    def __init__(self, *, imgs, masks, timesteps, batch_size, squeeze=False):
        self.imgs = imgs
        self.masks = masks
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        for _ in range(self.batch_size):
            index = np.random.randint(0, len(self.imgs) - self.timesteps)
            xs.append(self.imgs[index : index + self.timesteps])
            ys.append(self.masks[index + self.timesteps])
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = self.augmentation(tf.concat((x, y), axis=-1))

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y


class DataLoader:
    def __init__(
        self,
        data_folder: str,
        *,
        timesteps: int = 3,
        batch_size=400,
        squeeze=False,
    ):
        self.batch_size = batch_size
        self.data_folder = data_folder
        self.timesteps = timesteps
        self.squeeze = squeeze
        train_img_file_names = [
            os.path.join(data_folder, "train_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]
        train_img_file_names = natsorted(train_img_file_names)
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.train_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.train_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

        val_img_file_names = [
            os.path.join(data_folder, "val_images", "images", fn)
            for fn in os.listdir(os.path.join(data_folder, "val_images", "images"))
        ]
        val_img_file_names = natsorted(val_img_file_names)
        val_mask_file_names = [
            fn.replace("images", "masks") for fn in val_img_file_names
        ]
        self.val_imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_img_file_names
                ]
            )
            / 255
        )
        self.val_masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in val_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)

    def get_loaders(self):
        return (
            GetLoader(
                imgs=self.train_imgs,
                masks=self.train_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
            GetLoader(
                imgs=self.val_imgs,
                masks=self.val_masks,
                timesteps=self.timesteps,
                batch_size=self.batch_size,
                squeeze=self.squeeze,
            ),
        )

# %%
data_folder = "/gdrive/MyDrive/adjustedROI/final_output"
train,val_loader = DataLoader(data_folder, batch_size=477).get_loaders()

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)

prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.uint8)
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.axis('off')
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,0], cmap='gray')


plt.subplot(232)
plt.title('Real Mask ')
plt.axis('off')
plt.imshow(ground_truth[0,:,:,0], cmap='gray')
plt.subplot(233)
plt.axis('off')
plt.title('Predicted mask')
plt.imshow(prediction, cmap='gray')

plt.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.8870435

# %%
 import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.49835968
# 1/1 [==============================] - 0s 29ms/step
# 0.59586596
# 1/1 [==============================] - 0s 28ms/step
# 0.49552155
# 1/1 [==============================] - 0s 28ms/step
# 0.856087
# 1/1 [==============================] - 0s 28ms/step
# 0.88686323
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.48950195
# 1/1 [==============================] - 0s 26ms/step
# 0.6476436
# 1/1 [==============================] - 0s 30ms/step
# 0.4994583
# 1/1 [==============================] - 0s 25ms/step
# 0.64761525
# 1/1 [==============================] - 0s 26ms/step
# 0.8759252
# 1/1 [==============================] - 0s 30ms/step
# 0.6476436
# 1/1 [==============================] - 0s 29ms/step
# 0.8243412
# 1/1 [==============================] - 0s 27ms/step
# 0.8243412
# 1/1 [==============================] - 0s 28ms/step
# 0.83344793
# 1/1 [==============================] - 0s 28ms/step
# 0.8634763
# 1/1 [==============================] - 0s 25ms/step
# 0.8861809
# 1/1 [==============================] - 0s 25ms/step
# 0.88105994
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.6990621
# 1/1 [==============================] - 0s 24ms/step
# 0.8663893
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.49990845
# 1/1 [==============================] - 0s 25ms/step
# 0.8504026
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.6134735
# 1/1 [==============================] - 0s 29ms/step
# 0.4992218
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.82320726
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 0.6476436
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.8298284
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.8825535
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.50784534
# 1/1 [==============================] - 0s 25ms/step
# 0.854143
# 1/1 [==============================] - 0s 33ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.83946764
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.82357156
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.4753189
# 1/1 [==============================] - 0s 25ms/step
# 0.76073205
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.86886144
# 1/1 [==============================] - 0s 25ms/step
# 0.8455085
# 1/1 [==============================] - 0s 34ms/step
# 0.52665424
# 1/1 [==============================] - 0s 26ms/step
# 0.7808887
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 28ms/step
# 0.4744873
# 1/1 [==============================] - 0s 25ms/step
# 0.48363495
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 29ms/step
# 0.49973297
# 1/1 [==============================] - 0s 28ms/step
# 0.82283944
# 1/1 [==============================] - 0s 30ms/step
# 0.8195117
# 1/1 [==============================] - 0s 28ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1.0
# 1/1 [==============================] - 0s 31ms/step
# 0.