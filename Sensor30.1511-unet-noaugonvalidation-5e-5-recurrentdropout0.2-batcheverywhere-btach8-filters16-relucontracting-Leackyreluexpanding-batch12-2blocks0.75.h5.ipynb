# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiaradisanto/Segmentation/blob/main/Sensor30.1511-unet-noaugonvalidation-5e-5-recurrentdropout0.2-batcheverywhere-btach8-filters16-relucontracting-Leackyreluexpanding-batch12-2blocks0.75.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np

# %%
import os
from IPython.core.completer import time
from natsort import natsorted
from tensorflow.keras.preprocessing.image import (
    array_to_img,
    img_to_array,
    load_img,
)
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np


class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 8,
        squeeze=False,
        augmentation=True,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        self.imgs = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_img_file_names
                ]
            )
            / 255
        )
        self.masks = (
            np.array(
                [
                    img_to_array(load_img(fn, color_mode="grayscale"))
                    for fn in train_mask_file_names
                ]
            )
            / 255
            > 0.5
        ).astype(float)
        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.9),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
        x, y = np.array(xs), np.array(ys)
      #  print(x.shape)
      #  print(y.shape)

        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        # if not tf.reduce_all(y[0] == 0):
        #    ipdb.set_trace()
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/TESI/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=8,
    squeeze=False,
    augmentation=False,
)

train_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/TESI/adjustedROI/final_output", "train_images", "images"
    ),
    batch_size=8,
    squeeze=False,
    augmentation=True
)

# %%
x, y = train_loader.__next__()

# %%
from matplotlib import pyplot as plt

# %%
x, y = train_loader.__next__()

for i in range(0,8):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
x.shape
# Out:
# TensorShape([8, 3, 256, 256, 1])

# %%
y.shape
# Out:
# TensorShape([8, 1, 256, 256, 1])

# %%
x, y = val_loader.__next__()

for i in range(0,3):
    image = x[i,0,:,:,0]
    #mask = np.argmax(y[i], axis=2)
    mask= y[i,0,:,:,0]
    plt.subplot(1,2,1)
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.show()

# %%
batch_size=8

# %%
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/gdrive/MyDrive/TESI/adjustedROI/final_output/train_images/images'))
num_val_images = len(os.listdir('/gdrive/MyDrive/TESI/adjustedROI/final_output/val_images/images'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size

# %%
print(num_val_images)
# Out:
# 477

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, TimeDistributed,Dropout,Input, Dense,\
    BatchNormalization, GRU, Layer, Flatten,MaxPooling2D, concatenate,Lambda
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from keras import layers
from keras import models
from tensorflow.python.keras.layers import ConvLSTM2D

# %%
input_shape=(3,256,256,1)

# %%
input_l = layers.Input(shape=(input_shape))
x =  (layers.TimeDistributed(layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal', activation='relu' ))) (input_l)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv2 = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv2=layers.TimeDistributed(layers.BatchNormalization())(conv2)
x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv2)

x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv5 = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv5=layers.TimeDistributed(layers.BatchNormalization())(conv5)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv5)

x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
conv8 = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv8=layers.TimeDistributed(layers.BatchNormalization())(conv8)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv8)

x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv9 = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv9=layers.TimeDistributed(layers.BatchNormalization())(conv9)

x=layers.TimeDistributed(layers.MaxPooling2D(pool_size=(2,2)))(conv9)

x = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

conv10 = layers.TimeDistributed( layers.Conv2D( 256, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
conv10=layers.TimeDistributed(layers.BatchNormalization())(conv10)

x=(layers.ConvLSTM2D(256,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=True,recurrent_dropout=0.2))(conv10)
up1 = layers.TimeDistributed( layers.Conv2DTranspose(128,kernel_size=(3,3),padding='same',strides=(2,2),kernel_initializer='he_normal',activation='relu'))(x)
#expanding path
concat1 = layers.concatenate([up1, conv9])
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat1)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 128, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up2 = layers.TimeDistributed( layers.Conv2DTranspose( 64,kernel_size=(3,3),padding='same',strides=(2,2),kernel_initializer='he_normal',activation='relu'))(x)
concat2 = layers.concatenate([up2, conv8])
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ,kernel_initializer='he_normal',activation='relu') ) (concat2)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 64, kernel_size=(3, 3),padding='same',strides=(1,1) ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)

up3 = layers.TimeDistributed( layers.Conv2DTranspose( 32,kernel_size=(3,3),padding='same',strides=(2,2),kernel_initializer='he_normal',activation='relu'))(x)
concat3 = layers.concatenate([up3, conv5])
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (concat3)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 32, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal',activation='relu' ) ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
up4= layers.TimeDistributed( layers.Conv2DTranspose( 16,kernel_size=(3,3),padding='same',strides=(2,2),kernel_initializer='he_normal',activation='relu'))(x)
concat4 = layers.concatenate([up4, conv2])
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1), kernel_initializer='he_normal',activation='relu') ) (concat4)
x=layers.TimeDistributed(layers.Dropout(0.1))(x)
x = layers.TimeDistributed( layers.Conv2D( 16, kernel_size=(3, 3),padding='same',strides=(1,1),kernel_initializer='he_normal' ,activation='relu') ) (x)
x=layers.TimeDistributed(layers.BatchNormalization())(x)
x=(layers.ConvLSTM2D(16,kernel_size=(3,3),padding='same',strides=(1,1),return_sequences=False,recurrent_dropout=0.2))(x)
x=tf.expand_dims(x,axis=1)

out = layers.Conv2D( 1, kernel_size=(1, 1),padding='same',strides=(1,1), activation='sigmoid' )  (x)


model = models.Model(inputs=input_l, outputs=out)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 256, 256  0           []
#                                 , 1)]
#
#  time_distributed (TimeDistribu  (None, 3, 256, 256,  160        ['input_1[0][0]']
#  ted)                            16)
#
#  time_distributed_1 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed[0][0]']
#  buted)                          16)
#
#  time_distributed_2 (TimeDistri  (None, 3, 256, 256,  2320       ['time_distributed_1[0][0]']
#  buted)                          16)
#
#  time_distributed_3 (TimeDistri  (None, 3, 256, 256,  64         ['time_distributed_2[0][0]']
#  buted)                          16)
#
#  time_distributed_4 (TimeDistri  (None, 3, 128, 128,  0          ['time_distributed_3[0][0]']
#  buted)                          16)
#
#  time_distributed_5 (TimeDistri  (None, 3, 128, 128,  4640       ['time_distributed_4[0][0]']
#  buted)                          32)
#
#  time_distributed_6 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_5[0][0]']
#  buted)                          32)
#
#  time_distributed_7 (TimeDistri  (None, 3, 128, 128,  9248       ['time_distributed_6[0][0]']
#  buted)                          32)
#
#  time_distributed_8 (TimeDistri  (None, 3, 128, 128,  128        ['time_distributed_7[0][0]']
#  buted)                          32)
#
#  time_distributed_9 (TimeDistri  (None, 3, 64, 64, 3  0          ['time_distributed_8[0][0]']
#  buted)                         2)
#
#  time_distributed_10 (TimeDistr  (None, 3, 64, 64, 6  18496      ['time_distributed_9[0][0]']
#  ibuted)                        4)
#
#  time_distributed_11 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_10[0][0]']
#  ibuted)                        4)
#
#  time_distributed_12 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_11[0][0]']
#  ibuted)                        4)
#
#  time_distributed_13 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_12[0][0]']
#  ibuted)                        4)
#
#  time_distributed_14 (TimeDistr  (None, 3, 32, 32, 6  0          ['time_distributed_13[0][0]']
#  ibuted)                        4)
#
#  time_distributed_15 (TimeDistr  (None, 3, 32, 32, 1  73856      ['time_distributed_14[0][0]']
#  ibuted)                        28)
#
#  time_distributed_16 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_15[0][0]']
#  ibuted)                        28)
#
#  time_distributed_17 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_16[0][0]']
#  ibuted)                        28)
#
#  time_distributed_18 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_17[0][0]']
#  ibuted)                        28)
#
#  time_distributed_19 (TimeDistr  (None, 3, 16, 16, 1  0          ['time_distributed_18[0][0]']
#  ibuted)                        28)
#
#  time_distributed_20 (TimeDistr  (None, 3, 16, 16, 2  295168     ['time_distributed_19[0][0]']
#  ibuted)                        56)
#
#  time_distributed_21 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_20[0][0]']
#  ibuted)                        56)
#
#  time_distributed_22 (TimeDistr  (None, 3, 16, 16, 2  590080     ['time_distributed_21[0][0]']
#  ibuted)                        56)
#
#  time_distributed_23 (TimeDistr  (None, 3, 16, 16, 2  1024       ['time_distributed_22[0][0]']
#  ibuted)                        56)
#
#  conv_lstm2d (ConvLSTM2D)       (None, 3, 16, 16, 2  4719616     ['time_distributed_23[0][0]']
#                                 56)
#
#  time_distributed_24 (TimeDistr  (None, 3, 32, 32, 1  295040     ['conv_lstm2d[0][0]']
#  ibuted)                        28)
#
#  concatenate (Concatenate)      (None, 3, 32, 32, 2  0           ['time_distributed_24[0][0]',
#                                 56)                               'time_distributed_18[0][0]']
#
#  time_distributed_25 (TimeDistr  (None, 3, 32, 32, 1  295040     ['concatenate[0][0]']
#  ibuted)                        28)
#
#  time_distributed_26 (TimeDistr  (None, 3, 32, 32, 1  0          ['time_distributed_25[0][0]']
#  ibuted)                        28)
#
#  time_distributed_27 (TimeDistr  (None, 3, 32, 32, 1  147584     ['time_distributed_26[0][0]']
#  ibuted)                        28)
#
#  time_distributed_28 (TimeDistr  (None, 3, 32, 32, 1  512        ['time_distributed_27[0][0]']
#  ibuted)                        28)
#
#  time_distributed_29 (TimeDistr  (None, 3, 64, 64, 6  73792      ['time_distributed_28[0][0]']
#  ibuted)                        4)
#
#  concatenate_1 (Concatenate)    (None, 3, 64, 64, 1  0           ['time_distributed_29[0][0]',
#                                 28)                               'time_distributed_13[0][0]']
#
#  time_distributed_30 (TimeDistr  (None, 3, 64, 64, 6  73792      ['concatenate_1[0][0]']
#  ibuted)                        4)
#
#  time_distributed_31 (TimeDistr  (None, 3, 64, 64, 6  0          ['time_distributed_30[0][0]']
#  ibuted)                        4)
#
#  time_distributed_32 (TimeDistr  (None, 3, 64, 64, 6  36928      ['time_distributed_31[0][0]']
#  ibuted)                        4)
#
#  time_distributed_33 (TimeDistr  (None, 3, 64, 64, 6  256        ['time_distributed_32[0][0]']
#  ibuted)                        4)
#
#  time_distributed_34 (TimeDistr  (None, 3, 128, 128,  18464      ['time_distributed_33[0][0]']
#  ibuted)                         32)
#
#  concatenate_2 (Concatenate)    (None, 3, 128, 128,  0           ['time_distributed_34[0][0]',
#                                  64)                              'time_distributed_8[0][0]']
#
#  time_distributed_35 (TimeDistr  (None, 3, 128, 128,  18464      ['concatenate_2[0][0]']
#  ibuted)                         32)
#
#  time_distributed_36 (TimeDistr  (None, 3, 128, 128,  0          ['time_distributed_35[0][0]']
#  ibuted)                         32)
#
#  time_distributed_37 (TimeDistr  (None, 3, 128, 128,  9248       ['time_distributed_36[0][0]']
#  ibuted)                         32)
#
#  time_distributed_38 (TimeDistr  (None, 3, 128, 128,  128        ['time_distributed_37[0][0]']
#  ibuted)                         32)
#
#  time_distributed_39 (TimeDistr  (None, 3, 256, 256,  4624       ['time_distributed_38[0][0]']
#  ibuted)                         16)
#
#  concatenate_3 (Concatenate)    (None, 3, 256, 256,  0           ['time_distributed_39[0][0]',
#                                  32)                              'time_distributed_3[0][0]']
#
#  time_distributed_40 (TimeDistr  (None, 3, 256, 256,  4624       ['concatenate_3[0][0]']
#  ibuted)                         16)
#
#  time_distributed_41 (TimeDistr  (None, 3, 256, 256,  0          ['time_distributed_40[0][0]']
#  ibuted)                         16)
#
#  time_distributed_42 (TimeDistr  (None, 3, 256, 256,  2320       ['time_distributed_41[0][0]']
#  ibuted)                         16)
#
#  time_distributed_43 (TimeDistr  (None, 3, 256, 256,  64         ['time_distributed_42[0][0]']
#  ibuted)                         16)
#
#  conv_lstm2d_1 (ConvLSTM2D)     (None, 256, 256, 16  18496       ['time_distributed_43[0][0]']
#                                 )
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 256, 256,  0           ['conv_lstm2d_1[0][0]']
#                                  16)
#
#  conv2d_18 (Conv2D)             (None, 1, 256, 256,  17          ['tf.expand_dims[0][0]']
#                                  1)
#
# ==================================================================================================
# Total params: 6,901,457
# Trainable params: 6,898,993
# Non-trainable params: 2,464
# __________________________________________________________________________________________________

# %%
from keras import backend as K


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
from keras import backend as K
smooth = 1


def dice_coefficient(y_true, y_pred, smooth=0.0001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return ((2. * intersection + smooth) / (K.sum(y_true_f) +
            K.sum(y_pred_f) + smooth))


def dice_coefficient_loss(y_true, y_pred):
    return 1.0-dice_coefficient(y_true, y_pred)


def iou_loss(y_true, y_pred):
    return 1-iou(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(K.abs(y_true * y_pred))
    sum_ = K.sum(K.square(y_true)) + K.sum(K.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac
def tversky(y_true, y_pred):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos)*y_pred_pos)
    alpha = 0.7
    return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true,y_pred)

def focal_tversky(y_true,y_pred):
    pt_1 = tversky(y_true, y_pred)
    gamma = 0.60
    return K.pow((1-pt_1), gamma)

# %%
LR = 5e-5
optim = tf.keras.optimizers.Adam(LR)

# %%
metrics=[dice_coefficient, 'binary_accuracy']

# %%
model.compile(optimizer=optim, loss=tversky_loss, metrics=metrics)

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='/gdrive/MyDrive/chk/',
    save_weights_only=True,
    monitor='val_dice_coefficient',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(train_loader,
          steps_per_epoch=steps_per_epoch,
          epochs=30,
          verbose=1,
          validation_data=val_loader,
          callbacks=model_checkpoint_callback,

    
          validation_steps=val_steps_per_epoch)
# Out:
# Epoch 1/30
# 372/372 [==============================] - 295s 742ms/step - loss: 0.8022 - dice_coefficient: 0.1365 - binary_accuracy: 0.8276 - val_loss: 0.7388 - val_dice_coefficient: 0.1788 - val_binary_accuracy: 0.8019
# Epoch 2/30
# 372/372 [==============================] - 272s 731ms/step - loss: 0.5102 - dice_coefficient: 0.3970 - binary_accuracy: 0.9696 - val_loss: 0.4093 - val_dice_coefficient: 0.4980 - val_binary_accuracy: 0.9647
# Epoch 3/30
# 372/372 [==============================] - 271s 730ms/step - loss: 0.3788 - dice_coefficient: 0.5483 - binary_accuracy: 0.9767 - val_loss: 0.4821 - val_dice_coefficient: 0.5227 - val_binary_accuracy: 0.9830
# Epoch 4/30
# 372/372 [==============================] - 271s 728ms/step - loss: 0.3410 - dice_coefficient: 0.5930 - binary_accuracy: 0.9796 - val_loss: 0.3739 - val_dice_coefficient: 0.5862 - val_binary_accuracy: 0.9784
# Epoch 5/30
# 372/372 [==============================] - 271s 728ms/step - loss: 0.3144 - dice_coefficient: 0.6215 - binary_accuracy: 0.9811 - val_loss: 0.3835 - val_dice_coefficient: 0.6300 - val_binary_accuracy: 0.9848
# Epoch 6/30
# 372/372 [==============================] - 271s 728ms/step - loss: 0.2955 - dice_coefficient: 0.6449 - binary_accuracy: 0.9827 - val_loss: 0.3681 - val_dice_coefficient: 0.6431 - val_binary_accuracy: 0.9851
# Epoch 7/30
# 372/372 [==============================] - 271s 728ms/step - loss: 0.2738 - dice_coefficient: 0.6711 - binary_accuracy: 0.9830 - val_loss: 0.3304 - val_dice_coefficient: 0.6519 - val_binary_accuracy: 0.9820
# Epoch 8/30
# 372/372 [==============================] - 270s 725ms/step - loss: 0.2621 - dice_coefficient: 0.6834 - binary_accuracy: 0.9844 - val_loss: 0.4368 - val_dice_coefficient: 0.5837 - val_binary_accuracy: 0.9841
# Epoch 9/30
# 372/372 [==============================] - 270s 727ms/step - loss: 0.2643 - dice_coefficient: 0.6852 - binary_accuracy: 0.9847 - val_loss: 0.3081 - val_dice_coefficient: 0.6744 - val_binary_accuracy: 0.9830
# Epoch 10/30
# 372/372 [==============================] - 270s 727ms/step - loss: 0.2409 - dice_coefficient: 0.7118 - binary_accuracy: 0.9853 - val_loss: 0.3050 - val_dice_coefficient: 0.6833 - val_binary_accuracy: 0.9862
# Epoch 11/30
# 372/372 [==============================] - 270s 726ms/step - loss: 0.2404 - dice_coefficient: 0.7131 - binary_accuracy: 0.9857 - val_loss: 0.3453 - val_dice_coefficient: 0.6487 - val_binary_accuracy: 0.9831
# Epoch 12/30
# 372/372 [==============================] - 272s 730ms/step - loss: 0.1876 - dice_coefficient: 0.7726 - binary_accuracy: 0.9877 - val_loss: 0.2858 - val_dice_coefficient: 0.7258 - val_binary_accuracy: 0.9868
# Epoch 26/30
# 372/372 [==============================] - 272s 731ms/step - loss: 0.1627 - dice_coefficient: 0.8028 - binary_accuracy: 0.9881 - val_loss: 0.2903 - val_dice_coefficient: 0.6837 - val_binary_accuracy: 0.9833
# Epoch 27/30
# 372/372 [==============================] - 271s 730ms/step - loss: 0.1564 - dice_coefficient: 0.8086 - binary_accuracy: 0.9888 - val_loss: 0.3468 - val_dice_coefficient: 0.6623 - val_binary_accuracy: 0.9844
# Epoch 28/30
# 372/372 [==============================] - 272s 731ms/step - loss: 0.1645 - dice_coefficient: 0.8022 - binary_accuracy: 0.9884 - val_loss: 0.3616 - val_dice_coefficient: 0.6335 - val_binary_accuracy: 0.9821
# Epoch 29/30
# 372/372 [==============================] - 272s 731ms/step - loss: 0.1650 - dice_coefficient: 0.8009 - binary_accuracy: 0.9886 - val_loss: 0.2969 - val_dice_coefficient: 0.6879 - val_binary_accuracy: 0.9826
# Epoch 30/30
# 372/372 [==============================] - 272s 730ms/step - loss: 0.1599 - dice_coefficient: 0.8065 - binary_accuracy: 0.9889 - val_loss: 0.2965 - val_dice_coefficient: 0.7083 - val_binary_accuracy: 0.9865

# %%
model.save('/gdrive/MyDrive/Sensor30.1511-unet-noaugonvalidation-5e-5-recurrentdropout0.2-batcheverywhere-btach8-filters16-relucontracting-Leackyreluexpanding-batch12-2blocks0.75.h5')

# %%
#Load previously saved model
from keras.models import load_model
model = load_model("/gdrive/MyDrive/Sensor30.1511-unet-noaugonvalidation-5e-5-recurrentdropout0.2-batcheverywhere-btach8-filters16-relucontracting-Leackyreluexpanding-batch12-2blocks0.75.h5", compile=False)

# %%
class DataLoader:
    def __init__(
        self,
        *,
        data_path,
        timesteps: int = 3,
        batch_size: int = 477,
        squeeze=False,
        augmentation=False,
        shuffle=True,
        sort_method="natsort"  # oppure "number"
    ):
        self.shuffle = shuffle
        self.do_augmentation = augmentation
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.squeeze = squeeze
        self.data_path = data_path
        train_img_file_names = [
            os.path.join(data_path, fn)
            for fn in os.listdir(
                data_path
            )  # os.listdir(os.path.join(data_folder, "train_images", "images"))
        ]

        def sort_by_number(file_names: list):
            return sorted(file_names, key=lambda x: int(x.split("/")[-1].split(".")[0]))

        train_img_file_names = (
            natsorted(train_img_file_names)
            if sort_method == "natsort"
            else sort_by_number(train_img_file_names)
        )
        self.filenames = train_img_file_names
        # train_img_file_names.sort(key=lambda x: int(x.split("_")[-1].split(".")[0]))
        train_mask_file_names = [
            fn.replace("images", "masks") for fn in train_img_file_names
        ]
        if not os.path.exists("imgs.pickle"):
            self.imgs = (
                np.array(
                    [
                        img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_img_file_names
                    ]
                )
                / 255
            )
            self.masks = (
                np.array(
                    [
                      img_to_array(load_img(fn, color_mode="grayscale"))
                        for fn in train_mask_file_names
                    ]
                )
                / 255
                > 0.5
            ).astype(float)

        self.augmentation = tf.keras.Sequential(
            [
                layers.RandomFlip("horizontal_and_vertical"),
                layers.RandomRotation(0.2),
            ]
        )
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        xs = []
        ys = []
        if self.shuffle:
            for _ in range(self.batch_size):
                index = np.random.randint(0, len(self.imgs) - self.timesteps)
                xs.append(self.imgs[index : index + self.timesteps])
                ys.append(self.masks[index + self.timesteps])
        else:
            # i = np.random.randint(0, len(self.imgs) - self.timesteps - self.batch_size)
            xs = [
                self.imgs[i * self.timesteps : (i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            ys = [
                self.masks[(i + 1) * self.timesteps]
                for i in range(self.index, self.batch_size // self.timesteps)
            ]
            self.index += self.batch_size // self.timesteps
            if self.index >= len(self.imgs) - self.timesteps - self.batch_size:
                self.index = 0
                raise StopIteration
        x, y = np.array(xs), np.array(ys)
        x = x.squeeze(-1).transpose(0, 2, 3, 1)
        xy = tf.concat((x, y), axis=-1)
        if self.do_augmentation:
            xy = self.augmentation(xy)

        x = xy[:, :, :, :3]
        y = xy[:, :, :, 3:]
        if not self.squeeze:
            x = tf.transpose(x, perm=(0, 3, 1, 2))[..., None]
            y = tf.expand_dims(y, 1)
        return x, y

# %%
val_loader = DataLoader(
    data_path=os.path.join(
        "/gdrive/MyDrive/TESI/adjustedROI/final_output",
        "val_images", "images"
    ),
    batch_size=477,
    squeeze=False,
    augmentation=False,

    
)

# %%
a, b = val_loader.__next__()

# %%
import random
test_img_number = random.randint(0, a.shape[0]-1)
test_img = a[test_img_number]
ground_truth=b[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
ground_truth.shape
# Out:
# TensorShape([1, 256, 256, 1])

# %%
  test_img_number = random.randint(0, a.shape[0]-1)
  test_img = a[test_img_number]
  ground_truth=b[test_img_number]
  #test_img_norm=test_img[:,:,0][:,:,None]
  test_img_input=np.expand_dims(test_img, 0)

  prediction = (model.predict(test_img_input)[0,0,:,:,0] > 0.5).astype(np.float32)
  plt.figure(figsize=(16, 8))
  plt.subplot(231)
  plt.axis('off')
  plt.title('Testing Image')
  plt.imshow(test_img[0,:,:,0], cmap='gray')


  plt.subplot(232)
  plt.title('Real Mask ')
  plt.axis('off')
  plt.imshow(ground_truth[0,:,:,0], cmap='gray')
  plt.subplot(233)
  plt.axis('off')
  plt.title('Predicted mask')
  
  plt.imshow(prediction, cmap='gray')

  plt.show()
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[0,:,:,0], prediction)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# Mean IoU = 0.49851227

# %%
import pandas as pd

IoU_values = []
for img in range(0, a.shape[0]):
    temp_img = a[img]
    ground_truth=b[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,0,:,:,0]> 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[0,:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    print(IoU)
    


df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0
ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.8272356
# 1/1 [==============================] - 0s 25ms/step
# 0.9004053
# 1/1 [==============================] - 0s 23ms/step
# 0.7276632
# 1/1 [==============================] - 0s 24ms/step
# 0.7766397
# 1/1 [==============================] - 0s 22ms/step
# 0.88333106
# 1/1 [==============================] - 0s 28ms/step
# 0.48764038
# 1/1 [==============================] - 0s 22ms/step
# 0.48838806
# 1/1 [==============================] - 0s 24ms/step
# 0.7752958
# 1/1 [==============================] - 0s 30ms/step
# 0.76293266
# 1/1 [==============================] - 0s 25ms/step
# 0.80313903
# 1/1 [==============================] - 0s 25ms/step
# 0.6770031
# 1/1 [==============================] - 0s 26ms/step
# 0.48784637
# 1/1 [==============================] - 0s 24ms/step
# 0.743627
# 1/1 [==============================] - 0s 26ms/step
# 0.90131485
# 1/1 [==============================] - 0s 22ms/step
# 0.49417114
# 1/1 [==============================] - 0s 26ms/step
# 0.8985504
# 1/1 [==============================] - 0s 31ms/step
# 0.49848175
# 1/1 [==============================] - 0s 22ms/step
# 0.8894501
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.7300404
# 1/1 [==============================] - 0s 23ms/step
# 0.915748
# 1/1 [==============================] - 0s 23ms/step
# 0.48264313
# 1/1 [==============================] - 0s 30ms/step
# 0.7877803
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 0.69745994
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.915748
# 1/1 [==============================] - 0s 25ms/step
# 0.48220062
# 1/1 [==============================] - 0s 22ms/step
# 0.74491286
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 26ms/step
# 0.8691503
# 1/1 [==============================] - 0s 29ms/step
# 0.5755187
# 1/1 [==============================] - 0s 22ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.6325231
# 1/1 [==============================] - 0s 31ms/step
# 0.4998703
# 1/1 [==============================] - 0s 25ms/step
# 0.7606678
# 1/1 [==============================] - 0s 23ms/step
# 0.89454824
# 1/1 [==============================] - 0s 26ms/step
# 0.48181915
# 1/1 [==============================] - 0s 29ms/step
# 0.4815445
# 1/1 [==============================] - 0s 24ms/step
# 0.49934387
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 30ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 0.8797273
# 1/1 [==============================] - 0s 23ms/step
# 0.917523
# 1/1 [==============================] - 0s 26ms/step
# 0.48242188
# 1/1 [==============================] - 0s 24ms/step
# 0.4911728
# 1/1 [==============================] - 0s 29ms/step
# 0.8756008
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 0.89953804
# 1/1 [==============================] - 0s 24ms/step
# 0.4909134
# 1/1 [==============================] - 0s 25ms/step
# 0.9009825
# 1/1 [==============================] - 0s 26ms/step
# 0.4913559
# 1/1 [==============================] - 0s 26ms/step
# 1.0
# 1/1 [==============================] - 0s 24ms/step
# 0.49012756
# 1/1 [==============================] - 0s 27ms/step
# 0.88333106
# 1/1 [==============================] - 0s 24ms/step
# 0.7300404
# 1/1 [==============================] - 0s 28ms/step
# 0.7231185
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 22ms/step
# 0.487648
# 1/1 [==============================] - 0s 22ms/step
# 0.4887619
# 1/1 [==============================] - 0s 23ms/step
# 0.4766693
# 1/1 [==============================] - 0s 40ms/step
# 1.0
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1.0
# 1/1 [==============================] - 0s 32ms/step
# 0.8965145
# 1/1 [==============================] - 0s 22ms/step
# 0.89074934
# 1/1 [==============================] - 0s 23ms/step
# 0.49620056
# 1/1 [==============================] - 0s 25ms/step
# 1.0
# Mean IoU is:  [0.69263464]
